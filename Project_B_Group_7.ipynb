# %% [markdown]
# #### CIE-Project B || Group - 7

# %% [markdown]
# #### Imports

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
from scipy.signal import resample, find_peaks
from scipy.io import loadmat
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pickle
import time

# from sklearn import preprocessing ##importing for normalization
# from sklearn.decomposition import PCA
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import MinMaxScaler, minmax_scale, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error
from sklearn.multioutput import MultiOutputRegressor
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D, AveragePooling1D, GlobalAveragePooling1D
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['legend.frameon'] = True
# plt.rcParams['figure.figsize'] = (8, 8)
#%matplotlib widget

tf.random.set_seed(1)
np.random.seed(2)

# %% [markdown]
# ##### Get the root directory and change to it

# %%
rootdir = os.getcwd()
os.chdir(rootdir)

# %% [markdown]
# #### Folder Variables Assignment

# %%
# Names of the folders
Training_Folder = 'EPOT_DATA'
Validation_Aug_Folder = 'Validation_augmented_data'
Experiment = 'Experiment_Data_Group7'
Ex_Validation = 'Experimental_validation'

counter = 0

# %% [markdown]
# ### Parsing

# %% [markdown]
# ##### Parse training and validation-augmented data

# %%
# Initialize lists for training and validation
training_tr = []; training_tr_labels = []

validation_aug = []; validation_aug_labels = [] # validation augmented data

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Training_Folder.lower() in subdir.lower():
        for file in files:
            if file.endswith('.mat'):
                lbl = [file.split('_')[1], file.split('_')[2][:3]]
                lb = np.asarray(lbl, dtype=float)
                # load mat-file
                mat = loadmat(os.path.join(subdir, file))
                # get the numpy data from the mat file
                mat = mat['num_data']
                # append data to the list
                training_tr.append(mat)
                training_tr_labels.append(lb)

    elif Validation_Aug_Folder.lower() in subdir.lower():
        for file in files:
            if file.endswith('.mat'):
                lbl = [file.split('_')[1], file.split('_')[2][:3]]
                lb = np.asarray(lbl, dtype=float)
                # load mat-file
                mat = loadmat(os.path.join(subdir, file))
                # get the numpy data from the mat file
                mat = mat['num_data']
                # append data to the list
                validation_aug.append(mat)
                validation_aug_labels.append(lb)

# %%
plt.close()
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

l = 6

fig.suptitle(f'EPOT Training Data - {training_tr_labels[l]}')

axs[0,0].plot(training_tr[l][:,0], training_tr[l][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training_tr[l][:,0], training_tr[l][:,2], label='P - 2', c = 'g')
axs[1,0].plot(training_tr[l][:,0], training_tr[l][:,3], label='P - 3', c = 'b')
axs[1,1].plot(training_tr[l][:,0], training_tr[l][:,4], label='P - 4', c = 'y')

fig.legend()
plt.show()

# %% [markdown]
# ##### Parse, Cut, Normalize, and Resample the experimental data

# %%
# Initialize lists for training and validation
ex_data = []; ex_labels = []

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Experiment.lower() in subdir.lower():
        for file in files:
            if file.endswith('.txt'):
                
                with open(os.path.join(subdir, file), 'r') as f:
                    x = pd.read_csv(os.path.join(subdir, file), delimiter='\t', decimal=',', skiprows=8, header=None)
                    x = np.asarray(x, dtype=float)
                    ex_data.append(x)

# %%
plt.close()
l = 5
plt.plot(ex_data[l][:,0], ex_data[l][:,1], label='P - 1', c = 'r')
plt.show()

# %%
ex_cut_data = []
for i in range(len(ex_data)):
    
    threshold = 0.1

    x = np.where(abs(ex_data[i][:,1])>threshold)[0][0]
    y = np.where(abs(ex_data[i][:,2])>threshold)[0][0]
    z = np.where(abs(ex_data[i][:,3])>threshold)[0][0]
    p = np.where(abs(ex_data[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)
    end = start+200

    d = np.empty_like(ex_data[i][start:end,:])

    d[:,0] = ex_data[i][start:end, 0]
    d[:,1] = (-1)*ex_data[i][start:end, 1]
    d[:,2] = (-1)*ex_data[i][start:end, 2]
    d[:,3] = (-1)*ex_data[i][start:end, 4]
    d[:,4] = (-1)*ex_data[i][start:end, 3]

    ex_cut_data.append(d)

# %%
plt.close()
l = 5
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,1], label='P - 1')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,2], label='P - 2')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,3], label='P - 3')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,4], label='P - 4')
plt.show()

# %% [markdown]
# Normalize and Resample experimental data

# %%
# create variables for normalized data
ex_norm = np.zeros_like(np.asarray(ex_cut_data))

for i in range (0, len(ex_cut_data)):
    for j in range (1, 5):
        ex_norm[i][:,j] = minmax_scale(ex_cut_data[i][:,j])

# %%
ex_resample = []

# create a dataframe from the normalized data
for i in range (0, len(ex_norm)):
    ex_resample.append(pd.DataFrame(ex_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    ex_resample[i] = ex_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(ex_resample)):
    ex_resample[i] = resample(ex_resample[i], size)

np.asarray(ex_resample).shape
# Out:
# (18, 100, 4)

# %% [markdown]
# ##### Parse, Cut, Normalize, and Resample the experimental validation data

# %%
# Initialize lists for training and validation
ex_val_data = []; ex_val_labels = []

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Ex_Validation.lower() in subdir.lower():
        for file in files:
            if file.endswith('.txt'):
                
                with open(os.path.join(subdir, file), 'r') as f:
                    # print(file.split('_')[2], file.split('_')[3], file.split('_')[5][:3])
                    lbl = [file.split('_')[2], file.split('_')[3], file.split('_')[5][:3]]
                    lb = np.asarray(lbl, dtype=float)

                    x = pd.read_csv(os.path.join(subdir, file), delimiter='\t', decimal=',', skiprows=8, header=None)
                    x = np.asarray(x, dtype=float)
                    ex_val_data.append(x)
                    ex_val_labels.append(lb)


ex_val_trails = np.asarray(ex_val_labels)[:,2]
ex_val_labels = np.delete(ex_val_labels, 2, 1)

# %%
# ex_val_cut_data=[]
# for i in range(0,len(ex_val_data)):
#     data=ex_data[i][:,0]
    
#     start_time = 0.04996
#     end_time = 0.05016
#     start=np.where(data==(start_time))
#     end = np.where(data==(end_time))
    
#     d = np.zeros(((start[0][0]+200-start[0][0]),5))

#     d[:,0]=ex_val_data[i][start[0][0]:start[0][0]+200,0]
#     d[:,1]=ex_val_data[i][start[0][0]:start[0][0]+200,1]
#     d[:,2]=ex_val_data[i][start[0][0]:start[0][0]+200,2]
#     d[:,3]=ex_val_data[i][start[0][0]:start[0][0]+200,4]
#     d[:,4]=ex_val_data[i][start[0][0]:start[0][0]+200,3]
    
#     ex_val_cut_data.append(d)
#----------------------------------------------------------------------------------------


ex_val_cut_data = []
for i in range(len(ex_val_data)):
    
    threshold = 0.1

    x = np.where(abs(ex_val_data[i][:,1])>threshold)[0][0]
    y = np.where(abs(ex_val_data[i][:,2])>threshold)[0][0]
    z = np.where(abs(ex_val_data[i][:,3])>threshold)[0][0]
    p = np.where(abs(ex_val_data[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)
    end = start+200

    d = np.empty_like(ex_val_data[i][start:end,:])

    d[:,0] = ex_val_data[i][start:end, 0]
    d[:,1] = (-1)*ex_val_data[i][start:end, 1]
    d[:,2] = (-1)*ex_val_data[i][start:end, 2]
    d[:,3] = (-1)*ex_val_data[i][start:end, 4]
    d[:,4] = (-1)*ex_val_data[i][start:end, 3]

    ex_val_cut_data.append(d)

# %% [markdown]
# Normalize and Resample experimental validation data

# %%
# create variables for normalized data
ex_val_norm = np.zeros_like(np.asarray(ex_val_cut_data)); ex_val_norm_labels = np.zeros_like(np.asarray(ex_val_cut_data))

for i in range (0, len(ex_val_cut_data)):
    for j in range (1, 5):
        ex_val_norm[i][:,j] = minmax_scale(ex_val_cut_data[i][:,j])

scalar = MinMaxScaler()
ex_val_norm_labels = scalar.fit_transform(ex_val_labels)

# %%
ex_val_resample = []

# create a dataframe from the normalized data
for i in range (0, len(ex_val_norm)):
    ex_val_resample.append(pd.DataFrame(ex_val_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    ex_val_resample[i] = ex_val_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(ex_val_resample)):
    ex_val_resample[i] = resample(ex_val_resample[i], size)

np.asarray(ex_val_resample).shape
# Out:
# (24, 100, 4)

# %% [markdown]
# ### Augmentation

# %% [markdown]
# ##### Variable initialization

# %%
## -----------------------------------------------------------------------------
#Assuming P1 on top and counter clockwise order
## -----------------------------------------------------------------------------


# Variables for the augmented data
training_tl = np.zeros_like(np.asarray(training_tr)); training_tl_labels = np.zeros_like(np.asarray(training_tr_labels))
training_bl = np.zeros_like(np.asarray(training_tr)); training_bl_labels = np.zeros_like(np.asarray(training_tr_labels))
training_br = np.zeros_like(np.asarray(training_tr)); training_br_labels = np.zeros_like(np.asarray(training_tr_labels))

# %% [markdown]
# ##### Top-Left

# %%
for i in range (0, len(training_tr)):
        training_tl[i][:,0] = training_tr[i][:,0]
        training_tl[i][:,1] = training_tr[i][:,1]
        training_tl[i][:,2] = training_tr[i][:,4]
        training_tl[i][:,3] = training_tr[i][:,3]
        training_tl[i][:,4] = training_tr[i][:,2]

for i in range (0, len(training_tl_labels)):
    training_tl_labels[i][0] = 500 - training_tr_labels[i][0]
    training_tl_labels[i][1] = training_tr_labels[i][1]

# %% [markdown]
# ##### Bottom-Left

# %%
for i in range (0, len(training_bl)):
    training_bl[i][:,0] = training_tl[i][:,0]
    training_bl[i][:,1] = training_tl[i][:,3]
    training_bl[i][:,2] = training_tl[i][:,2]
    training_bl[i][:,3] = training_tl[i][:,1]
    training_bl[i][:,4] = training_tl[i][:,4]

for i in range (0, len(training_bl_labels)):
    training_bl_labels[i][0] = 500. - training_tr_labels[i][0]
    training_bl_labels[i][1] = 500. - training_tr_labels[i][1]

# %% [markdown]
# ##### Bottom-Right

# %%
for i in range (0, len(training_br)):
        training_br[i][:,0] = training_bl[i][:,0]
        training_br[i][:,1] = training_bl[i][:,1]
        training_br[i][:,2] = training_bl[i][:,4]
        training_br[i][:,3] = training_bl[i][:,3]
        training_br[i][:,4] = training_bl[i][:,2]

for i in range (0, len(training_br_labels)):
    training_br_labels[i][0] = training_tr_labels[i][0]
    training_br_labels[i][1] = 500 - training_tr_labels[i][1]

# %% [markdown]
# ##### Delete overlapping data points

# %%
training_tl = np.delete(np.asarray(training_tl), np.where(np.asanyarray(training_tl_labels) == 250.)[0], axis = 0)
training_tl_labels = np.delete(np.asarray(training_tl_labels), np.where(np.asanyarray(training_tl_labels) == 250.)[0], axis = 0)

training_bl = np.delete(np.asarray(training_bl), 0, axis = 0)
training_bl_labels = np.delete(np.asarray(training_bl_labels), 0, axis = 0)

training_br = np.delete(np.asarray(training_br), np.where(np.asanyarray(training_br_labels) == 250.)[0], axis = 0)
training_br_labels = np.delete(np.asarray(training_br_labels), np.where(np.asanyarray(training_br_labels) == 250.)[0], axis = 0)

# %% [markdown]
# ##### Makesure the augmentation is done on all quadrants

# %%
print(f'{np.asarray(training_tl).shape} \t{np.asarray(training_tr).shape} \n{np.asarray(training_bl).shape} \t{np.asarray(training_br).shape} \n{counter}')
# Out:
# (219, 20000, 5) 	(244, 20000, 5)
# (243, 20000, 5) 	(219, 20000, 5)
# 0

# %%
plt.close()
for i in range(0, len(training_tr_labels)):
    plt.plot(training_tr_labels[i][0], training_tr_labels[i][1], 'o', c = 'r')
for j in range (0, len(training_tl_labels)):
    plt.plot(training_tl_labels[j][0], training_tl_labels[j][1], 's', c = 'g')
    plt.plot(training_br_labels[j][0], training_br_labels[j][1], 'P', c = 'y')
for k in range (0, len(training_bl_labels)):
    plt.plot(training_bl_labels[k][0], training_bl_labels[k][1], '*', c = 'b')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))
plt.show()

# %% [markdown]
# ### Concatenate, Cut, Normalize, Resample Training Data

# %% [markdown]
# ##### Concatenate

# %%
training = np.concatenate((training_tr, training_tl, training_bl, training_br), axis = 0)
training_labels = np.concatenate((training_tr_labels, training_tl_labels, training_bl_labels, training_br_labels), axis = 0)

print(f'Shape of all training set: {training.shape} \nShape of all training labels: {training_labels.shape}')
# Out:
# Shape of all training set: (925, 20000, 5)
# Shape of all training labels: (925, 2)

# %% [markdown]
# ##### check with the validation augmented data

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharex=True)

val_c = 1 # Given validation folder has 4 data points. so use - (0, 1, 2, 3)

# find out the index of the validation set in the training data
x = []
for i in range (0, len(training_labels)):
    if (training_labels[i][0] == validation_aug_labels[val_c][0]) and (training_labels[i][1] == validation_aug_labels[val_c][1]):
        x.append(i)

# plot to compare the validation set with the training set
fig.suptitle(f'EPOT Training Data Coordinates - {training_labels[x[0]]} \nValidation Augmented Data Coordinates - {validation_aug_labels[val_c]}')

axs[0,0].plot(training[x[0]][:,0], training[x[0]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[x[0]][:,0], training[x[0]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[x[0]][:,0], training[x[0]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[x[0]][:,0], training[x[0]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,4], label='P - 4', c = 'y')

# check if the data is exactly the same
for i in range (1, 5):
    if np.all(training[x[0]][:,i] == validation_aug[val_c][:,i], axis = 0):
        print('Data is augmented correctly')

fig.legend()
plt.show()

# %%
diff = training[x[0]][:,1] - validation_aug[val_c][:,1]
diff
# Out:
# array([0.     , 0.     , 0.     , ..., 0.00011, 0.00012, 0.00012])

# %% [markdown]
# ##### -- Check -- for outliers

# %%
'''
plt.close()
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

for i in range(len(training)):
    axs[0,0].plot(training[i][:,0], training[i][:,1], label='Training P-1')
    axs[0,1].plot(training[i][:,0], training[i][:,2], label='Training P-2')
    axs[1,0].plot(training[i][:,0], training[i][:,3], label='Training P-3')
    axs[1,1].plot(training[i][:,0], training[i][:,4], label='Training P-4')

plt.show()
'''
# Out:
# "\nplt.close()\nfig, axs = plt.subplots(2, 2, sharex=True, sharey=True)\n\nfor i in range(len(training)):\n    axs[0,0].plot(training[i][:,0], training[i][:,1], label='Training P-1')\n    axs[0,1].plot(training[i][:,0], training[i][:,2], label='Training P-2')\n    axs[1,0].plot(training[i][:,0], training[i][:,3], label='Training P-3')\n    axs[1,1].plot(training[i][:,0], training[i][:,4], label='Training P-4')\n\nplt.show()\n"

# %%
'''
# %matplotlib inline
sns.set(rc={'figure.figsize':(30, 30)})

x = []; y = []; z = []

for i in range(len(training)):
    xi = training_labels[i][0]
    x.append(xi)
    yi = training_labels[i][1]
    y.append(yi)
    zi = pd.DataFrame(training[i][:,1]).max()[0]
    # zi = pd.DataFrame(training[i][:,2]).max()[0]
    # zi = pd.DataFrame(training[i][:,3]).max()[0]
    # zi = pd.DataFrame(training[i][:,4]).max()[0]

    z.append(zi)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')

ax = sns.heatmap(heatmap1_data, 
                square=True, 
                annot = True, 
                annot_kws={"fontsize": 10}, 
                fmt='.1f', 
                linewidths=0.1, 
                linecolor='gray',
                cbar_kws = dict(use_gridspec=False, location='right'))

ax.invert_yaxis()
'''
# Out:
# '\n%matplotlib inline\nsns.set(rc={\'figure.figsize\':(30, 30)})\n\nx = []; y = []; z = []\n\nfor i in range(len(training)):\n    xi = training_labels[i][0]\n    x.append(xi)\n    yi = training_labels[i][1]\n    y.append(yi)\n    zi = pd.DataFrame(training[i][:,1]).max()[0]\n    # zi = pd.DataFrame(training[i][:,2]).max()[0]\n    # zi = pd.DataFrame(training[i][:,3]).max()[0]\n    # zi = pd.DataFrame(training[i][:,4]).max()[0]\n\n    z.append(zi)\n\ndf = pd.DataFrame({\'x\': x, \'y\': y, \'z\': z})\n\nheatmap1_data = pd.pivot_table(df, values=\'z\', index=[\'y\'], columns=\'x\')\n\nax = sns.heatmap(heatmap1_data, \n                square=True, \n                annot = True, \n                annot_kws={"fontsize": 10}, \n                fmt=\'.1f\', \n                linewidths=0.1, \n                linecolor=\'gray\',\n                cbar_kws = dict(use_gridspec=False, location=\'right\'))\n\nax.invert_yaxis()\n'

# %% [markdown]
# Experimental Validation

# %%
'''
# %matplotlib inline
sns.set(rc={'figure.figsize':(30, 30)})

x = []; y = []; z = []

for i in range(len(ex_val_data)):
    xi = ex_val_labels[i][0]
    x.append(xi)
    yi = ex_val_labels[i][1]
    y.append(yi)
    zi = pd.DataFrame(ex_val_data[i][:,1]).max()[0]
    # zi = pd.DataFrame(training[i][:,2]).max()[0]
    # zi = pd.DataFrame(training[i][:,3]).max()[0]
    # zi = pd.DataFrame(training[i][:,4]).max()[0]

    z.append(zi)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')

ax = sns.heatmap(heatmap1_data, 
                square=True, 
                annot = True, 
                annot_kws={"fontsize": 10}, 
                fmt='.1f', 
                linewidths=0.1, 
                linecolor='gray',
                cbar_kws = dict(use_gridspec=False, location='right'))

ax.invert_yaxis()
'''
# Out:
# '\n%matplotlib inline\nsns.set(rc={\'figure.figsize\':(30, 30)})\n\nx = []; y = []; z = []\n\nfor i in range(len(ex_val_data)):\n    xi = ex_val_labels[i][0]\n    x.append(xi)\n    yi = ex_val_labels[i][1]\n    y.append(yi)\n    zi = pd.DataFrame(ex_val_data[i][:,1]).max()[0]\n    # zi = pd.DataFrame(training[i][:,2]).max()[0]\n    # zi = pd.DataFrame(training[i][:,3]).max()[0]\n    # zi = pd.DataFrame(training[i][:,4]).max()[0]\n\n    z.append(zi)\n\ndf = pd.DataFrame({\'x\': x, \'y\': y, \'z\': z})\n\nheatmap1_data = pd.pivot_table(df, values=\'z\', index=[\'y\'], columns=\'x\')\n\nax = sns.heatmap(heatmap1_data, \n                square=True, \n                annot = True, \n                annot_kws={"fontsize": 10}, \n                fmt=\'.1f\', \n                linewidths=0.1, \n                linecolor=\'gray\',\n                cbar_kws = dict(use_gridspec=False, location=\'right\'))\n\nax.invert_yaxis()\n'

# %% [markdown]
# #### Cutting Training Data

# %%
train_cut = []
for i in range(len(training)):
    
    threshold = 0.1

    x = np.where(abs(training[i][:,1])>threshold)[0][0]
    y = np.where(abs(training[i][:,2])>threshold)[0][0]
    z = np.where(abs(training[i][:,3])>threshold)[0][0]
    p = np.where(abs(training[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)

    d = np.empty_like(training[i][start:,:])

    d[:,0] = training[i][start:, 0]
    d[:,1] = training[i][start:, 1]
    d[:,2] = training[i][start:, 2]
    d[:,3] = training[i][start:, 3]
    d[:,4] = training[i][start:, 4]

    train_cut.append(d)

# %% [markdown]
# #### Normalize Training Data

# %%
# maxim = []
# minim = []
# for i in range (len(train_cut)):
#     for j in range (1,5):
#         p = train_cut[i][:,j].max()
#         q = train_cut[i][:,j].min()

#         maxim.append(p)
#         minim.append(q)
# # print(np.asarray(maxim).max(),np.asarray(minim).min())

# create variables for normalized data
# train_norm = np.zeros_like(np.array(train_cut)) 
train_norm = []
train_norm_labels = np.zeros_like(np.asarray(training_labels))

for i in range (0, len(train_cut)):
    
    n = np.zeros_like(train_cut[i])
    n[:,1] = minmax_scale(train_cut[i][:,1])
    n[:,2] = minmax_scale(train_cut[i][:,2])
    n[:,3] = minmax_scale(train_cut[i][:,3])
    n[:,4] = minmax_scale(train_cut[i][:,4])
    
    train_norm.append(n)

    
scalar = MinMaxScaler()
train_norm_labels = scalar.fit_transform(training_labels)

# %%
maxim = []
minim = []
for i in range (len(train_norm)):
    for j in range (1,5):
        p = train_norm[i][:,j].max()
        q = train_norm[i][:,j].min()

        maxim.append(p)
        minim.append(q)
print(np.asarray(maxim).max(),np.asarray(minim).min())
# Out:
# 1.0000000000000002 0.0

# %%
plt.close()
plt.plot(train_norm_labels[:,0], train_norm_labels[:,1], 'o', c = 'r', label = 'Normalized Training Data Labels')
plt.legend(loc='lower center', bbox_to_anchor=(1, -0.5))
plt.show()

# %% [markdown]
# #### Resample Training Data

# %%
train_resample = []

# create a dataframe from the normalized data
for i in range (0, len(training)):
    train_resample.append(pd.DataFrame(train_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    train_resample[i] = train_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(training)):
    train_resample[i] = resample(train_resample[i], size)

np.asarray(train_resample).shape
# Out:
# (925, 100, 4)

# %%
plt.close()
fig, axs = plt.subplots(2, 1)

axs[0].plot(train_cut[12][:,2], c = 'r')
axs[1].plot(train_resample[12][:,1], c = 'b')

plt.show()

# %% [markdown]
# ### Compare Experimental, Experimental-Validation and Training Data

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharey=True)

ex_val_c = 20 # Given validation folder has 24 data points. so use - (0, 1, .... , 23)

# find out the index of the validation set in the training data
x = []
for i in range (0, len(training_labels)):
    if (training_labels[i][0] == ex_val_labels[ex_val_c][0]) and (training_labels[i][1] == ex_val_labels[ex_val_c][1]):
        x.append(i)

# plot to compare the validation set with the training set
fig.suptitle(f'Training Data Coordinates - {training_labels[x[0]]} \nExperimental Validation Data Coordinates - {ex_val_labels[ex_val_c]} - Trial [{ex_val_trails[ex_val_c]}]')

axs[0,0].plot(training[x[0]][:,0], training[x[0]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[x[0]][:,0], training[x[0]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[x[0]][:,0], training[x[0]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[x[0]][:,0], training[x[0]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,4], label='P - 4', c = 'y')

fig.legend()
plt.show()

# %%
plt.close()
fig, axs = plt.subplots(1, 4, sharex=True, sharey=True)

for i in range(4):
    axs[0].plot(ex_val_cut_data[i][:,0], ex_cut_data[i][:,1], c = 'r', label = 'Exp Val Data - P-1')
    axs[1].plot(ex_val_cut_data[i][:,0], ex_cut_data[i][:,2], c = 'g', label = 'Exp Val Data - P-2')
    axs[2].plot(ex_val_cut_data[i][:,0], ex_cut_data[i][:,3], c = 'b', label = 'Exp Val Data - P-3')
    axs[3].plot(ex_val_cut_data[i][:,0], ex_cut_data[i][:,4], c = 'y', label = 'Exp Val Data - P-4')

plt.show()

# %% [markdown]
# ### Export data to pickle

# %%
# with open('training_data.pickle', 'wb') as f:
#     pickle.dump(training, f)

# with open('train_resample.pickle', 'wb') as f:
#     pickle.dump(train_resample, f)
# with open('train_norm_labels.pickle', 'wb') as f:
#     pickle.dump(train_norm_labels, f)

# with open('training_labels.pickle', 'wb') as f:
#     pickle.dump(training_labels, f)

# with open('exp_validation_data.pickle', 'wb') as f:
#     pickle.dump(ex_val_data, f)
# with open('exp_validation_labels.pickle', 'wb') as f:
#     pickle.dump(ex_val_labels, f)
# with open('exp_validation_trails.pickle', 'wb') as f:
#     pickle.dump(ex_val_trails, f)


# with open('exp_val_resample.pickle', 'wb') as f:
#     pickle.dump(ex_val_resample, f)
# with open('exp_val_norm_labels.pickle', 'wb') as f:
#     pickle.dump(ex_val_norm_labels, f)

# with open('ex_resample.pickle', 'wb') as f:
#     pickle.dump(ex_resample, f)

# %% [markdown]
# #### AI Model

# %% [markdown]
# ##### Split the data into training and testing sets

# %%
# Extract the data from the pickle files
'''
with open('train_resample.pickle', 'rb') as f:
    train_resample = pickle.load(f)
with open('train_norm_labels.pickle', 'rb') as f:
    train_norm_labels = pickle.load(f)
'''

X = np.asarray(train_resample)
y = np.asarray(train_norm_labels)

# create split data from the normalized data
size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {len(x_train)} length of labels - {len(y_train)} \nLength of test data - {len(x_test)} length of labels - {len(y_test)}')
# Out:
# Length of training data - 740 length of labels - 740
# Length of test data - 185 length of labels - 185

# %% [markdown]
# ##### TensorBoard

# %%
# %tensorboard --logdir=logs/

# %% [markdown]
# #### Model Training and Tuning

# %% [markdown]
# DNN Tuning

# %%
'''
log_files = f'DNN_log.{int(time.time())}'
tuner_logs= f'tunelog/DNN_tuner_log.{int(time.time())}'

tensorboard = TensorBoard(log_dir=f'logs/{log_files}', 
                          histogram_freq=1, 
                          write_graph=True,
                          write_grads=True)


def dnnModel(hp):
    model = Sequential()
    model.add(Flatten(input_shape=(100,4)))
    model.add(Dense(units=hp.Int('layer_1_nodes', 
                    min_value=32, max_value=512, step=32), 
                    activation=hp.Choice("activation_1", ["relu", "sigmoid", "tanh"])))
    
    for i in range(hp.Int('n_layers', min_value=0, max_value=4, step=1)):
        model.add(Dense(units=hp.Int(f'layer_{i+1}_nodes', min_value=32, max_value=512, step=32), activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid", "tanh"])))
    
    model.add(Dense(units=2, activation=hp.Choice("activation_out", ['sigmoid', 'linear']))) # output layer

    model.summary()

    # Compile model
    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(loss = hp.Choice('loss', ['mae']),
                optimizer = hp.Choice('optimizer', ['Adam', 'RMSprop']), 
                metrics=['Accuracy'])
    
    return model

# Hyperparameter tuning
tuner = RandomSearch(dnnModel,
                    objective='val_Accuracy',
                    max_trials=50,
                    executions_per_trial=2,
                    directory=tuner_logs,
                    project_name='DNN_tuning')

tuner.search(x=x_train,
            y=y_train,
            epochs=60,
            batch_size=32,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard])
            '''
# Out:
# '\nlog_files = f\'DNN_log.{int(time.time())}\'\ntuner_logs= f\'tunelog/DNN_tuner_log.{int(time.time())}\'\n\ntensorboard = TensorBoard(log_dir=f\'logs/{log_files}\', \n                          histogram_freq=1, \n                          write_graph=True,\n                          write_grads=True)\n\n\ndef dnnModel(hp):\n    model = Sequential()\n    model.add(Flatten(input_shape=(100,4)))\n    model.add(Dense(units=hp.Int(\'layer_1_nodes\', \n                    min_value=32, max_value=512, step=32), \n                    activation=hp.Choice("activation_1", ["relu", "sigmoid", "tanh"])))\n    \n    for i in range(hp.Int(\'n_layers\', min_value=0, max_value=4, step=1)):\n        model.add(Dense(units=hp.Int(f\'layer_{i+1}_nodes\', min_value=32, max_value=512, step=32), activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid", "tanh"])))\n    \n    model.add(Dense(units=2, activation=hp.Choice("activation_out", [\'sigmoid\', \'linear\']))) # output layer\n\n    model.summary()\n\n    # Compile model\n    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)\n    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)\n    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)\n\n    model.compile(loss = hp.Choice(\'loss\', [\'mae\']),\n                optimizer = hp.Choice(\'optimizer\', [\'Adam\', \'RMSprop\']), \n                metrics=[\'Accuracy\'])\n    \n    return model\n\n# Hyperparameter tuning\ntuner = RandomSearch(dnnModel,\n                    objective=\'val_Accuracy\',\n                    max_trials=50,\n                    executions_per_trial=2,\n                    directory=tuner_logs,\n                    project_name=\'DNN_tuning\')\n\ntuner.search(x=x_train,\n            y=y_train,\n            epochs=60,\n            batch_size=32,\n            validation_data=(x_test, y_test),\n            callbacks=[tensorboard])\n            '

# %%
# bestModels = tuner.get_best_models(num_models=2)

# %%
# Save the keras model
# model.save(f'model/complete_tunedModel_97perAcc.{int(time.time())}.h5')

# %% [markdown]
# #### CNN Tuning

# %%
'''
log_files = f'CNN_log.{int(time.time())}'
tuner_logs= f'tunelog/CNN_tuner_log.{int(time.time())}'

tensorboard = TensorBoard(log_dir=f'logs/{log_files}', 
                          histogram_freq=1, 
                          write_graph=True,
                          write_grads=True)

def cnnModel(hp):
    model = Sequential()

    model.add(Conv1D(filters=hp.Int('conv_1_filter', min_value=32, max_value=512, step=32), 
                     kernel_size=hp.Int('Kernal_1', min_value=2, max_value=5, step=1), 
                     strides=hp.Int('stride_1', min_value=1, max_value=5, step=1),
                     activation=hp.Choice("activation_1", ["relu", "sigmoid"]), 
                     input_shape=(100,4)))
    
    model.add(MaxPooling1D(pool_size=hp.Int('pool_1', min_value=2, max_value=5, step=1))),

    for i in range(hp.Int('n_layers', min_value=0, max_value=4, step=1)):
        model.add(Conv1D(filters=hp.Int(f'conv_{i+1}_filter', min_value=32, max_value=512, step=32), 
                         kernel_size=hp.Int(f'Kernal_{i+1}', min_value=2, max_value=5, step=1), 
                         strides=hp.Int(f'stride_{i+1}', min_value=1, max_value=5, step=1),
                         activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid"])))
        model.add(MaxPooling1D(pool_size=hp.Int(f'pool_{i+1}', min_value=2, max_value=5, step=1)))

    model.add(Flatten())


    model.add(Dense(units=hp.Int('FC_layer_1_nodes',
                    min_value=32, max_value=512, step=32),
                    activation=hp.Choice("FC_activation_1", ["relu", "sigmoid"])))
    
    model.add(Dense(units=hp.Int('FC_layer_2_nodes',
                    min_value=32, max_value=512, step=32),
                    activation=hp.Choice("FC_activation_2", ["relu", "sigmoid"])))

    model.add(Dense(units=2, activation=hp.Choice("activation_out", ['sigmoid', 'linear']))) # output layer

    model.summary()

    # Compile model
    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(loss = hp.Choice('loss', ['mse', 'mae']),
                optimizer = hp.Choice('optimizer', ['Adam', 'RMSprop']), 
                metrics=['Accuracy'])

    return model

# Hyperparameter tuning
tuner = RandomSearch(cnnModel,
                    objective='val_Accuracy',
                    max_trials=560,
                    executions_per_trial=3,
                    directory=tuner_logs,
                    project_name='CNN_tuning')

tuner.search(x=x_train,
            y=y_train,
            epochs=60,
            batch_size=32,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard])
'''
# Out:
# '\nlog_files = f\'CNN_log.{int(time.time())}\'\ntuner_logs= f\'tunelog/CNN_tuner_log.{int(time.time())}\'\n\ntensorboard = TensorBoard(log_dir=f\'logs/{log_files}\', \n                          histogram_freq=1, \n                          write_graph=True,\n                          write_grads=True)\n\ndef cnnModel(hp):\n    model = Sequential()\n\n    model.add(Conv1D(filters=hp.Int(\'conv_1_filter\', min_value=32, max_value=512, step=32), \n                     kernel_size=hp.Int(\'Kernal_1\', min_value=2, max_value=5, step=1), \n                     strides=hp.Int(\'stride_1\', min_value=1, max_value=5, step=1),\n                     activation=hp.Choice("activation_1", ["relu", "sigmoid"]), \n                     input_shape=(100,4)))\n    \n    model.add(MaxPooling1D(pool_size=hp.Int(\'pool_1\', min_value=2, max_value=5, step=1))),\n\n    for i in range(hp.Int(\'n_layers\', min_value=0, max_value=4, step=1)):\n        model.add(Conv1D(filters=hp.Int(f\'conv_{i+1}_filter\', min_value=32, max_value=512, step=32), \n                         kernel_size=hp.Int(f\'Kernal_{i+1}\', min_value=2, max_value=5, step=1), \n                         strides=hp.Int(f\'stride_{i+1}\', min_value=1, max_value=5, step=1),\n                         activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid"])))\n        model.add(MaxPooling1D(pool_size=hp.Int(f\'pool_{i+1}\', min_value=2, max_value=5, step=1)))\n\n    model.add(Flatten())\n\n\n    model.add(Dense(units=hp.Int(\'FC_layer_1_nodes\',\n                    min_value=32, max_value=512, step=32),\n                    activation=hp.Choice("FC_activation_1", ["relu", "sigmoid"])))\n    \n    model.add(Dense(units=hp.Int(\'FC_layer_2_nodes\',\n                    min_value=32, max_value=512, step=32),\n                    activation=hp.Choice("FC_activation_2", ["relu", "sigmoid"])))\n\n    model.add(Dense(units=2, activation=hp.Choice("activation_out", [\'sigmoid\', \'linear\']))) # output layer\n\n    model.summary()\n\n    # Compile model\n    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)\n    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)\n    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)\n\n    model.compile(loss = hp.Choice(\'loss\', [\'mse\', \'mae\']),\n                optimizer = hp.Choice(\'optimizer\', [\'Adam\', \'RMSprop\']), \n                metrics=[\'Accuracy\'])\n\n    return model\n\n# Hyperparameter tuning\ntuner = RandomSearch(cnnModel,\n                    objective=\'val_Accuracy\',\n                    max_trials=560,\n                    executions_per_trial=3,\n                    directory=tuner_logs,\n                    project_name=\'CNN_tuning\')\n\ntuner.search(x=x_train,\n            y=y_train,\n            epochs=60,\n            batch_size=32,\n            validation_data=(x_test, y_test),\n            callbacks=[tensorboard])\n'

# %%
# bestModels = tuner.get_best_models(num_models=2)

# %% [markdown]
# #### DNN Model

# %%
model = Sequential()
model.add(Flatten(input_shape=(100,4)))

model.add(Dense(units=512, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=16, activation='relu'))

model.add(Dense(units=2, activation='linear'))

model.summary()

# Compile model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss = 'mae', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the model
history = model.fit(x_train, y_train, epochs=60, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               205312
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 378,866
# Trainable params: 378,866
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 24/24 [==============================] - 1s 10ms/step - loss: 0.3088 - Accuracy: 0.5176 - val_loss: 0.3044 - val_Accuracy: 0.5027
# Epoch 2/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2636 - Accuracy: 0.4973 - val_loss: 0.2736 - val_Accuracy: 0.5405
# Epoch 3/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2480 - Accuracy: 0.5405 - val_loss: 0.2595 - val_Accuracy: 0.4973
# Epoch 4/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2271 - Accuracy: 0.5716 - val_loss: 0.2673 - val_Accuracy: 0.6270
# Epoch 5/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2091 - Accuracy: 0.6162 - val_loss: 0.2101 - val_Accuracy: 0.6486
# Epoch 6/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1729 - Accuracy: 0.7446 - val_loss: 0.1737 - val_Accuracy: 0.7568
# Epoch 7/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1523 - Accuracy: 0.7905 - val_loss: 0.1737 - val_Accuracy: 0.7838
# Epoch 8/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1447 - Accuracy: 0.8081 - val_loss: 0.1401 - val_Accuracy: 0.8595
# Epoch 9/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1060 - Accuracy: 0.8608 - val_loss: 0.1378 - val_Accuracy: 0.8378
# Epoch 10/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1068 - Accuracy: 0.8649 - val_loss: 0.1299 - val_Accuracy: 0.8432
# Epoch 11/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0946 - Accuracy: 0.8824 - val_loss: 0.1315 - val_Accuracy: 0.8811
# Epoch 12/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - Accuracy: 0.8770 - val_loss: 0.1030 - val_Accuracy: 0.8378
# Epoch 13/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0736 - Accuracy: 0.8986 - val_loss: 0.0851 - val_Accuracy: 0.8919
# Epoch 14/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0651 - Accuracy: 0.9203 - val_loss: 0.0765 - val_Accuracy: 0.9027
# Epoch 15/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0652 - Accuracy: 0.9162 - val_loss: 0.0766 - val_Accuracy: 0.9189
# Epoch 16/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0520 - Accuracy: 0.9189 - val_loss: 0.0723 - val_Accuracy: 0.9135
# Epoch 17/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0533 - Accuracy: 0.9270 - val_loss: 0.0796 - val_Accuracy: 0.9189
# Epoch 18/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0541 - Accuracy: 0.9365 - val_loss: 0.0557 - val_Accuracy: 0.8973
# Epoch 19/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0499 - Accuracy: 0.9189 - val_loss: 0.0615 - val_Accuracy: 0.8973
# Epoch 20/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0531 - Accuracy: 0.9054 - val_loss: 0.0614 - val_Accuracy: 0.9135
# Epoch 21/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0463 - Accuracy: 0.9230 - val_loss: 0.0556 - val_Accuracy: 0.8811
# Epoch 22/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0471 - Accuracy: 0.9405 - val_loss: 0.0626 - val_Accuracy: 0.9243
# Epoch 23/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0545 - Accuracy: 0.9189 - val_loss: 0.0593 - val_Accuracy: 0.9297
# Epoch 24/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0439 - Accuracy: 0.9243 - val_loss: 0.0587 - val_Accuracy: 0.9459
# Epoch 25/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0508 - Accuracy: 0.9243 - val_loss: 0.0586 - val_Accuracy: 0.9135
# Epoch 26/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0418 - Accuracy: 0.9446 - val_loss: 0.0542 - val_Accuracy: 0.9189
# Epoch 27/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0477 - Accuracy: 0.9122 - val_loss: 0.0604 - val_Accuracy: 0.9027
# Epoch 28/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0406 - Accuracy: 0.9514 - val_loss: 0.0434 - val_Accuracy: 0.9189
# Epoch 29/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0359 - Accuracy: 0.9514 - val_loss: 0.0442 - val_Accuracy: 0.9135
# Epoch 30/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0408 - Accuracy: 0.9419 - val_loss: 0.0430 - val_Accuracy: 0.9297
# Epoch 31/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0408 - Accuracy: 0.9568 - val_loss: 0.0467 - val_Accuracy: 0.9189
# Epoch 32/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0358 - Accuracy: 0.9500 - val_loss: 0.0597 - val_Accuracy: 0.8919
# Epoch 33/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0366 - Accuracy: 0.9365 - val_loss: 0.0467 - val_Accuracy: 0.9297
# Epoch 34/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0337 - Accuracy: 0.9419 - val_loss: 0.0409 - val_Accuracy: 0.9243
# Epoch 35/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0341 - Accuracy: 0.9595 - val_loss: 0.0374 - val_Accuracy: 0.9351
# Epoch 36/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0356 - Accuracy: 0.9419 - val_loss: 0.0377 - val_Accuracy: 0.9351
# Epoch 37/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0311 - Accuracy: 0.9595 - val_loss: 0.0414 - val_Accuracy: 0.9459
# Epoch 38/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0350 - Accuracy: 0.9554 - val_loss: 0.0409 - val_Accuracy: 0.9243
# Epoch 39/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0334 - Accuracy: 0.9595 - val_loss: 0.0335 - val_Accuracy: 0.9351
# Epoch 40/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0283 - Accuracy: 0.9635 - val_loss: 0.0473 - val_Accuracy: 0.9243
# Epoch 41/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0320 - Accuracy: 0.9500 - val_loss: 0.0318 - val_Accuracy: 0.9243
# Epoch 42/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0290 - Accuracy: 0.9676 - val_loss: 0.0614 - val_Accuracy: 0.9081
# Epoch 43/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0362 - Accuracy: 0.9527 - val_loss: 0.0397 - val_Accuracy: 0.9568
# Epoch 44/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0269 - Accuracy: 0.9581 - val_loss: 0.0336 - val_Accuracy: 0.9459
# Epoch 45/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0279 - Accuracy: 0.9622 - val_loss: 0.0367 - val_Accuracy: 0.9297
# Epoch 46/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0279 - Accuracy: 0.9514 - val_loss: 0.0379 - val_Accuracy: 0.9459
# Epoch 47/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0263 - Accuracy: 0.9568 - val_loss: 0.0512 - val_Accuracy: 0.9297
# Epoch 48/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0362 - Accuracy: 0.9568 - val_loss: 0.0420 - val_Accuracy: 0.9297
# Epoch 49/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0291 - Accuracy: 0.9568 - val_loss: 0.0378 - val_Accuracy: 0.9297
# Epoch 50/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0283 - Accuracy: 0.9662 - val_loss: 0.0367 - val_Accuracy: 0.9297
# Epoch 51/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0282 - Accuracy: 0.9622 - val_loss: 0.0315 - val_Accuracy: 0.9351
# Epoch 52/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0241 - Accuracy: 0.9743 - val_loss: 0.0275 - val_Accuracy: 0.9568
# Epoch 53/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0288 - Accuracy: 0.9649 - val_loss: 0.0417 - val_Accuracy: 0.9514
# Epoch 54/60
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0258 - Accuracy: 0.9568 - val_loss: 0.0276 - val_Accuracy: 0.9297
# Epoch 55/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0235 - Accuracy: 0.9703 - val_loss: 0.0370 - val_Accuracy: 0.9243
# Epoch 56/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0297 - Accuracy: 0.9554 - val_loss: 0.0347 - val_Accuracy: 0.9189
# Epoch 57/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0312 - Accuracy: 0.9595 - val_loss: 0.0326 - val_Accuracy: 0.9405
# Epoch 58/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0277 - Accuracy: 0.9649 - val_loss: 0.0354 - val_Accuracy: 0.9297
# Epoch 59/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0269 - Accuracy: 0.9554 - val_loss: 0.0355 - val_Accuracy: 0.9351
# Epoch 60/60
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0259 - Accuracy: 0.9608 - val_loss: 0.0315 - val_Accuracy: 0.9459

# %%
# model.save(f'model/DNN_val_acc_97perAcc.{int(time.time())}.h5')

# %%
dnnmse=mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(model.predict(x_test)), squared=False)

# %%
# mean_squared_error((ex_val_labels), scalar.inverse_transform(model.predict(ex_val_resample)), squared=True)

# %%
plt.close()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['Accuracy'], label='Training Accuracy')
plt.plot(history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.legend()
plt.show()

# %%
# '''
# %matplotlib inline
# sns.set(rc={'figure.figsize':(30, 30)})

# X = scalar.inverse_transform(y_test)[:,0]
# Y = np.flip(scalar.inverse_transform(y_test)[:,1])
# Z = ((scalar.inverse_transform(y_test) - scalar.inverse_transform(model.predict(x_test)))[:,0] + (scalar.inverse_transform(y_test) - scalar.inverse_transform(model.predict(x_test)))[:,1])/2

# df = pd.DataFrame({'x': X, 'y': Y, 'z': Z})

# heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')
# sns.color_palette("hls", 8)
# ax = sns.heatmap(heatmap1_data,
#                 cmap='coolwarm',
#                 center = 0,
#                 square=True, 
#                 annot = True, 
#                 annot_kws={"fontsize": 10}, 
#                 fmt='.1f', 
#                 linewidths=0.1, 
#                 linecolor='gray',
#                 cbar_kws = dict(use_gridspec=False, location='right'))
# ax.invert_yaxis()
# '''

# %%
# X = scalar.inverse_transform(y_test)[:,0]
# Y = np.flip(scalar.inverse_transform(y_test)[:,1])
# Z = ((scalar.inverse_transform(y_test) - scalar.inverse_transform(model.predict(x_test)))[:,0] + (scalar.inverse_transform(y_test) - scalar.inverse_transform(model.predict(x_test)))[:,1])/2

# x = np.reshape(X, (37, 5))
# y = np.reshape(Y, (37, 5))
# z = np.reshape(Z, (37, 5))

# fig = plt.figure()
# ax = Axes3D(fig)

# surf = ax.scatter(x, y, z, cmap = 'seismic', linewidth=0, antialiased=False)

# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')
# ax.set_zlabel('Mean Error')

# fig.colorbar(surf, shrink=0.5, aspect=5)
# plt.title('Original Code')
# plt.show()

# %% [markdown]
# #### Modified - AlexNet - Shiva

# %%
Alex4= Sequential()

Alex4.add(Conv1D(filters=96, kernel_size=5, strides=4, activation='relu', input_shape=(100,4), padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides= 2, padding='valid'))
Alex4.add(Dropout(0.25))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=5, activation='relu', padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides=2, padding='valid'))

Alex4.add(Conv1D(filters=384, strides=1, kernel_size=3, activation='relu', padding='same'))
Alex4.add(Dropout(0.25))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=3, activation='relu', padding='same'))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=3, activation='relu', padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides=2, padding='valid'))

# Fully Connected Layers
Alex4.add(Flatten())
Alex4.add(Dense(units=128, activation='relu',use_bias='False'))
Alex4.add(Dense(units=64, activation='relu',use_bias='False'))
Alex4.add(Dense(units=2, activation='linear',use_bias='False'))
Alex4.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

Alex4.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the cnn_model
Alex_history = Alex4.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 25, 96)            2016
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 12, 96)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 96)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 12, 256)           123136
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 5, 256)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 5, 384)            295296
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 384)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 5, 256)            295168
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 5, 256)            196864
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 2, 256)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 986,530
# Trainable params: 986,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1410 - Accuracy: 0.5243 - val_loss: 0.1045 - val_Accuracy: 0.5027
# Epoch 2/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0944 - Accuracy: 0.5095 - val_loss: 0.1020 - val_Accuracy: 0.5027
# Epoch 3/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0880 - Accuracy: 0.5122 - val_loss: 0.1138 - val_Accuracy: 0.4973
# Epoch 4/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0745 - Accuracy: 0.5203 - val_loss: 0.0983 - val_Accuracy: 0.5730
# Epoch 5/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0574 - Accuracy: 0.5311 - val_loss: 0.0651 - val_Accuracy: 0.5838
# Epoch 6/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0476 - Accuracy: 0.5946 - val_loss: 0.0460 - val_Accuracy: 0.6324
# Epoch 7/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0223 - Accuracy: 0.8149 - val_loss: 0.0226 - val_Accuracy: 0.8216
# Epoch 8/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0147 - Accuracy: 0.8635 - val_loss: 0.0148 - val_Accuracy: 0.8973
# Epoch 9/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0101 - Accuracy: 0.8703 - val_loss: 0.0133 - val_Accuracy: 0.9081
# Epoch 10/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0091 - Accuracy: 0.9081 - val_loss: 0.0101 - val_Accuracy: 0.9297
# Epoch 11/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0074 - Accuracy: 0.8689 - val_loss: 0.0106 - val_Accuracy: 0.9405
# Epoch 12/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0063 - Accuracy: 0.9095 - val_loss: 0.0036 - val_Accuracy: 0.9189
# Epoch 13/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0059 - Accuracy: 0.9257 - val_loss: 0.0039 - val_Accuracy: 0.9297
# Epoch 14/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0051 - Accuracy: 0.9162 - val_loss: 0.0058 - val_Accuracy: 0.9405
# Epoch 15/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0038 - Accuracy: 0.9392 - val_loss: 0.0043 - val_Accuracy: 0.9514
# Epoch 16/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0036 - Accuracy: 0.9230 - val_loss: 0.0059 - val_Accuracy: 0.9514
# Epoch 17/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0046 - Accuracy: 0.9284 - val_loss: 0.0023 - val_Accuracy: 0.9405
# Epoch 18/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0041 - Accuracy: 0.9581 - val_loss: 0.0049 - val_Accuracy: 0.9622
# Epoch 19/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0037 - Accuracy: 0.9419 - val_loss: 0.0031 - val_Accuracy: 0.9514
# Epoch 20/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0032 - Accuracy: 0.9419 - val_loss: 0.0018 - val_Accuracy: 0.9514
# Epoch 21/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0030 - Accuracy: 0.9500 - val_loss: 0.0012 - val_Accuracy: 0.9730
# Epoch 22/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0025 - Accuracy: 0.9392 - val_loss: 0.0013 - val_Accuracy: 0.9622
# Epoch 23/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0024 - Accuracy: 0.9365 - val_loss: 0.0023 - val_Accuracy: 0.9514
# Epoch 24/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - Accuracy: 0.9514 - val_loss: 0.0014 - val_Accuracy: 0.9622
# Epoch 25/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0029 - Accuracy: 0.9554 - val_loss: 0.0036 - val_Accuracy: 0.9568
# Epoch 26/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0022 - Accuracy: 0.9527 - val_loss: 0.0016 - val_Accuracy: 0.9514
# Epoch 27/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - Accuracy: 0.9527 - val_loss: 0.0031 - val_Accuracy: 0.9568
# Epoch 28/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0019 - Accuracy: 0.9365 - val_loss: 0.0015 - val_Accuracy: 0.9730
# Epoch 29/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - Accuracy: 0.9595 - val_loss: 0.0026 - val_Accuracy: 0.9514
# Epoch 30/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - Accuracy: 0.9486 - val_loss: 0.0013 - val_Accuracy: 0.9568
# Epoch 31/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - Accuracy: 0.9581 - val_loss: 9.5180e-04 - val_Accuracy: 0.9676
# Epoch 32/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - Accuracy: 0.9500 - val_loss: 0.0016 - val_Accuracy: 0.9676
# Epoch 33/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - Accuracy: 0.9689 - val_loss: 0.0013 - val_Accuracy: 0.9622
# Epoch 34/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - Accuracy: 0.9622 - val_loss: 0.0030 - val_Accuracy: 0.9676
# Epoch 35/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - Accuracy: 0.9608 - val_loss: 9.8795e-04 - val_Accuracy: 0.9622
# Epoch 36/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0015 - Accuracy: 0.9649 - val_loss: 0.0015 - val_Accuracy: 0.9514
# Epoch 37/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - Accuracy: 0.9730 - val_loss: 9.9345e-04 - val_Accuracy: 0.9459
# Epoch 38/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9689 - val_loss: 0.0014 - val_Accuracy: 0.9405
# Epoch 39/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9459 - val_loss: 0.0016 - val_Accuracy: 0.9730
# Epoch 40/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - Accuracy: 0.9595 - val_loss: 8.7967e-04 - val_Accuracy: 0.9568
# Epoch 41/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0015 - Accuracy: 0.9527 - val_loss: 0.0012 - val_Accuracy: 0.9568
# Epoch 42/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - Accuracy: 0.9554 - val_loss: 0.0014 - val_Accuracy: 0.9730
# Epoch 43/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9527 - val_loss: 5.0505e-04 - val_Accuracy: 0.9730
# Epoch 44/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9608 - val_loss: 5.4572e-04 - val_Accuracy: 0.9676
# Epoch 45/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - Accuracy: 0.9716 - val_loss: 7.8590e-04 - val_Accuracy: 0.9514
# Epoch 46/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9689 - val_loss: 8.7648e-04 - val_Accuracy: 0.9568
# Epoch 47/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0010 - Accuracy: 0.9622 - val_loss: 5.1843e-04 - val_Accuracy: 0.9405
# Epoch 48/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9635 - val_loss: 7.1304e-04 - val_Accuracy: 0.9568
# Epoch 49/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9581 - val_loss: 8.3691e-04 - val_Accuracy: 0.9676
# Epoch 50/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.4136e-04 - Accuracy: 0.9649 - val_loss: 8.3927e-04 - val_Accuracy: 0.9568
# Epoch 51/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0011 - Accuracy: 0.9784 - val_loss: 0.0011 - val_Accuracy: 0.9784
# Epoch 52/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9581 - val_loss: 0.0015 - val_Accuracy: 0.9514
# Epoch 53/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9689 - val_loss: 5.6425e-04 - val_Accuracy: 0.9405
# Epoch 54/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0010 - Accuracy: 0.9662 - val_loss: 4.9905e-04 - val_Accuracy: 0.9676
# Epoch 55/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.3789e-04 - Accuracy: 0.9716 - val_loss: 4.4260e-04 - val_Accuracy: 0.9730
# Epoch 56/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.1583e-04 - Accuracy: 0.9703 - val_loss: 0.0020 - val_Accuracy: 0.9784
# Epoch 57/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0010 - Accuracy: 0.9662 - val_loss: 5.0728e-04 - val_Accuracy: 0.9514
# Epoch 58/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.5719e-04 - Accuracy: 0.9676 - val_loss: 8.3157e-04 - val_Accuracy: 0.9730
# Epoch 59/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.7207e-04 - Accuracy: 0.9689 - val_loss: 0.0011 - val_Accuracy: 0.9459
# Epoch 60/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.7176e-04 - Accuracy: 0.9689 - val_loss: 6.5861e-04 - val_Accuracy: 0.9568
# Epoch 61/90
# 24/24 [==============================] - 0s 14ms/step - loss: 7.9171e-04 - Accuracy: 0.9716 - val_loss: 8.5294e-04 - val_Accuracy: 0.9784
# Epoch 62/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.8880e-04 - Accuracy: 0.9581 - val_loss: 5.7187e-04 - val_Accuracy: 0.9568
# Epoch 63/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0181e-04 - Accuracy: 0.9716 - val_loss: 6.3174e-04 - val_Accuracy: 0.9784
# Epoch 64/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.7475e-04 - Accuracy: 0.9689 - val_loss: 4.0464e-04 - val_Accuracy: 0.9568
# Epoch 65/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.8799e-04 - Accuracy: 0.9770 - val_loss: 4.2267e-04 - val_Accuracy: 0.9622
# Epoch 66/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.3217e-04 - Accuracy: 0.9784 - val_loss: 4.9613e-04 - val_Accuracy: 0.9622
# Epoch 67/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.9225e-04 - Accuracy: 0.9743 - val_loss: 4.3965e-04 - val_Accuracy: 0.9459
# Epoch 68/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.5739e-04 - Accuracy: 0.9541 - val_loss: 8.1361e-04 - val_Accuracy: 0.9568
# Epoch 69/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.9963e-04 - Accuracy: 0.9662 - val_loss: 0.0021 - val_Accuracy: 0.9676
# Epoch 70/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.8997e-04 - Accuracy: 0.9689 - val_loss: 7.8892e-04 - val_Accuracy: 0.9514
# Epoch 71/90
# 24/24 [==============================] - 0s 15ms/step - loss: 7.0807e-04 - Accuracy: 0.9595 - val_loss: 0.0010 - val_Accuracy: 0.9676
# Epoch 72/90
# 24/24 [==============================] - 0s 14ms/step - loss: 7.8579e-04 - Accuracy: 0.9676 - val_loss: 4.0766e-04 - val_Accuracy: 0.9568
# Epoch 73/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.0815e-04 - Accuracy: 0.9703 - val_loss: 5.0003e-04 - val_Accuracy: 0.9730
# Epoch 74/90
# 24/24 [==============================] - 0s 15ms/step - loss: 6.2150e-04 - Accuracy: 0.9743 - val_loss: 6.3933e-04 - val_Accuracy: 0.9459
# Epoch 75/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.7925e-04 - Accuracy: 0.9662 - val_loss: 4.4978e-04 - val_Accuracy: 0.9784
# Epoch 76/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.5812e-04 - Accuracy: 0.9676 - val_loss: 4.0960e-04 - val_Accuracy: 0.9676
# Epoch 77/90
# 24/24 [==============================] - 0s 14ms/step - loss: 7.1604e-04 - Accuracy: 0.9757 - val_loss: 3.2306e-04 - val_Accuracy: 0.9622
# Epoch 78/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.1885e-04 - Accuracy: 0.9716 - val_loss: 3.2529e-04 - val_Accuracy: 0.9622
# Epoch 79/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.0941e-04 - Accuracy: 0.9703 - val_loss: 3.8626e-04 - val_Accuracy: 0.9730
# Epoch 80/90
# 24/24 [==============================] - 0s 14ms/step - loss: 7.0651e-04 - Accuracy: 0.9730 - val_loss: 8.0493e-04 - val_Accuracy: 0.9514
# Epoch 81/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.3933e-04 - Accuracy: 0.9676 - val_loss: 6.3422e-04 - val_Accuracy: 0.9676
# Epoch 82/90
# 24/24 [==============================] - 0s 14ms/step - loss: 5.8387e-04 - Accuracy: 0.9757 - val_loss: 4.9058e-04 - val_Accuracy: 0.9676
# Epoch 83/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.2369e-04 - Accuracy: 0.9770 - val_loss: 5.1269e-04 - val_Accuracy: 0.9784
# Epoch 84/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.9904e-04 - Accuracy: 0.9689 - val_loss: 4.7743e-04 - val_Accuracy: 0.9568
# Epoch 85/90
# 24/24 [==============================] - 0s 14ms/step - loss: 5.4142e-04 - Accuracy: 0.9770 - val_loss: 5.0299e-04 - val_Accuracy: 0.9892
# Epoch 86/90
# 24/24 [==============================] - 0s 14ms/step - loss: 5.2439e-04 - Accuracy: 0.9743 - val_loss: 3.6467e-04 - val_Accuracy: 0.9676
# Epoch 87/90
# 24/24 [==============================] - 0s 14ms/step - loss: 4.9175e-04 - Accuracy: 0.9757 - val_loss: 3.5182e-04 - val_Accuracy: 0.9568
# Epoch 88/90
# 24/24 [==============================] - 0s 14ms/step - loss: 5.3777e-04 - Accuracy: 0.9784 - val_loss: 4.5231e-04 - val_Accuracy: 0.9676
# Epoch 89/90
# 24/24 [==============================] - 0s 14ms/step - loss: 5.2503e-04 - Accuracy: 0.9757 - val_loss: 6.1768e-04 - val_Accuracy: 0.9459
# Epoch 90/90
# 24/24 [==============================] - 0s 14ms/step - loss: 5.4154e-04 - Accuracy: 0.9703 - val_loss: 2.9066e-04 - val_Accuracy: 0.9892

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(Alex4.predict(x_test)), squared=True)
# mean_absolute_error(scalar.inverse_transform(y_test), scalar.inverse_transform(Alex4.predict(x_test)))
# Out:
# 6.539924991379396

# %%
# Alex4.save(f'model/CNN_val_acc_96_48_MSEperAcc.{int(time.time())}.h5')

# %%
plt.close()
plt.plot(Alex_history.history['loss'], label='Training Loss')
plt.plot(Alex_history.history['val_loss'], label='Validation Loss')
plt.plot(Alex_history.history['Accuracy'], label='Training Accuracy')
plt.plot(Alex_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## NIN
# (This is prelimnary, changes are underway for a better accuracy)

# %%
'''''''''
def nin_block(num_channels, kernel_size, strides, padding):
    return Sequential([
        tf.keras.layers.Conv2D(num_channels, kernel_size, strides=strides,
                               padding=padding, activation='relu'),
        tf.keras.layers.Conv2D(num_channels, kernel_size=1,
                               activation='relu'),
        tf.keras.layers.Conv2D(num_channels, kernel_size=1,
                               activation='relu')])


def net():
    return Sequential([
        nin_block(96, kernel_size=11, strides=4, padding='valid'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        nin_block(256, kernel_size=5, strides=1, padding='same'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        nin_block(384, kernel_size=3, strides=1, padding='same'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Dropout(0.5),
       
        nin_block(10, kernel_size=3, strides=1, padding='same'),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Flatten(),
        ])


lr, num_epochs, batch_size = 0.1, 10, 128
model= net()
model.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])
model.fit(x_train, y_train, lr,num_epochs, batch_size)
''''''''''
# Out:
#   File "<ipython-input-56-5e22d1eed6dc>", line 32
#     ''''''''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
nin= Sequential()

nin.add(Conv1D(filters=96, kernel_size=5, strides=2, activation='relu', input_shape=(100,4), padding='same'))
nin.add(Conv1D( filters=96,kernel_size=1,activation='relu',padding='same'))
nin.add(Conv1D(filters=96,kernel_size=1,activation='relu', padding='same'))

nin.add(MaxPooling1D(pool_size=3, strides=2 ))

nin.add(Conv1D(filters=256, kernel_size=5, strides=2, activation='relu', padding='same'))
nin.add(Conv1D(filters=256, kernel_size=1, activation='relu',padding='same'))
nin.add(Conv1D(filters=256, kernel_size=1, activation='relu', padding='same'))

nin.add(MaxPooling1D(pool_size=3, strides= 2))
nin.add(Dropout(0.5))

nin.add(Conv1D(filters=384, kernel_size=3, strides=2, activation='relu', padding='same'))
nin.add(Conv1D(filters=384, kernel_size=1,  activation='relu',padding='same'))
nin.add(Conv1D(filters=384, kernel_size=1,  activation='relu', padding='same'))

nin.add(MaxPooling1D(pool_size=3, strides= 2))


nin.add(Conv1D(filters=2, kernel_size=3, strides=2, activation='relu', padding='same'))
nin.add(Conv1D(filters=2, kernel_size=1, activation='relu',padding='same'))
nin.add(Conv1D(filters=2, kernel_size=1, activation='relu', padding='same'))

nin.add(GlobalAveragePooling1D())
nin.add(Flatten())

nin.summary()
nin.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the cnn_model
nin_act=nin.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 50, 96)            2016
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 50, 96)            9312
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 50, 96)            9312
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 24, 96)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 12, 256)           123136
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 12, 256)           65792
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 12, 256)           65792
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 5, 256)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 256)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 3, 384)            295296
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 3, 384)            147840
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 3, 384)            147840
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 1, 384)            0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 1, 2)              2306
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 1, 2)              6
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 1, 2)              6
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 2)                 0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2)                 0
# =================================================================
# Total params: 868,654
# Trainable params: 868,654
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 24/24 [==============================] - 2s 23ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 2/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 3/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 4/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 5/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 6/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 7/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 8/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 9/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 10/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 11/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 12/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 13/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 14/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 15/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 16/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 17/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 18/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 19/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 20/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 21/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 22/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 23/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 24/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 25/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 26/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 27/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 28/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 29/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 30/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 31/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 32/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 33/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 34/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 35/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 36/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 37/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 38/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 39/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 40/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 41/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 42/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 43/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 44/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 45/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 46/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 47/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 48/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 49/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 50/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 51/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 52/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 53/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 54/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 55/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 56/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 57/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 58/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 59/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 60/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 61/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 62/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 63/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 64/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 65/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 66/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 67/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 68/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 69/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 70/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 71/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 72/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 73/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 74/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 75/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 76/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 77/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 78/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 79/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 80/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 81/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 82/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 83/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 84/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 85/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 86/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 87/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 88/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 89/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973
# Epoch 90/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.3436 - Accuracy: 0.5216 - val_loss: 0.3332 - val_Accuracy: 0.4973

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(nin.predict(x_test)), squared=True)

# %%
#nin.summary()
#nin.save('nin.h5')

# %%
plt.close()
plt.plot(nin_act.history['loss'], label='Training Loss')
plt.plot(nin_act.history['val_loss'], label='Validation Loss')
plt.plot(nin_act.history['Accuracy'], label='Training Accuracy')
plt.plot(nin_act.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## VGGNet7

# %%
VGG = Sequential()

VGG.add(Conv1D(filters=28, kernel_size=3, activation='relu', input_shape=(100,4), padding='same'))
VGG.add(Conv1D(filters=28, kernel_size=3, activation='relu', padding='same'))
VGG.add(Conv1D(filters=28, kernel_size=3, activation='relu', padding='same'))

VGG.add(MaxPooling1D(pool_size=14, padding='valid'))

VGG.add(Conv1D(filters=14, kernel_size=2, activation='relu', padding='same'))
VGG.add(Conv1D(filters=14, kernel_size=2, activation='relu', padding='same'))

VGG.add(MaxPooling1D(pool_size=7, padding='valid'))

VGG.add(Conv1D(filters=512,kernel_size=1, activation='relu'))
VGG.add(Conv1D(filters=256,kernel_size=1, activation='relu'))
VGG.add(Conv1D(filters=2,kernel_size=1, activation='relu'))

VGG.add(MaxPooling1D(pool_size=1, padding='valid'))
VGG.add(Flatten())
#VGG.add(Dense(units=256, activation='relu',use_bias='False'))

VGG.summary()
VGG.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])
VGG_act=VGG.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_17 (Conv1D)           (None, 100, 28)           364
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 100, 28)           2380
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 100, 28)           2380
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 7, 28)             0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 7, 14)             798
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 7, 14)             406
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 14)             0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 1, 512)            7680
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 1, 256)            131328
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 1, 2)              514
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 1, 2)              0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2)                 0
# =================================================================
# Total params: 145,850
# Trainable params: 145,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 24/24 [==============================] - 1s 13ms/step - loss: 0.1217 - Accuracy: 0.4568 - val_loss: 0.0956 - val_Accuracy: 0.4973
# Epoch 2/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0871 - Accuracy: 0.4919 - val_loss: 0.0918 - val_Accuracy: 0.6595
# Epoch 3/90
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0804 - Accuracy: 0.5595 - val_loss: 0.0826 - val_Accuracy: 0.5081
# Epoch 4/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0709 - Accuracy: 0.5676 - val_loss: 0.0659 - val_Accuracy: 0.6595
# Epoch 5/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0593 - Accuracy: 0.6014 - val_loss: 0.0562 - val_Accuracy: 0.6432
# Epoch 6/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0486 - Accuracy: 0.6541 - val_loss: 0.0575 - val_Accuracy: 0.6865
# Epoch 7/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0421 - Accuracy: 0.7257 - val_loss: 0.0500 - val_Accuracy: 0.7243
# Epoch 8/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0345 - Accuracy: 0.7703 - val_loss: 0.0360 - val_Accuracy: 0.8270
# Epoch 9/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0259 - Accuracy: 0.8162 - val_loss: 0.0269 - val_Accuracy: 0.8216
# Epoch 10/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0221 - Accuracy: 0.8473 - val_loss: 0.0251 - val_Accuracy: 0.8649
# Epoch 11/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0182 - Accuracy: 0.8689 - val_loss: 0.0227 - val_Accuracy: 0.8649
# Epoch 12/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0173 - Accuracy: 0.8608 - val_loss: 0.0290 - val_Accuracy: 0.8378
# Epoch 13/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0184 - Accuracy: 0.8500 - val_loss: 0.0200 - val_Accuracy: 0.8757
# Epoch 14/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0126 - Accuracy: 0.8676 - val_loss: 0.0161 - val_Accuracy: 0.8595
# Epoch 15/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0107 - Accuracy: 0.8811 - val_loss: 0.0158 - val_Accuracy: 0.8703
# Epoch 16/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0109 - Accuracy: 0.8770 - val_loss: 0.0141 - val_Accuracy: 0.8811
# Epoch 17/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0097 - Accuracy: 0.9014 - val_loss: 0.0157 - val_Accuracy: 0.8703
# Epoch 18/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0096 - Accuracy: 0.8811 - val_loss: 0.0136 - val_Accuracy: 0.8595
# Epoch 19/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0082 - Accuracy: 0.8905 - val_loss: 0.0141 - val_Accuracy: 0.8649
# Epoch 20/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0086 - Accuracy: 0.8932 - val_loss: 0.0117 - val_Accuracy: 0.8811
# Epoch 21/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0076 - Accuracy: 0.9027 - val_loss: 0.0134 - val_Accuracy: 0.9027
# Epoch 22/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0075 - Accuracy: 0.9000 - val_loss: 0.0122 - val_Accuracy: 0.8595
# Epoch 23/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0066 - Accuracy: 0.9054 - val_loss: 0.0107 - val_Accuracy: 0.9081
# Epoch 24/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0066 - Accuracy: 0.9081 - val_loss: 0.0112 - val_Accuracy: 0.8595
# Epoch 25/90
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0057 - Accuracy: 0.9068 - val_loss: 0.0108 - val_Accuracy: 0.8865
# Epoch 26/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0056 - Accuracy: 0.9108 - val_loss: 0.0093 - val_Accuracy: 0.8919
# Epoch 27/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0056 - Accuracy: 0.9135 - val_loss: 0.0097 - val_Accuracy: 0.8865
# Epoch 28/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0055 - Accuracy: 0.9027 - val_loss: 0.0095 - val_Accuracy: 0.9027
# Epoch 29/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0062 - Accuracy: 0.9162 - val_loss: 0.0102 - val_Accuracy: 0.8919
# Epoch 30/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0060 - Accuracy: 0.9095 - val_loss: 0.0089 - val_Accuracy: 0.8973
# Epoch 31/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0050 - Accuracy: 0.9189 - val_loss: 0.0094 - val_Accuracy: 0.9135
# Epoch 32/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0048 - Accuracy: 0.9216 - val_loss: 0.0085 - val_Accuracy: 0.8973
# Epoch 33/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0048 - Accuracy: 0.9189 - val_loss: 0.0083 - val_Accuracy: 0.8973
# Epoch 34/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - Accuracy: 0.9162 - val_loss: 0.0098 - val_Accuracy: 0.9027
# Epoch 35/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0047 - Accuracy: 0.9203 - val_loss: 0.0091 - val_Accuracy: 0.9027
# Epoch 36/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - Accuracy: 0.9230 - val_loss: 0.0081 - val_Accuracy: 0.8973
# Epoch 37/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0035 - Accuracy: 0.9257 - val_loss: 0.0078 - val_Accuracy: 0.8811
# Epoch 38/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0038 - Accuracy: 0.9230 - val_loss: 0.0078 - val_Accuracy: 0.9027
# Epoch 39/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - Accuracy: 0.9324 - val_loss: 0.0082 - val_Accuracy: 0.9027
# Epoch 40/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - Accuracy: 0.9392 - val_loss: 0.0077 - val_Accuracy: 0.9027
# Epoch 41/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - Accuracy: 0.9365 - val_loss: 0.0086 - val_Accuracy: 0.9081
# Epoch 42/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0044 - Accuracy: 0.9230 - val_loss: 0.0098 - val_Accuracy: 0.8919
# Epoch 43/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0036 - Accuracy: 0.9230 - val_loss: 0.0070 - val_Accuracy: 0.9135
# Epoch 44/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - Accuracy: 0.9392 - val_loss: 0.0077 - val_Accuracy: 0.9081
# Epoch 45/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - Accuracy: 0.9405 - val_loss: 0.0070 - val_Accuracy: 0.8919
# Epoch 46/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - Accuracy: 0.9419 - val_loss: 0.0071 - val_Accuracy: 0.9081
# Epoch 47/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - Accuracy: 0.9446 - val_loss: 0.0071 - val_Accuracy: 0.9081
# Epoch 48/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - Accuracy: 0.9419 - val_loss: 0.0071 - val_Accuracy: 0.9081
# Epoch 49/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - Accuracy: 0.9392 - val_loss: 0.0093 - val_Accuracy: 0.9027
# Epoch 50/90
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030 - Accuracy: 0.9405 - val_loss: 0.0075 - val_Accuracy: 0.8973
# Epoch 51/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - Accuracy: 0.9486 - val_loss: 0.0067 - val_Accuracy: 0.9189
# Epoch 52/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - Accuracy: 0.9459 - val_loss: 0.0078 - val_Accuracy: 0.9081
# Epoch 53/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - Accuracy: 0.9459 - val_loss: 0.0093 - val_Accuracy: 0.9081
# Epoch 54/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0028 - Accuracy: 0.9338 - val_loss: 0.0070 - val_Accuracy: 0.9135
# Epoch 55/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - Accuracy: 0.9486 - val_loss: 0.0066 - val_Accuracy: 0.9081
# Epoch 56/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0021 - Accuracy: 0.9419 - val_loss: 0.0076 - val_Accuracy: 0.8973
# Epoch 57/90
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0026 - Accuracy: 0.9446 - val_loss: 0.0073 - val_Accuracy: 0.9135
# Epoch 58/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0020 - Accuracy: 0.9541 - val_loss: 0.0075 - val_Accuracy: 0.9027
# Epoch 59/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - Accuracy: 0.9392 - val_loss: 0.0088 - val_Accuracy: 0.9081
# Epoch 60/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0028 - Accuracy: 0.9392 - val_loss: 0.0062 - val_Accuracy: 0.9297
# Epoch 61/90
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0019 - Accuracy: 0.9541 - val_loss: 0.0060 - val_Accuracy: 0.9135
# Epoch 62/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0017 - Accuracy: 0.9649 - val_loss: 0.0063 - val_Accuracy: 0.9027
# Epoch 63/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0018 - Accuracy: 0.9581 - val_loss: 0.0059 - val_Accuracy: 0.9081
# Epoch 64/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0018 - Accuracy: 0.9514 - val_loss: 0.0061 - val_Accuracy: 0.9189
# Epoch 65/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0025 - Accuracy: 0.9595 - val_loss: 0.0075 - val_Accuracy: 0.9081
# Epoch 66/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0026 - Accuracy: 0.9554 - val_loss: 0.0067 - val_Accuracy: 0.9297
# Epoch 67/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0022 - Accuracy: 0.9473 - val_loss: 0.0067 - val_Accuracy: 0.9081
# Epoch 68/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0019 - Accuracy: 0.9554 - val_loss: 0.0065 - val_Accuracy: 0.9027
# Epoch 69/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0018 - Accuracy: 0.9622 - val_loss: 0.0063 - val_Accuracy: 0.9189
# Epoch 70/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0022 - Accuracy: 0.9541 - val_loss: 0.0071 - val_Accuracy: 0.9189
# Epoch 71/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - Accuracy: 0.9486 - val_loss: 0.0064 - val_Accuracy: 0.9135
# Epoch 72/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0021 - Accuracy: 0.9554 - val_loss: 0.0069 - val_Accuracy: 0.9027
# Epoch 73/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0020 - Accuracy: 0.9662 - val_loss: 0.0060 - val_Accuracy: 0.9135
# Epoch 74/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0019 - Accuracy: 0.9446 - val_loss: 0.0060 - val_Accuracy: 0.9081
# Epoch 75/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0022 - Accuracy: 0.9527 - val_loss: 0.0070 - val_Accuracy: 0.8973
# Epoch 76/90
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0019 - Accuracy: 0.9514 - val_loss: 0.0070 - val_Accuracy: 0.8919
# Epoch 77/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0018 - Accuracy: 0.9419 - val_loss: 0.0060 - val_Accuracy: 0.9297
# Epoch 78/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0014 - Accuracy: 0.9622 - val_loss: 0.0062 - val_Accuracy: 0.9243
# Epoch 79/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0015 - Accuracy: 0.9473 - val_loss: 0.0057 - val_Accuracy: 0.9243
# Epoch 80/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0014 - Accuracy: 0.9568 - val_loss: 0.0065 - val_Accuracy: 0.9135
# Epoch 81/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0017 - Accuracy: 0.9568 - val_loss: 0.0059 - val_Accuracy: 0.9189
# Epoch 82/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0013 - Accuracy: 0.9622 - val_loss: 0.0057 - val_Accuracy: 0.9189
# Epoch 83/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0011 - Accuracy: 0.9703 - val_loss: 0.0058 - val_Accuracy: 0.9351
# Epoch 84/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0014 - Accuracy: 0.9622 - val_loss: 0.0065 - val_Accuracy: 0.9081
# Epoch 85/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0015 - Accuracy: 0.9541 - val_loss: 0.0070 - val_Accuracy: 0.9135
# Epoch 86/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0014 - Accuracy: 0.9527 - val_loss: 0.0056 - val_Accuracy: 0.9243
# Epoch 87/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0013 - Accuracy: 0.9716 - val_loss: 0.0053 - val_Accuracy: 0.9351
# Epoch 88/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0012 - Accuracy: 0.9716 - val_loss: 0.0055 - val_Accuracy: 0.9243
# Epoch 89/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0012 - Accuracy: 0.9676 - val_loss: 0.0064 - val_Accuracy: 0.9027
# Epoch 90/90
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0016 - Accuracy: 0.9581 - val_loss: 0.0054 - val_Accuracy: 0.9351

# %% [markdown]
# VGG Plot

# %%
plt.close()
plt.plot(VGG_act.history['loss'], label='Training Loss')
plt.plot(VGG_act.history['val_loss'], label='Validation Loss')
plt.plot(VGG_act.history['Accuracy'], label='Training Accuracy')
plt.plot(VGG_act.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# #### Old CNN Model

# %%
# reg = tf.keras.regularizers.L2(0.01)

cnn_model = Sequential()
# create a CNN cnn_model
cnn_model.add(Conv1D(filters=224, kernel_size=3, activation='relu', input_shape=(100,4)))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.25))
cnn_model.add(Conv1D(filters=384, kernel_size=3, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Conv1D(filters=384, kernel_size=3, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))

cnn_model.add(Flatten())

cnn_model.add(Dense(units=32, activation='sigmoid'))
cnn_model.add(Dense(units=480, activation='relu'))
cnn_model.add(Dense(units=2, activation='linear'))
cnn_model.summary()
3
# Compile cnn_model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

cnn_model.compile(loss = 'mse', optimizer = 'RMSprop', metrics=['Accuracy'])

# Fit the cnn_model
cnn_history = cnn_model.fit(x_train, y_train, epochs=80, verbose=1, batch_size=32, validation_data=(x_test, y_test))

# %%
plt.close()
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.plot(cnn_history.history['Accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.legend()
plt.show()

# %%
msecnn=mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(cnn_model.predict(x_test)), squared=False)

# %%
# cnn_save = cnn_model.save(f'model/cnn_model_98-7perAcc.{int(time.time())}.h5')

# %%
# cnn_98 = tf.keras.models.load_model('CNN_98_1.h5')

# %% [markdown]
# #### SVR Model

# %%
X = train_resample
y = training_labels

# create split data from the normalized data
size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {len(x_train)} length of labels - {len(y_train)} \nLength of test data - {len(x_test)} and length of labels - {len(y_test)}')

x_train_flat = []
for i in range(len(x_train)):    
    x_dummy = np.asarray(x_train[i]).flatten()
    x_train_flat.append(x_dummy)
    
x_train_flat = np.asarray(x_train_flat)

x_test_flat = []
for i in range(len(x_test)):    
    x_dummy = np.asarray(x_test[i]).flatten()
    x_test_flat.append(x_dummy)
    
x_test_flat = np.asarray(x_test_flat)

print(np.asarray(x_train_flat).shape, np.asarray(y_train).shape)

# %%
regr_multirf = MultiOutputRegressor(svm.SVR(kernel='rbf', C=1e3, epsilon=0.2, tol=1e-6))
regr_multirf.fit(x_train_flat, y_train)

y_pred = regr_multirf.predict(x_test_flat)
y_test-y_pred

# %%
svrrmse= mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# #### KNN Model

# %%
X = train_resample
y = training_labels

exp_val_X = ex_val_resample
exp_val_y = ex_val_labels

scalar = MinMaxScaler()
y_norm = scalar.fit_transform(training_labels)

print(np.asarray(X).shape, np.asarray(y).shape)

# create split data from the normalized data
size = 0.1
x_train, x_test, y_train, y_test = train_test_split(X, y_norm, shuffle=True, test_size=size)
print(f'Length of training data - {np.asarray(x_train).shape} length of labels - {np.asarray(y_train).shape} \nLength of test data - {np.asarray(x_test).shape} and length of labels - {np.asarray(y_test).shape}')

# %%
x_train_flat = []
for i in range(len(x_train)):    
    x_dummy = np.asarray(x_train[i]).flatten()
    x_train_flat.append(x_dummy)
    
x_train_flat = np.asarray(x_train_flat)

x_test_flat = []
for i in range(len(x_test)):    
    x_dummy = np.asarray(x_test[i]).flatten()
    x_test_flat.append(x_dummy)
    
x_test_flat = np.asarray(x_test_flat)

exp_val_X_flat = []
for i in range(len(exp_val_X)):
    x_dummy = np.asarray(exp_val_X[i]).flatten()
    exp_val_X_flat.append(x_dummy)

exp_val_X_flat = np.asarray(exp_val_X_flat)

print(np.asarray(x_train_flat).shape, np.asarray(y_train).shape)
print(x_test_flat.shape, y_test.shape)
print(exp_val_X_flat.shape, exp_val_y.shape)

# %%
knn = KNeighborsRegressor(n_neighbors=5, weights='distance')
knn.fit(x_train_flat, y_train)
y_pred = knn.predict(x_test_flat)
y_test-y_pred

# %%
from math import sqrt
y_test=scalar.inverse_transform(y_test)
y_pred=scalar.inverse_transform(y_pred)
KNNrmse=sqrt(mean_squared_error(y_test,y_pred))

# %%
y_pred_exp = knn.predict(exp_val_X_flat)
y_pred_exp = scalar.inverse_transform(y_pred_exp)

exp_val_y-y_pred_exp

# %% [markdown]
# #### Predict experimental data validation

# %%
# model = tf.keras.models.load_model('model/tunedModel_98perAcc.1640573960.h5')
# model = tf.keras.models.load_model('Alex3.h5')
# model = tf.keras.models.load_model('model/CNN_val_acc_96_48_MSEperAcc.1642513870.h5')
# model.summary()

# %%
y_pred = Alex4.predict(np.asarray(ex_val_resample))
y_abs = ex_val_labels

y_pred = scalar.inverse_transform(np.asarray(y_pred))
diff = y_abs-y_pred
for i in range(len(y_pred)):
    print(f'Absolute Trial {ex_val_trails[i]}- {y_abs[i]} Predicted - {y_pred[i]} \tDifference - {y_abs[i] - y_pred[i]}')

# %%
mean_squared_error(y_abs, y_pred, squared=True)
# mean_absolute_error(y_abs, y_pred)

# %% [markdown]
# #### Experimental Group Data

# %%
y_pred_g7 = Alex4.predict(np.asarray(ex_resample))
y_pred_g7 = scalar.inverse_transform(y_pred_g7)
y_pred_g7

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharey=True)

ex_c = 10 # Given validation folder has 18 data points. so use - (0, 1, .... , 17)

# find out the index of the validation set in the training data
p = []

for i in range (len(y_pred_g7)):
    xi = np.where(training_labels[:,0] == min(training_labels[:,0], key=lambda x:abs(x-y_pred_g7[i][0])))[0]
    yi = np.where(training_labels[:,1] == min(training_labels[:,1], key=lambda x:abs(x-y_pred_g7[i][1])))[0]
    pi = np.intersect1d(xi, yi)[0]
    
    p.append(pi)

# plot to compare the validation set with the training set
fig.suptitle(f'Closest Training Data Coordinates - {training_labels[p[ex_c]]} \nExperimental Predicted Coordinates - {y_pred_g7[ex_c]}')

axs[0,0].plot(training[p[ex_c]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[p[ex_c]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[p[ex_c]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[p[ex_c]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(ex_cut_data[ex_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(ex_cut_data[ex_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(ex_cut_data[ex_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(ex_cut_data[ex_c][:,4], label='P - 4', c = 'y')

# fig.legend()
plt.show()

# %% [markdown]
# #### -- Check -- prediction for augmentation validation data

# %%
c = []
checking1 = validation_aug[0][:,1:5]
checking1 = minmax_scale(checking1)
checking1 = resample(checking1, 100)

checking2 = validation_aug[1][:,1:5]
checking2 = minmax_scale(checking2)
checking2 = resample(checking2, 100)

checking3 = validation_aug[2][:,1:5]
checking3 = minmax_scale(checking3)
checking3 = resample(checking3, 100)

checking4 = validation_aug[3][:,1:5]
checking4 = minmax_scale(checking4)
checking4 = resample(checking4, 100)

c.append(checking1)
c.append(checking2)
c.append(checking3)
c.append(checking4)

'''
plt.close()
plt.title(f'Validation Data {validation_aug_labels[0]}')
plt.plot(checking1[:,0], label = 'P - 1')
plt.plot(checking1[:,1], label = 'P - 2')
plt.plot(checking1[:,2], label = 'P - 3')
plt.plot(checking1[:,3], label = 'P - 4')
plt.legend()
plt.show()
'''

# %%
print(f'{validation_aug_labels[0]} \n{validation_aug_labels[1]} \n{validation_aug_labels[2]} \n{validation_aug_labels[3]}')

p = Alex4.predict(np.asarray(c))
p = scalar.inverse_transform(p)
print(p)

error = []
for i in range(0, len(p)):
    a = validation_aug_labels[i][0]-p[i][0]
    b = validation_aug_labels[i][1]-p[i][1]
    e = [a, b]
    error.append(e)

print(f'Difference between the actual and predicted coordinates: \n{np.asarray(error)}')

# %% [markdown]
# #### Plot for RMSE

# %%
import matplotlib.pyplot as plt
height = [dnnmse, msecnn, KNNrmse, svrrmse ]
bars = ('DNN','1D_CNN', 'KNN', 'SVR')
y_pos = np.arange(len(bars))


# Create bars

label = ['rmse= msecnn', 'rmse=svrrmse', 'rmse= msecnn']
plt.bar(y_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'], width=0.4)

plt.xlabel("Models", size=14)
# Setting the label for y-axis
plt.ylabel("RMSE value", size=14)

plt.xticks(y_pos, bars)
plt.savefig('models.png')
# Show graphic
plt.show()
