# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
print(tf.__version__)
# Out:
# 2.3.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# ### Read csv files and Process the Dataset

# %% [markdown]
# We read the accelerometer reading of Smartphone 4, of the Subjects 125,126,127,128 and 129. Each subject had 3 normal and 3 impaired csv files for Smartphone 4 location. So total for 5 subjects 15 Normal and 15 Impaired csv files.
#
# For loop was used initially, however the processing time was more. Hence the files were read individually for Normal and Impaired csv files.

# %%
normal_1= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject125_normal01\Accelerometer.csv")
normal_2= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject125_normal02\Accelerometer.csv")
normal_3= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject125_normal03\Accelerometer.csv")
normal_4= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject126_normal01\Accelerometer.csv")
normal_5= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject126_normal02\Accelerometer.csv")
normal_6= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject126_normal03\Accelerometer.csv")
normal_7= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject127_normal01\Accelerometer.csv")
normal_8= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject127_normal02\Accelerometer.csv")
normal_9= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject127_normal03\Accelerometer.csv")
normal_10= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject128_normal01\Accelerometer.csv")
normal_11= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject128_normal02\Accelerometer.csv")
normal_12= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject128_normal03\Accelerometer.csv")
normal_13= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject129_normal01\Accelerometer.csv")
normal_14= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject129_normal02\Accelerometer.csv")
normal_15= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Normal\subject129_normal03\Accelerometer.csv")

normal_data = pd.concat([normal_1, normal_2, normal_3, normal_4, normal_5, normal_6, normal_7, normal_8, normal_9, normal_10, normal_11, normal_12, normal_13, normal_14, normal_15])

normal.head()
# Out:
#    Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0  0.000000                0.086191                7.232883
# 1  0.001984                2.207454                2.901772
# 2  0.004028                4.228160                0.919373
# 3  0.006012                5.008670               -2.619257
# 4  0.007996                5.985504               -5.355829
#
#    Acceleration z (m/s^2)
# 0               13.012486
# 1               15.387534
# 2               15.540763
# 3               14.714764
# 4               12.109872

# %%
normal.shape
# Out:
# (163062, 4)

# %%
impaired_1= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject125_impaired01\Accelerometer.csv")
impaired_2= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject125_impaired02\Accelerometer.csv")
impaired_3= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject125_impaired03\Accelerometer.csv")
impaired_4= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject126_impaired01\Accelerometer.csv")
impaired_5= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject126_impaired02\Accelerometer.csv")
impaired_6= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject126_impaired03\Accelerometer.csv")
impaired_7= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject127_impaired01\Accelerometer.csv")
impaired_8= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject127_impaired02\Accelerometer.csv")
impaired_9= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject127_impaired03\Accelerometer.csv")
impaired_10= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject128_impaired01\Accelerometer.csv")
impaired_11= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject128_impaired02\Accelerometer.csv")
impaired_12= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject128_impaired03\Accelerometer.csv")
impaired_13= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject129_impaired01\Accelerometer.csv")
impaired_14= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject129_impaired02\Accelerometer.csv")
impaired_15= pd.read_csv(r"C:\Users\siddhanthshah\Desktop\Impaired\subject129_impaired03\Accelerometer.csv")

impaired_data = pd.concat([impaired_1, impaired_2, impaired_3, impaired_4, impaired_5, impaired_6, impaired_7, impaired_8, impaired_9, impaired_10, impaired_11, impaired_12, impaired_13, impaired_14, impaired_15])

impaired.head()
# Out:
#    Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0  0.000000               -1.865083               -2.406173
# 1  0.002014               -1.838747               -2.499547
# 2  0.003998               -1.795651               -2.705448
# 3  0.005981               -1.781286               -2.956839
# 4  0.007935               -1.728614               -3.107674
#
#    Acceleration z (m/s^2)
# 0                0.663194
# 1                0.797269
# 2                1.086968
# 3                1.388637
# 4                1.558625

# %%
impaired.shape
# Out:
# (162064, 4)

# %% [markdown]
# ### Renaming of the Columns

# %% [markdown]
# Renaming the column names for our convenience. Also the operations on the columns can then be easily performed.

# %%
normal.columns
impaired.columns
# Out:
# Index(['Time (s)', 'Acceleration x (m/s^2)', 'Acceleration y (m/s^2)',
#        'Acceleration z (m/s^2)'],
#       dtype='object')

# %%
normal.rename(columns = {'Time (s)':'time', 'Acceleration x (m/s^2)':'x', 'Acceleration y (m/s^2)':'y', 'Acceleration z (m/s^2)':'z'}, inplace = True)
impaired.rename(columns = {'Time (s)':'time', 'Acceleration x (m/s^2)':'x', 'Acceleration y (m/s^2)':'y', 'Acceleration z (m/s^2)':'z'}, inplace = True)
normal.columns
impaired.columns
# Out:
# Index(['time', 'x', 'y', 'z'], dtype='object')

# %% [markdown]
# ### Adding 'type' column

# %% [markdown]
# Adding the 'type' column to both the dataset with values 'normal' for the normal dataset and 'impaired' for the impaired dataset. This is done so that the labelling operation can be performed on the dataset assigning particular numerical values.

# %%
normal['type'] = "normal"
normal.head()
# Out:
#        time         x         y          z    type
# 0  0.000000  0.086191  7.232883  13.012486  normal
# 1  0.001984  2.207454  2.901772  15.387534  normal
# 2  0.004028  4.228160  0.919373  15.540763  normal
# 3  0.006012  5.008670 -2.619257  14.714764  normal
# 4  0.007996  5.985504 -5.355829  12.109872  normal

# %%
normal.shape
# Out:
# (163062, 5)

# %%
impaired['type'] = "impaired"
impaired.head()
# Out:
#        time         x         y         z      type
# 0  0.000000 -1.865083 -2.406173  0.663194  impaired
# 1  0.002014 -1.838747 -2.499547  0.797269  impaired
# 2  0.003998 -1.795651 -2.705448  1.086968  impaired
# 3  0.005981 -1.781286 -2.956839  1.388637  impaired
# 4  0.007935 -1.728614 -3.107674  1.558625  impaired

# %%
impaired.shape
# Out:
# (162064, 5)

# %% [markdown]
# ### Concatenate both the datasets

# %% [markdown]
# Since we need to split the dataset in the further steps in a sample-wise or record-wise manner, we concatenate both the datasets containing both thr normal and impaired values for every subject.

# %%
data = pd.concat([normal, impaired])
data.shape
# Out:
# (325126, 5)

# %% [markdown]
# ### Checking the data type of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325126 entries, 0 to 6071
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    325126 non-null  float64
#  1   x       300984 non-null  float64
#  2   y       300984 non-null  float64
#  3   z       300984 non-null  float64
#  4   type    325126 non-null  object
# dtypes: float64(4), object(1)
# memory usage: 14.9+ MB

# %% [markdown]
# ### Checking for null values and other noise

# %%
data.isnull().sum()
# Out:
# time        0
# x       24142
# y       24142
# z       24142
# type        0
# dtype: int64

# %%
data[data.x.isnull()]
# Out:
#            time   x   y   z      type
# 0      0.000000 NaN NaN NaN    normal
# 1      0.009979 NaN NaN NaN    normal
# 2      0.019928 NaN NaN NaN    normal
# 3      0.029907 NaN NaN NaN    normal
# 4      0.039856 NaN NaN NaN    normal
# ...         ...  ..  ..  ..       ...
# 4059  40.439680 NaN NaN NaN  impaired
# 4060  40.449659 NaN NaN NaN  impaired
# 4061  40.459608 NaN NaN NaN  impaired
# 4062  40.469587 NaN NaN NaN  impaired
# 4063  40.479536 NaN NaN NaN  impaired
#
# [24142 rows x 5 columns]

# %% [markdown]
# ### Dropping the rows that contain noise / Filtering noise

# %% [markdown]
# We drop the rows which contain noise or null values so that we get uniform and structured dataset.

# %%
data1 = data.dropna(how = "any")
data1.shape
# Out:
# (300984, 5)

# %%
sampling_rate = 1
types = data1['type'].value_counts().index
types
# Out:
# Index(['normal', 'impaired'], dtype='object')

# %% [markdown]
# ### Extracting motion sequence

# %% [markdown]
# We plot both the datasets after removal of noise to check of any other descrepency is still there in the data.

# %%
def plot_activity(type, data):
    fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(15, 7), sharex=True)
    plot_axis(ax0, data['time'], data['x'], 'X-Axis')
    plot_axis(ax1, data['time'], data['y'], 'Y-Axis')
    plot_axis(ax2, data['time'], data['z'], 'Z-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(type)
    plt.subplots_adjust(top=0.90)
    plt.show()

def plot_axis(ax, x, y, title):
    ax.plot(x, y, 'g')
    ax.set_title(title)
    ax.xaxis.set_visible(True)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for type in types:
    data_for_plot = data[(data['type'] == type)][:sampling_rate*10000]
    plot_activity(type, data_for_plot)

# %%
data1['type'].value_counts()
# Out:
# normal      151102
# impaired    149882
# Name: type, dtype: int64

# %% [markdown]
# ### Dropping the 'time' column to remove time dependency

# %% [markdown]
# We drop the 'time' column from the dataset so that we remove the time dependency of our data.

# %%
df = data1.drop(['time'], axis = 1).copy()
df.head()
# Out:
#           x         y          z    type
# 0  0.086191  7.232883  13.012486  normal
# 1  2.207454  2.901772  15.387534  normal
# 2  4.228160  0.919373  15.540763  normal
# 3  5.008670 -2.619257  14.714764  normal
# 4  5.985504 -5.355829  12.109872  normal

# %% [markdown]
# ### Balancing of the dataset

# %% [markdown]
# We take equal number of datapoints from both the datasets so that we can have equal number of datapoints for the processing. If we use this data directly then there is a possibility of Overfitting.

# %%
impaired1 = df[df['type'] == 'impaired'].head(149882).copy()
normal1 = df[df['type'] == 'normal'].head(149882).copy()

# %%
balanced_data = pd.DataFrame()
balanced_data = balanced_data.append([impaired1, normal1])
balanced_data.shape
# Out:
# (299764, 4)

# %%
balanced_data['type'].value_counts()
# Out:
# impaired    149882
# normal      149882
# Name: type, dtype: int64

# %% [markdown]
# ### Labelling the dataset

# %% [markdown]
# We label the dataset. For impaired values 0 is assigned and for normal values 1 is assigned. This helps in removing the dependency of the model from 'string' datatype to purely numerical datatype. As we can see, the values in 'type' are of data type string. We will convert them into numeric values using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()
balanced_data['label'] = label.fit_transform(balanced_data['type'])
balanced_data.head()
# Out:
#           x         y         z      type  label
# 0 -1.865083 -2.406173  0.663194  impaired      0
# 1 -1.838747 -2.499547  0.797269  impaired      0
# 2 -1.795651 -2.705448  1.086968  impaired      0
# 3 -1.781286 -2.956839  1.388637  impaired      0
# 4 -1.728614 -3.107674  1.558625  impaired      0

# %%
label.classes_
# Out:
# array(['impaired', 'normal'], dtype=object)

# %% [markdown]
# ### Standardization of Data and Principal Component Analysis

# %% [markdown]
# We standardize our dataset using the Standard Scaler function. We use the scaled data for our Principal Component Analysis (PCA) or the rotation of the data. We use PCA for reducing the dimensionality of our dataset and increasing the interpretability but at the same time minimizing information loss.

# %%
X = balanced_data[['x', 'y', 'z']]
y = balanced_data['label']

# %%
df1 = pd.DataFrame(data = X, columns = ['x', 'y', 'z'])
df1['label'] = y.values

scaler = StandardScaler()
scaler.fit(df1)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(df1)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

# %%
x_pca = pca.fit_transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (299764, 4)

# %%
x_pca.shape
# Out:
# (299764, 2)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_pca[:,0], x_pca[:,1], c = balanced_data['label'], cmap = 'viridis', alpha = 0.3)
plt.title('Principal Component Analysis')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

plt.show()

plt.savefig('PCA.png')

# %% [markdown]
# ### Frame Preparation

# %% [markdown]
# We consider 40 observations at a time and a hop size of 20. Since we have 149882 observations in each dataset, i.e total 299764 observations. This divided by the hop size gives us the number of frames in the dataset i.e approximately 14987.

# %%
import scipy.stats as stats

# %%
sampling_rate = 1
frame_size = sampling_rate * 40 
hop_size = sampling_rate * 20

# %%
def get_frames(df, frame_size, hop_size):

    N_FEATURES = 3

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, hop_size):
        x = df['x'].values[i: i + frame_size]
        y = df['y'].values[i: i + frame_size]
        z = df['z'].values[i: i + frame_size]
        
        # Retrieve the most often used label in this segment
        label = stats.mode(df['label'][i: i + frame_size])[0][0]
        frames.append([x, y, z])
        labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

X, y = get_frames(df1, frame_size, hop_size)

X.shape, y.shape
# Out:
# ((14987, 40, 3), (14987,))

# %% [markdown]
# ### Splitting the dataset

# %% [markdown]
# Here we divide the data into training data and test data using test_train_split()/ We rae going to use 80% of our data for training the model and 20% of the data for testing. We can see that we have got 11989 samples in training dataset and 2998 samples in test dataset.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True)

# %%
X_train.shape, X_test.shape
# Out:
# ((11989, 40, 3), (2998, 40, 3))

# %%
X_train[0].shape, X_test[0].shape
# Out:
# ((40, 3), (40, 3))

# %% [markdown]
# ### Reshaping the data

# %% [markdown]
# Our entire data is 3-Dimensional but each sample in the data is 2-Dimensional. The Neural Network Model accepts the data in 3-Dimensions. Hence we are going to reshape our data.

# %%
X_train = X_train.reshape(11989, 40, 3, 1)
X_test = X_test.reshape(2998, 40, 3, 1)

# %%
X_train[0].shape, X_test[0].shape
# Out:
# ((40, 3, 1), (40, 3, 1))

# %% [markdown]
# ### K-Fold Cross Validation Model using Neural Networks.

# %% [markdown]
# We use K-Fold Cross Validation model for 10 splits i.e for each split, the same model is trained, and performance is displayed per fold. In our scenario we train the model 10 times.

# %%
from sklearn.model_selection import KFold

# %%
num_folds = 10

#Normalize the data
#X_train = X_train / 255
#y_test = y_test / 255

#Define per-fold score conatiners
accuracy_per_fold = []
loss_per_fold = []

# %%
# Merge train and tests
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %%
# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True)

# %%
# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets):

  # Define the model architecture
  model = Sequential()
  model.add(Conv2D(16, kernel_size=(2, 2), activation='relu', input_shape = X_train[0].shape))
  model.add(Dropout(0.1))
  
  model.add(Conv2D(32, kernel_size=(2, 2), activation='relu'))
  model.add(Dropout(0.2))

  model.add(Flatten())
    
  model.add(Dense(64, activation='relu'))
  model.add(Dropout(0.5))
  #model.add(Dense(128, activation='relu'))
  model.add(Dense(6, activation='softmax'))

  # Compile the model
  model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])


  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  # Fit data to model
  history = model.fit(inputs[train], targets[train], batch_size=50, epochs=25, verbose=1)
 
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  accuracy_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.7017 - accuracy: 0.6172
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6212 - accuracy: 0.6414
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6083 - accuracy: 0.6518
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6004 - accuracy: 0.6592
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5913 - accuracy: 0.6610
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5833 - accuracy: 0.6751
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5719 - accuracy: 0.6802
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5670 - accuracy: 0.6819
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5565 - accuracy: 0.6858
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5529 - accuracy: 0.6870
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5469 - accuracy: 0.6883
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5431 - accuracy: 0.6917
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5314 - accuracy: 0.7014
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5304 - accuracy: 0.7023
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5231 - accuracy: 0.7105
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5108 - accuracy: 0.7175
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5029 - accuracy: 0.7216
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5069 - accuracy: 0.7269
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4996 - accuracy: 0.7315
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4890 - accuracy: 0.7395
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4827 - accuracy: 0.7424
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4813 - accuracy: 0.7427
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4731 - accuracy: 0.7478
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4730 - accuracy: 0.7510
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4631 - accuracy: 0.7562
# Score for fold 1: loss of 0.4392538070678711; accuracy of 77.98532247543335%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.7248 - accuracy: 0.6068
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6337 - accuracy: 0.6307
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6191 - accuracy: 0.6423
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6118 - accuracy: 0.6475
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6037 - accuracy: 0.6514
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5968 - accuracy: 0.6588
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5896 - accuracy: 0.6646
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5847 - accuracy: 0.6628
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5783 - accuracy: 0.6696
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5692 - accuracy: 0.6730: 0s - loss: 0
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5637 - accuracy: 0.6856
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5606 - accuracy: 0.6853
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5540 - accuracy: 0.6881
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5475 - accuracy: 0.6948
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5363 - accuracy: 0.7083
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5353 - accuracy: 0.7069
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5350 - accuracy: 0.7066
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5275 - accuracy: 0.7114
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5194 - accuracy: 0.7152
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5205 - accuracy: 0.7133
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5154 - accuracy: 0.7159
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5089 - accuracy: 0.7275
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5080 - accuracy: 0.7241
# Epoch 24/25
# 270/270 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.72 - 1s 4ms/step - loss: 0.5013 - accuracy: 0.7288
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4982 - accuracy: 0.7292
# Score for fold 2: loss of 0.4532725214958191; accuracy of 77.58505940437317%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.7225 - accuracy: 0.6160
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6278 - accuracy: 0.6408
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6140 - accuracy: 0.6429
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6048 - accuracy: 0.6498: 0s - loss: 0.6063 -
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5962 - accuracy: 0.6618
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5871 - accuracy: 0.6614
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5808 - accuracy: 0.6630
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5709 - accuracy: 0.6735
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5664 - accuracy: 0.6753
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5560 - accuracy: 0.6808
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5517 - accuracy: 0.6897
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5426 - accuracy: 0.6985
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5377 - accuracy: 0.7001
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5321 - accuracy: 0.7059
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5264 - accuracy: 0.7109
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5212 - accuracy: 0.7177
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5157 - accuracy: 0.7218
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5106 - accuracy: 0.7252
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5021 - accuracy: 0.7296
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4930 - accuracy: 0.7337
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4950 - accuracy: 0.7318
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4930 - accuracy: 0.7322
# Epoch 23/25
# 270/270 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.73 - 1s 4ms/step - loss: 0.4913 - accuracy: 0.7348
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4777 - accuracy: 0.7434
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4779 - accuracy: 0.7478
# Score for fold 3: loss of 0.4409685432910919; accuracy of 77.98532247543335%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6970 - accuracy: 0.6187
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6286 - accuracy: 0.6395
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6107 - accuracy: 0.6421
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6029 - accuracy: 0.6546
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5969 - accuracy: 0.6584
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5848 - accuracy: 0.6682
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5758 - accuracy: 0.6773
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5674 - accuracy: 0.6874
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5583 - accuracy: 0.6916
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5484 - accuracy: 0.6991
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5397 - accuracy: 0.7051
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5362 - accuracy: 0.7019
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5280 - accuracy: 0.7091
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5244 - accuracy: 0.7152
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5165 - accuracy: 0.7190
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5030 - accuracy: 0.7303
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5048 - accuracy: 0.7257
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5021 - accuracy: 0.7327
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4955 - accuracy: 0.7306
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4989 - accuracy: 0.7347
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4840 - accuracy: 0.7435
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4824 - accuracy: 0.7467
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4801 - accuracy: 0.7467
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4715 - accuracy: 0.7500
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4703 - accuracy: 0.7542
# Score for fold 4: loss of 0.44204363226890564; accuracy of 77.0513653755188%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.7436 - accuracy: 0.6097
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6298 - accuracy: 0.6389
# Epoch 3/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6177 - accuracy: 0.6453
# Epoch 4/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6078 - accuracy: 0.6545
# Epoch 5/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5987 - accuracy: 0.6624
# Epoch 6/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5959 - accuracy: 0.6655
# Epoch 7/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5817 - accuracy: 0.6780
# Epoch 8/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5757 - accuracy: 0.6756
# Epoch 9/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5682 - accuracy: 0.6871
# Epoch 10/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5606 - accuracy: 0.6879
# Epoch 11/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5586 - accuracy: 0.6914
# Epoch 12/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5490 - accuracy: 0.6968
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5385 - accuracy: 0.7077
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5374 - accuracy: 0.7079
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5257 - accuracy: 0.7172
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5197 - accuracy: 0.7212
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5130 - accuracy: 0.7228
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5082 - accuracy: 0.7320
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5056 - accuracy: 0.7302
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4971 - accuracy: 0.7336
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4890 - accuracy: 0.7400
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4867 - accuracy: 0.7390
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4800 - accuracy: 0.7438
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4774 - accuracy: 0.7485
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4726 - accuracy: 0.7487
# Score for fold 5: loss of 0.42267119884490967; accuracy of 79.11941409111023%
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6943 - accuracy: 0.6226
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6176 - accuracy: 0.6523
# Epoch 3/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6091 - accuracy: 0.6510
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6012 - accuracy: 0.6533
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5958 - accuracy: 0.6598
# Epoch 6/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5846 - accuracy: 0.6683
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5811 - accuracy: 0.6709
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5751 - accuracy: 0.6750
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5676 - accuracy: 0.6816
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5556 - accuracy: 0.6892
# Epoch 11/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5525 - accuracy: 0.6945
# Epoch 12/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5467 - accuracy: 0.6994
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5389 - accuracy: 0.7031
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5304 - accuracy: 0.7103
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5256 - accuracy: 0.7149
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5235 - accuracy: 0.7174
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5164 - accuracy: 0.7192
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5139 - accuracy: 0.7236
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5095 - accuracy: 0.7309
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5040 - accuracy: 0.7324
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4955 - accuracy: 0.7378
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4882 - accuracy: 0.7397
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4851 - accuracy: 0.7420
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4849 - accuracy: 0.7412
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4740 - accuracy: 0.7446
# Score for fold 6: loss of 0.4580092430114746; accuracy of 76.71781182289124%
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6843 - accuracy: 0.6193
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6227 - accuracy: 0.6466
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6114 - accuracy: 0.6532
# Epoch 4/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5976 - accuracy: 0.6595
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5939 - accuracy: 0.6641
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5872 - accuracy: 0.6696
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5799 - accuracy: 0.6749
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5704 - accuracy: 0.6779
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5621 - accuracy: 0.6885
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5579 - accuracy: 0.6888
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5508 - accuracy: 0.6968
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5431 - accuracy: 0.7008
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5398 - accuracy: 0.7040
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5371 - accuracy: 0.7077
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5324 - accuracy: 0.7097
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5262 - accuracy: 0.7157
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5217 - accuracy: 0.7125
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5116 - accuracy: 0.7208
# Epoch 19/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5117 - accuracy: 0.7233
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5133 - accuracy: 0.7206
# Epoch 21/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5069 - accuracy: 0.7235
# Epoch 22/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5024 - accuracy: 0.7300
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5009 - accuracy: 0.7318
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4904 - accuracy: 0.7351
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4897 - accuracy: 0.7370
# Score for fold 7: loss of 0.47289764881134033; accuracy of 75.58372020721436%
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.7104 - accuracy: 0.6175
# Epoch 2/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6296 - accuracy: 0.6413
# Epoch 3/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6113 - accuracy: 0.6528
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6042 - accuracy: 0.6615
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5915 - accuracy: 0.6661
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5844 - accuracy: 0.6719
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5739 - accuracy: 0.6788
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5705 - accuracy: 0.6818
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5608 - accuracy: 0.6885
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5550 - accuracy: 0.6935
# Epoch 11/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5511 - accuracy: 0.6958
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5490 - accuracy: 0.6944
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5358 - accuracy: 0.7034
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5315 - accuracy: 0.7052
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5262 - accuracy: 0.7144
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5191 - accuracy: 0.7187
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5146 - accuracy: 0.7252
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5089 - accuracy: 0.7264
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5073 - accuracy: 0.7259
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4958 - accuracy: 0.7376
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4936 - accuracy: 0.7428
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4882 - accuracy: 0.7408
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4821 - accuracy: 0.7443
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4808 - accuracy: 0.7502
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4773 - accuracy: 0.7526
# Score for fold 8: loss of 0.44811201095581055; accuracy of 78.30440402030945%
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6968 - accuracy: 0.6157
# Epoch 2/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6261 - accuracy: 0.6386
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6112 - accuracy: 0.6479
# Epoch 4/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.6025 - accuracy: 0.6531
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5919 - accuracy: 0.6608
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5835 - accuracy: 0.6699
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5738 - accuracy: 0.6759
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5681 - accuracy: 0.6787
# Epoch 9/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.5582 - accuracy: 0.6892
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5491 - accuracy: 0.6946
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5405 - accuracy: 0.7026
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5399 - accuracy: 0.7041
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5330 - accuracy: 0.7104
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5276 - accuracy: 0.7149
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5202 - accuracy: 0.7181
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5135 - accuracy: 0.7214
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5133 - accuracy: 0.7207
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5051 - accuracy: 0.7310
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5019 - accuracy: 0.7280
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4972 - accuracy: 0.7331
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4871 - accuracy: 0.7356
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4906 - accuracy: 0.7399
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4863 - accuracy: 0.7418
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4782 - accuracy: 0.7465
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4724 - accuracy: 0.7511
# Score for fold 9: loss of 0.41941961646080017; accuracy of 78.90520691871643%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/25
# 270/270 [==============================] - 1s 5ms/step - loss: 0.7133 - accuracy: 0.6164
# Epoch 2/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6280 - accuracy: 0.6397
# Epoch 3/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6153 - accuracy: 0.6485
# Epoch 4/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6044 - accuracy: 0.6530
# Epoch 5/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5989 - accuracy: 0.6613
# Epoch 6/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5933 - accuracy: 0.6649
# Epoch 7/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5852 - accuracy: 0.6720
# Epoch 8/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5794 - accuracy: 0.6730
# Epoch 9/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5750 - accuracy: 0.6787
# Epoch 10/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5669 - accuracy: 0.6872
# Epoch 11/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5609 - accuracy: 0.6860
# Epoch 12/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5548 - accuracy: 0.6940
# Epoch 13/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5462 - accuracy: 0.6986
# Epoch 14/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5418 - accuracy: 0.7018
# Epoch 15/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5352 - accuracy: 0.7085
# Epoch 16/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5320 - accuracy: 0.7094
# Epoch 17/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5218 - accuracy: 0.7144
# Epoch 18/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5213 - accuracy: 0.7144
# Epoch 19/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5107 - accuracy: 0.7233
# Epoch 20/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5095 - accuracy: 0.7261
# Epoch 21/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5025 - accuracy: 0.7296
# Epoch 22/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5006 - accuracy: 0.7310
# Epoch 23/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.5021 - accuracy: 0.7287
# Epoch 24/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4936 - accuracy: 0.7305
# Epoch 25/25
# 270/270 [==============================] - 1s 4ms/step - loss: 0.4924 - accuracy: 0.7358
# Score for fold 10: loss of 0.4648180305957794; accuracy of 76.16822719573975%

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(accuracy_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {accuracy_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(accuracy_per_fold)} (+- {np.std(accuracy_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.4392538070678711 - Accuracy: 77.98532247543335%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.4532725214958191 - Accuracy: 77.58505940437317%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.4409685432910919 - Accuracy: 77.98532247543335%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.44204363226890564 - Accuracy: 77.0513653755188%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.42267119884490967 - Accuracy: 79.11941409111023%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.4580092430114746 - Accuracy: 76.71781182289124%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.47289764881134033 - Accuracy: 75.58372020721436%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.44811201095581055 - Accuracy: 78.30440402030945%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.41941961646080017 - Accuracy: 78.90520691871643%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.4648180305957794 - Accuracy: 76.16822719573975%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 77.54058539867401 (+- 1.0938396543653635)
# > Loss: 0.44614662528038024
# ------------------------------------------------------------------------

# %% [markdown]
# ### Plotting Fold-wise and 2, 5, 10 fold accuracy and loss

# %%
accuracy1 = [accuracy_per_fold[1], accuracy_per_fold[4], accuracy_per_fold[9]]
loss1 = [loss_per_fold[1], loss_per_fold[4], loss_per_fold[9]]
folds = [2, 5, 10]
fold = range(1,11)

# %%
plt.figure(figsize = (15, 10))
ax1 = plt.subplot(2,2,1)
plt.plot(fold, accuracy_per_fold, color='green', marker='o', linewidth=2, markersize=10)
plt.title('Fold-wise Accuracy')
plt.ylabel('Accuracy in %')
plt.xlabel('Fold')

ax2 = plt.subplot(2,2,2)
plt.plot(folds, accuracy1, color='green', marker='o', linewidth=2, markersize=10)
plt.title('2, 5, 10 Fold-wise Accuracy')
plt.ylabel('Accuracy in %')
plt.xlabel('Fold')

ax3 = plt.subplot(2,2,3)
plt.plot(fold, loss_per_fold, color='green', marker='o', linewidth=2, markersize=10)
plt.title('Fold-wise Loss')
plt.ylabel('Loss in %')
plt.xlabel('Fold')

ax4 = plt.subplot(2,2,4)
plt.plot(folds, loss1, color='green', marker='o', linewidth=2, markersize=10)
plt.title('2, 5, 10 Fold-wise Loss')
plt.ylabel('Loss in %')
plt.xlabel('Fold')

plt.savefig('Fold-Loss.png')

# %% [markdown]
# ### Plotting the error fold-wise and 2, 5, 10 fold

# %%
error = []
for i in range(0, len(accuracy_per_fold)):
    x = 100 - accuracy_per_fold[i]
    error.append(x)

# %%
error1 = []
x2 = 100 - accuracy_per_fold[1]
x5 = 100 - accuracy_per_fold[4]
x10 = 100 - accuracy_per_fold[9]
error1.append(x2)
error1.append(x5)
error1.append(x10)

# %%
folds = [2, 5, 10]
plt.figure(figsize = (12, 3))
ax1 = plt.subplot(1,2,1)
plt.plot(fold, error, color='green', marker='o', linewidth=2, markersize=10)
plt.title('Fold-wise Error')
plt.ylabel('Error in %')
plt.xlabel('Fold')

ax2 = plt.subplot(1,2,2)
plt.plot(folds, error1, color='green', marker='o', linewidth=2, markersize=10)
plt.title('2, 5, 10 Fold-wise Error')
plt.ylabel('Error in %')
plt.xlabel('Fold')

plt.savefig('Error.png')

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# A confusion matrix is a table that is often used to describe the performance of a classification model on test dataset for which the true values are known. As we can see, our model can predict the normal walk of a person with 85% accuracy and impaired walk of a person with 77% accuracy.

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-58-fdaaf2360398>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
mat = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(conf_mat = mat, class_names = label.classes_, show_normed = True, figsize = (7, 7))

plt.savefig('confusion_matrix.png')

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Metrics Analysis of the data

# %%
# summarize the first 150 cases
for i in range(150):
	print('%s => %d (expected %d)' % (X_test[i].tolist(), y_pred[i], y_test[i]))
# Out:
# [[[-2.1540784840000002], [-2.242712021], [-2.3936285969999997]], [[-2.585268497], [-2.8607509139999996], [-3.0356225969999997]], [[-3.155397415], [-3.272777081], [-3.4069249630000003]], [[-3.52670002], [-3.569818974], [-3.682407618]], [[-3.691989422], [-3.68959403], [-3.7470860480000003]], [[-3.821346521], [-3.854883432], [-3.886024952]], [[-3.902793407], [-3.9339349269999997], [-3.962681055]], [[-3.953099012], [-3.9339349269999997], [-3.893211603]], [[-3.835719585], [-3.727921963], [-3.59377408]], [[-3.485976458], [-3.404529572], [-3.282358885]], [[-3.181747913], [-3.088323593], [-3.081136942]], [[-3.0691595080000003], [-3.088323593], [-2.9829216]], [[-2.81763196], [-2.6164100169999998], [-2.489448547]], [[-2.355300426], [2.052644014], [2.1029493809999997]], [[2.122113466], [2.16523242], [2.2299110890000002]], [[2.299380541], [2.431133032], [2.526952982]], [[2.663496494], [2.816808462], [2.9485609530000003]], [[3.061149597], [3.1449921130000003], [3.233625412]], [[3.310281515], [3.4037060739999996], [3.430056572]], [[3.386937618], [3.3677735330000003], [3.331840992]], [[3.29351306], [3.200088501], [3.1018729210000004]], [[3.003657579], [2.8695094589999997], [2.759316444]], [[2.603609085], [2.467065573], [2.29458952]], [[2.1005539890000002], [1.9711970090000002], [1.839444518]], [[1.6741549969999998], [1.5519845490000002], [1.5208430290000001]], [[1.470537543], [1.441791534], [1.441791534]], [[1.4513734580000002], [1.5208430290000001], [9.389037132]], [[9.566304207], [9.65972805], [9.729198456]], [[9.999889374], [10.06217289], [10.054986]], [[10.09810543], [10.10050011], [10.05977726]], [[9.992703438], [9.966352463], [9.894487381]], [[9.834600449], [9.8633461], [9.750757217]], [[9.719615936], [9.66691494], [9.547140121]], [[9.441738128999999], [9.345917702000001], [9.286030769]], [[9.300403595], [9.27644825], [9.27644825]], [[9.288426399], [9.365081787000001], [9.398618698]], [[9.537557602], [9.745966911], [9.935211182]], [[10.10289574], [10.38316917], [10.63709259]], [[10.79279995], [10.95329857], [11.02755928]], [[11.11379719], [11.13296127], [11.13775158]]] => 0 (expected 0)
# [[[-0.7565677166], [-0.6751648784000001], [-0.586579442]], [[-0.4141969085], [-0.3208230138], [-0.2202665508]], [[-0.12210428710000001], [0.03112462163], [0.3112462163]], [[0.6368576288000001], [0.9840168953], [1.314416766]], [[1.6807296280000001], [2.035071373], [2.260126352]], [[2.346317768], [2.432508945], [2.5210943219999997]], [[2.67432332], [3.055001259], [3.371036053]], [[3.816357613], [4.249708176], [4.527435303]], [[4.714183331], [4.764461517], [4.783615112]], [[4.616020679], [4.448426723], [4.280832767]], [[4.118026733], [3.971980572], [3.816357613]], [[3.7541081910000003], [3.8283286089999997], [3.811569214]], [[3.6272156239999997], [3.4141316410000004], [3.1890766619999997]], [[2.930502892], [-9.763554573], [-9.627084732]], [[-9.452308655], [-9.200917244], [-8.973467827]], [[-8.817844391], [-8.769960402999999], [-8.710105896]], [[-8.645462036], [-8.497021675], [-8.449137687999999]], [[-8.456320762999999], [-8.480262756], [-8.499416351]], [[-8.616731644], [-8.719682693], [-8.750806808]], [[-8.647856712000001], [-8.487444878], [-8.209717751]], [[-8.0229702], [-7.857769966], [-7.7955207820000005]], [[-7.771578788999999], [-7.888894558], [-8.063671112]], [[-8.255207062], [-8.511386871000001], [-8.753201485]], [[-8.966285706], [-9.13866806], [-9.251194953999999]], [[-9.287108421000001], [-9.234436035], [-9.10036087]], [[-9.026140213], [-9.030928612], [-9.014169693]], [[-9.004592896], [-8.992621422000001], [2.059013367]], [[1.18991828], [0.3806780577], [-0.3088520169]], [[-1.029506683], [-1.616086125], [-2.063801765]], [[-2.41335535], [-2.746149302], [-3.004723072]], [[-3.0238766669999997], [-2.849100113], [-2.427720547]], [[-1.766920805], [-0.4620809257], [0.9528923035]], [[2.525882721], [3.9647979739999997], [5.13556242]], [[6.244078159], [6.58405447], [6.557718277]], [[6.368576527], [6.095637321], [5.707777022999999]], [[5.42765522], [5.133168221], [4.912901878]], [[4.61362648], [4.319139957], [3.9743747710000004]], [[3.5506010060000004], [3.143586874], [2.731784105]], [[2.19308877], [1.8076223130000002], [1.431732655]], [[1.015141487], [0.6200982332], [0.349553436]]] => 0 (expected 0)
# [[[0.49287399649999997], [0.34914401170000003], [0.21499599519999998]], [[0.004191999789], [-0.1826570034], [-0.35992398859999997]], [[-0.570728004], [-0.8486059904000001], [-1.140856981]], [[-1.4810179469999998], [-1.744523048], [-2.0463559630000003]], [[-2.362561941], [-2.578156948], [-2.726677895]], [[-2.822498083], [-2.865617037], [-2.903944969]], [[-2.899153948], [-2.822498083], [-2.7554240230000002]], [[-2.697932005], [-2.530246973], [-2.367352962]], [[-2.190085888], [-2.022401094], [-1.859506965]], [[-1.629539013], [-1.351660967], [-1.07378304]], [[-0.8006960154], [-0.4701170027], [-0.1347469985]], [[0.15750400720000002], [0.4257999957], [0.674932003]], [[0.9240639806000001], [1.125285983], [1.316926003]], [[1.3839999440000001], [4.977399826], [4.986981869]], [[5.0492649080000005], [5.097175121], [5.135502815]], [[5.2025771139999994], [5.3079791069999995], [5.40858984]], [[5.432545185], [5.537947178], [5.729587078]], [[5.863735199], [5.973927975], [6.064957142000001]], [[6.170359135], [6.266179085], [6.4099087720000005]], [[6.529684067000001], [6.711741924], [6.8794269560000005]], [[7.066276072999999], [7.2627072329999995], [7.435183048]], [[7.69868803], [7.9286561010000005], [8.13945961]], [[8.326309204], [8.541904449], [8.747917175]], [[8.973093987], [9.207853317], [9.428238869]], [[9.672579765], [9.888175011], [10.098979]], [[10.2906189], [10.37206554], [10.45830441]], [[10.49184132], [10.55412388], [1.755064964]], [[1.83651197], [1.8892129659999999], [1.970659971]], [[2.171881914], [2.329984903], [2.478506088]], [[2.679728031], [2.828248978], [2.962397099]], [[3.048635006], [3.15882802], [3.206737995]], [[3.2594389919999998], [3.273812056], [3.3265130519999997]], [[3.3265130519999997], [3.312139988], [3.321722031]], [[3.307348967], [3.2594389919999998], [3.2450659280000003]], [[3.206737995], [3.139663935], [3.086962938]], [[3.005516052], [2.943233013], [2.86657691]], [[2.8474130630000003], [2.895323038], [3.010307074]], [[3.139663935], [3.302557945], [3.556480885]], [[3.796030998], [4.030789852], [4.25117588]], [[4.538636208], [4.735066891000001], [4.902751923]]] => 1 (expected 1)
# [[[-7.472088337000001], [-7.649355412], [-7.781107903]], [[-7.781107903], [-7.761943817000001], [-7.601445675]], [[-7.369081974], [-6.93549633], [-6.45400095]], [[-5.828775406], [-5.1795949939999995], [-4.374707222]], [[-3.5602369310000004], [-2.6858794689999996], [-1.751634479]], [[-0.829366982], [0.05217700079], [0.8858109713]], [[1.71944499], [2.512355566], [3.226214409]], [[3.913722992], [4.462292671], [4.96534729]], [[5.377373695], [5.518708229], [5.612132549]], [[5.612132549], [5.489962101000001], [5.312695026]], [[5.027630329], [4.718610764], [4.409591675]], [[3.942468882], [3.353176117], [2.8117930889999996]], [[2.1985449790000002], [1.592483521], [0.9936084747]], [[0.5480455160000001], [-7.857539654], [-7.704227447999999]], [[-7.584452628999999], [-7.486237049], [-7.438326836]], [[-7.4958190920000005], [-7.603616714], [-7.761719704]], [[-7.850352764], [-8.027620316], [-8.312684059]], [[-8.501929282999999], [-8.765434265], [-9.076848984]], [[-9.3307724], [-9.570322037], [-9.831431389]], [[-10.10212326], [-10.43749332], [-10.73932552]], [[-11.02199459], [-11.25914955], [-11.49630356]], [[-11.71908569], [-11.90593433], [-12.03050041]], [[-12.03289604], [-11.96103096], [-11.85323334]], [[-11.63524342], [-11.41964817], [-11.08188248]], [[-10.65069294], [-10.28657627], [-9.991930007999999]], [[-9.682910919], [-9.436174393], [-9.225370407]], [[-8.997797966], [-8.844485283], [0.41788950560000004]], [[0.5017319917999999], [0.5089185238], [0.3915390074]], [[0.1256384999], [-0.1234935001], [-0.4157445133]], [[-0.6433169842], [-0.8900535106999999], [-1.139185548]], [[-1.251773953], [-1.3332209590000001], [-1.3739445209999999]], [[-1.33801198], [-1.239796519], [-1.196677446]], [[-1.14397645], [-1.0265970229999999], [-0.9283815026000001]], [[-0.6888315081999999], [-0.5235419869], [-0.3798120022]], [[-0.1546349972], [0.029818499460000005], [0.2358314991]], [[0.4801724851], [0.6574394703], [0.8898029923]], [[1.124562025], [1.36411202], [1.5533565280000001]], [[1.634803534], [1.6012665030000002], [1.4743050340000001]], [[1.4383724930000001], [1.3449480530000002], [1.330574989]], [[1.225172997], [1.146121502], [1.057487965]]] => 0 (expected 1)
# [[[0.24853299559999997], [0.3730989993], [0.46412798759999996]], [[0.5839030147], [0.7994980215999999], [1.024675012]], [[1.254642963], [1.508566022], [1.69541502]], [[1.805608034], [1.934965014], [1.98287499]], [[2.030785084], [2.08348608], [2.150559902]], [[2.160141945], [2.140978098], [2.145768881]], [[2.164932966], [2.2367980480000003], [2.260752916]], [[2.27512598], [2.255961895], [2.1984701159999998]], [[2.049948931], [1.819980979], [1.66187799]], [[1.40795505], [1.120494962], [0.8090800047]], [[0.5264109968999999], [0.31081599], [0.05210199952]], [[-0.168283999], [-0.2928499877], [-0.3982520103]], [[-0.5515639782], [-0.6473839879], [-0.7288309931999999]], [[-0.8821430206], [7.2387518879999995], [7.444765091]], [[7.564539909], [7.69389677], [7.880745888]], [[8.062804222], [8.216115952000001], [8.33589077]], [[8.426919937000001], [8.513157845], [8.565858841]], [[8.57544136], [8.484412192999999], [8.422128677]], [[8.235280037], [8.101132393], [8.000520706]], [[7.818462848999999], [7.521420956], [7.31540823]], [[7.032739162], [6.7644429210000006], [6.520102024]], [[6.251805782000001], [6.031420231], [5.743959904]], [[5.50440979], [5.322351933], [5.169040203]], [[4.9342808719999995], [4.809714794], [4.680357933]], [[4.627656937], [4.6037020680000005], [4.5797472]], [[4.551001072], [4.584537983], [4.622866154]], [[4.627656937], [4.694731236], [1.390949011]], [[1.5394699569999999], [1.692782044], [1.937122941]], [[2.157509089], [2.3922679419999997], [2.6366090769999997]], [[2.83783102], [3.096544981], [3.264230013]], [[3.451078892], [3.590018034], [3.681046963]], [[3.724165916], [3.6762559410000004], [3.637928009]], [[3.594809055], [3.3648409839999998], [3.2450659280000003]], [[3.06300807], [2.8569951060000003], [2.751593113]], [[2.622236013], [2.4880878930000003], [2.411432028]], [[2.329984903], [2.219791889], [2.147927046]], [[2.056898117], [1.99940598], [2.056898117]], [[2.123971939], [2.186254978], [2.253329039]], [[2.363522053], [2.502460957], [2.627027035]], [[2.789921045], [2.909696102], [3.039052963]]] => 1 (expected 1)
# [[[13.26627159], [12.56237602], [11.00614548]], [[9.327810287], [8.556877136], [7.12993288]], [[5.659893036000001], [4.94402647], [3.593696833]], [[2.928108692], [1.683123827], [0.6177040339000001]], [[0.1532289088], [-0.5530605912], [-0.9816226959000001]], [[-1.108515382], [-1.242590666], [-1.431732655]], [[-1.532289028], [-1.7118542190000001], [-1.8483237030000002]], [[-1.9321208], [-2.102109194], [-2.248155355]], [[-2.274491549], [-2.363077164], [-2.573766708]], [[-2.6910827160000004], [-2.86107111], [-3.031059265]], [[-3.095702887], [-3.253720045], [-3.3279404639999997]], [[-3.507505417], [-3.713406801], [-3.82593441]], [[-4.079719543], [-4.414907932], [-4.637568474]], [[-5.137956619], [-18.85433769], [-18.23423958]], [[-17.08262825], [-16.06269836], [-15.62695408]], [[-14.84165668], [-14.11860752], [-13.78581333]], [[-13.12501335], [-12.80897903], [-12.18888092]], [[-11.58554173], [-11.26950741], [-10.59434223]], [[-9.856928825], [-9.485827446], [-8.791508675]], [[-8.087613106000001], [-7.7284832], [-7.091625214]], [[-6.54574728], [-6.2919621470000004], [-5.906495571000001]], [[-5.64313364], [-5.595249176], [-5.628767967000001]], [[-5.8322753910000005], [-5.997475147], [-6.428431511]], [[-6.677428722], [-7.223306656], [-7.8386163710000005]], [[-8.149862289], [-8.808267593], [-9.519346237]], [[-9.902418137], [-10.68532181], [-11.52329254]], [[-11.97819138], [-12.9478426], [16.81687355]], [[16.02199745], [14.41309452], [12.72039318]], [[11.8728466], [10.18253994], [8.530540466]], [[7.754819392999999], [6.339846134], [5.6958060260000005]], [[4.544194698], [3.648763418], [3.318363667]], [[2.8562827110000004], [2.6647465230000003], [2.67671752]], [[2.8945899010000002], [3.2225954530000003], [3.3949780460000003]], [[3.770867586], [4.079719543], [4.189853191]], [[4.362235546], [4.429273128999999], [4.414907932]], [[4.254496574], [4.031835556], [3.895366192]], [[3.545812607], [3.12203908], [2.865859509]], [[2.391807556], [2.135627985], [1.601720929]], [[1.086967587], [0.8044517636], [0.19393034280000002]], [[-0.4644751251], [-0.7685387731000001], [-1.268926859]]] => 0 (expected 0)
# [[[-2.772117615], [-2.637969494], [-2.5685000419999997]], [[-2.5637090209999998], [-2.508612394], [-2.494239569]], [[-2.551731586], [-2.645155907], [-2.714625597]], [[-2.796072483], [-2.9398024080000003], [-3.0236449239999996]], [[-3.1530020239999996], [-3.299127579], [-3.4069249630000003]], [[-3.5362820630000003], [-3.636893034], [-3.88362956]], [[-4.30044651], [-4.726845264], [-5.052633286]], [[-5.198759078999999], [-5.313743113999999], [-5.3161382680000004]], [[-5.220318317], [-5.253855705], [-5.165222168000001]], [[-4.935254097], [-4.420221328999999], [-3.725526571]], [[-2.8032588960000004], [-1.5264575480000002], [-0.13467200099999999]], [[1.7122584580000002], [3.738851547], [5.312695026]], [[6.234962463], [6.424207211000001], [5.74628067]], [[4.562903404], [-8.442041397], [-8.482765198]], [[-8.600144386], [-8.636076927000001], [-8.600144386]], [[-8.597748756], [-8.528279305], [-8.482765198]], [[-8.425272942000001], [-8.451623917000001], [-8.418086052]], [[-8.408504486], [-8.446832657], [-8.528279305]], [[-8.540257453999999], [-8.607331276], [-8.755851746]], [[-9.060080528], [-9.467315674], [-10.04702663]], [[-10.69141579], [-11.40287971], [-12.09996986]], [[-12.66770363], [-13.23543739], [-13.87263966]], [[-14.50505161], [-15.1398592], [-15.67405605]], [[-16.22741699], [-16.85743332], [-17.58087349]], [[-18.37138939], [-18.99901009], [-19.46613312]], [[-19.68651772], [-19.58590698], [-18.94630814]], [[-17.9809227], [-16.44540787], [5.343037605]], [[5.343037605], [5.275963306], [5.333455563]], [[5.338246346], [5.309500694], [5.283150196]], [[5.331059933], [5.299918652], [5.12744236]], [[4.923824787], [4.914243221], [4.931011677]], [[5.105883121000001], [5.311895847], [5.486767292000001]], [[5.61612463], [5.750272273999999], [5.661639214]], [[5.242426395], [4.617200851000001], [3.80991745]], [[2.854113102], [1.9222635030000002], [1.3856714959999998]], [[0.9880185127], [1.0335329770000001], [1.4383724930000001]], [[2.4564599990000002], [4.10456419], [6.2653050420000005]], [[8.402091026], [10.20111179], [10.86945629]], [[10.03103065], [8.009228706], [5.0603685380000005]], [[0.9856230021], [-3.872451067], [-9.02277565]]] => 0 (expected 0)
# [[[1.501164436], [1.5658079390000001], [1.7597382069999998]], [[2.0614075659999997], [2.202665567], [2.494758129]], [[2.633621931], [2.817975283], [3.043030262]], [[3.1723172660000003], [3.34469986], [3.56496644]], [[3.6631286139999997], [3.806780815], [3.967192173]], [[4.005499363], [4.082113743], [4.177882195]], [[4.192247391], [4.180276394], [4.098873138]], [[4.034229755], [3.8498764039999998], [3.64158082]], [[3.5242648119999997], [3.263296843], [2.952050686]], [[2.7748796939999996], [2.418143749], [2.245761156]], [[1.936909199], [1.687912226], [1.5514427419999999]], [[1.350329757], [1.216254473], [1.177947283]], [[1.113303781], [1.098938584], [1.113303781]], [[1.194706678], [-10.20648193], [-10.23281765]], [[-10.30464458], [-10.42674828], [-10.47942066]], [[-10.55603504], [-10.60152531], [-10.62786102]], [[-10.69011021], [-10.71644688], [-10.77390766]], [[-10.89361763], [-10.94150162], [-10.98459721]], [[-11.04924107], [-11.04205799], [-11.0133276]], [[-11.00135708], [-10.99178028], [-10.94150162]], [[-10.88164711], [-10.84333992], [-10.77630138]], [[-10.69011021], [-10.65419769], [-10.58716011]], [[-10.55124664], [-10.49139214], [-10.41238308]], [[-10.39801788], [-10.38365269], [-10.38125896]], [[-10.36928749], [-10.39083576], [-10.37647057]], [[-10.36449909], [-10.36689377], [-10.39083576]], [[-10.41717148], [-10.44829655], [0.0191536136]], [[0.02394201607], [0.06464344262999999], [0.107739076]], [[0.117315881], [0.1340752989], [0.14844051]], [[0.141257897], [0.15562310810000002], [0.1723825186]], [[0.1364694983], [0.1244984865], [0.1268926859]], [[0.09576806426000001], [0.1244984865], [0.14844051]], [[0.19393034280000002], [0.2585737705], [0.3088520169]], [[0.4165911078], [0.4860229492], [0.5099649428999999]], [[0.6224924326], [0.7398083209999999], [0.8164227605]], [[0.9576807022], [1.084573388], [1.1324573759999998]], [[1.18991828], [1.216254473], [1.307234168]], [[1.383848548], [1.400607944], [1.429338455]], [[1.431732655], [1.419761658], [1.393425345]], [[1.357512355], [1.3479355569999998], [1.326387763]]] => 0 (expected 0)
# [[[-1.983997941], [-2.11095953], [-2.240316391]], [[-2.343322992], [-2.511008024], [-2.841587067]], [[-3.090718985], [-3.1530020239999996], [-3.172166109]], [[-3.215285063], [-3.186538935], [-3.265590429]], [[-3.265590429], [-3.186538935], [-3.155397415]], [[-3.208098412], [-3.191329956], [-3.143419981]], [[-3.052391052], [-2.9182429310000004], [-2.714625597]], [[-2.5637090209999998], [-2.475075483], [-2.290621996]], [[-2.151683092], [-2.070235968], [-1.962438464]], [[-1.873805046], [-1.6893515590000001], [-1.595927]], [[-1.528853059], [-1.416264534], [-1.399495959]], [[-1.406682491], [-1.399495959], [-1.3443994519999998]], [[-1.253370523], [-1.294093966], [-1.325235486]], [[-1.318048954], [-8.966655731], [-8.681591034]], [[-8.451623917000001], [-8.243214607], [-8.00366497]], [[-7.867121696], [-7.737764359], [-7.562892914]], [[-7.385625838999999], [-7.277828692999999], [-7.0909795760000005]], [[-6.93766737], [-6.796332836], [-6.635834694]], [[-6.523245811000001], [-6.465754032], [-6.410657406]], [[-6.283696175], [-6.173502922000001], [-6.048936844]], [[-5.981863022000001], [-5.900415897], [-5.744708537999999]], [[-5.696798325], [-5.636910915], [-5.557859421]], [[-5.52192688], [-5.493181229], [-5.497972012000001]], [[-5.517136097000001], [-5.562650681], [-5.572232723]], [[-5.6153516770000005], [-5.62493372], [-5.699193954]], [[-5.7303357120000005], [-5.857296944], [-5.878856658999999]], [[-5.9147892], [-5.984258652], [0.03940049931]], [[0.04179599881], [-0.025278000159999998], [-0.030068999160000002]], [[-0.08516550063999999], [0.06335549802], [0.22385400530000002]], [[0.1735485047], [0.264577508], [0.42747148869999996]], [[0.573597014], [0.5759925246], [0.6622304915999999]], [[0.7460730076000001], [0.7101405262999999], [0.6478574872]], [[0.5304780006], [0.3268604875], [0.293323487]], [[0.3053010106], [0.3100920022], [0.2885324955]], [[0.1256384999], [-0.08995649963999999], [-0.30315598850000003]], [[-0.4756320119], [-0.7008090019], [-0.8756805062]], [[-1.019410491], [-1.069715977], [-1.131999016]], [[-1.139185548], [-1.076902509], [-0.9140084982]], [[-0.8660985231], [-0.7678830028], [-0.6864359975]], [[-0.5834295154], [-0.4947960079], [-0.4828185141]]] => 0 (expected 1)
# [[[0.6774024962999999], [0.5720005035], [0.5504410267000001]], [[0.5839779973], [0.5767915249000001], [0.6342834829999999]], [[0.763640523], [0.9600715041], [1.240345001]], [[1.5613420009999999], [1.990136504], [2.404557943]], [[2.797420025], [3.305265903], [3.7101054189999996]], [[4.083803654], [4.450314999], [4.800057888]], [[4.991697788], [5.125845909], [5.16656971]], [[4.984511375], [4.589253902], [3.913722992]], [[2.9555230139999997], [1.8224514719999998], [0.7037529945000001]], [[-0.2736110091], [-1.009029508], [-1.615090966]], [[-2.125332594], [-2.458307028], [-2.714625597]], [[-2.896683455], [-2.9781305789999997], [-3.0236449239999996]], [[-3.10988307], [-3.1170694830000003], [-3.119465113]], [[-3.006876469], [-12.2413044], [-12.43533993]], [[-12.53834629], [-12.67728519], [-12.78268719]], [[-12.86892509], [-12.94079018], [-13.00067806]], [[-13.02702808], [-13.01505089], [-12.98151398]], [[-12.93839455], [-12.90725327], [-12.88329887]], [[-12.92641735], [-13.05577469], [-13.17554951]], [[-13.37198067], [-13.57559776], [-13.83431244]], [[-14.20561409], [-14.54817104], [-14.8955183]], [[-15.36743164], [-15.72196579], [-15.92797947]], [[-16.05733681], [-16.06931305], [-16.00942612]], [[-15.7555027], [-15.46085644], [-15.1398592]], [[-14.75178814], [-14.38767242], [-14.1409359]], [[-13.90378189], [-13.75526047], [-13.58757591]], [[-13.44145012], [-13.32886124], [6.787524222999999]], [[6.871366501000001], [6.888134956], [6.847411632999999]], [[6.765964508], [6.516832352000001], [6.29405117]], [[6.030546188], [5.594564915], [4.952570915]], [[4.243503093999999], [3.330817461], [2.372617483]], [[1.217986465], [0.1400115043], [-0.8253750205]], [[-1.745247006], [-2.624395609], [-3.448447466]], [[-4.203030109], [-4.857001305], [-5.336101532]], [[-5.642725467999999], [-5.611584187], [-5.285796165]], [[-4.895329475], [-4.509654045], [-4.085650444]], [[-3.702370405], [-3.4292836189999996], [-3.125055075]], [[-2.6914694310000002], [-2.36807704], [-2.0063564780000003]], [[-1.577561975], [-1.093670964], [-0.6528990269]], [[-0.31034249070000003], [0.008259000257], [0.161570996]]] => 0 (expected 1)
# [[[-2.300278902], [-2.544620037], [-2.784169912]], [[-3.028511047], [-3.296807051], [-3.4501190189999997]], [[-3.55072999], [-3.55072999], [-3.4501190189999997]], [[-3.3303439619999997], [-3.22973299], [-2.990183115]], [[-2.707514048], [-2.448800087], [-2.199667931]], [[-1.955327034], [-1.672657967], [-1.3756159540000001]], [[-1.078573942], [-0.7815319895999999], [-0.41741600630000003]], [[-0.2257760018], [-0.04850900173], [0.1910409927]], [[0.2868610024], [0.2772789896], [0.2581149936]], [[0.2006230056], [0.1479219943], [0.04731100053]], [[-0.08683700114], [-0.139538005], [-0.19702999289999998]], [[-0.21619400379999998], [-0.18744799489999997], [-0.20661200579999997]], [[-0.177865997], [-0.09641899913999999], [0.004191999789]], [[0.1335490048], [11.11467075], [11.47878742]], [[11.88123131], [12.25971985], [12.60946274]], [[12.90171432], [13.25145721], [13.47184277]], [[13.70181084], [13.86949635], [13.97968864]], [[13.97968864], [13.91740608], [13.7066021]], [[13.47184277], [13.20833778], [12.82026672]], [[12.47531509], [12.1255722], [11.75187397]], [[11.35901165], [10.90865803], [10.4295578]], [[9.883383751], [9.31325531], [8.829363823]], [[8.240071297], [7.703478812999999], [7.109395027000001]], [[6.577593802999999], [6.060165882000001], [5.667304038999999]], [[5.355888844], [5.111547947], [5.039682865]], [[5.154666901000001], [5.470872879], [6.041001797000001]], [[6.956082821], [8.177787781000001], [6.900599003]], [[6.708959103], [6.41191721], [6.038218975]], [[5.664521217000001], [5.324359894], [5.0225272180000005]], [[4.735066891000001], [4.428442955], [4.164937973]], [[3.843940973], [3.594809055], [3.4654519560000003]], [[3.2929759030000003], [3.2498569489999998], [3.273812056]], [[3.297766924], [3.3744230269999997], [3.590018034]], [[3.810404062], [3.982880116], [4.169729233]], [[4.25117588], [4.31345892], [4.414070129]], [[4.509890079], [4.553009033], [4.624874115]], [[4.672783852], [4.73985815], [4.859632969]], [[4.89796114], [5.032108784], [5.2333312030000005]], [[5.386642932999999], [5.520791054], [5.7172222139999995]], [[5.894488811], [6.0094728470000005], [6.01905489]]] => 1 (expected 0)
# [[[-0.3119390011], [-0.1993505061], [-0.09394849837000001]], [[-0.04843400046], [-0.03885199875], [-0.017292499540000002]], [[-0.024478999900000003], [-0.036456499249999996], [-0.07238899916000001]], [[-0.1753955036], [-0.2975659966], [-0.4652509987]], [[-0.6544954777], [-0.7862480283], [-0.961119473]], [[-1.088081002], [-1.128804445], [-1.162341475]], [[-1.215042472], [-1.308467031], [-1.392309546]], [[-1.471361041], [-1.476151943], [-1.4450105430000002]], [[-1.454592466], [-1.471361041], [-1.5048979519999999]], [[-1.62706852], [-1.7684030530000001], [-1.9408789869999998]], [[-2.137310028], [-2.3409276009999997], [-2.566104412]], [[-2.808049917], [-3.052391052], [-3.330269098]], [[-3.725526571], [-4.0417323110000005], [-4.35793829]], [[-4.666957855], [-12.29160976], [-12.16225338]], [[-12.14548492], [-12.10476112], [-12.06403732]], [[-12.1359024], [-12.11913395], [-12.11194706]], [[-12.12392521], [-12.17183495], [-12.26286411]], [[-12.37784767], [-12.45210838], [-12.55271912]], [[-12.63416672], [-12.70842743], [-12.69644928]], [[-12.63416672], [-12.54792881], [-12.44731712]], [[-12.20537186], [-12.09278393], [-11.98019505]], [[-11.87000179], [-11.73106289], [-11.61128807]], [[-11.49630356], [-11.44120789], [-11.44360256]], [[-11.50109482], [-11.58733273], [-11.69992161]], [[-11.82209206], [-11.91312122], [-12.12871647]], [[-12.36347485], [-12.56469727], [-12.84736633]], [[-13.12045288], [-13.46540546], [3.0337755680000003]], [[2.947537422], [2.8493220810000004], [2.844531059]], [[2.8373444080000003], [2.8948364260000004], [2.9187915330000003]], [[3.021797895], [3.191878557], [3.32842207]], [[3.539226055], [3.800335407], [4.063840389]], [[4.358487128999999], [4.6866703030000005], [5.000481129]], [[5.196911812], [5.2855453489999995], [5.254404068]], [[5.158584118], [4.957362175], [4.753744602]], [[4.473471165], [4.1740336419999995], [3.884177923]], [[3.541621447], [3.155946016], [2.6912190910000002]], [[2.046829462], [1.529401541], [1.035928488]], [[0.5759925246], [0.1591755003], [-0.2217089981]], [[-0.4828185141], [-0.7271595001000001], [-1.031388044]], [[-1.270938039], [-1.388317466], [-1.4553915259999999]]] => 0 (expected 0)
# [[[4.898536682], [4.455609322], [3.6942532060000004]], [[3.0166940689999997], [2.573766708], [1.953668594]], [[1.460463047], [1.185129881], [1.11569798]], [[1.007958889], [0.8475474118999999], [0.5219359994]], [[0.1053448766], [-0.2753331959], [-0.4405331016]], [[-0.4285621047], [-0.5339069963], [-0.6464344859000001]], [[-0.8331822157], [-0.9600749016], [-1.108515382]], [[-1.312022567], [-1.6950948240000001], [-1.604115129]], [[-1.644816518], [-1.9440917969999998], [-2.042253971]], [[-2.068590164], [-2.059013367], [-1.9608511919999998]], [[-1.8148049119999998], [-1.668758631], [-1.276109457]], [[-1.177947283], [-0.9002198576999999], [-0.7637503147]], [[-0.3088520169], [0.21068975329999998], [0.7326257229]], [[1.292868972], [-10.52969933], [-10.29267311]], [[-9.900024413999999], [-9.550470352], [-9.390059471]], [[-9.449913979], [-9.610325813], [-9.763554573]], [[-9.921571732], [-10.0269165], [-10.13944435]], [[-10.3214035], [-10.47702694], [-10.67095661]], [[-10.78587818], [-10.75714779], [-10.65898609]], [[-10.40998936], [-10.11789608], [-9.701305389]], [[-9.172186852000001], [-8.702922821], [-8.176198959]], [[-7.967903137], [-7.575253963], [-7.307103634]], [[-7.2687964439999995], [-7.364564419], [-7.496245384]], [[-7.702147007000001], [-7.934384346], [-8.113949776]], [[-8.28633213], [-8.453926086000001], [-8.63109684]], [[-8.865729332], [-8.968679428], [-9.06205368]], [[-9.241618156], [-9.308655738999999], [-1.2210428709999999]], [[-1.556231141], [-1.9440917969999998], [-2.372653961]], [[-2.782062292], [-3.143586874], [-3.658340216]], [[-4.005499363], [-4.362235546], [-4.556165695]], [[-4.352658749], [-3.8043866160000004], [-2.8826189039999996]], [[-2.121262789], [-1.393425345], [-0.5315127969]], [[0.4046200812], [1.453280449], [2.4636335369999998]], [[3.3016040330000003], [4.077325344], [4.532223701]], [[4.704606533], [4.38617754], [4.165910721]], [[3.790021181], [3.2800562380000002], [2.8251581189999997]], [[2.4085669519999997], [2.085349798], [1.829170108]], [[1.613691926], [1.3479355569999998], [1.295263171]], [[1.247379065], [1.37427175], [1.501164436]], [[1.628057122], [1.884236693], [1.8602947]]] => 0 (expected 0)
# [[[-0.5993989706], [-0.2736110091], [-0.04843400046]], [[0.025826500730000004], [-0.053224999460000005], [-0.3646399975]], [[-0.8006209731], [-1.262952447], [-1.5504125359999998]], [[-1.7564255], [-1.8905735019999999], [-1.945670009]], [[-1.964833975], [-1.833081484], [-1.6366504430000002]], [[-1.3036760090000001], [-1.011425018], [-0.6712639928]], [[-0.3382894993], [0.056967999789999994], [0.3348459899]], [[0.7923864722], [1.290650487], [1.4846860169999998]], [[1.388865948], [1.259508967], [1.237949491]], [[1.240345001], [1.087033033], [1.063078046]], [[1.206807971], [1.427193999], [1.7601685519999999]], [[1.872756958], [1.863175035], [1.6140429969999999]], [[0.9912130237000001], [0.044990498569999995], [-1.085685492]], [[-1.6677919630000002], [-5.291958809], [-3.9504790310000004]], [[-2.8293850419999997], [-1.840043545], [-1.159721494]], [[-0.7309269905], [-0.6279205084], [-0.668644011]], [[-0.8195605278], [-1.013596058], [-1.27710104]], [[-1.581329465], [-2.053242922], [-2.498806]], [[-3.0952854160000003], [-3.770816565], [-4.501443863]], [[-5.411734104], [-6.345979214], [-7.414371967]], [[-8.511510849], [-9.460128784], [-10.60038662]], [[-12.02091885], [-13.48696423], [-14.76616192]], [[-15.86330032], [-16.83347893], [-17.43953896]], [[-17.70064926], [-17.58566475], [-17.25748062]], [[-16.69932938], [-15.93995667], [-15.16381454]], [[-14.40204525], [-13.68818665], [-12.90485764]], [[-11.98738194], [-11.0507412], [-3.575408936]], [[-4.97198534], [-5.997259617], [-6.646440029]], [[-7.005764961000001], [-7.07044363], [-6.790170193]], [[-6.308674335], [-5.683448792], [-4.902515888]], [[-4.025763035], [-3.007675409], [-2.07582593]], [[-1.096066475], [-0.1426575035], [0.7652369738]], [[1.4527455569999999], [1.960591555], [2.291170597]], [[2.513952017], [2.648099899], [2.5283250809999998]], [[2.331893921], [2.482810497], [2.49239254]], [[2.310334444], [1.869562507], [1.517423987]], [[1.052696943], [0.714931488], [0.5855745077000001]], [[0.6526485085], [0.937713027], [1.198822498]], [[1.548565507], [1.62282598], [1.991732955]], [[2.130671978], [1.507841945], [0.7604460120000001]]] => 1 (expected 1)
# [[[3.9423940180000003], [4.057377815], [3.971139908]], [[3.6884710789999997], [3.4537119869999997], [3.103969097]], [[2.715898037], [2.519467115], [2.418855906]], [[2.294290066], [2.145768881], [1.882264018]], [[1.5756399630000002], [1.21152401], [0.8186619878]], [[0.5168290138], [0.3826810122], [0.24853299559999997]], [[0.07126600295], [-0.08204600215], [-0.2353579998]], [[-0.3407599926], [-0.5084450245000001], [-0.6761299968000001]], [[-0.8581879735], [-1.025872946], [-1.131275058]], [[-1.193557978], [-1.246258974], [-1.389989018]], [[-1.495391011], [-1.543300986], [-1.528928041]], [[-1.533718944], [-1.52413702], [-1.380406976]], [[-1.251049995], [-1.217512965], [-1.198348999]], [[-1.049828053], [7.133349895], [7.382482052]], [[7.655569077000001], [8.029267311], [8.618559837000001]], [[9.088077545], [9.356373787], [9.600714684]], [[9.888175011], [10.25708199], [10.62598896]], [[11.06676102], [11.4692049], [11.7422924]], [[11.9051857], [12.02496147], [12.13515377]], [[12.05849838], [12.00100613], [12.07287121]], [[11.93872261], [11.75187397], [11.58897972]], [[11.51232433], [11.45004082], [11.29672909]], [[11.11946201], [10.9469862], [10.78409195]], [[10.65952587], [10.53495979], [10.46309471]], [[10.40081215], [10.28582764], [10.16605282]], [[10.13251591], [10.19479942], [10.19000816]], [[10.13730717], [10.03669643], [0.054260000589999996]], [[0.4183759987], [0.8831030129999999], [1.1370259520000001]], [[0.9741320014], [0.9022669792], [1.055578947]], [[1.252009988], [1.390949011], [1.496351004]], [[1.616125941], [1.5394699569999999], [1.4436500069999998]], [[1.3765759469999999], [1.295128942], [0.9262220263]], [[0.557314992], [0.46149501200000004], [0.322555989]], [[0.1692440063], [0.1404979974], [0.2219450027]], [[0.2650640011], [0.1357070059], [-0.09426099807]], [[-0.04156000167], [0.0063499999230000005], [0.03509600088]], [[0.1117520034], [0.2650640011], [0.38962998990000003]], [[0.518987], [0.7729099989], [1.041206002]], [[1.242427945], [1.400531054], [1.477187037]], [[1.347830057], [1.347830057], [1.4436500069999998]]] => 1 (expected 0)
# [[[1.470039845], [1.467645645], [1.434126854]], [[1.357512355], [1.340752959], [1.297657371]], [[1.292868972], [1.4077905419999999], [1.491587639]], [[1.5131354330000002], [1.508347034], [1.572990537]], [[1.59932673], [1.81959331], [1.939303398]], [[1.9201498030000002], [1.980004787], [2.066195965]], [[2.066195965], [2.085349798], [2.118868589]], [[2.276885748], [2.334346771], [2.367865562]], [[2.511517525], [2.499546528], [2.501940727]], [[2.590526342], [2.659958124], [2.667140722]], [[2.640804529], [2.588132143], [2.604891539]], [[2.645592928], [2.588132143], [2.5210943219999997]], [[2.432508945], [2.37744236], [2.4085669519999997]], [[2.3846249580000003], [0.8571242094], [0.7805097699]], [[0.6799532771], [0.6488286853], [0.5746083856]], [[0.4979939461], [0.4716577232], [0.4094084799]], [[0.3423708379], [0.2968810201], [0.2537853718]], [[0.2346317619], [0.2178723514], [0.1843535304]], [[0.1915361285], [0.2035071403], [0.2346317619]], [[0.2633621991], [0.2753331959], [0.3016694188]], [[0.3064578176], [0.323217243], [0.3256114423]], [[0.3208230138], [0.2896983922], [0.2729389966]], [[0.2537853718], [0.19632454219999998], [0.1149216816]], [[0.06943184882], [-0.0143652102], [-0.07661445438999999]], [[-0.09816227107999999], [-0.1244984865], [-0.1340752989]], [[-0.12210428710000001], [-0.09097966552000002], [-0.03351882473]], [[-0.0023942017], [0.07900865376], [1.194706678]], [[1.312022567], [1.352723956], [1.350329757]], [[1.33835876], [1.364694953], [1.37427175]], [[1.381454349], [1.328781962], [1.177947283]], [[0.9528923035], [0.8379706144], [0.7996633648999999]], [[0.7709329723999999], [0.7302315235], [0.7110779285]], [[0.6440402865], [0.6296750307], [0.6153098345]], [[0.6224924326], [0.6177040339000001], [0.5410895943999999]], [[0.4932055473], [0.46686932439999995], [0.4525041282]], [[0.4405331016], [0.457292527], [0.5410895943999999]], [[0.5602431892999999], [0.5961562395000001], [0.6799532771]], [[0.7972691654999999], [0.8427590131999999], [0.9672574997]], [[1.1444283720000001], [1.237802267], [1.41257906]], [[1.613691926], [1.726219416], [1.97042799]]] => 1 (expected 1)
# [[[-0.28079751129999997], [-0.3790130019], [-0.5275340079999999]], [[-0.6065855026], [-0.7670840025], [-0.968306005]], [[-1.174319029], [-1.387518525], [-1.579158545]], [[-1.773193955], [-1.900155544], [-1.8426635269999998]], [[-1.845059037], [-1.962438464], [-2.077422619]], [[-2.192406416], [-2.221152544], [-2.30259943]], [[-2.343322992], [-2.458307028], [-2.43195653]], [[-2.360091448], [-2.290621996], [-2.2642714980000003]], [[-2.283435583], [-2.245107412], [-2.170846939]], [[-2.132519007], [-2.163660526], [-2.1013774869999997]], [[-2.000766516], [-1.9289015530000002], [-1.902551055]], [[-1.8546409609999999], [-1.739657044], [-1.674978495]], [[-1.617486477], [-1.694142461], [-1.708515525]], [[-1.651023507], [-10.24345779], [-10.17877865]], [[-10.1093092], [-9.958393097], [-9.821849822999999]], [[-9.663746834], [-9.457733154], [-9.222974777000001]], [[-9.026543617], [-8.777411461], [-8.480369567999999]], [[-8.226446152000001], [-8.037201881], [-7.90544939]], [[-7.761719704], [-7.574870586], [-7.392812729]], [[-7.220336437], [-7.117330074], [-6.995159626]], [[-6.796332836], [-6.499290942999999], [-6.259740829]], [[-6.139966011], [-6.015399932999999], [-5.8022003170000005]], [[-5.648888587999999], [-5.43089819], [-5.3111228939999995]], [[-5.224884987], [-5.050013542], [-4.894306183]], [[-4.810463428], [-4.712247849], [-4.621219158]], [[-4.5972638130000005], [-4.527794361000001], [-4.489466667]], [[-4.415205956], [-4.3864598269999995], [-0.33908849950000003]], [[-0.315133512], [-0.2528505027], [-0.269618988]], [[-0.2456640005], [-0.3582524955], [-0.36783450840000004]], [[-0.2480594963], [-0.1929630041], [-0.2025450021]], [[-0.1234935001], [-0.14505299929999999], [-0.042046498509999995]], [[0.05856449902000001], [0.02502750047], [-0.1091205031]], [[-0.1977539957], [-0.3798120022], [-0.4301174879]], [[-0.2744100094], [-0.2288955003], [-0.2145224959]], [[-0.1905674934], [-0.042046498509999995], [-0.09953849763]], [[-0.2480594963], [-0.39178949590000006], [-0.5690565109000001]], [[-0.6984134912000001], [-0.8565164804000001], [-1.134394526]], [[-1.340407491], [-1.575166464], [-1.843462467]], [[-1.903349996], [-2.049475431], [-2.2291378969999998]], [[-2.353703976], [-2.2986075880000003], [-2.291420937]]] => 0 (expected 1)
# [[[0.6055374742], [0.32047298550000003], [0.02822200023]], [[-0.1466494948], [-0.34068501], [-0.5802350044]], [[-0.7670840025], [-0.9539330006], [-1.1479685309999998]], [[-1.2485795020000001], [-1.387518525], [-1.308467031]], [[-1.231811047], [-1.1839009520000001], [-1.090476513]], [[-0.9012320042], [-0.6712639928], [-0.4269230068]], [[-0.218514502], [-0.08197099715], [-0.06759800017]], [[0.03301300108], [0.07852750272], [0.11445999890000001]], [[-0.2544470131], [-1.1383864879999999], [-2.525381088]], [[-4.192648888], [-5.342488766000001], [-6.734274387]], [[-8.521317482], [-9.740627288999999], [-10.43053055]], [[-10.90004921], [-11.13720322], [-12.20080566]], [[-12.47868347], [-9.999341011], [-5.886267662000001]], [[-1.98160255], [-9.412219047999999], [-8.916350365]], [[-8.475578308], [-8.041993141], [-7.6802725789999995]], [[-7.373648642999999], [-7.052651405], [-6.741236687000001]], [[-6.451381207000001], [-6.219017506], [-6.01060915]], [[-5.766267776], [-5.565045834], [-5.344659805]], [[-5.224884987], [-5.011685371], [-4.803277016]], [[-4.561331271999999], [-4.348132133], [-4.084627151]], [[-3.756443501], [-3.327649117], [-2.680864096]], [[-1.873580456], [-1.1812809709999998], [-0.6973900198999999]], [[-0.56803298], [-0.8171650170999999], [-1.24356401]], [[-2.40298605], [-4.309803963], [-6.607088566]], [[-9.242138863], [-12.60781574], [-16.82629204]], [[-21.44002533], [-26.18071938], [-31.09628487]], [[-35.88967896], [-39.86381531], [7.182781696]], [[6.964790821], [7.015096664], [7.582829952000001]], [[8.323039055], [9.063248633999999], [9.525580406]], [[9.683683395], [9.484856606000001], [9.063248633999999]], [[8.656014442], [8.049952507], [7.245064735]], [[6.519227982], [6.040128231000001], [5.721526623]], [[5.946703434], [6.2605137829999995], [6.365915775]], [[6.241350174], [5.544259547999999], [3.867409468]], [[0.9616680145000001], [-2.274652481], [-5.666680336000001]], [[-9.188065529], [-12.34533405], [-14.20903397]], [[-14.18747425], [-11.90695763], [-8.419110298]], [[-5.137275219], [-1.6230765580000002], [2.360640049]], [[7.007909775], [13.8135252], [23.39312935]], [[31.19048309], [32.65413284], [28.27515984]]] => 0 (expected 0)
# [[[-0.2353579998], [-0.2257760018], [-0.20661200579999997]], [[-0.149120003], [-0.10600099710000001], [-0.014972000380000001]], [[0.04252000153], [0.06647499651000001], [0.08563899993999999]], [[0.1718769968], [0.253324002], [0.31081599]], [[0.35872599479999995], [0.3970539868], [0.3970539868]], [[0.3970539868], [0.3443529904], [0.31560701129999996]], [[0.329979986], [0.2868610024], [0.2820700109]], [[0.2820700109], [0.24374200399999998], [0.2006230056]], [[0.2006230056], [0.1239669994], [0.09522099793]], [[0.1048030034], [0.1000119969], [0.09042999892999999]], [[0.06647499651000001], [0.05210199952], [0.03293799981]], [[0.1239669994], [0.1479219943], [0.1335490048]], [[0.1335490048], [0.1335490048], [0.1239669994]], [[0.1527130008], [8.92039299], [8.829363823]], [[8.91560173], [9.025794982999999], [9.07370472]], [[9.107241631], [9.126405716], [9.198270798]], [[9.236598969], [9.322836876], [9.433030128]], [[9.524059296], [9.528849602000001], [9.557596207000001]], [[9.576760292000001], [9.619878769], [9.567177773]], [[9.595924377000001], [9.662998199], [9.65341568]], [[9.605505942999999], [9.586341857999999], [9.639042854]], [[9.643834114], [9.643834114], [9.581550598]], [[9.581550598], [9.562387466], [9.567177773]], [[9.552804947], [9.586341857999999], [9.543223381]], [[9.514476776], [9.485731125], [9.46177578]], [[9.404283524], [9.389910698], [9.423447609]], [[9.332419395], [9.322836876], [-1.680081964]], [[-1.761528969], [-1.814229965], [-1.9052590130000002]], [[-1.943586946], [-1.886095047], [-1.8190209869999998]], [[-1.67050004], [-1.493232965], [-1.3734580280000002]], [[-1.229727983], [-1.062042952], [-0.9997599720999999]], [[-0.8943579793], [-0.8704029918], [-0.7937470078]], [[-0.7650009990000001], [-0.7506279945000001], [-0.7793740034000001]], [[-0.8224930167], [-0.8081200123000001], [-0.8416569829]], [[-0.8224930167], [-0.812910974], [-0.7889559865000001]], [[-0.7602099776000001], [-0.7027180195], [-0.6931359768]], [[-0.6595990062], [-0.6404349804], [-0.626061976]], [[-0.6068980098], [-0.5973160267000001], [-0.5925250053]], [[-0.6021069884], [-0.6021069884], [-0.6500170231]], [[-0.6979269981], [-0.7602099776000001], [-0.7650009990000001]]] => 0 (expected 0)
# [[[-3.033226967], [-3.1122784610000003], [-3.196120977]], [[-3.239239931], [-3.320687056], [-3.30152297]], [[-3.3733880519999997], [-3.42848444], [-3.375783443]], [[-3.351828575], [-3.3158960339999997], [-3.2919409280000003]], [[-3.260799408], [-3.263195038], [-3.263195038]], [[-3.246426582], [-3.188934565], [-3.164979458]], [[-3.143419981], [-3.0835325719999997], [-3.021249533]], [[-3.002085447], [-2.956571102], [-2.9541754719999997]], [[-2.9541754719999997], [-2.9302206039999996], [-2.9110565189999997]], [[-2.827214003], [-2.764930964], [-2.647551537]], [[-2.518194437], [-2.259480476], [-2.120541573]], [[-2.007952929], [-1.9887889619999999], [-1.9408789869999998]], [[-1.8905735019999999], [-1.873805046], [-1.8881779909999998]], [[-1.8905735019999999], [-6.511268616000001], [-6.326815128]], [[-6.228599547999999], [-6.127988338], [-5.984258652]], [[-5.826155663], [-5.680029869], [-5.572232723]], [[-5.4404802320000005], [-5.246444702], [-5.07636404]], [[-4.985334873], [-4.860768795], [-4.7817173]], [[-4.652360439], [-4.549354076], [-4.419997215]], [[-4.381669044], [-4.29782629], [-4.20440197]], [[-4.113372803], [-4.089417934], [-4.051089763999999]], [[-4.0151577], [-3.9720385069999997], [-3.9768295289999998]], [[-3.988806963], [-3.9025690560000004], [-3.9696431160000003]], [[-3.984015942], [-4.0750451089999995], [-4.101395607]], [[-4.144514561], [-4.2115883830000005], [-4.364900588999999]], [[-4.3984375], [-4.49186182], [-4.657151699]], [[-4.757762432], [-4.827231884], [-1.2278189659999998]], [[-1.445809484], [-1.687754989], [-1.85304451]], [[-2.039893389], [-2.231533527], [-2.384845495]], [[-2.471083403], [-2.583672047], [-2.698656082]], [[-2.6914694310000002], [-2.7202155589999997], [-2.763334513]], [[-2.82082653], [-2.837594986], [-2.902273417]], [[-2.9166464810000003], [-2.91904211], [-2.902273417]], [[-2.998093605], [-3.041212559], [-3.086726904]], [[-3.084331512], [-3.062772036], [-3.101099968]], [[-3.0987045760000003], [-2.9909069539999997], [-2.952579021]], [[-2.818430901], [-2.6962604519999998], [-2.583672047]], [[-2.468688011], [-2.4351511], [-2.4351511]], [[-2.475874424], [-2.406404972], [-2.291420937]], [[-2.1213405130000003], [-1.905745506], [-1.72368753]]] => 0 (expected 1)
# [[[2.284782887], [2.119493484], [1.9997185469999998]], [[1.75298202], [1.523013949], [1.290650487]], [[1.046309471], [0.8187369704], [0.6462609767999999]], [[0.4258750081], [0.2869360149], [0.1791384965]], [[0.047386001799999994], [-0.07957550138], [-0.1682090014]], [[-0.23767849800000002], [-0.2544470131], [-0.35745349530000003]], [[-0.4245274961], [-0.5610709786], [-0.6425179839]], [[-0.6688684821], [-0.7766659856], [-0.9012320042]], [[-1.0018429759999998], [-1.121618032], [-1.217437983]], [[-1.4258464569999998], [-1.528853059], [-1.643836975]], [[-1.792358041], [-1.9935799840000001], [-1.986393452]], [[-1.938483477], [-1.7684030530000001], [-1.5025024409999999]], [[-1.1144315], [-0.6521000266], [-0.1370674968]], [[0.3564054966], [-9.86975956], [-9.893714905]], [[-9.953601837], [-9.991930007999999], [-10.04702663]], [[-10.09014511], [-10.14524174], [-10.15482426]], [[-10.10212326], [-10.10691357], [-10.11170483]], [[-10.04223537], [-9.967974663], [-9.903296471]], [[-9.764357567000001], [-9.67572403], [-9.565530777000001]], [[-9.424196242999999], [-9.340353966], [-9.242138863]], [[-9.084035873], [-9.014566422], [-8.918745995]], [[-8.858858109], [-8.830112457], [-8.815739632]], [[-8.952282906], [-9.079244614], [-9.278071404]], [[-9.536785126], [-9.989534378], [-10.45905209]], [[-11.01959991], [-11.54421425], [-12.15027523]], [[-12.67009926], [-13.07493877], [-13.36239815]], [[-13.62829876], [-13.87263966], [8.54582119]], [[8.473956108], [8.323039055], [8.112235069]], [[7.920595646000001], [7.728955269], [7.647508621]], [[7.503778457999999], [7.431913376000001], [7.427122592999999]], [[7.436704636], [7.407958507999999], [7.32411623]], [[7.22110939], [7.161221981000001], [7.055819988]], [[6.912089825], [6.904903412], [6.964790821]], [[7.039051532999999], [7.007909775], [6.969582081]], [[6.916881084], [6.943231582999999], [6.785128593]], [[6.593488692999999], [6.5359964370000005], [6.519227982]], [[6.502459526], [6.502459526], [6.54797411]], [[6.397057533], [6.176671505], [5.836510658]], [[5.426879883], [5.101091862], [4.969339371]], [[4.892683506], [4.7992591860000005], [4.911847591]]] => 0 (expected 1)
# [[[-0.03413600102], [-0.2736859918], [-0.6713389754000001]], [[-1.236677051], [-1.893043995], [-2.362561941]], [[-2.645231009], [-2.81291604], [-2.9087359910000004]], [[-2.961436987], [-2.994973898], [-3.1195399760000004]], [[-3.277642965], [-3.253688097], [-3.2584791180000003]], [[-3.244106054], [-3.263269901], [-3.3159708980000002]], [[-3.32555294], [-3.148286104], [-2.84166193]], [[-2.515873909], [-2.237996101], [-2.0798931119999997]], [[-1.8834619519999998], [-1.6439119580000001], [-1.279796004]], [[-0.9204710126000001], [-0.5371909738], [-0.20661200579999997]], [[0.1143850014], [0.5264109968999999], [0.8761540055]], [[1.11570406], [1.197150946], [1.345672011]], [[1.40795505], [1.4989839790000001], [1.4941929580000002]], [[1.585222006], [13.66348267], [13.31853104]], [[13.03586197], [12.76277542], [12.50406075]], [[12.19264603], [11.89560413], [11.55544281]], [[11.18174458], [10.97573185], [10.74097347]], [[10.53495979], [10.40560341], [10.15647125]], [[9.878593445], [9.730072021], [9.629461288]], [[9.500103951], [9.485731125], [9.466567039]], [[9.490522385], [9.365956306000001], [9.356373787]], [[9.26534462], [9.298881531000001], [9.356373787]], [[9.46177578], [9.50489521], [9.50968647]], [[9.50489521], [9.452194214], [9.423447609]], [[9.389910698], [9.284508705], [9.212643623]], [[9.07370472], [8.973093987], [8.87727356]], [[8.72875309], [8.618559837000001], [-0.36255699399999997]], [[-0.38172098990000003], [-0.42963099479999994], [-0.4152579904]], [[-0.324229002], [-0.18049900230000002], [0.274646014]], [[0.9789230227], [1.093906999], [0.8160290122]], [[0.6100159883], [0.4950320125], [0.5908520222]], [[0.8016560078], [1.0364149809999998], [1.280755997]], [[1.381366968], [1.467604995], [1.5250970130000001]], [[1.5394699569999999], [1.592170954], [1.7215280530000001]], [[1.783810973], [1.802975059], [1.879631042]], [[1.913167953], [1.9419139619999999], [1.937122941]], [[1.8892129659999999], [1.870049], [1.8604669569999999]], [[1.932332039], [1.96586895], [1.96586895]], [[1.9227499959999999], [1.9467049840000001], [1.956287026]], [[1.8892129659999999], [1.798184037], [1.683200002]]] => 1 (expected 1)
# ...
# [[[2.3870191569999997], [2.133233786], [1.996764183]], [[1.975216389], [1.965639591], [2.006340981]], [[2.080561161], [2.099714994], [1.9464859959999998]], [[1.563413739], [1.072602391], [0.6607996821000001]], [[0.4165911078], [0.3399766386], [0.3208230138]], [[0.3591302633], [0.5243301988], [0.8667010069]], [[1.3479355569999998], [1.8315643069999998], [2.236184359]], [[2.480392933], [2.614468336], [2.583343744]], [[2.540247917], [2.2433669569999997], [1.723825216]], [[1.285686255], [0.8499416112999999], [0.3040636182]], [[-0.1651999205], [-0.5817909836999999], [-1.156399369]], [[-1.6615760330000002], [-2.205059767], [-2.707842112]], [[-3.1364042760000004], [-3.330334663], [-3.095702887]], [[-2.8467059139999997], [-9.054870605], [-9.057265282000001]], [[-9.042900085], [-9.030928612], [-9.006986617999999]], [[-8.920795441000001], [-8.777143478], [-8.626308441]], [[-8.528146743999999], [-8.532935143], [-8.650250435]], [[-8.858546257], [-9.083600998], [-9.339780807]], [[-9.603142737999999], [-10.01015759], [-10.39801788]], [[-10.83855152], [-11.37724686], [-11.96382618]], [[-12.58871269], [-13.25908947], [-13.74271774]], [[-14.06114674], [-14.13057804], [-13.97016716]], [[-13.73553562], [-13.25190639], [-12.61744308]], [[-11.93270111], [-11.3078146], [-10.64701462]], [[-10.09395409], [-9.646238327], [-9.323021889]], [[-8.990227699], [-8.760383606], [-8.647856712000001]], [[-8.46589756], [-8.508993149], [3.476380825]], [[3.406949043], [3.330334663], [3.3111810680000002]], [[3.268085241], [3.2225954530000003], [3.1172506810000002]], [[3.0166940689999997], [2.8538885119999997], [2.616862535]], [[2.2984335419999997], [1.9033904080000001], [1.477222443]], [[1.086967587], [0.7158663273], [0.5770025849]], [[0.5650315881], [0.5937620401], [0.7062895298]], [[0.921767652], [1.177947283], [1.44849205]], [[1.769315004], [2.013523579], [2.190694571]], [[2.188300371], [2.2433669569999997], [2.312798738]], [[2.11647439], [1.936909199], [1.738190413]], [[1.493981838], [1.367089152], [1.249773264]], [[0.8403648137999999], [0.29209262129999997], [-0.02394201607]], [[-0.2130839527], [-0.4405331016], [-0.39743748310000004]]] => 0 (expected 0)
# [[[3.882581472], [3.415458918], [2.9746870989999996]], [[2.4907960890000003], [2.088351965], [1.844010949]], [[1.7721459869999998], [1.173270941], [0.5025309920000001]], [[0.056967999789999994], [-0.3478715122], [-0.5802350044]], [[-0.7383379936], [-0.79103899], [-0.8078075051000001]], [[-0.7287560104999999], [-0.4987879992], [-0.3334985077]], [[-0.1155079976], [-0.01489700004], [0.02343099937]], [[0.1575790048], [0.3779650033], [0.4067110121]], [[0.3516145051], [0.5049265027000001], [0.7684314847]], [[0.9648625255], [1.103801489], [1.218785524]], [[1.345746994], [1.326583028], [1.3601200580000001]], [[1.350538015], [1.307418942], [1.257113457]], [[1.305023551], [1.293045998], [1.225972056]], [[1.26909101], [-10.17159271], [-9.843408585]], [[-9.512829781], [-9.263697624], [-9.12715435]], [[-8.93311882], [-8.923537254], [-8.791784286]], [[-8.59056282], [-8.54983902], [-8.583375931]], [[-8.609726906], [-8.655241013], [-8.703150749]], [[-8.765434265], [-8.863649367999999], [-8.957074165]], [[-9.040916442999999], [-9.151109695], [-9.285257339]], [[-9.32118988], [-9.309212685], [-9.378682137]], [[-9.342749596], [-9.314003944], [-9.256511688]], [[-9.177459717], [-9.196623802000001], [-9.175064087]], [[-9.208601952], [-9.278071404], [-9.342749596]], [[-9.345145226], [-9.407427788], [-9.488875389]], [[-9.563135147], [-9.584694862000001], [-9.599067688]], [[-9.615836143], [-9.654164313999999], [0.2094810009]], [[0.1831305027], [0.1663620025], [0.1208475009]], [[0.1543844938], [0.1328250021], [0.2765550017]], [[0.2286449969], [0.1304295063], [0.10647449640000001]], [[0.1591755003], [0.3053010106], [0.2885324955]], [[0.1184519976], [0.09449700266000001], [-0.06360600143999999]], [[-0.23847749829999998], [-0.39178949590000006], [-0.44209501149999997]], [[-0.5187510252], [-0.578638494], [-0.616966486]], [[-0.7678830028], [-0.6217575073], [-0.3510659933]], [[-0.269618988], [-0.1115159988], [-0.03486000001]], [[0.0034680000969999998], [0.08012399822], [0.07772850245]], [[0.1160565019], [0.1855259985], [0.2142720073]], [[0.1208475009], [0.2262495011], [0.2885324955]], [[0.2957189977], [0.2478089929], [0.22145849469999998]]] => 1 (expected 1)
# [[[0.3543418646], [0.4692635238], [0.8092401624]], [[1.314416766], [1.613691926], [2.30801034]], [[2.700659513], [3.548206806], [4.280832767]], [[4.630385876], [5.305551052], [6.057330132000001]], [[6.385335922], [7.038952827], [7.627926826]], [[7.884106159], [8.269572258], [8.537723541]], [[8.576030731], [8.468291283], [8.101978302000001]], [[7.817068577000001], [7.086836815], [6.162675381000001]], [[5.638344765], [4.604049683], [4.079719543]], [[3.114856482], [2.262520552], [1.874659896]], [[1.15400517], [0.5099649428999999], [0.1364694983]], [[-0.5554547906], [-1.031900883], [-1.22583127]], [[-1.616086125], [-1.927332401], [-2.070984364]], [[-2.331952572], [-9.998186111], [-10.43393135]], [[-11.288661], [-12.13142014], [-12.56237602]], [[-13.38119316], [-13.73553562], [-14.30056667]], [[-14.96376038], [-15.29894924], [-15.89031696]], [[-16.37633896], [-16.5870285], [-16.9006691]], [[-17.02995682], [-17.00601387], [-16.76180649]], [[-16.30690765], [-16.01002693], [-15.31570816]], [[-14.49689102], [-14.05875206], [-13.18008041]], [[-12.32535076], [-11.8967886], [-11.08515358]], [[-10.7044754], [-10.00297451], [-9.363722801]], [[-9.081207275], [-8.588001251], [-8.140285492]], [[-7.908048152999999], [-7.51061058], [-7.252037047999999]], [[-7.127538681], [-6.87854147], [-6.651092529]], [[-6.5241994860000005], [-6.27999115], [-4.630385876]], [[-4.4316673280000005], [-3.988739967], [-3.600879431]], [[-3.3854012489999996], [-2.925714493], [-2.698265314]], [[-2.245761156], [-1.82198751], [-1.6400281190000001]], [[-1.242590666], [-0.8786720037000001], [-0.7302315235]], [[-0.4405331016], [-0.1628057212], [0.0]], [[0.35673606399999996], [0.7972691654999999], [1.00317049]], [[1.395819545], [1.82198751], [2.003946781]], [[2.274491549], [2.425326347], [2.439691544]], [[2.379836559], [2.315192938], [2.183511972]], [[2.0183119769999998], [1.9177556040000001], [1.74776721]], [[1.611297727], [1.5227122309999999], [1.367089152]], [[1.288080573], [1.244984865], [1.1492167709999999]], [[1.029506683], [0.9624691009999999], [0.7805097699]]] => 0 (expected 0)
# [[[-0.6330109835000001], [-0.5803099871], [-0.532400012]], [[-0.4796989858], [-0.40783399340000004], [-0.37429699299999997]], [[-0.3120140135], [-0.2928499877], [-0.2257760018]], [[-0.12995600699999998], [-0.014972000380000001], [0.05210199952]], [[0.06168400124], [0.1431310028], [0.2102050036]], [[0.19583199920000002], [0.15750400720000002], [0.13833999630000002]], [[0.1000119969], [0.07126600295], [0.02814700082]], [[0.004191999789], [-0.10600099710000001], [-0.25452199579999996]], [[-0.3311780095], [-0.3982520103], [-0.5180270076]], [[-0.6234290004], [-0.6378020047999999], [-0.6713389754000001]], [[-0.6905030012000001], [-0.6952940226000001], [-0.7048760056000001]], [[-0.7336220145], [-0.7432039976], [-0.7719500065]], [[-0.8102779984], [-0.8150690198], [-0.7863230109]], [[-0.8150690198], [9.916920662], [9.84984684]], [[9.792354584], [9.720490456], [9.629461288]], [[9.65341568], [9.591133118], [9.519268036]], [[9.519268036], [9.476148605], [9.433030128]], [[9.471358299], [9.471358299], [9.50968647]], [[9.610297203], [9.662998199], [9.758817673]], [[9.816309928999999], [9.873802185], [9.960040092]], [[10.03669643], [10.15647125], [10.1852169]], [[10.24270916], [10.30020142], [10.41039371]], [[10.46788597], [10.49184132], [10.5110054]], [[10.4822588], [10.45830441], [10.41518497]], [[10.2906189], [10.20917225], [10.15647125]], [[10.09418774], [10.06065083], [10.046278]], [[10.07502365], [10.14209843], [-1.062042952]], [[-1.09078896], [-1.062042952], [-1.0572520490000001]], [[-1.076416016], [-1.076416016], [-1.052461028]], [[-1.09078896], [-1.095579982], [-1.1147439479999999]], [[-1.177026987], [-1.172235966], [-1.18660903]], [[-1.200981975], [-1.2441010479999999], [-1.153072]], [[-1.1243259909999999], [-1.09078896], [-1.052461028]], [[-1.018923998], [-1.042878985], [-1.0572520490000001]], [[-1.033296943], [-1.047670007], [-1.0572520490000001]], [[-1.081207037], [-1.062042952], [-1.066833973]], [[-1.105162024], [-1.105162024], [-1.119534969]], [[-1.1243259909999999], [-1.129117012], [-1.042878985]], [[-0.9997599720999999], [-0.9662230015000001], [-0.8943579793]], [[-0.7985380292], [-0.7410460114], [-0.6021069884]]] => 0 (expected 0)
# [[[1.175553083], [1.019929886], [0.9840168953]], [[0.9792284966], [0.9457096456999999], [0.9888052940000001]], [[0.9265560508], [0.7613561153], [0.4979939461]], [[0.1436520964], [-0.2298433632], [-0.5195417404]], [[-0.5506663918], [-0.5913678407999999], [-0.5889736414]], [[-0.5961562395000001], [-0.7254431248000001], [-0.9600749016]], [[-1.094150186], [-1.505952835], [-1.7908629180000002]], [[-2.260126352], [-2.930502892], [-3.579331636]], [[-4.118026733], [-4.443638325], [-4.414907932]], [[-4.276044369], [-3.8283286089999997], [-3.2800562380000002]], [[-2.614468336], [-1.800439715], [-1.15400517]], [[-0.787692368], [-0.6129156351], [-0.2681505978]], [[-0.0023942017], [0.5602431892999999], [0.8906430602]], [[0.9289502501000001], [-13.55836391], [-13.00290966]], [[-12.46181965], [-11.98776817], [-11.41315937]], [[-10.80024433], [-10.22802925], [-9.864110947]], [[-9.52173996], [-9.289502144], [-9.095572472]], [[-8.839392662], [-8.655038833999999], [-8.535328865]], [[-8.54251194], [-8.633491516], [-8.868123055]], [[-9.13866806], [-9.380482674], [-9.655815125]], [[-9.749189377], [-9.706093787999999], [-9.804255486]], [[-9.935936928], [-10.10592556], [-10.27591324]], [[-10.26394272], [-10.0317049], [-9.830592155]], [[-9.651026726], [-9.428366661], [-9.203310966]], [[-8.906430244], [-8.638279915], [-8.406042099]], [[-8.365341187], [-8.501810074], [-8.61912632]], [[-8.710105896], [-8.757989882999999], [4.335899353]], [[4.4891281130000005], [4.398148537], [4.1994299889999995]], [[3.878606796], [3.38061285], [2.904166698]], [[2.334346771], [1.9177556040000001], [1.362300754]], [[0.7062895298], [0.14844051], [-0.1364694983]], [[-0.07422025502], [0.1388636976], [0.5147533417]], [[0.8810662031000001], [1.158793569], [1.290474772]], [[1.271321058], [1.2210428709999999], [1.843535304]], [[2.1284453869999997], [2.178723574], [2.482787132]], [[2.6312277319999997], [2.4636335369999998], [2.67432332]], [[2.41335535], [1.8602947], [1.4796166419999999]], [[1.237802267], [1.244984865], [1.223437071]], [[1.517923832], [1.6974890230000002], [1.877054095]], [[1.8650830980000002], [2.1068975930000002], [2.875436306]]] => 0 (expected 0)
# [[[-0.5530605912], [-1.091755986], [-1.589749932]], [[-1.8052281140000002], [-2.217030764], [-2.588132143]], [[-2.772485495], [-3.167528868], [-3.500322819]], [[-3.648763418], [-3.936067581], [-4.173093796]], [[-4.2568907739999995], [-4.357447147], [-4.367023945]], [[-4.333505154], [-4.240131378], [-4.165910721]], [[-3.998316765], [-3.8307228089999996], [-3.7181952]], [[-3.423708439], [-3.126827478], [-2.9664158819999997]], [[-2.604891539], [-2.173935175], [-1.9464859959999998]], [[-1.477222443], [-0.9241618514], [-0.6344634295]], [[-0.04309562966], [0.5650315881], [0.8786720037000001]], [[1.517923832], [2.15478158], [2.437297344]], [[3.0238766669999997], [3.34469986], [3.926490784]], [[4.38617754], [-8.054094315], [-7.637503624]], [[-7.24485445], [-7.048529625], [-6.6798229220000005]], [[-6.387730122000001], [-6.253654957], [-6.02381134]], [[-5.877765179], [-5.803544998], [-5.691017627999999]], [[-5.640739441], [-5.650316237999999], [-5.6958060260000005]], [[-5.83466959], [-5.8969187739999995], [-6.069301127999999]], [[-6.169857979], [-6.349422932], [-6.552929878]], [[-6.663063526], [-6.938396453999999], [-7.237671852]], [[-7.378929615], [-7.6782050129999995], [-8.013393402]], [[-8.188169478999999], [-8.55448246], [-8.949525833]], [[-9.172186852000001], [-9.643844604], [-10.10831928]], [[-10.32379818], [-10.75954247], [-11.16416264]], [[-11.33654499], [-11.6669445], [-11.84172153]], [[-12.10987186], [-12.2750721], [0.5985504389]], [[0.7015010715000001], [0.7781155705], [0.8116343617]], [[0.8355764151], [0.7757213712000001], [0.7374141216]], [[0.6129156351], [0.5027823448], [0.4189853072]], [[0.2346317619], [0.08619125932], [-0.0023942017]], [[-0.17956513170000002], [-0.3423708379], [-0.4165911078]], [[-0.5602431892999999], [-0.6392518282], [-0.7829039693000001]], [[-0.9313444495000001], [-1.015141487], [-1.170764685]], [[-1.316810966], [-1.395819545], [-1.5442601440000001]], [[-1.651999116], [-1.707065821], [-1.812410712]], [[-1.829170108], [-1.8315643069999998], [-1.838746905]], [[-1.8698714969999999], [-1.8866308930000002], [-1.9345149990000001]], [[-1.912967205], [-1.884236693], [-1.881842494]], [[-1.867477298], [-1.67115283], [-1.37427175]]] => 0 (expected 0)
# [[[-3.406949043], [-3.483563423], [-3.5194764139999997]], [[-3.287238836], [-3.320757866], [-2.901772499]], [[-2.317587137], [-1.7764976019999998], [-1.283292055]], [[-1.07739079], [-1.055842996], [0.09576806426000001]], [[0.5602431892999999], [1.2138602729999999], [1.6950948240000001]], [[1.575384736], [1.292868972], [0.9720458984]], [[0.7254431248000001], [0.6129156351], [0.5817909836999999]], [[0.6847416759], [0.8954314590000001], [1.173158884]], [[1.4173674580000002], [1.515529633], [1.7118542190000001]], [[1.841141105], [1.850717902], [1.6615760330000002]], [[1.290474772], [0.8212111592], [0.33758243920000003]], [[-0.1340752989], [-0.5626373887], [-0.9744400978]], [[-1.288080573], [-1.532289028], [-1.683123827]], [[-1.754949808], [-9.205705643], [-9.47146225]], [[-9.648633002999999], [-9.605537415], [-9.43315506]], [[-9.10036087], [-8.757989882999999], [-8.499416351]], [[-8.06127739], [-7.706935406], [-7.443572998]], [[-7.117961884], [-7.074865817999999], [-7.414842606000001]], [[-7.781155586000001], [-8.276755332999999], [-8.588001251]], [[-8.834604263], [-9.011775017], [-9.093177795]], [[-9.179368972999999], [-9.18894577], [-9.131484985]], [[-9.064447402999999], [-9.050082207], [-8.918401718]], [[-8.705317497000001], [-8.58081913], [-8.50420475]], [[-8.50420475], [-8.518569946], [-8.540117264]], [[-8.597578049], [-8.678980827], [-8.77235508]], [[-8.839392662], [-8.935160637000001], [-9.026140213]], [[-9.117119789], [-9.279925346], [4.757278919]], [[4.410119534], [5.231330872], [6.030993938]], [[6.162675381000001], [5.667075634], [5.183446883999999]], [[4.6184148789999995], [4.376600742], [4.000710964]], [[3.727771997], [3.785232782], [3.730166197]], [[3.526659012], [3.167528868], [2.892195702]], [[2.645592928], [2.30561614], [1.951274395]], [[1.728613615], [1.556231141], [1.436521053]], [[1.4413094519999998], [1.491587639], [1.383848548]], [[1.278503656], [1.185129881], [1.261744261]], [[1.364694953], [1.4077905419999999], [1.5825673340000002]], [[1.9201498030000002], [2.418143749], [2.93529129]], [[3.5625722410000003], [3.983951569], [4.328716755]], [[4.563348293], [4.8314991], [4.970362663]]] => 0 (expected 1)

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:' ,accuracy*100)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f', precision*100)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f', recall*100)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f',f1)
 # kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f', kappa)
# ROC AUC
auc_1 = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f', auc_1)
# confusion matrix
matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix' , matrix)
# MAE
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error', mae)
#RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('Root Mean Squared Error', rmse)
# Out:
# Accuracy: 78.45230153435624
# Precision: %f 85.60855263157895
# Recall: %f 68.84920634920636
# F1 score: %f 0.7631964809384164
# Cohens kappa: %f 0.5697504754118756
# ROC AUC: %f 0.7853631246127881
# Confusion Matrix [[1311  175]
#  [ 471 1041]]
# Mean Absolute Error 0.21547698465643764
# Root Mean Squared Error 0.464194985600273

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred)
auc_keras = auc(fpr_keras, tpr_keras)
plt.figure(1)
plt.plot([0, 1], [0, 1])
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras), marker='o', markersize=10)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Characteristic (ROC) curve')
plt.legend(loc = 'lower right')
plt.show()
