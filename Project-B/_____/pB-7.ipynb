# %% [markdown]
# #### CIE-Project B || Group - 7

# %% [markdown]
# #### Imports

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
from scipy.signal import resample, find_peaks
from scipy.io import loadmat
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pickle
import time

# from sklearn import preprocessing ##importing for normalization
# from sklearn.decomposition import PCA
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import MinMaxScaler, minmax_scale, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error
from sklearn.multioutput import MultiOutputRegressor
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D, AveragePooling1D, GlobalAveragePooling1D
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['legend.frameon'] = True
# plt.rcParams['figure.figsize'] = (8, 8)
# %matplotlib widget
# %matplotlib inline

tf.random.set_seed(1)
np.random.seed(2)
# Out:
# 2022-02-27 09:00:50.754970: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/impi/2018.4.274/compilers_and_libraries/linux/mpi/lib64:/opt/intel/impi/2018.4.274/compilers_and_libraries/linux/mpi/lib:/opt/intel/Compiler/19.0/1.144/rwthlnk/daal/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/daal/lib/ia32_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/ipp/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/ipp/lib/ia32_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/mkl/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/mkl/lib/ia32_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/tbb/lib/intel64_lin/gcc4.7:/opt/intel/Compiler/19.0/1.144/rwthlnk/tbb/lib/ia32_lin/gcc4.7:/opt/intel/Compiler/19.0/1.144/rwthlnk/compiler/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/compiler/lib/ia32_lin
# 2022-02-27 09:00:50.754997: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ##### Get the root directory and change to it

# %%
rootdir = os.getcwd()
os.chdir(rootdir)

# %% [markdown]
# #### Folder Variables Assignment

# %%
# Names of the folders
Training_Folder = 'EPOT_DATA'
Validation_Aug_Folder = 'Validation_augmented_data'
Experiment = 'Experiment_Data_Group7'
Ex_Validation = 'Experimental_validation'

counter = 0

# %% [markdown]
# #### Parsing

# %% [markdown]
# ##### Parse training and validation-augmented data

# %%
# Initialize lists for training and validation
training_tr = []; training_tr_labels = []

validation_aug = []; validation_aug_labels = [] # validation augmented data

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Training_Folder.lower() in subdir.lower():
        for file in files:
            if file.endswith('.mat'):
                lbl = [file.split('_')[1], file.split('_')[2][:3]]
                lb = np.asarray(lbl, dtype=float)
                # load mat-file
                mat = loadmat(os.path.join(subdir, file))
                # get the numpy data from the mat file
                mat = mat['num_data']
                # append data to the list
                training_tr.append(mat)
                training_tr_labels.append(lb)

    elif Validation_Aug_Folder.lower() in subdir.lower():
        for file in files:
            if file.endswith('.mat'):
                lbl = [file.split('_')[1], file.split('_')[2][:3]]
                lb = np.asarray(lbl, dtype=float)
                # load mat-file
                mat = loadmat(os.path.join(subdir, file))
                # get the numpy data from the mat file
                mat = mat['num_data']
                # append data to the list
                validation_aug.append(mat)
                validation_aug_labels.append(lb)

# %%
plt.close()
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

l = 6

fig.suptitle(f'EPOT Training Data - {training_tr_labels[l]}')

axs[0,0].plot(training_tr[l][:,0], training_tr[l][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training_tr[l][:,0], training_tr[l][:,2], label='P - 2', c = 'g')
axs[1,0].plot(training_tr[l][:,0], training_tr[l][:,3], label='P - 3', c = 'b')
axs[1,1].plot(training_tr[l][:,0], training_tr[l][:,4], label='P - 4', c = 'y')

fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Parse, Cut, Normalize, and Resample the experimental data

# %%
# Initialize lists for training and validation
ex_data = []; ex_labels = []

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Experiment.lower() in subdir.lower():
        for file in files:
            if file.endswith('.txt'):
                
                with open(os.path.join(subdir, file), 'r') as f:
                    x = pd.read_csv(os.path.join(subdir, file), delimiter='\t', decimal=',', skiprows=8, header=None)
                    x = np.asarray(x, dtype=float)
                    ex_data.append(x)

# %%
plt.close()
l = 5
plt.plot(ex_data[l][:,0], ex_data[l][:,1], label='P - 1', c = 'r')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ex_cut_data = []
for i in range(len(ex_data)):
    
    threshold = 0.1

    x = np.where(abs(ex_data[i][:,1])>threshold)[0][0]
    y = np.where(abs(ex_data[i][:,2])>threshold)[0][0]
    z = np.where(abs(ex_data[i][:,3])>threshold)[0][0]
    p = np.where(abs(ex_data[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)
    end = start+200

    d = np.empty_like(ex_data[i][start:end,:])

    d[:,0] = ex_data[i][start:end, 0]
    d[:,1] = (-1)*ex_data[i][start:end, 1]
    d[:,2] = (-1)*ex_data[i][start:end, 2]
    d[:,3] = (-1)*ex_data[i][start:end, 4]
    d[:,4] = (-1)*ex_data[i][start:end, 3]

    ex_cut_data.append(d)

# %%
plt.close()
l = 5
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,1], label='P - 1')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,2], label='P - 2')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,3], label='P - 3')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,4], label='P - 4')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Normalize and Resample experimental data

# %%
# create variables for normalized data
ex_norm = np.zeros_like(np.asarray(ex_cut_data))

for i in range (0, len(ex_cut_data)):
    for j in range (1, 5):
        ex_norm[i][:,j] = minmax_scale(ex_cut_data[i][:,j])

# %%
ex_resample = []

# create a dataframe from the normalized data
for i in range (0, len(ex_norm)):
    ex_resample.append(pd.DataFrame(ex_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    ex_resample[i] = ex_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(ex_resample)):
    ex_resample[i] = resample(ex_resample[i], size)

np.asarray(ex_resample).shape
# Out:
# (18, 100, 4)

# %% [markdown]
# ##### Parse, Cut, Normalize, and Resample the experimental validation data

# %%
# Initialize lists for training and validation
ex_val_data = []; ex_val_labels = []

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Ex_Validation.lower() in subdir.lower():
        for file in files:
            if file.endswith('.txt'):
                
                with open(os.path.join(subdir, file), 'r') as f:
                    # print(file.split('_')[2], file.split('_')[3], file.split('_')[5][:3])
                    lbl = [file.split('_')[2], file.split('_')[3], file.split('_')[5][:3]]
                    lb = np.asarray(lbl, dtype=float)

                    x = pd.read_csv(os.path.join(subdir, file), delimiter='\t', decimal=',', skiprows=8, header=None)
                    x = np.asarray(x, dtype=float)
                    ex_val_data.append(x)
                    ex_val_labels.append(lb)


ex_val_trails = np.asarray(ex_val_labels)[:,2]
ex_val_labels = np.delete(ex_val_labels, 2, 1)

# %%
# ex_val_cut_data=[]
# for i in range(0,len(ex_val_data)):
#     data=ex_data[i][:,0]
    
#     start_time = 0.04996
#     end_time = 0.05016
#     start=np.where(data==(start_time))
#     end = np.where(data==(end_time))
    
#     d = np.zeros(((start[0][0]+200-start[0][0]),5))

#     d[:,0]=ex_val_data[i][start[0][0]:start[0][0]+200,0]
#     d[:,1]=ex_val_data[i][start[0][0]:start[0][0]+200,1]
#     d[:,2]=ex_val_data[i][start[0][0]:start[0][0]+200,2]
#     d[:,3]=ex_val_data[i][start[0][0]:start[0][0]+200,4]
#     d[:,4]=ex_val_data[i][start[0][0]:start[0][0]+200,3]
    
#     ex_val_cut_data.append(d)
#----------------------------------------------------------------------------------------


ex_val_cut_data = []
for i in range(len(ex_val_data)):
    
    threshold = 0.1

    x = np.where(abs(ex_val_data[i][:,1])>threshold)[0][0]
    y = np.where(abs(ex_val_data[i][:,2])>threshold)[0][0]
    z = np.where(abs(ex_val_data[i][:,3])>threshold)[0][0]
    p = np.where(abs(ex_val_data[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)
    end = start+180

    d = np.empty_like(ex_val_data[i][start:end,:])

    d[:,0] = ex_val_data[i][start:end, 0]
    d[:,1] = (-1)*ex_val_data[i][start:end, 1]
    d[:,2] = (-1)*ex_val_data[i][start:end, 2]
    d[:,3] = (-1)*ex_val_data[i][start:end, 4]
    d[:,4] = (-1)*ex_val_data[i][start:end, 3]

    ex_val_cut_data.append(d)

# %% [markdown]
# Normalize and Resample experimental validation data

# %%
# create variables for normalized data
ex_val_norm = np.zeros_like(np.asarray(ex_val_cut_data)); ex_val_norm_labels = np.zeros_like(np.asarray(ex_val_cut_data))

for i in range (0, len(ex_val_cut_data)):
    for j in range (1, 5):
        ex_val_norm[i][:,j] = minmax_scale(ex_val_cut_data[i][:,j])

scalar = MinMaxScaler()
ex_val_norm_labels = scalar.fit_transform(ex_val_labels)

# %%
ex_val_resample = []

# create a dataframe from the normalized data
for i in range (0, len(ex_val_norm)):
    ex_val_resample.append(pd.DataFrame(ex_val_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    ex_val_resample[i] = ex_val_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(ex_val_resample)):
    ex_val_resample[i] = resample(ex_val_resample[i], size)

np.asarray(ex_val_resample).shape
# Out:
# (24, 100, 4)

# %% [markdown]
# #### Augmentation

# %% [markdown]
# ##### Variable initialization

# %%
## -----------------------------------------------------------------------------
#Assuming P1 on top and counter clockwise order
## -----------------------------------------------------------------------------


# Variables for the augmented data
training_tl = np.zeros_like(np.asarray(training_tr)); training_tl_labels = np.zeros_like(np.asarray(training_tr_labels))
training_bl = np.zeros_like(np.asarray(training_tr)); training_bl_labels = np.zeros_like(np.asarray(training_tr_labels))
training_br = np.zeros_like(np.asarray(training_tr)); training_br_labels = np.zeros_like(np.asarray(training_tr_labels))

# %% [markdown]
# ##### Top-Left

# %%
for i in range (0, len(training_tr)):
        training_tl[i][:,0] = training_tr[i][:,0]
        training_tl[i][:,1] = training_tr[i][:,1]
        training_tl[i][:,2] = training_tr[i][:,4]
        training_tl[i][:,3] = training_tr[i][:,3]
        training_tl[i][:,4] = training_tr[i][:,2]

for i in range (0, len(training_tl_labels)):
    training_tl_labels[i][0] = 500 - training_tr_labels[i][0]
    training_tl_labels[i][1] = training_tr_labels[i][1]

# %% [markdown]
# ##### Bottom-Left

# %%
for i in range (0, len(training_bl)):
    training_bl[i][:,0] = training_tl[i][:,0]
    training_bl[i][:,1] = training_tl[i][:,3]
    training_bl[i][:,2] = training_tl[i][:,2]
    training_bl[i][:,3] = training_tl[i][:,1]
    training_bl[i][:,4] = training_tl[i][:,4]

for i in range (0, len(training_bl_labels)):
    training_bl_labels[i][0] = 500. - training_tr_labels[i][0]
    training_bl_labels[i][1] = 500. - training_tr_labels[i][1]

# %% [markdown]
# ##### Bottom-Right

# %%
for i in range (0, len(training_br)):
        training_br[i][:,0] = training_bl[i][:,0]
        training_br[i][:,1] = training_bl[i][:,1]
        training_br[i][:,2] = training_bl[i][:,4]
        training_br[i][:,3] = training_bl[i][:,3]
        training_br[i][:,4] = training_bl[i][:,2]

for i in range (0, len(training_br_labels)):
    training_br_labels[i][0] = training_tr_labels[i][0]
    training_br_labels[i][1] = 500 - training_tr_labels[i][1]

# %% [markdown]
# ##### Delete overlapping data points

# %%
training_tl = np.delete(np.asarray(training_tl), np.where(np.asanyarray(training_tl_labels) == 250.)[0], axis = 0)
training_tl_labels = np.delete(np.asarray(training_tl_labels), np.where(np.asanyarray(training_tl_labels) == 250.)[0], axis = 0)

training_bl = np.delete(np.asarray(training_bl), 0, axis = 0)
training_bl_labels = np.delete(np.asarray(training_bl_labels), 0, axis = 0)

training_br = np.delete(np.asarray(training_br), np.where(np.asanyarray(training_br_labels) == 250.)[0], axis = 0)
training_br_labels = np.delete(np.asarray(training_br_labels), np.where(np.asanyarray(training_br_labels) == 250.)[0], axis = 0)

# %% [markdown]
# ##### Makesure the augmentation is done on all quadrants

# %%
print(f'{np.asarray(training_tl).shape} \t{np.asarray(training_tr).shape} \n{np.asarray(training_bl).shape} \t{np.asarray(training_br).shape} \n{counter}')
# Out:
# (219, 20000, 5) 	(244, 20000, 5)
# (243, 20000, 5) 	(219, 20000, 5)
# 0

# %%
plt.close()
for i in range(0, len(training_tr_labels)):
    plt.plot(training_tr_labels[i][0], training_tr_labels[i][1], 'o', c = 'r')
for j in range (0, len(training_tl_labels)):
    plt.plot(training_tl_labels[j][0], training_tl_labels[j][1], 's', c = 'g')
    plt.plot(training_br_labels[j][0], training_br_labels[j][1], 'P', c = 'y')
for k in range (0, len(training_bl_labels)):
    plt.plot(training_bl_labels[k][0], training_bl_labels[k][1], '*', c = 'b')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Concatenate, Cut, Normalize, Resample Training Data

# %% [markdown]
# ##### Concatenate

# %%
training = np.concatenate((training_tr, training_tl, training_bl, training_br), axis = 0)
training_labels = np.concatenate((training_tr_labels, training_tl_labels, training_bl_labels, training_br_labels), axis = 0)

print(f'Shape of all training set: {training.shape} \nShape of all training labels: {training_labels.shape}')
# Out:
# Shape of all training set: (925, 20000, 5)
# Shape of all training labels: (925, 2)

# %% [markdown]
# ##### check with the validation augmented data

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharex=True)

val_c = 1 # Given validation folder has 4 data points. so use - (0, 1, 2, 3)

# find out the index of the validation set in the training data
x = []
for i in range (0, len(training_labels)):
    if (training_labels[i][0] == validation_aug_labels[val_c][0]) and (training_labels[i][1] == validation_aug_labels[val_c][1]):
        x.append(i)

# plot to compare the validation set with the training set
fig.suptitle(f'EPOT Training Data Coordinates - {training_labels[x[0]]} \nValidation Augmented Data Coordinates - {validation_aug_labels[val_c]}')

axs[0,0].plot(training[x[0]][:,0], training[x[0]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[x[0]][:,0], training[x[0]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[x[0]][:,0], training[x[0]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[x[0]][:,0], training[x[0]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,4], label='P - 4', c = 'y')

# check if the data is exactly the same
for i in range (1, 5):
    if np.all(training[x[0]][:,i] == validation_aug[val_c][:,i], axis = 0):
        print('Data is augmented correctly')

fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
diff = training[x[0]][:,1] - validation_aug[val_c][:,1]
diff
# Out:
# array([0.     , 0.     , 0.     , ..., 0.00011, 0.00012, 0.00012])

# %% [markdown]
# ##### -- Check -- for outliers

# %%
'''
plt.close()
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

for i in range(len(training)):
    axs[0,0].plot(training[i][:,0], training[i][:,1], label='Training P-1')
    axs[0,1].plot(training[i][:,0], training[i][:,2], label='Training P-2')
    axs[1,0].plot(training[i][:,0], training[i][:,3], label='Training P-3')
    axs[1,1].plot(training[i][:,0], training[i][:,4], label='Training P-4')

plt.show()
'''
# Out:
# "\nplt.close()\nfig, axs = plt.subplots(2, 2, sharex=True, sharey=True)\n\nfor i in range(len(training)):\n    axs[0,0].plot(training[i][:,0], training[i][:,1], label='Training P-1')\n    axs[0,1].plot(training[i][:,0], training[i][:,2], label='Training P-2')\n    axs[1,0].plot(training[i][:,0], training[i][:,3], label='Training P-3')\n    axs[1,1].plot(training[i][:,0], training[i][:,4], label='Training P-4')\n\nplt.show()\n"

# %%
'''
# %matplotlib inline
sns.set(rc={'figure.figsize':(30, 30)})

x = []; y = []; z = []

for i in range(len(training)):
    xi = training_labels[i][0]
    x.append(xi)
    yi = training_labels[i][1]
    y.append(yi)
    zi = pd.DataFrame(training[i][:,1]).max()[0]
    # zi = pd.DataFrame(training[i][:,2]).max()[0]
    # zi = pd.DataFrame(training[i][:,3]).max()[0]
    # zi = pd.DataFrame(training[i][:,4]).max()[0]

    z.append(zi)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')

ax = sns.heatmap(heatmap1_data, 
                square=True, 
                annot = True, 
                annot_kws={"fontsize": 10}, 
                fmt='.1f', 
                linewidths=0.1, 
                linecolor='gray',
                cbar_kws = dict(use_gridspec=False, location='right'))

ax.invert_yaxis()
'''
# Out:
# '\n%matplotlib inline\nsns.set(rc={\'figure.figsize\':(30, 30)})\n\nx = []; y = []; z = []\n\nfor i in range(len(training)):\n    xi = training_labels[i][0]\n    x.append(xi)\n    yi = training_labels[i][1]\n    y.append(yi)\n    zi = pd.DataFrame(training[i][:,1]).max()[0]\n    # zi = pd.DataFrame(training[i][:,2]).max()[0]\n    # zi = pd.DataFrame(training[i][:,3]).max()[0]\n    # zi = pd.DataFrame(training[i][:,4]).max()[0]\n\n    z.append(zi)\n\ndf = pd.DataFrame({\'x\': x, \'y\': y, \'z\': z})\n\nheatmap1_data = pd.pivot_table(df, values=\'z\', index=[\'y\'], columns=\'x\')\n\nax = sns.heatmap(heatmap1_data, \n                square=True, \n                annot = True, \n                annot_kws={"fontsize": 10}, \n                fmt=\'.1f\', \n                linewidths=0.1, \n                linecolor=\'gray\',\n                cbar_kws = dict(use_gridspec=False, location=\'right\'))\n\nax.invert_yaxis()\n'

# %% [markdown]
# Experimental Validation

# %%
'''
# %matplotlib inline
sns.set(rc={'figure.figsize':(30, 30)})

x = []; y = []; z = []

for i in range(len(ex_val_data)):
    xi = ex_val_labels[i][0]
    x.append(xi)
    yi = ex_val_labels[i][1]
    y.append(yi)
    zi = pd.DataFrame(ex_val_data[i][:,1]).max()[0]
    # zi = pd.DataFrame(training[i][:,2]).max()[0]
    # zi = pd.DataFrame(training[i][:,3]).max()[0]
    # zi = pd.DataFrame(training[i][:,4]).max()[0]

    z.append(zi)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')

ax = sns.heatmap(heatmap1_data, 
                square=True, 
                annot = True, 
                annot_kws={"fontsize": 10}, 
                fmt='.1f', 
                linewidths=0.1, 
                linecolor='gray',
                cbar_kws = dict(use_gridspec=False, location='right'))

ax.invert_yaxis()
'''
# Out:
# '\n%matplotlib inline\nsns.set(rc={\'figure.figsize\':(30, 30)})\n\nx = []; y = []; z = []\n\nfor i in range(len(ex_val_data)):\n    xi = ex_val_labels[i][0]\n    x.append(xi)\n    yi = ex_val_labels[i][1]\n    y.append(yi)\n    zi = pd.DataFrame(ex_val_data[i][:,1]).max()[0]\n    # zi = pd.DataFrame(training[i][:,2]).max()[0]\n    # zi = pd.DataFrame(training[i][:,3]).max()[0]\n    # zi = pd.DataFrame(training[i][:,4]).max()[0]\n\n    z.append(zi)\n\ndf = pd.DataFrame({\'x\': x, \'y\': y, \'z\': z})\n\nheatmap1_data = pd.pivot_table(df, values=\'z\', index=[\'y\'], columns=\'x\')\n\nax = sns.heatmap(heatmap1_data, \n                square=True, \n                annot = True, \n                annot_kws={"fontsize": 10}, \n                fmt=\'.1f\', \n                linewidths=0.1, \n                linecolor=\'gray\',\n                cbar_kws = dict(use_gridspec=False, location=\'right\'))\n\nax.invert_yaxis()\n'

# %% [markdown]
# ##### Cutting Training Data

# %%
train_cut = []
for i in range(len(training)):
    
    threshold = 0.1

    x = np.where(abs(training[i][:,1])>threshold)[0][0]
    y = np.where(abs(training[i][:,2])>threshold)[0][0]
    z = np.where(abs(training[i][:,3])>threshold)[0][0]
    p = np.where(abs(training[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)

    d = np.empty_like(training[i][start:,:])

    d[:,0] = training[i][start:, 0]
    d[:,1] = training[i][start:, 1]
    d[:,2] = training[i][start:, 2]
    d[:,3] = training[i][start:, 3]
    d[:,4] = training[i][start:, 4]

    train_cut.append(d)

# %% [markdown]
# ##### Normalize Training Data

# %%
# maxim = []
# minim = []
# for i in range (len(train_cut)):
#     for j in range (1,5):
#         p = train_cut[i][:,j].max()
#         q = train_cut[i][:,j].min()

#         maxim.append(p)
#         minim.append(q)
# # print(np.asarray(maxim).max(),np.asarray(minim).min())

# create variables for normalized data
# train_norm = np.zeros_like(np.array(train_cut)) 
train_norm = []
train_norm_labels = np.zeros_like(np.asarray(training_labels))

for i in range (0, len(train_cut)):
    
    n = np.zeros_like(train_cut[i])
    n[:,1] = minmax_scale(train_cut[i][:,1])
    n[:,2] = minmax_scale(train_cut[i][:,2])
    n[:,3] = minmax_scale(train_cut[i][:,3])
    n[:,4] = minmax_scale(train_cut[i][:,4])
    
    train_norm.append(n)

    
scalar = MinMaxScaler()
train_norm_labels = scalar.fit_transform(training_labels)

# %%
maxim = []
minim = []
for i in range (len(train_norm)):
    for j in range (1,5):
        p = train_norm[i][:,j].max()
        q = train_norm[i][:,j].min()

        maxim.append(p)
        minim.append(q)
print(np.asarray(maxim).max(),np.asarray(minim).min())
# Out:
# 1.0000000000000002 0.0

# %%
plt.close()
plt.plot(train_norm_labels[:,0], train_norm_labels[:,1], 'o', c = 'r', label = 'Normalized Training Data Labels')
plt.legend(loc='lower center', bbox_to_anchor=(1, -0.5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Resample Training Data

# %%
train_resample = []

# create a dataframe from the normalized data
for i in range (0, len(training)):
    train_resample.append(pd.DataFrame(train_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    train_resample[i] = train_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(training)):
    train_resample[i] = resample(train_resample[i], size)

np.asarray(train_resample).shape
# Out:
# (925, 100, 4)

# %%
plt.close()
fig, axs = plt.subplots(2, 1)

axs[0].plot(training[10][:,2], c = 'r', label = 'Original Training Data')
axs[1].plot(train_resample[10][:,1], c = 'b', label = 'cut/ norm/ resampled Data')

axs[0].legend(loc='lower left')
axs[1].legend(loc='lower left')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Compare Experimental, Experimental-Validation and Training Data

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharey=True)

ex_val_c = 20 # Given validation folder has 24 data points. so use - (0, 1, .... , 23)

# find out the index of the validation set in the training data
x = []
for i in range (0, len(training_labels)):
    if (training_labels[i][0] == ex_val_labels[ex_val_c][0]) and (training_labels[i][1] == ex_val_labels[ex_val_c][1]):
        x.append(i)

# plot to compare the validation set with the training set
fig.suptitle(f'Training Data Coordinates - {training_labels[x[0]]} \nExperimental Validation Data Coordinates - {ex_val_labels[ex_val_c]} - Trial [{ex_val_trails[ex_val_c]}]')

axs[0,0].plot(training[x[0]][:,0], training[x[0]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[x[0]][:,0], training[x[0]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[x[0]][:,0], training[x[0]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[x[0]][:,0], training[x[0]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,4], label='P - 4', c = 'y')

# fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
fig, axs = plt.subplots(1, 4, sharex=True, sharey=True)

for i in range(4):
    axs[0].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,1], c = 'r', label = 'Exp Val Data - P-1')
    axs[1].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,2], c = 'g', label = 'Exp Val Data - P-2')
    axs[2].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,3], c = 'b', label = 'Exp Val Data - P-3')
    axs[3].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,4], c = 'y', label = 'Exp Val Data - P-4')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Export data to pickle

# %%
# with open('training_data.pickle', 'wb') as f:
#     pickle.dump(training, f)

# with open('train_resample.pickle', 'wb') as f:
#     pickle.dump(train_resample, f)
# with open('train_norm_labels.pickle', 'wb') as f:
#     pickle.dump(train_norm_labels, f)

# with open('training_labels.pickle', 'wb') as f:
#     pickle.dump(training_labels, f)

# with open('exp_validation_data.pickle', 'wb') as f:
#     pickle.dump(ex_val_data, f)
# with open('exp_validation_labels.pickle', 'wb') as f:
#     pickle.dump(ex_val_labels, f)
# with open('exp_validation_trails.pickle', 'wb') as f:
#     pickle.dump(ex_val_trails, f)


# with open('exp_val_resample.pickle', 'wb') as f:
#     pickle.dump(ex_val_resample, f)
# with open('exp_val_norm_labels.pickle', 'wb') as f:
#     pickle.dump(ex_val_norm_labels, f)

# with open('ex_resample.pickle', 'wb') as f:
#     pickle.dump(ex_resample, f)

# %% [markdown]
# #### AI Model

# %% [markdown]
# ##### Split the data into training and testing sets

# %%
# Extract the data from the pickle files
'''
with open('train_resample.pickle', 'rb') as f:
    train_resample = pickle.load(f)
with open('train_norm_labels.pickle', 'rb') as f:
    train_norm_labels = pickle.load(f)
'''

X = np.asarray(train_resample)
y = np.asarray(train_norm_labels)

# create split data from the normalized data
size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {len(x_train)} length of labels - {len(y_train)} \nLength of test data - {len(x_test)} length of labels - {len(y_test)}')
# Out:
# Length of training data - 740 length of labels - 740
# Length of test data - 185 length of labels - 185

# %% [markdown]
# ##### TensorBoard

# %%
# %tensorboard --logdir=logs/

# %% [markdown]
# ##### Model Training and Tuning

# %% [markdown]
# DNN Tuning

# %%
'''
log_files = f'DNN_log.{int(time.time())}'
tuner_logs= f'tunelog/DNN_tuner_log.{int(time.time())}'

tensorboard = TensorBoard(log_dir=f'logs/{log_files}', 
                          histogram_freq=1, 
                          write_graph=True,
                          write_grads=True)


def dnnModel(hp):
    model = Sequential()
    model.add(Flatten(input_shape=(100,4)))
    model.add(Dense(units=hp.Int('layer_1_nodes', 
                    min_value=32, max_value=512, step=32), 
                    activation=hp.Choice("activation_1", ["relu", "sigmoid", "tanh"])))
    
    for i in range(hp.Int('n_layers', min_value=0, max_value=4, step=1)):
        model.add(Dense(units=hp.Int(f'layer_{i+1}_nodes', min_value=32, max_value=512, step=32), activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid", "tanh"])))
    
    model.add(Dense(units=2, activation=hp.Choice("activation_out", ['sigmoid', 'linear']))) # output layer

    model.summary()

    # Compile model
    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(loss = hp.Choice('loss', ['mae']),
                optimizer = hp.Choice('optimizer', ['Adam', 'RMSprop']), 
                metrics=['Accuracy'])
    
    return model

# Hyperparameter tuning
tuner = RandomSearch(dnnModel,
                    objective='val_Accuracy',
                    max_trials=50,
                    executions_per_trial=2,
                    directory=tuner_logs,
                    project_name='DNN_tuning')

tuner.search(x=x_train,
            y=y_train,
            epochs=60,
            batch_size=32,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard])
            '''

# %%
# bestModels = tuner.get_best_models(num_models=2)

# %%
# Save the keras model
# model.save(f'model/complete_tunedModel_97perAcc.{int(time.time())}.h5')

# %% [markdown]
# CNN Tuning

# %%
'''
log_files = f'CNN_log.{int(time.time())}'
tuner_logs= f'tunelog/CNN_tuner_log.{int(time.time())}'

tensorboard = TensorBoard(log_dir=f'logs/{log_files}', 
                          histogram_freq=1, 
                          write_graph=True,
                          write_grads=True)

def cnnModel(hp):
    model = Sequential()

    model.add(Conv1D(filters=hp.Int('conv_1_filter', min_value=32, max_value=512, step=32), 
                     kernel_size=hp.Int('Kernal_1', min_value=2, max_value=5, step=1), 
                     strides=hp.Int('stride_1', min_value=1, max_value=5, step=1),
                     activation=hp.Choice("activation_1", ["relu", "sigmoid"]), 
                     input_shape=(100,4)))
    
    model.add(MaxPooling1D(pool_size=hp.Int('pool_1', min_value=2, max_value=5, step=1))),

    for i in range(hp.Int('n_layers', min_value=0, max_value=4, step=1)):
        model.add(Conv1D(filters=hp.Int(f'conv_{i+1}_filter', min_value=32, max_value=512, step=32), 
                         kernel_size=hp.Int(f'Kernal_{i+1}', min_value=2, max_value=5, step=1), 
                         strides=hp.Int(f'stride_{i+1}', min_value=1, max_value=5, step=1),
                         activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid"])))
        model.add(MaxPooling1D(pool_size=hp.Int(f'pool_{i+1}', min_value=2, max_value=5, step=1)))

    model.add(Flatten())


    model.add(Dense(units=hp.Int('FC_layer_1_nodes',
                    min_value=32, max_value=512, step=32),
                    activation=hp.Choice("FC_activation_1", ["relu", "sigmoid"])))
    
    model.add(Dense(units=hp.Int('FC_layer_2_nodes',
                    min_value=32, max_value=512, step=32),
                    activation=hp.Choice("FC_activation_2", ["relu", "sigmoid"])))

    model.add(Dense(units=2, activation=hp.Choice("activation_out", ['sigmoid', 'linear']))) # output layer

    model.summary()

    # Compile model
    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(loss = hp.Choice('loss', ['mse', 'mae']),
                optimizer = hp.Choice('optimizer', ['Adam', 'RMSprop']), 
                metrics=['Accuracy'])

    return model

# Hyperparameter tuning
tuner = RandomSearch(cnnModel,
                    objective='val_Accuracy',
                    max_trials=560,
                    executions_per_trial=3,
                    directory=tuner_logs,
                    project_name='CNN_tuning')

tuner.search(x=x_train,
            y=y_train,
            epochs=60,
            batch_size=32,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard])
'''

# %%
# bestModels = tuner.get_best_models(num_models=2)

# %% [markdown]
# #### DNN Model

# %%
model = Sequential()
model.add(Flatten(input_shape=(100,4)))

model.add(Dense(units=512, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=96, activation='relu'))
model.add(Dense(units=12, activation='relu'))

model.add(Dense(units=2, activation='linear'))

model.summary()

# Compile model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the model
history = model.fit(x_train, y_train, epochs=50, verbose=1, batch_size=32, validation_data=(x_test, y_test))

# %%
# model.save(f'model/DNN_val_acc_97perAcc.{int(time.time())}.h5')

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(model.predict(x_test)), squared=True)

# %%
# mean_squared_error((ex_val_labels), scalar.inverse_transform(model.predict(ex_val_resample)), squared=True)

# %%
plt.close()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['Accuracy'], label='Training Accuracy')
plt.plot(history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### FINAL - Tuned - CNN

# %%
Alex4=Sequential()

Alex4.add(Conv1D(filters=96, kernel_size=5, strides=4, activation='relu', input_shape=(100,4), padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides= 2, padding='valid'))
Alex4.add(Dropout(0.3))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=5, activation='relu', padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides=2, padding='valid'))

Alex4.add(Conv1D(filters=384, strides=1, kernel_size=3, activation='relu', padding='same'))
Alex4.add(Dropout(0.4))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=3, activation='relu', padding='same'))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=3, activation='relu', padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides=2, padding='valid'))

# Fully Connected Layers
Alex4.add(Flatten())
Alex4.add(Dense(units=128, activation='relu',use_bias='False'))
Alex4.add(Dense(units=64, activation='relu',use_bias='False'))
Alex4.add(Dense(units=2, activation='linear',use_bias='False'))
Alex4.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

Alex4.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the cnn_model
Alex_history = Alex4.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 25, 96)            2016
#
#  max_pooling1d (MaxPooling1D  (None, 12, 96)           0
#  )
#
#  dropout (Dropout)           (None, 12, 96)            0
#
#  conv1d_1 (Conv1D)           (None, 12, 256)           123136
#
#  max_pooling1d_1 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 384)            295296
#
#  dropout_1 (Dropout)         (None, 5, 384)            0
#
#  conv1d_3 (Conv1D)           (None, 5, 256)            295168
#
#  conv1d_4 (Conv1D)           (None, 5, 256)            196864
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 986,530
# Trainable params: 986,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 2022-02-27 09:01:35.287762: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/intel/impi/2018.4.274/compilers_and_libraries/linux/mpi/lib64:/opt/intel/impi/2018.4.274/compilers_and_libraries/linux/mpi/lib:/opt/intel/Compiler/19.0/1.144/rwthlnk/daal/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/daal/lib/ia32_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/ipp/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/ipp/lib/ia32_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/mkl/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/mkl/lib/ia32_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/tbb/lib/intel64_lin/gcc4.7:/opt/intel/Compiler/19.0/1.144/rwthlnk/tbb/lib/ia32_lin/gcc4.7:/opt/intel/Compiler/19.0/1.144/rwthlnk/compiler/lib/intel64_lin:/opt/intel/Compiler/19.0/1.144/rwthlnk/compiler/lib/ia32_lin
# 2022-02-27 09:01:35.287791: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-27 09:01:35.287808: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (login18-1.hpc.itc.rwth-aachen.de): /proc/driver/nvidia/version does not exist
# 2022-02-27 09:01:35.288125: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 24/24 [==============================] - 1s 19ms/step - loss: 0.1265 - Accuracy: 0.4973 - val_loss: 0.1052 - val_Accuracy: 0.4162
# Epoch 2/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0918 - Accuracy: 0.4730 - val_loss: 0.1031 - val_Accuracy: 0.5946
# Epoch 3/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0806 - Accuracy: 0.5095 - val_loss: 0.1277 - val_Accuracy: 0.7135
# Epoch 4/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0635 - Accuracy: 0.5473 - val_loss: 0.0646 - val_Accuracy: 0.7135
# Epoch 5/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0496 - Accuracy: 0.6243 - val_loss: 0.0463 - val_Accuracy: 0.7676
# Epoch 6/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0282 - Accuracy: 0.7554 - val_loss: 0.0117 - val_Accuracy: 0.9135
# Epoch 7/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0145 - Accuracy: 0.8581 - val_loss: 0.0160 - val_Accuracy: 0.9243
# Epoch 8/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0101 - Accuracy: 0.8851 - val_loss: 0.0152 - val_Accuracy: 0.9027
# Epoch 9/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0100 - Accuracy: 0.8905 - val_loss: 0.0199 - val_Accuracy: 0.8324
# Epoch 10/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0102 - Accuracy: 0.9068 - val_loss: 0.0085 - val_Accuracy: 0.8703
# Epoch 11/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0080 - Accuracy: 0.9054 - val_loss: 0.0117 - val_Accuracy: 0.9405
# Epoch 12/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0052 - Accuracy: 0.9230 - val_loss: 0.0066 - val_Accuracy: 0.9351
# Epoch 13/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0054 - Accuracy: 0.9216 - val_loss: 0.0140 - val_Accuracy: 0.9027
# Epoch 14/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0055 - Accuracy: 0.9419 - val_loss: 0.0058 - val_Accuracy: 0.9568
# Epoch 15/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0046 - Accuracy: 0.9257 - val_loss: 0.0029 - val_Accuracy: 0.9135
# Epoch 16/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0045 - Accuracy: 0.9392 - val_loss: 0.0041 - val_Accuracy: 0.9189
# Epoch 17/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0037 - Accuracy: 0.9432 - val_loss: 0.0029 - val_Accuracy: 0.9081
# Epoch 18/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0040 - Accuracy: 0.9500 - val_loss: 0.0036 - val_Accuracy: 0.9676
# Epoch 19/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0035 - Accuracy: 0.9459 - val_loss: 0.0021 - val_Accuracy: 0.9243
# Epoch 20/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0050 - Accuracy: 0.9392 - val_loss: 0.0016 - val_Accuracy: 0.9622
# Epoch 21/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0049 - Accuracy: 0.9392 - val_loss: 0.0033 - val_Accuracy: 0.9622
# Epoch 22/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0027 - Accuracy: 0.9473 - val_loss: 0.0028 - val_Accuracy: 0.9351
# Epoch 23/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0026 - Accuracy: 0.9446 - val_loss: 0.0057 - val_Accuracy: 0.9568
# Epoch 24/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0025 - Accuracy: 0.9378 - val_loss: 0.0064 - val_Accuracy: 0.9351
# Epoch 25/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0033 - Accuracy: 0.9432 - val_loss: 0.0031 - val_Accuracy: 0.9459
# Epoch 26/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0022 - Accuracy: 0.9473 - val_loss: 0.0041 - val_Accuracy: 0.9189
# Epoch 27/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0025 - Accuracy: 0.9608 - val_loss: 0.0086 - val_Accuracy: 0.8919
# Epoch 28/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0027 - Accuracy: 0.9514 - val_loss: 0.0030 - val_Accuracy: 0.9351
# Epoch 29/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0021 - Accuracy: 0.9581 - val_loss: 0.0021 - val_Accuracy: 0.9405
# Epoch 30/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0024 - Accuracy: 0.9608 - val_loss: 0.0039 - val_Accuracy: 0.9081
# Epoch 31/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0022 - Accuracy: 0.9608 - val_loss: 0.0030 - val_Accuracy: 0.9568
# Epoch 32/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0019 - Accuracy: 0.9500 - val_loss: 0.0014 - val_Accuracy: 0.9243
# Epoch 33/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0022 - Accuracy: 0.9649 - val_loss: 0.0015 - val_Accuracy: 0.9189
# Epoch 34/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0016 - Accuracy: 0.9541 - val_loss: 0.0035 - val_Accuracy: 0.9297
# Epoch 35/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0019 - Accuracy: 0.9581 - val_loss: 0.0015 - val_Accuracy: 0.9297
# Epoch 36/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0017 - Accuracy: 0.9608 - val_loss: 0.0012 - val_Accuracy: 0.9135
# Epoch 37/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0015 - Accuracy: 0.9500 - val_loss: 0.0011 - val_Accuracy: 0.9297
# Epoch 38/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0015 - Accuracy: 0.9595 - val_loss: 0.0013 - val_Accuracy: 0.9568
# Epoch 39/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0015 - Accuracy: 0.9676 - val_loss: 0.0016 - val_Accuracy: 0.9676
# Epoch 40/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0015 - Accuracy: 0.9581 - val_loss: 0.0018 - val_Accuracy: 0.9189
# Epoch 41/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0014 - Accuracy: 0.9662 - val_loss: 8.4981e-04 - val_Accuracy: 0.9297
# Epoch 42/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0017 - Accuracy: 0.9649 - val_loss: 0.0018 - val_Accuracy: 0.9622
# Epoch 43/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0015 - Accuracy: 0.9676 - val_loss: 0.0015 - val_Accuracy: 0.9081
# Epoch 44/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0015 - Accuracy: 0.9608 - val_loss: 0.0010 - val_Accuracy: 0.9243
# Epoch 45/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0013 - Accuracy: 0.9649 - val_loss: 0.0019 - val_Accuracy: 0.9730
# Epoch 46/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - Accuracy: 0.9662 - val_loss: 0.0012 - val_Accuracy: 0.9622
# Epoch 47/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0013 - Accuracy: 0.9595 - val_loss: 0.0010 - val_Accuracy: 0.9351
# Epoch 48/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0013 - Accuracy: 0.9676 - val_loss: 6.3456e-04 - val_Accuracy: 0.9622
# Epoch 49/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0013 - Accuracy: 0.9730 - val_loss: 8.1391e-04 - val_Accuracy: 0.9514
# Epoch 50/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0010 - Accuracy: 0.9581 - val_loss: 0.0023 - val_Accuracy: 0.9568
# Epoch 51/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - Accuracy: 0.9676 - val_loss: 7.7991e-04 - val_Accuracy: 0.9135
# Epoch 52/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0010 - Accuracy: 0.9716 - val_loss: 0.0019 - val_Accuracy: 0.8973
# Epoch 53/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0012 - Accuracy: 0.9703 - val_loss: 0.0018 - val_Accuracy: 0.9405
# Epoch 54/90
# 24/24 [==============================] - 0s 11ms/step - loss: 9.7955e-04 - Accuracy: 0.9716 - val_loss: 8.1447e-04 - val_Accuracy: 0.9243
# Epoch 55/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0011 - Accuracy: 0.9689 - val_loss: 7.6039e-04 - val_Accuracy: 0.9676
# Epoch 56/90
# 24/24 [==============================] - 0s 11ms/step - loss: 9.9666e-04 - Accuracy: 0.9676 - val_loss: 0.0014 - val_Accuracy: 0.9784
# Epoch 57/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0010 - Accuracy: 0.9622 - val_loss: 0.0034 - val_Accuracy: 0.9027
# Epoch 58/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0011 - Accuracy: 0.9703 - val_loss: 0.0018 - val_Accuracy: 0.9459
# Epoch 59/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0011 - Accuracy: 0.9635 - val_loss: 7.0202e-04 - val_Accuracy: 0.9297
# Epoch 60/90
# 24/24 [==============================] - 0s 10ms/step - loss: 8.6785e-04 - Accuracy: 0.9689 - val_loss: 7.8781e-04 - val_Accuracy: 0.9351
# Epoch 61/90
# 24/24 [==============================] - 0s 10ms/step - loss: 8.5631e-04 - Accuracy: 0.9662 - val_loss: 8.5578e-04 - val_Accuracy: 0.8865
# Epoch 62/90
# 24/24 [==============================] - 0s 10ms/step - loss: 9.6635e-04 - Accuracy: 0.9527 - val_loss: 6.4036e-04 - val_Accuracy: 0.9243
# Epoch 63/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0012 - Accuracy: 0.9703 - val_loss: 5.5273e-04 - val_Accuracy: 0.9514
# Epoch 64/90
# 24/24 [==============================] - 0s 11ms/step - loss: 9.6673e-04 - Accuracy: 0.9676 - val_loss: 7.6601e-04 - val_Accuracy: 0.9243
# Epoch 65/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0011 - Accuracy: 0.9703 - val_loss: 6.9642e-04 - val_Accuracy: 0.9568
# Epoch 66/90
# 24/24 [==============================] - 0s 10ms/step - loss: 8.9708e-04 - Accuracy: 0.9716 - val_loss: 5.6175e-04 - val_Accuracy: 0.9351
# Epoch 67/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0011 - Accuracy: 0.9608 - val_loss: 0.0011 - val_Accuracy: 0.9838
# Epoch 68/90
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0011 - Accuracy: 0.9649 - val_loss: 9.4796e-04 - val_Accuracy: 0.9189
# Epoch 69/90
# 24/24 [==============================] - 0s 11ms/step - loss: 9.2934e-04 - Accuracy: 0.9635 - val_loss: 6.6111e-04 - val_Accuracy: 0.9568
# Epoch 70/90
# 24/24 [==============================] - 0s 11ms/step - loss: 8.7629e-04 - Accuracy: 0.9730 - val_loss: 4.6635e-04 - val_Accuracy: 0.9243
# Epoch 71/90
# 24/24 [==============================] - 0s 12ms/step - loss: 8.8041e-04 - Accuracy: 0.9716 - val_loss: 6.7907e-04 - val_Accuracy: 0.9676
# Epoch 72/90
# 24/24 [==============================] - 0s 11ms/step - loss: 6.8881e-04 - Accuracy: 0.9676 - val_loss: 7.1389e-04 - val_Accuracy: 0.8919
# Epoch 73/90
# 24/24 [==============================] - 0s 13ms/step - loss: 8.4066e-04 - Accuracy: 0.9662 - val_loss: 0.0013 - val_Accuracy: 0.9459
# Epoch 74/90
# 24/24 [==============================] - 0s 10ms/step - loss: 7.7043e-04 - Accuracy: 0.9703 - val_loss: 5.5423e-04 - val_Accuracy: 0.9243
# Epoch 75/90
# 24/24 [==============================] - 0s 10ms/step - loss: 7.2116e-04 - Accuracy: 0.9703 - val_loss: 5.4050e-04 - val_Accuracy: 0.9297
# Epoch 76/90
# 24/24 [==============================] - 0s 10ms/step - loss: 8.6096e-04 - Accuracy: 0.9703 - val_loss: 5.4405e-04 - val_Accuracy: 0.9351
# Epoch 77/90
# 24/24 [==============================] - 0s 10ms/step - loss: 6.9556e-04 - Accuracy: 0.9743 - val_loss: 6.6216e-04 - val_Accuracy: 0.9189
# Epoch 78/90
# 24/24 [==============================] - 0s 11ms/step - loss: 7.5497e-04 - Accuracy: 0.9581 - val_loss: 5.7523e-04 - val_Accuracy: 0.9892
# Epoch 79/90
# 24/24 [==============================] - 0s 10ms/step - loss: 9.3388e-04 - Accuracy: 0.9662 - val_loss: 7.0024e-04 - val_Accuracy: 0.9189
# Epoch 80/90
# 24/24 [==============================] - 0s 10ms/step - loss: 9.3773e-04 - Accuracy: 0.9730 - val_loss: 7.4880e-04 - val_Accuracy: 0.9676
# Epoch 81/90
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0011 - Accuracy: 0.9662 - val_loss: 0.0015 - val_Accuracy: 0.9297
# Epoch 82/90
# 24/24 [==============================] - 0s 12ms/step - loss: 7.0804e-04 - Accuracy: 0.9770 - val_loss: 5.2143e-04 - val_Accuracy: 0.9838
# Epoch 83/90
# 24/24 [==============================] - 0s 11ms/step - loss: 7.9440e-04 - Accuracy: 0.9784 - val_loss: 7.2615e-04 - val_Accuracy: 0.9297
# Epoch 84/90
# 24/24 [==============================] - 0s 12ms/step - loss: 6.6318e-04 - Accuracy: 0.9703 - val_loss: 9.1180e-04 - val_Accuracy: 0.9081
# Epoch 85/90
# 24/24 [==============================] - 0s 12ms/step - loss: 6.1325e-04 - Accuracy: 0.9743 - val_loss: 5.1472e-04 - val_Accuracy: 0.9243
# Epoch 86/90
# 24/24 [==============================] - 0s 11ms/step - loss: 6.6700e-04 - Accuracy: 0.9770 - val_loss: 7.1372e-04 - val_Accuracy: 0.9676
# Epoch 87/90
# 24/24 [==============================] - 0s 12ms/step - loss: 6.9760e-04 - Accuracy: 0.9703 - val_loss: 5.5625e-04 - val_Accuracy: 0.9243
# Epoch 88/90
# 24/24 [==============================] - 0s 11ms/step - loss: 7.3379e-04 - Accuracy: 0.9703 - val_loss: 9.4867e-04 - val_Accuracy: 0.9568
# Epoch 89/90
# 24/24 [==============================] - 0s 11ms/step - loss: 6.1410e-04 - Accuracy: 0.9716 - val_loss: 6.8703e-04 - val_Accuracy: 0.9568
# Epoch 90/90
# 24/24 [==============================] - 0s 12ms/step - loss: 6.3053e-04 - Accuracy: 0.9770 - val_loss: 5.0914e-04 - val_Accuracy: 0.9081

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(Alex4.predict(x_test)), squared=True)
# mean_absolute_error(scalar.inverse_transform(y_test), scalar.inverse_transform(Alex4.predict(x_test)))
# Out:
# 11.455645996559966

# %%
# Alex4.save(f'model/FINAL_CNN_val_acc_97_16_MSE.{int(time.time())}.h5')

# %%
plt.close()
plt.plot(Alex_history.history['loss'], label='Training Loss')
plt.plot(Alex_history.history['val_loss'], label='Validation Loss')
plt.plot(Alex_history.history['Accuracy'], label='Training Accuracy')
plt.plot(Alex_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Other Networks

# %% [markdown]
# ##### Wide ResNet

# %%
# Wide resnet model

wresnet= Sequential()

wresnet.add(Conv1D(filters=96, kernel_size=5, activation='relu', input_shape=(100,4)))
wresnet.add(Conv1D( filters=96,kernel_size=1,activation='relu'))
# wresnet.add(Conv1D(filters=96,kernel_size=1,activation='relu'))

wresnet.add(MaxPooling1D(pool_size=3))

wresnet.add(Conv1D(filters=256, kernel_size=5,activation='relu'))
wresnet.add(Conv1D(filters=256, kernel_size=1, activation='relu'))
# wresnet.add(Conv1D(filters=256, kernel_size=1, activation='relu'))

wresnet.add(MaxPooling1D(pool_size=3))
wresnet.add(Dropout(0.25))

wresnet.add(Conv1D(filters=384, kernel_size=3, activation='relu'))
wresnet.add(Conv1D(filters=384, kernel_size=1,  activation='relu'))
# wresnet.add(Conv1D(filters=384, kernel_size=1,  activation='relu'))

wresnet.add(MaxPooling1D(pool_size=3, strides= 2))
wresnet.add(Dropout(0.3))


wresnet.add(Conv1D(filters=2, kernel_size=3, activation='relu'))
wresnet.add(Conv1D(filters=2, kernel_size=1, activation='relu'))
# wresnet.add(Conv1D(filters=2, kernel_size=1, activation='relu'))

# wresnet.add(GlobalAveragePooling1D())
wresnet.add(Flatten())

wresnet.add(Dense(units=128, activation='relu'))
wresnet.add(Dense(units=64, activation='relu'))
wresnet.add(Dense(units=2, activation='linear'))
wresnet.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

wresnet.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the cnn_model
wresnet_history = wresnet.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 96, 96)            2016
#
#  conv1d_11 (Conv1D)          (None, 96, 96)            9312
#
#  max_pooling1d_6 (MaxPooling  (None, 32, 96)           0
#  1D)
#
#  conv1d_12 (Conv1D)          (None, 28, 256)           123136
#
#  conv1d_13 (Conv1D)          (None, 28, 256)           65792
#
#  max_pooling1d_7 (MaxPooling  (None, 9, 256)           0
#  1D)
#
#  dropout_4 (Dropout)         (None, 9, 256)            0
#
#  conv1d_14 (Conv1D)          (None, 7, 384)            295296
#
#  conv1d_15 (Conv1D)          (None, 7, 384)            147840
#
#  max_pooling1d_8 (MaxPooling  (None, 3, 384)           0
#  1D)
#
#  dropout_5 (Dropout)         (None, 3, 384)            0
#
#  conv1d_16 (Conv1D)          (None, 1, 2)              2306
#
#  conv1d_17 (Conv1D)          (None, 1, 2)              6
#
#  flatten_2 (Flatten)         (None, 2)                 0
#
#  dense_6 (Dense)             (None, 128)               384
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 654,474
# Trainable params: 654,474
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 24/24 [==============================] - 2s 36ms/step - loss: 0.2758 - Accuracy: 0.4797 - val_loss: 0.1847 - val_Accuracy: 0.5027
# Epoch 2/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1268 - Accuracy: 0.4784 - val_loss: 0.0979 - val_Accuracy: 0.5027
# Epoch 3/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0913 - Accuracy: 0.5000 - val_loss: 0.0967 - val_Accuracy: 0.4973
# Epoch 4/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0914 - Accuracy: 0.5216 - val_loss: 0.0965 - val_Accuracy: 0.4973
# Epoch 5/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0906 - Accuracy: 0.4892 - val_loss: 0.0965 - val_Accuracy: 0.4973
# Epoch 6/90
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0906 - Accuracy: 0.5108 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 7/90
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0906 - Accuracy: 0.5108 - val_loss: 0.0965 - val_Accuracy: 0.5027
# Epoch 8/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0908 - Accuracy: 0.4784 - val_loss: 0.0971 - val_Accuracy: 0.5027
# Epoch 9/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0904 - Accuracy: 0.4784 - val_loss: 0.0966 - val_Accuracy: 0.5027
# Epoch 10/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0904 - Accuracy: 0.5000 - val_loss: 0.0968 - val_Accuracy: 0.4973
# Epoch 11/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0906 - Accuracy: 0.4838 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 12/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0906 - Accuracy: 0.4973 - val_loss: 0.0965 - val_Accuracy: 0.4973
# Epoch 13/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0907 - Accuracy: 0.5081 - val_loss: 0.0980 - val_Accuracy: 0.5027
# Epoch 14/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0910 - Accuracy: 0.4784 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 15/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0906 - Accuracy: 0.4838 - val_loss: 0.0977 - val_Accuracy: 0.5027
# Epoch 16/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0906 - Accuracy: 0.4784 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 17/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0905 - Accuracy: 0.4784 - val_loss: 0.0972 - val_Accuracy: 0.5027
# Epoch 18/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0906 - Accuracy: 0.5243 - val_loss: 0.0963 - val_Accuracy: 0.4973
# Epoch 19/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0905 - Accuracy: 0.5054 - val_loss: 0.0970 - val_Accuracy: 0.5027
# Epoch 20/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0907 - Accuracy: 0.4892 - val_loss: 0.0964 - val_Accuracy: 0.4973
# Epoch 21/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0905 - Accuracy: 0.4838 - val_loss: 0.0968 - val_Accuracy: 0.5027
# Epoch 22/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0910 - Accuracy: 0.4730 - val_loss: 0.0973 - val_Accuracy: 0.5027
# Epoch 23/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0905 - Accuracy: 0.4676 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 24/90
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0907 - Accuracy: 0.4892 - val_loss: 0.0975 - val_Accuracy: 0.5027
# Epoch 25/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0907 - Accuracy: 0.4919 - val_loss: 0.0963 - val_Accuracy: 0.5027
# Epoch 26/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0909 - Accuracy: 0.5189 - val_loss: 0.0973 - val_Accuracy: 0.5027
# Epoch 27/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0909 - Accuracy: 0.4784 - val_loss: 0.0970 - val_Accuracy: 0.5027
# Epoch 28/90
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0904 - Accuracy: 0.5162 - val_loss: 0.0968 - val_Accuracy: 0.4973
# Epoch 29/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0906 - Accuracy: 0.4838 - val_loss: 0.0969 - val_Accuracy: 0.5027
# Epoch 30/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0905 - Accuracy: 0.5189 - val_loss: 0.0966 - val_Accuracy: 0.4973
# Epoch 31/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0906 - Accuracy: 0.5027 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 32/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0907 - Accuracy: 0.5189 - val_loss: 0.0970 - val_Accuracy: 0.4973
# Epoch 33/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0907 - Accuracy: 0.5000 - val_loss: 0.0967 - val_Accuracy: 0.5027
# Epoch 34/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0911 - Accuracy: 0.5027 - val_loss: 0.0977 - val_Accuracy: 0.4973
# Epoch 35/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0910 - Accuracy: 0.5216 - val_loss: 0.0967 - val_Accuracy: 0.5027
# Epoch 36/90
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0905 - Accuracy: 0.4784 - val_loss: 0.0967 - val_Accuracy: 0.5027
# Epoch 37/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0908 - Accuracy: 0.4757 - val_loss: 0.0963 - val_Accuracy: 0.5027
# Epoch 38/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0905 - Accuracy: 0.4784 - val_loss: 0.0972 - val_Accuracy: 0.5027
# Epoch 39/90
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0906 - Accuracy: 0.4514 - val_loss: 0.0965 - val_Accuracy: 0.5027
# Epoch 40/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0904 - Accuracy: 0.4784 - val_loss: 0.0973 - val_Accuracy: 0.5027
# Epoch 41/90
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0909 - Accuracy: 0.5135 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 42/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0905 - Accuracy: 0.4784 - val_loss: 0.0974 - val_Accuracy: 0.5027
# Epoch 43/90
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0910 - Accuracy: 0.4865 - val_loss: 0.0963 - val_Accuracy: 0.4973
# Epoch 44/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0903 - Accuracy: 0.5216 - val_loss: 0.0970 - val_Accuracy: 0.5027
# Epoch 45/90
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0905 - Accuracy: 0.5081 - val_loss: 0.0968 - val_Accuracy: 0.4973
# Epoch 46/90
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0905 - Accuracy: 0.4811 - val_loss: 0.0968 - val_Accuracy: 0.5027
# Epoch 47/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0905 - Accuracy: 0.4784 - val_loss: 0.0968 - val_Accuracy: 0.5027
# Epoch 48/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0905 - Accuracy: 0.5081 - val_loss: 0.0964 - val_Accuracy: 0.4973
# Epoch 49/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0904 - Accuracy: 0.5000 - val_loss: 0.0965 - val_Accuracy: 0.5027
# Epoch 50/90
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0909 - Accuracy: 0.4676 - val_loss: 0.0975 - val_Accuracy: 0.4973
# Epoch 51/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0904 - Accuracy: 0.5297 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 52/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0906 - Accuracy: 0.4811 - val_loss: 0.0965 - val_Accuracy: 0.4973
# Epoch 53/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0906 - Accuracy: 0.4622 - val_loss: 0.0966 - val_Accuracy: 0.5027
# Epoch 54/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0907 - Accuracy: 0.4946 - val_loss: 0.0972 - val_Accuracy: 0.4973
# Epoch 55/90
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0910 - Accuracy: 0.4811 - val_loss: 0.0969 - val_Accuracy: 0.4973
# Epoch 56/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0905 - Accuracy: 0.5216 - val_loss: 0.0967 - val_Accuracy: 0.4973
# Epoch 57/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0909 - Accuracy: 0.5216 - val_loss: 0.0978 - val_Accuracy: 0.4973
# Epoch 58/90
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0907 - Accuracy: 0.5189 - val_loss: 0.0965 - val_Accuracy: 0.4973
# Epoch 59/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0909 - Accuracy: 0.4919 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 60/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0913 - Accuracy: 0.4541 - val_loss: 0.0972 - val_Accuracy: 0.5027
# Epoch 61/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0905 - Accuracy: 0.4892 - val_loss: 0.0967 - val_Accuracy: 0.5027
# Epoch 62/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0914 - Accuracy: 0.5027 - val_loss: 0.0967 - val_Accuracy: 0.5027
# Epoch 63/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0914 - Accuracy: 0.4784 - val_loss: 0.0967 - val_Accuracy: 0.5027
# Epoch 64/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0906 - Accuracy: 0.4730 - val_loss: 0.0963 - val_Accuracy: 0.4973
# Epoch 65/90
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0902 - Accuracy: 0.4973 - val_loss: 0.0979 - val_Accuracy: 0.5027
# Epoch 66/90
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0907 - Accuracy: 0.4919 - val_loss: 0.0969 - val_Accuracy: 0.4973
# Epoch 67/90
# 24/24 [==============================] - 1s 36ms/step - loss: 0.0915 - Accuracy: 0.5216 - val_loss: 0.0969 - val_Accuracy: 0.4973
# Epoch 68/90
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0907 - Accuracy: 0.5054 - val_loss: 0.0968 - val_Accuracy: 0.5027
# Epoch 69/90
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0905 - Accuracy: 0.4838 - val_loss: 0.0965 - val_Accuracy: 0.5027
# Epoch 70/90
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0917 - Accuracy: 0.5000 - val_loss: 0.0973 - val_Accuracy: 0.4973
# Epoch 71/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0908 - Accuracy: 0.4784 - val_loss: 0.0974 - val_Accuracy: 0.5027
# Epoch 72/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0907 - Accuracy: 0.4784 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 73/90
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0904 - Accuracy: 0.4622 - val_loss: 0.0966 - val_Accuracy: 0.4973
# Epoch 74/90
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0905 - Accuracy: 0.5216 - val_loss: 0.0977 - val_Accuracy: 0.4973
# Epoch 75/90
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0909 - Accuracy: 0.4676 - val_loss: 0.0964 - val_Accuracy: 0.5027
# Epoch 76/90
# 20/24 [========================>.....] - ETA: 0s - loss: 0.0913 - Accuracy: 0.4828
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17120/3415057759.py in <module>
#      41
#      42 # Fit the cnn_model
# ---> 43 wresnet_history = wresnet.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
#
# ~\anaconda3\envs\ai\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\ai\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1218                 context.async_wait()
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
# -> 1220               end_step = step + data_handler.step_increment
#    1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#
# ~\anaconda3\envs\ai\lib\site-packages\keras\engine\data_adapter.py in step_increment(self)
#    1268         self._steps_per_execution.assign(original_spe)
#    1269
# -> 1270   @property
#    1271   def step_increment(self):
#    1272     """The number to increment the step for `on_batch_end` methods."""
#
# KeyboardInterrupt:

# %%
# Wide resnet model

wresnet= Sequential()

wresnet.add(Conv1D(filters=96, kernel_size=5, strides=2, activation='relu', input_shape=(100,4), padding='same'))
wresnet.add(Conv1D( filters=96,kernel_size=1,activation='relu',padding='same'))
wresnet.add(Conv1D(filters=96,kernel_size=1,activation='relu', padding='same'))

wresnet.add(MaxPooling1D(pool_size=3, strides=2 ))

wresnet.add(Conv1D(filters=256, kernel_size=5, strides=2, activation='relu', padding='same'))
wresnet.add(Conv1D(filters=256, kernel_size=1, activation='relu',padding='same'))
wresnet.add(Conv1D(filters=256, kernel_size=1, activation='relu', padding='same'))

wresnet.add(MaxPooling1D(pool_size=3, strides= 2))
wresnet.add(Dropout(0.5))

wresnet.add(Conv1D(filters=384, kernel_size=3, strides=2, activation='relu', padding='same'))
wresnet.add(Conv1D(filters=384, kernel_size=1,  activation='relu',padding='same'))
wresnet.add(Conv1D(filters=384, kernel_size=1,  activation='relu', padding='same'))

wresnet.add(MaxPooling1D(pool_size=3, strides= 2))


wresnet.add(Conv1D(filters=2, kernel_size=3, strides=2, activation='relu', padding='same'))
wresnet.add(Conv1D(filters=2, kernel_size=1, activation='relu',padding='same'))
wresnet.add(Conv1D(filters=2, kernel_size=1, activation='relu', padding='same'))

# wresnet.add(GlobalAveragePooling1D())
wresnet.add(Flatten())

wresnet.add(Dense(units=128, activation='relu',use_bias='False'))
wresnet.add(Dense(units=64, activation='relu',use_bias='False'))
wresnet.add(Dense(units=2, activation='linear',use_bias='False'))
wresnet.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

wresnet.compile(loss = 'mae', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the cnn_model
wresnet_history = wresnet.fit(x_train, y_train, epochs=40, verbose=1, batch_size=32, validation_data=(x_test, y_test))

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(wresnet.predict(x_test)), squared=True)
# mean_absolute_error(scalar.inverse_transform(y_test), scalar.inverse_transform(wresnet.predict(x_test)))
# Out:
# 424.8956041211212

# %%
# wresnet.save(f'model/wresnet_CNN_val_acc_97_16_MSE.{int(time.time())}.h5')

# %%
plt.close()
plt.plot(wresnet_history.history['loss'], label='Training Loss')
plt.plot(wresnet_history.history['val_loss'], label='Validation Loss')
plt.plot(wresnet_history.history['Accuracy'], label='Training Accuracy')
plt.plot(wresnet_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Predict experimental data validation

# %%
# model = tf.keras.models.load_model('model/tunedModel_98perAcc.1640573960.h5')
# model = tf.keras.models.load_model('Alex3.h5')
# model = tf.keras.models.load_model('model/CNN_val_acc_96_48_MSEperAcc.1642513870.h5')
# model.summary()

# %%
y_pred = Alex4.predict(np.asarray(ex_val_resample))
y_abs = ex_val_labels

y_pred = scalar.inverse_transform(np.asarray(y_pred))
diff = y_abs-y_pred
for i in range(len(y_pred)):
    print(f'Absolute Trial {ex_val_trails[i]}- {y_abs[i]} Predicted - {y_pred[i]} \tDifference - {y_abs[i] - y_pred[i]}')
# Out:
# Absolute Trial 1.0- [205. 200.] Predicted - [211.88933 209.00723] 	Difference - [-6.889328   -9.00723267]
# Absolute Trial 2.0- [205. 200.] Predicted - [211.77893 208.04541] 	Difference - [-6.77893066 -8.04541016]
# Absolute Trial 3.0- [205. 200.] Predicted - [217.23978 209.22516] 	Difference - [-12.23977661  -9.22515869]
# Absolute Trial 4.0- [205. 200.] Predicted - [210.91423 209.77544] 	Difference - [-5.91423035 -9.7754364 ]
# Absolute Trial 1.0- [225. 210.] Predicted - [228.30815 205.40869] 	Difference - [-3.30815125  4.59130859]
# Absolute Trial 2.0- [225. 210.] Predicted - [229.55978 206.81998] 	Difference - [-4.55978394  3.18002319]
# Absolute Trial 3.0- [225. 210.] Predicted - [227.4721  207.02498] 	Difference - [-2.47210693  2.97502136]
# Absolute Trial 4.0- [225. 210.] Predicted - [226.51326 207.50056] 	Difference - [-1.51325989  2.49943542]
# Absolute Trial 1.0- [230. 245.] Predicted - [229.5532  246.93808] 	Difference - [ 0.4467926  -1.93807983]
# Absolute Trial 2.0- [230. 245.] Predicted - [229.2917  246.13504] 	Difference - [ 0.70829773 -1.13504028]
# Absolute Trial 3.0- [230. 245.] Predicted - [226.79977 243.92343] 	Difference - [3.20022583 1.0765686 ]
# Absolute Trial 4.0- [230. 245.] Predicted - [224.44743 244.33675] 	Difference - [5.55256653 0.66325378]
# Absolute Trial 1.0- [240. 255.] Predicted - [229.14775 254.11053] 	Difference - [10.85224915  0.88946533]
# Absolute Trial 2.0- [240. 255.] Predicted - [236.42361 253.16829] 	Difference - [3.5763855  1.83171082]
# Absolute Trial 3.0- [240. 255.] Predicted - [244.7272  253.27286] 	Difference - [-4.72720337  1.72714233]
# Absolute Trial 4.0- [240. 255.] Predicted - [236.8524 252.4713] 	Difference - [3.14759827 2.52870178]
# Absolute Trial 1.0- [250. 260.] Predicted - [260.64383 256.3273 ] 	Difference - [-10.64382935   3.67269897]
# Absolute Trial 2.0- [250. 260.] Predicted - [252.68158 255.91354] 	Difference - [-2.68157959  4.0864563 ]
# Absolute Trial 3.0- [250. 260.] Predicted - [251.52362 249.91823] 	Difference - [-1.52362061 10.08177185]
# Absolute Trial 4.0- [250. 260.] Predicted - [258.60358 259.03522] 	Difference - [-8.60357666  0.96478271]
# Absolute Trial 1.0- [300. 235.] Predicted - [297.55365 231.55154] 	Difference - [2.4463501  3.44845581]
# Absolute Trial 2.0- [300. 235.] Predicted - [295.8563  231.24991] 	Difference - [4.14370728 3.75009155]
# Absolute Trial 3.0- [300. 235.] Predicted - [299.73233 233.88817] 	Difference - [0.26766968 1.11183167]
# Absolute Trial 4.0- [300. 235.] Predicted - [296.41898 229.90929] 	Difference - [3.58102417 5.0907135 ]

# %%
mean_squared_error(y_abs, y_pred, squared=True)
mean_absolute_error(y_abs, y_pred)
# Out:
# 4.230709075927734

# %% [markdown]
# #### Experimental Group - 7 Data (and plots for report)

# %%
training_labels.shape
# Out:
# (925, 2)

# %%
y_pred_g7 = Alex4.predict(np.asarray(ex_resample))
y_pred_g7 = scalar.inverse_transform(y_pred_g7)
y_pred_g7
# Out:
# array([[250.53885, 243.45609],
#        [236.22418, 236.65324],
#        [245.07315, 251.98546],
#        [263.69263, 220.28336],
#        [243.4668 , 251.71895],
#        [261.33875, 246.14745],
#        [238.11357, 296.278  ],
#        [226.96254, 229.83734],
#        [265.74573, 293.51343],
#        [251.57858, 247.45642],
#        [258.8063 , 226.47261],
#        [248.48349, 250.56963],
#        [200.45544, 233.5326 ],
#        [260.68024, 254.44629],
#        [245.63058, 250.34038],
#        [226.13751, 202.92587],
#        [260.649  , 307.68744],
#        [294.5068 , 275.73712]], dtype=float32)

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharey=True)

ex_c = 1 # Given validation folder has 18 data points. so use - (0, 1, .... , 17)

# find out the index of the validation set in the training data
p = []

for i in range (len(y_pred_g7)):
    xi = np.where(training_labels[:,0] == min(training_labels[:,0], key=lambda x:abs(x-y_pred_g7[i][0])))[0]
    yi = np.where(training_labels[:,1] == min(training_labels[:,1], key=lambda x:abs(x-y_pred_g7[i][1])))[0]
    pi = np.intersect1d(xi, yi)[0]
    
    p.append(pi)

# plot to compare the validation set with the training set
fig.suptitle(f'Closest Training Data Coordinates - {training_labels[p[ex_c]]} \nExperimental Predicted Coordinates - {y_pred_g7[ex_c]}')

axs[0,0].plot(training[p[ex_c]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[p[ex_c]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[p[ex_c]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[p[ex_c]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(ex_cut_data[ex_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(ex_cut_data[ex_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(ex_cut_data[ex_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(ex_cut_data[ex_c][:,4], label='P - 4', c = 'y')

# fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Prediction post processing

# %% [markdown]
# sorting the exact experimental data

# %%
'''
Group_7	AA	250	265
Group_7	AA	245	255
Group_7	AA	235	235
Group_7	AA	265	235
Group_7	AA	250	250
Group_7	AA	255	265
Group_7	B	225	200
Group_7	B	270	300
Group_7	B	200	225
Group_7	B	235	300
Group_7	B	260	320
Group_7	B	300	285
Group_7	A	250	265
Group_7	A	245	255
Group_7	A	235	235
Group_7	A	265	235
Group_7	A	250	250
Group_7	A	265	255
'''

exact_ex_labels = np.array(
[[250,	265], 
[245,	255],
[235,	235],
[265,	235],
[250,	250],
[255,	265],
[225,	200],
[270,	300],
[200,	225],
[235,	300],
[260,	320],
[300,	285],
[250,	265],
[245,	255],
[235,	235],
[265,	235],
[250,	250],
[265,	255]])

# %%
pred_ex_labels = np.array(
[[253.32326, 244.85556],
[234.51955, 233.11015],
[243.45721, 259.58542],
[260.85577, 225.5717 ],
[241.64229, 252.67258],
[262.7103 , 247.9715 ],
[236.75409, 299.41733],
[230.32304, 228.36177],
[264.8639 , 298.7226 ],
[252.88496, 258.21362],
[260.63187, 232.50989],
[252.09583, 252.05911],
[201.56601, 229.92183],
[256.91928, 257.9066 ],
[245.16226, 252.61618],
[224.14635, 201.8915 ],
[269.60422, 310.06744],
[298.5857 , 281.49817]])

# %%
print(exact_ex_labels.shape, pred_ex_labels.shape)
# Out:
# (18, 2) (18, 2)

# %%
plt.close()
plt.plot(training_labels[:,0], training_labels[:,1], '.', color = 'g', label='Training Data', alpha = 0.3)
plt.plot(pred_ex_labels[:,0], pred_ex_labels[:,1], 'o', color = 'b', label='Predicted')
plt.plot(exact_ex_labels[:,0], exact_ex_labels[:,1], 'o', color = 'r', label='Exact')
plt.scatter(exact_ex_labels[:,0], exact_ex_labels[:,1], s=750, facecolors='none', edgecolors='k')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))

legend_x = 0.5
legend_y = -0.27
plt.legend(bbox_to_anchor=(legend_x, legend_y), loc = 'lower center', ncol = 3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = []
p_loc=[]
for i in range(len(exact_ex_labels)):
    t = []
    for j in range(len(pred_ex_labels)):
        xi = (np.asarray(np.abs(exact_ex_labels[i]-pred_ex_labels[j])).sum())
        t.append(xi)
    p_loc.append(np.argmin(t))
    x.append(np.min(t))

# %%
# reorganising the predicted labels
pred_ex_labels_org = np.empty_like(pred_ex_labels)
for i in range (len(p_loc)):
    pred_ex_labels_org[i] = pred_ex_labels[p_loc[i]]

print('Exact Coordinates \tPredicted Coordinates \t     Difference')
for i in range(len(p_loc)):
    print(f'{exact_ex_labels[i]}---------------{pred_ex_labels[p_loc[i]]}--------{exact_ex_labels[i] - pred_ex_labels[p_loc[i]]}')

print(f'MSE of the Group-7 data - {mean_squared_error(exact_ex_labels, pred_ex_labels_org)}')
print(f'MAE of the Group-7 data - {mean_absolute_error(exact_ex_labels, pred_ex_labels_org)}')
# Out:
# Exact Coordinates 	Predicted Coordinates 	     Difference
# [250 265]---------------[252.88496 258.21362]--------[-2.88496  6.78638]
# [245 255]---------------[245.16226 252.61618]--------[-0.16226  2.38382]
# [235 235]---------------[234.51955 233.11015]--------[0.48045 1.88985]
# [265 235]---------------[260.63187 232.50989]--------[4.36813 2.49011]
# [250 250]---------------[252.09583 252.05911]--------[-2.09583 -2.05911]
# [255 265]---------------[252.88496 258.21362]--------[2.11504 6.78638]
# [225 200]---------------[224.14635 201.8915 ]--------[ 0.85365 -1.8915 ]
# [270 300]---------------[264.8639 298.7226]--------[5.1361 1.2774]
# [200 225]---------------[201.56601 229.92183]--------[-1.56601 -4.92183]
# [235 300]---------------[236.75409 299.41733]--------[-1.75409  0.58267]
# [260 320]---------------[269.60422 310.06744]--------[-9.60422  9.93256]
# [300 285]---------------[298.5857  281.49817]--------[1.4143  3.50183]
# [250 265]---------------[252.88496 258.21362]--------[-2.88496  6.78638]
# [245 255]---------------[245.16226 252.61618]--------[-0.16226  2.38382]
# [235 235]---------------[234.51955 233.11015]--------[0.48045 1.88985]
# [265 235]---------------[260.63187 232.50989]--------[4.36813 2.49011]
# [250 250]---------------[252.09583 252.05911]--------[-2.09583 -2.05911]
# [265 255]---------------[262.7103 247.9715]--------[2.2897 7.0285]
# MSE of the Group-7 data - 15.787427782150019
# MAE of the Group-7 data - 3.1071550000000006

# %% [markdown]
# Reinforce prediction with post-processing

# %%
# temp = 1

def find_leastmse_train(temp):
    # find out the index of the validation set in the training data
    p = []

    for i in range (len(pred_ex_labels)):
        xi = np.where(training_labels[:,0] == min(training_labels[:,0], key=lambda x:abs(x-pred_ex_labels[i][0])))[0]
        yi = np.where(training_labels[:,1] == min(training_labels[:,1], key=lambda x:abs(x-pred_ex_labels[i][1])))[0]
        pi = np.intersect1d(xi, yi)[0]
        
        p.append(pi)

    # for i in range(len(p)):
    #     print(f'{training_labels[p][i]} \t {pred_ex_labels[i]}')

    x_offset = [-5, 0, 5]
    y_offset = [-5, 0, 5]
    loc=[]; x=[]; y=[]

    for k in (x_offset):
        for l in (y_offset):
            xi = np.where(training_labels[:,0][p][temp] + k == training_labels[:,0])
            yi = np.where(training_labels[:,1][p][temp] + l == training_labels[:,1])
            x.append(xi)
            y.append(yi)
        
        for m in range(len(x)):
            for n in range(len(y)):
                loc.append(np.intersect1d(x[m], y[n])[0])
    locs = np.unique(loc)

    mse = []
    for i in range(len(locs)):
        err = mean_squared_error(train_resample[locs[i]], ex_resample[temp])
        mse.append(err)
    min_loc = locs[np.argmin(mse)]

    return locs, min_loc



leastmse_pred = []; leastmse_label = []
l = []; locs = []

for temp in range(len(pred_ex_labels)):
    try:    
        l, x = find_leastmse_train(temp)
        locs.append(l)
        leastmse_label.append(x)
        leastmse_pred.append(training_labels[x])
    except:
        print(f'{temp} - {pred_ex_labels[temp]} surrounding points are not in the training data')
        pass
    
    # print(f'loop - {temp}')

leastmse_pred = np.asarray(leastmse_pred)
leastmse_label = np.asarray(leastmse_label)
locs = np.asarray(locs)

leastmse_pred = np.insert(leastmse_pred, 3, values=[260, 225], axis=0)
leastmse_label = np.insert(leastmse_label, 3, values=722)
locs = np.insert(locs, 3, values=722, axis = 0)
print(np.asarray(leastmse_pred))
# Out:
# 3 - [260.85577 225.5717 ] surrounding points are not in the training data
# [[250. 245.]
#  [235. 235.]
#  [245. 255.]
#  [260. 225.]
#  [240. 250.]
#  [265. 250.]
#  [230. 300.]
#  [230. 225.]
#  [260. 295.]
#  [250. 255.]
#  [260. 230.]
#  [250. 250.]
#  [205. 225.]
#  [255. 255.]
#  [245. 250.]
#  [220. 200.]
#  [265. 305.]
#  [295. 280.]]

# %%
plt.close()
fig, axs = plt.subplots(2, 4)
#      |
ex_c = 4 # <----- give the group-7 experimental label
tr_loc = leastmse_label[ex_c] # Given validation folder has 18 data points. so use - (0, 1, .... , 17)

# plot to compare the validation set with the training set
fig.suptitle(f'Least MSE Training Data Coordinates - {training_labels[tr_loc]}mm \nExp G7 Predicted Coordinates - {pred_ex_labels[ex_c]}mm')

axs[0,0].plot(train_resample[tr_loc][:,0], label='P - 1', c = 'r')
axs[0,1].plot(train_resample[tr_loc][:,1], label='P - 2', c = 'g')
axs[0,2].plot(train_resample[tr_loc][:,2], label='P - 3', c = 'b')
axs[0,3].plot(train_resample[tr_loc][:,3], label='P - 4', c = 'y')

axs[1,0].plot(ex_resample[ex_c][:,0], label='P - 1', c = 'r')
axs[1,1].plot(ex_resample[ex_c][:,1], label='P - 2', c = 'g')
axs[1,2].plot(ex_resample[ex_c][:,2], label='P - 3', c = 'b')
axs[1,3].plot(ex_resample[ex_c][:,3], label='P - 4', c = 'y')

# fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
point = 4

plt.close()
plt.title('Find the least MSE Training Data Coordinate')

plt.plot(training_labels[:,0], training_labels[:,1], '.', color = 'g', label='Training Data', alpha = 0.3)
plt.plot(pred_ex_labels[:,0][point], pred_ex_labels[:,1][point], 's', color = 'k', label=f'Predicted Point {np.around(pred_ex_labels[point], decimals=1)}')

plt.scatter(training_labels[:,0][locs[point]], training_labels[:,1][locs[point]], c='b', alpha = 0.5, label = 'Buffer Set')
plt.scatter(training_labels[:,0][leastmse_label[point]], training_labels[:,1][leastmse_label[point]], c = 'r', label = f'Least MSE Point {training_labels[leastmse_label[point]]}')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))

plt.legend(bbox_to_anchor=(0.5, 0), loc = 'lower center', ncol = 2)
plt.xlabel('X (mm)')
plt.ylabel('Y (mm)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Old CNN Model

# %%
# reg = tf.keras.regularizers.L2(0.01)

cnn_model = Sequential()
# create a CNN cnn_model
cnn_model.add(Conv1D(filters=224, kernel_size=3, activation='relu', input_shape=(100,4)))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.25))
cnn_model.add(Conv1D(filters=384, kernel_size=3, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Conv1D(filters=384, kernel_size=3, activation='relu'))
cnn_model.add(MaxPooling1D(pool_size=2))

cnn_model.add(Flatten())

cnn_model.add(Dense(units=32, activation='sigmoid'))
cnn_model.add(Dense(units=480, activation='relu'))
cnn_model.add(Dense(units=2, activation='linear'))
cnn_model.summary()
3
# Compile cnn_model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

cnn_model.compile(loss = 'mse', optimizer = 'RMSprop', metrics=['Accuracy'])

# Fit the cnn_model
cnn_history = cnn_model.fit(x_train, y_train, epochs=80, verbose=1, batch_size=32, validation_data=(x_test, y_test))

# %%
plt.close()
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.plot(cnn_history.history['Accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.legend()
plt.show()

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(cnn_model.predict(x_test)), squared=False)

# %%
# cnn_save = cnn_model.save(f'model/cnn_model_98-7perAcc.{int(time.time())}.h5')

# %%
# cnn_98 = tf.keras.models.load_model('CNN_98_1.h5')

# %% [markdown]
# #### SVR Model

# %%
X = train_resample
y = training_labels

# create split data from the normalized data
size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {len(x_train)} length of labels - {len(y_train)} \nLength of test data - {len(x_test)} and length of labels - {len(y_test)}')

x_train_flat = []
for i in range(len(x_train)):    
    x_dummy = np.asarray(x_train[i]).flatten()
    x_train_flat.append(x_dummy)
    
x_train_flat = np.asarray(x_train_flat)

x_test_flat = []
for i in range(len(x_test)):    
    x_dummy = np.asarray(x_test[i]).flatten()
    x_test_flat.append(x_dummy)
    
x_test_flat = np.asarray(x_test_flat)

print(np.asarray(x_train_flat).shape, np.asarray(y_train).shape)

# %%
regr_multirf = MultiOutputRegressor(svm.SVR(kernel='rbf', C=1e5, gamma=0.03, epsilon=0.2, tol=1e-6))
regr_multirf.fit(x_train_flat, y_train)

y_pred = regr_multirf.predict(x_test_flat)
y_test-y_pred

# %%
mean_squared_error(y_test, y_pred, squared=True)

# %%
y_pred_exp = regr_multirf.predict(exp_val_X_flat)

mean_squared_error(exp_val_y,y_pred_exp)

# %%
ex_X_flat = []
for i in range(len(ex_resample)):
    x_dummy = np.asarray(ex_resample[i]).flatten()
    ex_X_flat.append(x_dummy)

ex_X_flat = np.asarray(ex_X_flat)
ex_X_flat.shape

# %%
y_pred_g7_knn = regr_multirf.predict(ex_X_flat)
y_pred_g7_knn

# %% [markdown]
# #### KNN Model

# %%
X = train_resample
y = training_labels

exp_val_X = ex_val_resample
exp_val_y = ex_val_labels

print(np.asarray(X).shape, np.asarray(y).shape)

# create split data from the normalized data
size = 0.1
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {np.asarray(x_train).shape} length of labels - {np.asarray(y_train).shape} \nLength of test data - {np.asarray(x_test).shape} and length of labels - {np.asarray(y_test).shape}')

# %%
x_train_flat = []
for i in range(len(x_train)):    
    x_dummy = np.asarray(x_train[i]).flatten()
    x_train_flat.append(x_dummy)
    
x_train_flat = np.asarray(x_train_flat)

x_test_flat = []
for i in range(len(x_test)):    
    x_dummy = np.asarray(x_test[i]).flatten()
    x_test_flat.append(x_dummy)
    
x_test_flat = np.asarray(x_test_flat)

exp_val_X_flat = []
for i in range(len(exp_val_X)):
    x_dummy = np.asarray(exp_val_X[i]).flatten()
    exp_val_X_flat.append(x_dummy)

exp_val_X_flat = np.asarray(exp_val_X_flat)

print(np.asarray(x_train_flat).shape, np.asarray(y_train).shape)
print(x_test_flat.shape, y_test.shape)
print(exp_val_X_flat.shape, exp_val_y.shape)

# %%
knn = KNeighborsRegressor(n_neighbors=5, weights='distance')
knn.fit(x_train_flat, y_train)
y_pred = knn.predict(x_test_flat)
y_test-y_pred

# %%
mean_squared_error(y_test, y_pred)

# %%
y_pred_exp = knn.predict(exp_val_X_flat)

mean_squared_error(exp_val_y,y_pred_exp)

# %%
ex_X_flat = []
for i in range(len(ex_resample)):
    x_dummy = np.asarray(ex_resample[i]).flatten()
    ex_X_flat.append(x_dummy)

ex_X_flat = np.asarray(ex_X_flat)
ex_X_flat.shape

# %%
y_pred_g7_knn = knn.predict(ex_X_flat)
y_pred_g7_knn

# %% [markdown]
# #### -- Check -- prediction for augmentation validation data

# %%
c = []
checking1 = validation_aug[0][:,1:5]
checking1 = minmax_scale(checking1)
checking1 = resample(checking1, 100)

checking2 = validation_aug[1][:,1:5]
checking2 = minmax_scale(checking2)
checking2 = resample(checking2, 100)

checking3 = validation_aug[2][:,1:5]
checking3 = minmax_scale(checking3)
checking3 = resample(checking3, 100)

checking4 = validation_aug[3][:,1:5]
checking4 = minmax_scale(checking4)
checking4 = resample(checking4, 100)

c.append(checking1)
c.append(checking2)
c.append(checking3)
c.append(checking4)

'''
plt.close()
plt.title(f'Validation Data {validation_aug_labels[0]}')
plt.plot(checking1[:,0], label = 'P - 1')
plt.plot(checking1[:,1], label = 'P - 2')
plt.plot(checking1[:,2], label = 'P - 3')
plt.plot(checking1[:,3], label = 'P - 4')
plt.legend()
plt.show()
'''

# %%
print(f'{validation_aug_labels[0]} \n{validation_aug_labels[1]} \n{validation_aug_labels[2]} \n{validation_aug_labels[3]}')

p = Alex4.predict(np.asarray(c))
p = scalar.inverse_transform(p)
print(p)

error = []
for i in range(0, len(p)):
    a = validation_aug_labels[i][0]-p[i][0]
    b = validation_aug_labels[i][1]-p[i][1]
    e = [a, b]
    error.append(e)

print(f'Difference between the actual and predicted coordinates: \n{np.asarray(error)}')
