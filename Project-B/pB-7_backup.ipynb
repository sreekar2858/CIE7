# %% [markdown]
# ### CIE-Project B || Group - 7

# %% [markdown]
# #### Imports

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
from scipy.signal import resample, find_peaks
from scipy.io import loadmat
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pickle
import time

# from sklearn import preprocessing ##importing for normalization
# from sklearn.decomposition import PCA
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import MinMaxScaler, minmax_scale, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error
from sklearn.multioutput import MultiOutputRegressor
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

import tensorflow as tf
from tensorflow import Tensor
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPooling1D, \
                         AveragePooling1D, GlobalAveragePooling1D, \
                         Add, BatchNormalization, ReLU, Input
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from keras.utils import np_utils
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['legend.frameon'] = True
# plt.rcParams['figure.figsize'] = (8, 8)
# %matplotlib widget
# %matplotlib inline

tf.random.set_seed(1)
np.random.seed(2)

# %% [markdown]
# ##### Get the root directory and change to it

# %%
rootdir = os.getcwd()
os.chdir(rootdir)

# %% [markdown]
# #### Folder Variables Assignment

# %%
# Names of the folders
Training_Folder = 'EPOT_DATA'
Validation_Aug_Folder = 'Validation_augmented_data'
Experiment = 'Experiment_Data_Group7'
Ex_Validation = 'Experimental_validation'

counter = 0

# %% [markdown]
# #### Parsing

# %% [markdown]
# ##### Parse training and validation-augmented data

# %%
# Initialize lists for training and validation
training_tr = []; training_tr_labels = []

validation_aug = []; validation_aug_labels = [] # validation augmented data

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Training_Folder.lower() in subdir.lower():
        for file in files:
            if file.endswith('.mat'):
                lbl = [file.split('_')[1], file.split('_')[2][:3]]
                lb = np.asarray(lbl, dtype=float)
                # load mat-file
                mat = loadmat(os.path.join(subdir, file))
                # get the numpy data from the mat file
                mat = mat['num_data']
                # append data to the list
                training_tr.append(mat)
                training_tr_labels.append(lb)

    elif Validation_Aug_Folder.lower() in subdir.lower():
        for file in files:
            if file.endswith('.mat'):
                lbl = [file.split('_')[1], file.split('_')[2][:3]]
                lb = np.asarray(lbl, dtype=float)
                # load mat-file
                mat = loadmat(os.path.join(subdir, file))
                # get the numpy data from the mat file
                mat = mat['num_data']
                # append data to the list
                validation_aug.append(mat)
                validation_aug_labels.append(lb)

# %%
plt.close()
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

l = 6

fig.suptitle(f'EPOT Training Data - {training_tr_labels[l]}')

axs[0,0].plot(training_tr[l][:,0], training_tr[l][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training_tr[l][:,0], training_tr[l][:,2], label='P - 2', c = 'g')
axs[1,0].plot(training_tr[l][:,0], training_tr[l][:,3], label='P - 3', c = 'b')
axs[1,1].plot(training_tr[l][:,0], training_tr[l][:,4], label='P - 4', c = 'y')

fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Parse, Cut, Normalize, and Resample the experimental data

# %%
# Initialize lists for training and validation
ex_data = []; ex_labels = []

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Experiment.lower() in subdir.lower():
        for file in files:
            if file.endswith('.txt'):
                
                with open(os.path.join(subdir, file), 'r') as f:
                    x = pd.read_csv(os.path.join(subdir, file), delimiter='\t', decimal=',', skiprows=8, header=None)
                    x = np.asarray(x, dtype=float)
                    ex_data.append(x)

# %%
plt.close()
l = 5
plt.plot(ex_data[l][:,0], ex_data[l][:,1], label='P - 1', c = 'r')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ex_cut_data = []
for i in range(len(ex_data)):
    
    threshold = 0.1

    x = np.where(abs(ex_data[i][:,1])>threshold)[0][0]
    y = np.where(abs(ex_data[i][:,2])>threshold)[0][0]
    z = np.where(abs(ex_data[i][:,3])>threshold)[0][0]
    p = np.where(abs(ex_data[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)
    end = start+200

    d = np.empty_like(ex_data[i][start:end,:])

    d[:,0] = ex_data[i][start:end, 0]
    d[:,1] = (-1)*ex_data[i][start:end, 1]
    d[:,2] = (-1)*ex_data[i][start:end, 2]
    d[:,3] = (-1)*ex_data[i][start:end, 4]
    d[:,4] = (-1)*ex_data[i][start:end, 3]

    ex_cut_data.append(d)

# %%
plt.close()
l = 5
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,1], label='P - 1')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,2], label='P - 2')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,3], label='P - 3')
plt.plot(ex_cut_data[l][:,0], ex_cut_data[l][:,4], label='P - 4')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Normalize and Resample experimental data

# %%
# create variables for normalized data
ex_norm = np.zeros_like(np.asarray(ex_cut_data))

for i in range (0, len(ex_cut_data)):
    for j in range (1, 5):
        ex_norm[i][:,j] = minmax_scale(ex_cut_data[i][:,j])

# %%
ex_resample = []

# create a dataframe from the normalized data
for i in range (0, len(ex_norm)):
    ex_resample.append(pd.DataFrame(ex_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    ex_resample[i] = ex_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(ex_resample)):
    ex_resample[i] = resample(ex_resample[i], size)

np.asarray(ex_resample).shape
# Out:
# (18, 100, 4)

# %% [markdown]
# ##### Parse, Cut, Normalize, and Resample the experimental validation data

# %%
# Initialize lists for training and validation
ex_val_data = []; ex_val_labels = []

#------------------------------------------------------------------------------

for subdir, dirs, files in os.walk(rootdir):
    
    if Ex_Validation.lower() in subdir.lower():
        for file in files:
            if file.endswith('.txt'):
                
                with open(os.path.join(subdir, file), 'r') as f:
                    # print(file.split('_')[2], file.split('_')[3], file.split('_')[5][:3])
                    lbl = [file.split('_')[2], file.split('_')[3], file.split('_')[5][:3]]
                    lb = np.asarray(lbl, dtype=float)

                    x = pd.read_csv(os.path.join(subdir, file), delimiter='\t', decimal=',', skiprows=8, header=None)
                    x = np.asarray(x, dtype=float)
                    ex_val_data.append(x)
                    ex_val_labels.append(lb)


ex_val_trails = np.asarray(ex_val_labels)[:,2]
ex_val_labels = np.delete(ex_val_labels, 2, 1)

# %%
# ex_val_cut_data=[]
# for i in range(0,len(ex_val_data)):
#     data=ex_data[i][:,0]
    
#     start_time = 0.04996
#     end_time = 0.05016
#     start=np.where(data==(start_time))
#     end = np.where(data==(end_time))
    
#     d = np.zeros(((start[0][0]+200-start[0][0]),5))

#     d[:,0]=ex_val_data[i][start[0][0]:start[0][0]+200,0]
#     d[:,1]=ex_val_data[i][start[0][0]:start[0][0]+200,1]
#     d[:,2]=ex_val_data[i][start[0][0]:start[0][0]+200,2]
#     d[:,3]=ex_val_data[i][start[0][0]:start[0][0]+200,4]
#     d[:,4]=ex_val_data[i][start[0][0]:start[0][0]+200,3]
    
#     ex_val_cut_data.append(d)
#----------------------------------------------------------------------------------------


ex_val_cut_data = []
for i in range(len(ex_val_data)):
    
    threshold = 0.1

    x = np.where(abs(ex_val_data[i][:,1])>threshold)[0][0]
    y = np.where(abs(ex_val_data[i][:,2])>threshold)[0][0]
    z = np.where(abs(ex_val_data[i][:,3])>threshold)[0][0]
    p = np.where(abs(ex_val_data[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)
    end = start+180

    d = np.empty_like(ex_val_data[i][start:end,:])

    d[:,0] = ex_val_data[i][start:end, 0]
    d[:,1] = (-1)*ex_val_data[i][start:end, 1]
    d[:,2] = (-1)*ex_val_data[i][start:end, 2]
    d[:,3] = (-1)*ex_val_data[i][start:end, 4]
    d[:,4] = (-1)*ex_val_data[i][start:end, 3]

    ex_val_cut_data.append(d)

# %% [markdown]
# Normalize and Resample experimental validation data

# %%
# create variables for normalized data
ex_val_norm = np.zeros_like(np.asarray(ex_val_cut_data)); ex_val_norm_labels = np.zeros_like(np.asarray(ex_val_cut_data))

for i in range (0, len(ex_val_cut_data)):
    for j in range (1, 5):
        ex_val_norm[i][:,j] = minmax_scale(ex_val_cut_data[i][:,j])

scalar = MinMaxScaler()
ex_val_norm_labels = scalar.fit_transform(ex_val_labels)

# %%
ex_val_resample = []

# create a dataframe from the normalized data
for i in range (0, len(ex_val_norm)):
    ex_val_resample.append(pd.DataFrame(ex_val_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    ex_val_resample[i] = ex_val_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(ex_val_resample)):
    ex_val_resample[i] = resample(ex_val_resample[i], size)

np.asarray(ex_val_resample).shape
# Out:
# (24, 100, 4)

# %% [markdown]
# #### Augmentation

# %% [markdown]
# ##### Variable initialization

# %%
## -----------------------------------------------------------------------------
#Assuming P1 on top and counter clockwise order
## -----------------------------------------------------------------------------


# Variables for the augmented data
training_tl = np.zeros_like(np.asarray(training_tr)); training_tl_labels = np.zeros_like(np.asarray(training_tr_labels))
training_bl = np.zeros_like(np.asarray(training_tr)); training_bl_labels = np.zeros_like(np.asarray(training_tr_labels))
training_br = np.zeros_like(np.asarray(training_tr)); training_br_labels = np.zeros_like(np.asarray(training_tr_labels))

# %% [markdown]
# ##### Top-Left

# %%
for i in range (0, len(training_tr)):
        training_tl[i][:,0] = training_tr[i][:,0]
        training_tl[i][:,1] = training_tr[i][:,1]
        training_tl[i][:,2] = training_tr[i][:,4]
        training_tl[i][:,3] = training_tr[i][:,3]
        training_tl[i][:,4] = training_tr[i][:,2]

for i in range (0, len(training_tl_labels)):
    training_tl_labels[i][0] = 500 - training_tr_labels[i][0]
    training_tl_labels[i][1] = training_tr_labels[i][1]

# %% [markdown]
# ##### Bottom-Left

# %%
for i in range (0, len(training_bl)):
    training_bl[i][:,0] = training_tl[i][:,0]
    training_bl[i][:,1] = training_tl[i][:,3]
    training_bl[i][:,2] = training_tl[i][:,2]
    training_bl[i][:,3] = training_tl[i][:,1]
    training_bl[i][:,4] = training_tl[i][:,4]

for i in range (0, len(training_bl_labels)):
    training_bl_labels[i][0] = 500. - training_tr_labels[i][0]
    training_bl_labels[i][1] = 500. - training_tr_labels[i][1]

# %% [markdown]
# ##### Bottom-Right

# %%
for i in range (0, len(training_br)):
        training_br[i][:,0] = training_bl[i][:,0]
        training_br[i][:,1] = training_bl[i][:,1]
        training_br[i][:,2] = training_bl[i][:,4]
        training_br[i][:,3] = training_bl[i][:,3]
        training_br[i][:,4] = training_bl[i][:,2]

for i in range (0, len(training_br_labels)):
    training_br_labels[i][0] = training_tr_labels[i][0]
    training_br_labels[i][1] = 500 - training_tr_labels[i][1]

# %% [markdown]
# ##### Delete overlapping data points

# %%
training_tl = np.delete(np.asarray(training_tl), np.where(np.asanyarray(training_tl_labels) == 250.)[0], axis = 0)
training_tl_labels = np.delete(np.asarray(training_tl_labels), np.where(np.asanyarray(training_tl_labels) == 250.)[0], axis = 0)

training_bl = np.delete(np.asarray(training_bl), 0, axis = 0)
training_bl_labels = np.delete(np.asarray(training_bl_labels), 0, axis = 0)

training_br = np.delete(np.asarray(training_br), np.where(np.asanyarray(training_br_labels) == 250.)[0], axis = 0)
training_br_labels = np.delete(np.asarray(training_br_labels), np.where(np.asanyarray(training_br_labels) == 250.)[0], axis = 0)

# %% [markdown]
# ##### Makesure the augmentation is done on all quadrants

# %%
print(f'{np.asarray(training_tl).shape} \t{np.asarray(training_tr).shape} \n{np.asarray(training_bl).shape} \t{np.asarray(training_br).shape} \n{counter}')
# Out:
# (219, 20000, 5) 	(244, 20000, 5)
# (243, 20000, 5) 	(219, 20000, 5)
# 0

# %%
plt.close()
for i in range(0, len(training_tr_labels)):
    plt.plot(training_tr_labels[i][0], training_tr_labels[i][1], 'o', c = 'r')
for j in range (0, len(training_tl_labels)):
    plt.plot(training_tl_labels[j][0], training_tl_labels[j][1], 's', c = 'g')
    plt.plot(training_br_labels[j][0], training_br_labels[j][1], 'P', c = 'y')
for k in range (0, len(training_bl_labels)):
    plt.plot(training_bl_labels[k][0], training_bl_labels[k][1], '*', c = 'b')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Concatenate, Cut, Normalize, Resample Training Data

# %% [markdown]
# ##### Concatenate

# %%
training = np.concatenate((training_tr, training_tl, training_bl, training_br), axis = 0)
training_labels = np.concatenate((training_tr_labels, training_tl_labels, training_bl_labels, training_br_labels), axis = 0)

print(f'Shape of all training set: {training.shape} \nShape of all training labels: {training_labels.shape}')
# Out:
# Shape of all training set: (925, 20000, 5)
# Shape of all training labels: (925, 2)

# %% [markdown]
# ##### check with the validation augmented data

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharex=True)

val_c = 1 # Given validation folder has 4 data points. so use - (0, 1, 2, 3)

# find out the index of the validation set in the training data
x = []
for i in range (0, len(training_labels)):
    if (training_labels[i][0] == validation_aug_labels[val_c][0]) and (training_labels[i][1] == validation_aug_labels[val_c][1]):
        x.append(i)

# plot to compare the validation set with the training set
fig.suptitle(f'EPOT Training Data Coordinates - {training_labels[x[0]]} \nValidation Augmented Data Coordinates - {validation_aug_labels[val_c]}')

axs[0,0].plot(training[x[0]][:,0], training[x[0]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[x[0]][:,0], training[x[0]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[x[0]][:,0], training[x[0]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[x[0]][:,0], training[x[0]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(validation_aug[val_c][:,0], validation_aug[val_c][:,4], label='P - 4', c = 'y')

# check if the data is exactly the same
for i in range (1, 5):
    if np.all(training[x[0]][:,i] == validation_aug[val_c][:,i], axis = 0):
        print('Data is augmented correctly')

fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
diff = training[x[0]][:,1] - validation_aug[val_c][:,1]
diff
# Out:
# array([0.     , 0.     , 0.     , ..., 0.00011, 0.00012, 0.00012])

# %% [markdown]
# ##### -- Check -- for outliers

# %%
'''
plt.close()
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)

for i in range(len(training)):
    axs[0,0].plot(training[i][:,0], training[i][:,1], label='Training P-1')
    axs[0,1].plot(training[i][:,0], training[i][:,2], label='Training P-2')
    axs[1,0].plot(training[i][:,0], training[i][:,3], label='Training P-3')
    axs[1,1].plot(training[i][:,0], training[i][:,4], label='Training P-4')

plt.show()
'''
# Out:
# "\nplt.close()\nfig, axs = plt.subplots(2, 2, sharex=True, sharey=True)\n\nfor i in range(len(training)):\n    axs[0,0].plot(training[i][:,0], training[i][:,1], label='Training P-1')\n    axs[0,1].plot(training[i][:,0], training[i][:,2], label='Training P-2')\n    axs[1,0].plot(training[i][:,0], training[i][:,3], label='Training P-3')\n    axs[1,1].plot(training[i][:,0], training[i][:,4], label='Training P-4')\n\nplt.show()\n"

# %%
'''
# %matplotlib inline
sns.set(rc={'figure.figsize':(30, 30)})

x = []; y = []; z = []

for i in range(len(training)):
    xi = training_labels[i][0]
    x.append(xi)
    yi = training_labels[i][1]
    y.append(yi)
    zi = pd.DataFrame(training[i][:,1]).max()[0]
    # zi = pd.DataFrame(training[i][:,2]).max()[0]
    # zi = pd.DataFrame(training[i][:,3]).max()[0]
    # zi = pd.DataFrame(training[i][:,4]).max()[0]

    z.append(zi)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')

ax = sns.heatmap(heatmap1_data, 
                square=True, 
                annot = True, 
                annot_kws={"fontsize": 10}, 
                fmt='.1f', 
                linewidths=0.1, 
                linecolor='gray',
                cbar_kws = dict(use_gridspec=False, location='right'))

ax.invert_yaxis()
'''
# Out:
# '\n%matplotlib inline\nsns.set(rc={\'figure.figsize\':(30, 30)})\n\nx = []; y = []; z = []\n\nfor i in range(len(training)):\n    xi = training_labels[i][0]\n    x.append(xi)\n    yi = training_labels[i][1]\n    y.append(yi)\n    zi = pd.DataFrame(training[i][:,1]).max()[0]\n    # zi = pd.DataFrame(training[i][:,2]).max()[0]\n    # zi = pd.DataFrame(training[i][:,3]).max()[0]\n    # zi = pd.DataFrame(training[i][:,4]).max()[0]\n\n    z.append(zi)\n\ndf = pd.DataFrame({\'x\': x, \'y\': y, \'z\': z})\n\nheatmap1_data = pd.pivot_table(df, values=\'z\', index=[\'y\'], columns=\'x\')\n\nax = sns.heatmap(heatmap1_data, \n                square=True, \n                annot = True, \n                annot_kws={"fontsize": 10}, \n                fmt=\'.1f\', \n                linewidths=0.1, \n                linecolor=\'gray\',\n                cbar_kws = dict(use_gridspec=False, location=\'right\'))\n\nax.invert_yaxis()\n'

# %% [markdown]
# Experimental Validation

# %%
'''
# %matplotlib inline
sns.set(rc={'figure.figsize':(30, 30)})

x = []; y = []; z = []

for i in range(len(ex_val_data)):
    xi = ex_val_labels[i][0]
    x.append(xi)
    yi = ex_val_labels[i][1]
    y.append(yi)
    zi = pd.DataFrame(ex_val_data[i][:,1]).max()[0]
    # zi = pd.DataFrame(training[i][:,2]).max()[0]
    # zi = pd.DataFrame(training[i][:,3]).max()[0]
    # zi = pd.DataFrame(training[i][:,4]).max()[0]

    z.append(zi)

df = pd.DataFrame({'x': x, 'y': y, 'z': z})

heatmap1_data = pd.pivot_table(df, values='z', index=['y'], columns='x')

ax = sns.heatmap(heatmap1_data, 
                square=True, 
                annot = True, 
                annot_kws={"fontsize": 10}, 
                fmt='.1f', 
                linewidths=0.1, 
                linecolor='gray',
                cbar_kws = dict(use_gridspec=False, location='right'))

ax.invert_yaxis()
'''
# Out:
# '\n%matplotlib inline\nsns.set(rc={\'figure.figsize\':(30, 30)})\n\nx = []; y = []; z = []\n\nfor i in range(len(ex_val_data)):\n    xi = ex_val_labels[i][0]\n    x.append(xi)\n    yi = ex_val_labels[i][1]\n    y.append(yi)\n    zi = pd.DataFrame(ex_val_data[i][:,1]).max()[0]\n    # zi = pd.DataFrame(training[i][:,2]).max()[0]\n    # zi = pd.DataFrame(training[i][:,3]).max()[0]\n    # zi = pd.DataFrame(training[i][:,4]).max()[0]\n\n    z.append(zi)\n\ndf = pd.DataFrame({\'x\': x, \'y\': y, \'z\': z})\n\nheatmap1_data = pd.pivot_table(df, values=\'z\', index=[\'y\'], columns=\'x\')\n\nax = sns.heatmap(heatmap1_data, \n                square=True, \n                annot = True, \n                annot_kws={"fontsize": 10}, \n                fmt=\'.1f\', \n                linewidths=0.1, \n                linecolor=\'gray\',\n                cbar_kws = dict(use_gridspec=False, location=\'right\'))\n\nax.invert_yaxis()\n'

# %% [markdown]
# ##### Cutting Training Data

# %%
train_cut = []
for i in range(len(training)):
    
    threshold = 0.1

    x = np.where(abs(training[i][:,1])>threshold)[0][0]
    y = np.where(abs(training[i][:,2])>threshold)[0][0]
    z = np.where(abs(training[i][:,3])>threshold)[0][0]
    p = np.where(abs(training[i][:,4])>threshold)[0][0]

    start = min(x,y,z,p)

    d = np.empty_like(training[i][start:,:])

    d[:,0] = training[i][start:, 0]
    d[:,1] = training[i][start:, 1]
    d[:,2] = training[i][start:, 2]
    d[:,3] = training[i][start:, 3]
    d[:,4] = training[i][start:, 4]

    train_cut.append(d)

# %% [markdown]
# ##### Normalize Training Data

# %%
# maxim = []
# minim = []
# for i in range (len(train_cut)):
#     for j in range (1,5):
#         p = train_cut[i][:,j].max()
#         q = train_cut[i][:,j].min()

#         maxim.append(p)
#         minim.append(q)
# # print(np.asarray(maxim).max(),np.asarray(minim).min())

# create variables for normalized data
# train_norm = np.zeros_like(np.array(train_cut)) 
train_norm = []
train_norm_labels = np.zeros_like(np.asarray(training_labels))

for i in range (0, len(train_cut)):
    
    n = np.zeros_like(train_cut[i])
    n[:,1] = minmax_scale(train_cut[i][:,1])
    n[:,2] = minmax_scale(train_cut[i][:,2])
    n[:,3] = minmax_scale(train_cut[i][:,3])
    n[:,4] = minmax_scale(train_cut[i][:,4])
    
    train_norm.append(n)

    
scalar = MinMaxScaler()
train_norm_labels = scalar.fit_transform(training_labels)

# %%
maxim = []
minim = []
for i in range (len(train_norm)):
    for j in range (1,5):
        p = train_norm[i][:,j].max()
        q = train_norm[i][:,j].min()

        maxim.append(p)
        minim.append(q)
print(np.asarray(maxim).max(),np.asarray(minim).min())
# Out:
# 1.0000000000000002 0.0

# %%
plt.close()
plt.plot(train_norm_labels[:,0], train_norm_labels[:,1], 'o', c = 'r', label = 'Normalized Training Data Labels')
plt.legend(loc='lower center', bbox_to_anchor=(1, -0.5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##### Resample Training Data

# %%
train_resample = []

# create a dataframe from the normalized data
for i in range (0, len(training)):
    train_resample.append(pd.DataFrame(train_norm[i], columns = ['time', '1', '2', '3', '4']))
    # drop the time column
    train_resample[i] = train_resample[i].drop(columns = ['time'])

size = 100

for i in range (0, len(training)):
    train_resample[i] = resample(train_resample[i], size)

np.asarray(train_resample).shape
# Out:
# (925, 100, 4)

# %%
plt.close()
fig, axs = plt.subplots(2, 1)

axs[0].plot(training[10][:,2], c = 'r', label = 'Original Training Data')
axs[1].plot(train_resample[10][:,1], c = 'b', label = 'cut/ norm/ resampled Data')

axs[0].legend(loc='lower left')
axs[1].legend(loc='lower left')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Compare Experimental, Experimental-Validation and Training Data

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharey=True)

ex_val_c = 20 # Given validation folder has 24 data points. so use - (0, 1, .... , 23)

# find out the index of the validation set in the training data
x = []
for i in range (0, len(training_labels)):
    if (training_labels[i][0] == ex_val_labels[ex_val_c][0]) and (training_labels[i][1] == ex_val_labels[ex_val_c][1]):
        x.append(i)

# plot to compare the validation set with the training set
fig.suptitle(f'Training Data Coordinates - {training_labels[x[0]]} \nExperimental Validation Data Coordinates - {ex_val_labels[ex_val_c]} - Trial [{ex_val_trails[ex_val_c]}]')

axs[0,0].plot(training[x[0]][:,0], training[x[0]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[x[0]][:,0], training[x[0]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[x[0]][:,0], training[x[0]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[x[0]][:,0], training[x[0]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(ex_val_cut_data[ex_val_c][:,0], ex_val_cut_data[ex_val_c][:,4], label='P - 4', c = 'y')

# fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
fig, axs = plt.subplots(1, 4, sharex=True, sharey=True)

for i in range(4):
    axs[0].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,1], c = 'r', label = 'Exp Val Data - P-1')
    axs[1].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,2], c = 'g', label = 'Exp Val Data - P-2')
    axs[2].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,3], c = 'b', label = 'Exp Val Data - P-3')
    axs[3].plot(ex_val_cut_data[i][:,0], ex_val_cut_data[i][:,4], c = 'y', label = 'Exp Val Data - P-4')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Export data to pickle

# %%
# with open('training_data.pickle', 'wb') as f:
#     pickle.dump(training, f)

# with open('train_resample.pickle', 'wb') as f:
#     pickle.dump(train_resample, f)
# with open('train_norm_labels.pickle', 'wb') as f:
#     pickle.dump(train_norm_labels, f)

# with open('training_labels.pickle', 'wb') as f:
#     pickle.dump(training_labels, f)

# with open('exp_validation_data.pickle', 'wb') as f:
#     pickle.dump(ex_val_data, f)
# with open('exp_validation_labels.pickle', 'wb') as f:
#     pickle.dump(ex_val_labels, f)
# with open('exp_validation_trails.pickle', 'wb') as f:
#     pickle.dump(ex_val_trails, f)


# with open('exp_val_resample.pickle', 'wb') as f:
#     pickle.dump(ex_val_resample, f)
# with open('exp_val_norm_labels.pickle', 'wb') as f:
#     pickle.dump(ex_val_norm_labels, f)

# with open('ex_resample.pickle', 'wb') as f:
#     pickle.dump(ex_resample, f)

# %% [markdown]
# #### AI Model Tuning and Training

# %% [markdown]
# ##### Split the data into training and testing sets

# %%
# Extract the data from the pickle files
'''
with open('train_resample.pickle', 'rb') as f:
    train_resample = pickle.load(f)
with open('train_norm_labels.pickle', 'rb') as f:
    train_norm_labels = pickle.load(f)
'''

X = np.asarray(train_resample)
y = np.asarray(train_norm_labels)

# create split data from the normalized data
size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {len(x_train)} length of labels - {len(y_train)} \nLength of test data - {len(x_test)} length of labels - {len(y_test)}')
# Out:
# Length of training data - 740 length of labels - 740
# Length of test data - 185 length of labels - 185

# %% [markdown]
# ##### TensorBoard

# %%
# %tensorboard --logdir=logs/

# %% [markdown]
# ##### Model Training and Tuning

# %% [markdown]
# DNN Tuning

# %%
'''
log_files = f'DNN_log.{int(time.time())}'
tuner_logs= f'tunelog/DNN_tuner_log.{int(time.time())}'

tensorboard = TensorBoard(log_dir=f'logs/{log_files}', 
                          histogram_freq=1, 
                          write_graph=True,
                          write_grads=True)


def dnnModel(hp):
    model = Sequential()
    model.add(Flatten(input_shape=(100,4)))
    model.add(Dense(units=hp.Int('layer_1_nodes', 
                    min_value=32, max_value=512, step=32), 
                    activation=hp.Choice("activation_1", ["relu", "sigmoid", "tanh"])))
    
    for i in range(hp.Int('n_layers', min_value=0, max_value=4, step=1)):
        model.add(Dense(units=hp.Int(f'layer_{i+1}_nodes', min_value=32, max_value=512, step=32), activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid", "tanh"])))
    
    model.add(Dense(units=2, activation=hp.Choice("activation_out", ['sigmoid', 'linear']))) # output layer

    model.summary()

    # Compile model
    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(loss = hp.Choice('loss', ['mae']),
                optimizer = hp.Choice('optimizer', ['Adam', 'RMSprop']), 
                metrics=['Accuracy'])
    
    return model

# Hyperparameter tuning
tuner = RandomSearch(dnnModel,
                    objective='val_Accuracy',
                    max_trials=50,
                    executions_per_trial=2,
                    directory=tuner_logs,
                    project_name='DNN_tuning')

tuner.search(x=x_train,
            y=y_train,
            epochs=60,
            batch_size=32,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard])
            '''

# %%
# bestModels = tuner.get_best_models(num_models=2)

# %%
# Save the keras model
# model.save(f'model/complete_tunedModel_97perAcc.{int(time.time())}.h5')

# %% [markdown]
# CNN Tuning

# %%
'''
log_files = f'CNN_log.{int(time.time())}'
tuner_logs= f'tunelog/CNN_tuner_log.{int(time.time())}'

tensorboard = TensorBoard(log_dir=f'logs/{log_files}', 
                          histogram_freq=1, 
                          write_graph=True,
                          write_grads=True)

def cnnModel(hp):
    model = Sequential()

    model.add(Conv1D(filters=hp.Int('conv_1_filter', min_value=32, max_value=512, step=32), 
                     kernel_size=hp.Int('Kernal_1', min_value=2, max_value=5, step=1), 
                     strides=hp.Int('stride_1', min_value=1, max_value=5, step=1),
                     activation=hp.Choice("activation_1", ["relu", "sigmoid"]), 
                     input_shape=(100,4)))
    
    model.add(MaxPooling1D(pool_size=hp.Int('pool_1', min_value=2, max_value=5, step=1))),

    for i in range(hp.Int('n_layers', min_value=0, max_value=4, step=1)):
        model.add(Conv1D(filters=hp.Int(f'conv_{i+1}_filter', min_value=32, max_value=512, step=32), 
                         kernel_size=hp.Int(f'Kernal_{i+1}', min_value=2, max_value=5, step=1), 
                         strides=hp.Int(f'stride_{i+1}', min_value=1, max_value=5, step=1),
                         activation=hp.Choice(f"activation_{i+1}", ["relu", "sigmoid"])))
        model.add(MaxPooling1D(pool_size=hp.Int(f'pool_{i+1}', min_value=2, max_value=5, step=1)))

    model.add(Flatten())


    model.add(Dense(units=hp.Int('FC_layer_1_nodes',
                    min_value=32, max_value=512, step=32),
                    activation=hp.Choice("FC_activation_1", ["relu", "sigmoid"])))
    
    model.add(Dense(units=hp.Int('FC_layer_2_nodes',
                    min_value=32, max_value=512, step=32),
                    activation=hp.Choice("FC_activation_2", ["relu", "sigmoid"])))

    model.add(Dense(units=2, activation=hp.Choice("activation_out", ['sigmoid', 'linear']))) # output layer

    model.summary()

    # Compile model
    # lr = hp.Float("lr", min_value=1e-4, max_value=1e-2)
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    sgd = tf.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(loss = hp.Choice('loss', ['mse', 'mae']),
                optimizer = hp.Choice('optimizer', ['Adam', 'RMSprop']), 
                metrics=['Accuracy'])

    return model

# Hyperparameter tuning
tuner = RandomSearch(cnnModel,
                    objective='val_Accuracy',
                    max_trials=560,
                    executions_per_trial=3,
                    directory=tuner_logs,
                    project_name='CNN_tuning')

tuner.search(x=x_train,
            y=y_train,
            epochs=60,
            batch_size=32,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard])
'''

# %%
# bestModels = tuner.get_best_models(num_models=2)

# %% [markdown]
# #### FFNN Model

# %%
model = Sequential()
model.add(Flatten(input_shape=(100,4)))

model.add(Dense(units=512, activation='relu'))
model.add(Dense(units=256, activation='relu'))
# model.add(Dropout(0.3))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=96, activation='relu'))
model.add(Dense(units=12, activation='relu'))

model.add(Dense(units=2, activation='linear'))

model.summary()

# Compile model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the model
history = model.fit(x_train, y_train, epochs=50, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 400)               0
#
#  dense_18 (Dense)            (None, 512)               205312
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  dense_20 (Dense)            (None, 256)               65792
#
#  dense_21 (Dense)            (None, 96)                24672
#
#  dense_22 (Dense)            (None, 12)                1164
#
#  dense_23 (Dense)            (None, 2)                 26
#
# =================================================================
# Total params: 428,294
# Trainable params: 428,294
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 24/24 [==============================] - 1s 18ms/step - loss: 0.1388 - Accuracy: 0.5176 - val_loss: 0.1231 - val_Accuracy: 0.5027
# Epoch 2/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0913 - Accuracy: 0.4986 - val_loss: 0.0960 - val_Accuracy: 0.5027
# Epoch 3/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0824 - Accuracy: 0.5716 - val_loss: 0.0853 - val_Accuracy: 0.6216
# Epoch 4/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0658 - Accuracy: 0.6851 - val_loss: 0.0646 - val_Accuracy: 0.6757
# Epoch 5/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0418 - Accuracy: 0.7865 - val_loss: 0.0688 - val_Accuracy: 0.7838
# Epoch 6/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0265 - Accuracy: 0.8135 - val_loss: 0.0299 - val_Accuracy: 0.7622
# Epoch 7/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0177 - Accuracy: 0.8703 - val_loss: 0.0181 - val_Accuracy: 0.8054
# Epoch 8/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0127 - Accuracy: 0.8716 - val_loss: 0.0138 - val_Accuracy: 0.8162
# Epoch 9/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0064 - Accuracy: 0.9108 - val_loss: 0.0086 - val_Accuracy: 0.9135
# Epoch 10/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0040 - Accuracy: 0.9419 - val_loss: 0.0062 - val_Accuracy: 0.8919
# Epoch 11/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0029 - Accuracy: 0.9527 - val_loss: 0.0049 - val_Accuracy: 0.8703
# Epoch 12/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0023 - Accuracy: 0.9446 - val_loss: 0.0051 - val_Accuracy: 0.8811
# Epoch 13/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0020 - Accuracy: 0.9554 - val_loss: 0.0038 - val_Accuracy: 0.8811
# Epoch 14/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0020 - Accuracy: 0.9500 - val_loss: 0.0042 - val_Accuracy: 0.9027
# Epoch 15/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016 - Accuracy: 0.9486 - val_loss: 0.0030 - val_Accuracy: 0.9081
# Epoch 16/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0010 - Accuracy: 0.9622 - val_loss: 0.0031 - val_Accuracy: 0.9081
# Epoch 17/50
# 24/24 [==============================] - 0s 9ms/step - loss: 9.4576e-04 - Accuracy: 0.9757 - val_loss: 0.0035 - val_Accuracy: 0.9027
# Epoch 18/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0011 - Accuracy: 0.9500 - val_loss: 0.0028 - val_Accuracy: 0.9135
# Epoch 19/50
# 24/24 [==============================] - 0s 12ms/step - loss: 7.0877e-04 - Accuracy: 0.9676 - val_loss: 0.0025 - val_Accuracy: 0.9189
# Epoch 20/50
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3123e-04 - Accuracy: 0.9797 - val_loss: 0.0026 - val_Accuracy: 0.9297
# Epoch 21/50
# 24/24 [==============================] - 0s 8ms/step - loss: 5.7995e-04 - Accuracy: 0.9689 - val_loss: 0.0022 - val_Accuracy: 0.9081
# Epoch 22/50
# 24/24 [==============================] - 0s 8ms/step - loss: 4.8438e-04 - Accuracy: 0.9716 - val_loss: 0.0025 - val_Accuracy: 0.9081
# Epoch 23/50
# 24/24 [==============================] - 0s 7ms/step - loss: 7.4889e-04 - Accuracy: 0.9581 - val_loss: 0.0024 - val_Accuracy: 0.9081
# Epoch 24/50
# 24/24 [==============================] - 0s 7ms/step - loss: 7.1070e-04 - Accuracy: 0.9662 - val_loss: 0.0024 - val_Accuracy: 0.8973
# Epoch 25/50
# 24/24 [==============================] - 0s 8ms/step - loss: 4.4387e-04 - Accuracy: 0.9757 - val_loss: 0.0022 - val_Accuracy: 0.9189
# Epoch 26/50
# 24/24 [==============================] - 0s 9ms/step - loss: 4.5917e-04 - Accuracy: 0.9824 - val_loss: 0.0020 - val_Accuracy: 0.9243
# Epoch 27/50
# 24/24 [==============================] - 0s 10ms/step - loss: 3.5958e-04 - Accuracy: 0.9784 - val_loss: 0.0018 - val_Accuracy: 0.8919
# Epoch 28/50
# 24/24 [==============================] - 0s 8ms/step - loss: 2.8255e-04 - Accuracy: 0.9797 - val_loss: 0.0020 - val_Accuracy: 0.9135
# Epoch 29/50
# 24/24 [==============================] - 0s 9ms/step - loss: 5.6488e-04 - Accuracy: 0.9730 - val_loss: 0.0020 - val_Accuracy: 0.8973
# Epoch 30/50
# 24/24 [==============================] - 0s 10ms/step - loss: 5.6149e-04 - Accuracy: 0.9595 - val_loss: 0.0023 - val_Accuracy: 0.9189
# Epoch 31/50
# 24/24 [==============================] - 0s 9ms/step - loss: 4.8357e-04 - Accuracy: 0.9757 - val_loss: 0.0023 - val_Accuracy: 0.9135
# Epoch 32/50
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0339e-04 - Accuracy: 0.9689 - val_loss: 0.0022 - val_Accuracy: 0.9243
# Epoch 33/50
# 24/24 [==============================] - 0s 10ms/step - loss: 6.2508e-04 - Accuracy: 0.9649 - val_loss: 0.0020 - val_Accuracy: 0.9081
# Epoch 34/50
# 24/24 [==============================] - 0s 9ms/step - loss: 5.1034e-04 - Accuracy: 0.9703 - val_loss: 0.0020 - val_Accuracy: 0.9135
# Epoch 35/50
# 24/24 [==============================] - 0s 10ms/step - loss: 4.4908e-04 - Accuracy: 0.9743 - val_loss: 0.0019 - val_Accuracy: 0.9243
# Epoch 36/50
# 24/24 [==============================] - 0s 10ms/step - loss: 3.7422e-04 - Accuracy: 0.9743 - val_loss: 0.0016 - val_Accuracy: 0.8973
# Epoch 37/50
# 24/24 [==============================] - 0s 9ms/step - loss: 4.2013e-04 - Accuracy: 0.9757 - val_loss: 0.0018 - val_Accuracy: 0.9243
# Epoch 38/50
# 24/24 [==============================] - 0s 9ms/step - loss: 4.0265e-04 - Accuracy: 0.9689 - val_loss: 0.0019 - val_Accuracy: 0.9189
# Epoch 39/50
# 24/24 [==============================] - 0s 8ms/step - loss: 4.5293e-04 - Accuracy: 0.9784 - val_loss: 0.0017 - val_Accuracy: 0.9189
# Epoch 40/50
# 24/24 [==============================] - 0s 9ms/step - loss: 3.7046e-04 - Accuracy: 0.9757 - val_loss: 0.0017 - val_Accuracy: 0.9027
# Epoch 41/50
# 24/24 [==============================] - 0s 10ms/step - loss: 3.8463e-04 - Accuracy: 0.9730 - val_loss: 0.0018 - val_Accuracy: 0.9189
# Epoch 42/50
# 24/24 [==============================] - 0s 10ms/step - loss: 5.1669e-04 - Accuracy: 0.9622 - val_loss: 0.0018 - val_Accuracy: 0.9189
# Epoch 43/50
# 24/24 [==============================] - 0s 9ms/step - loss: 4.4496e-04 - Accuracy: 0.9649 - val_loss: 0.0022 - val_Accuracy: 0.9243
# Epoch 44/50
# 24/24 [==============================] - 0s 9ms/step - loss: 7.9800e-04 - Accuracy: 0.9743 - val_loss: 0.0019 - val_Accuracy: 0.9135
# Epoch 45/50
# 24/24 [==============================] - 0s 9ms/step - loss: 5.0623e-04 - Accuracy: 0.9662 - val_loss: 0.0026 - val_Accuracy: 0.9297
# Epoch 46/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0011 - Accuracy: 0.9689 - val_loss: 0.0031 - val_Accuracy: 0.9189
# Epoch 47/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0015 - Accuracy: 0.9500 - val_loss: 0.0032 - val_Accuracy: 0.9135
# Epoch 48/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0014 - Accuracy: 0.9622 - val_loss: 0.0024 - val_Accuracy: 0.9243
# Epoch 49/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0012 - Accuracy: 0.9527 - val_loss: 0.0033 - val_Accuracy: 0.8973
# Epoch 50/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0016 - Accuracy: 0.9527 - val_loss: 0.0026 - val_Accuracy: 0.8865

# %%
# model.save(f'model/DNN_val_acc_97perAcc.{int(time.time())}.h5')

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(model.predict(x_test)), squared=True)
# Out:
# 59.23490109319131

# %%
# mean_squared_error((ex_val_labels), scalar.inverse_transform(model.predict(ex_val_resample)), squared=True)

# %%
plt.close()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['Accuracy'], label='Training Accuracy')
plt.plot(history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### mAlexNet

# %%
Alex4=Sequential()

Alex4.add(Conv1D(filters=96, kernel_size=5, strides=4, activation='relu', input_shape=(100,4), padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides= 2, padding='valid'))
Alex4.add(Dropout(0.3))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=5, activation='relu', padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides=2, padding='valid'))

Alex4.add(Conv1D(filters=384, strides=1, kernel_size=3, activation='relu', padding='same'))
Alex4.add(Dropout(0.4))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=3, activation='relu', padding='same'))

Alex4.add(Conv1D(filters=256, strides=1, kernel_size=3, activation='relu', padding='same'))
Alex4.add(MaxPooling1D(pool_size=3, strides=2, padding='valid'))

# Fully Connected Layers
Alex4.add(Flatten())
Alex4.add(Dense(units=128, activation='relu',use_bias='False'))
Alex4.add(Dense(units=64, activation='relu',use_bias='False'))
Alex4.add(Dense(units=2, activation='linear',use_bias='False'))
Alex4.summary()

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

Alex4.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])

# Fit the cnn_model
Alex_history = Alex4.fit(x_train, y_train, epochs=90, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 25, 96)            2016
#
#  max_pooling1d (MaxPooling1D  (None, 12, 96)           0
#  )
#
#  dropout_1 (Dropout)         (None, 12, 96)            0
#
#  conv1d_1 (Conv1D)           (None, 12, 256)           123136
#
#  max_pooling1d_1 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 384)            295296
#
#  dropout_2 (Dropout)         (None, 5, 384)            0
#
#  conv1d_3 (Conv1D)           (None, 5, 256)            295168
#
#  conv1d_4 (Conv1D)           (None, 5, 256)            196864
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  flatten_4 (Flatten)         (None, 512)               0
#
#  dense_24 (Dense)            (None, 128)               65664
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dense_26 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 986,530
# Trainable params: 986,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/90
# 24/24 [==============================] - 8s 35ms/step - loss: 0.1369 - Accuracy: 0.5014 - val_loss: 0.1015 - val_Accuracy: 0.5027
# Epoch 2/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0961 - Accuracy: 0.4946 - val_loss: 0.0945 - val_Accuracy: 0.4973
# Epoch 3/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0926 - Accuracy: 0.5081 - val_loss: 0.1280 - val_Accuracy: 0.5027
# Epoch 4/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0831 - Accuracy: 0.5257 - val_loss: 0.1002 - val_Accuracy: 0.6054
# Epoch 5/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0648 - Accuracy: 0.5581 - val_loss: 0.0819 - val_Accuracy: 0.6216
# Epoch 6/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0501 - Accuracy: 0.6405 - val_loss: 0.0475 - val_Accuracy: 0.7514
# Epoch 7/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0221 - Accuracy: 0.8189 - val_loss: 0.0151 - val_Accuracy: 0.8865
# Epoch 8/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0155 - Accuracy: 0.8892 - val_loss: 0.0160 - val_Accuracy: 0.9405
# Epoch 9/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0108 - Accuracy: 0.8959 - val_loss: 0.0095 - val_Accuracy: 0.9514
# Epoch 10/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0112 - Accuracy: 0.8811 - val_loss: 0.0090 - val_Accuracy: 0.9405
# Epoch 11/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0086 - Accuracy: 0.8986 - val_loss: 0.0189 - val_Accuracy: 0.9676
# Epoch 12/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0076 - Accuracy: 0.9014 - val_loss: 0.0064 - val_Accuracy: 0.9189
# Epoch 13/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0066 - Accuracy: 0.9243 - val_loss: 0.0026 - val_Accuracy: 0.9351
# Epoch 14/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0061 - Accuracy: 0.9189 - val_loss: 0.0048 - val_Accuracy: 0.9514
# Epoch 15/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0046 - Accuracy: 0.9230 - val_loss: 0.0030 - val_Accuracy: 0.9405
# Epoch 16/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0047 - Accuracy: 0.9365 - val_loss: 0.0045 - val_Accuracy: 0.9405
# Epoch 17/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0042 - Accuracy: 0.9500 - val_loss: 0.0033 - val_Accuracy: 0.9730
# Epoch 18/90
# 24/24 [==============================] - ETA: 0s - loss: 0.0037 - Accuracy: 0.94 - 1s 33ms/step - loss: 0.0036 - Accuracy: 0.9473 - val_loss: 0.0050 - val_Accuracy: 0.9297
# Epoch 19/90
# 24/24 [==============================] - 1s 19ms/step - loss: 0.0043 - Accuracy: 0.9500 - val_loss: 0.0037 - val_Accuracy: 0.9405
# Epoch 20/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0031 - Accuracy: 0.9405 - val_loss: 0.0019 - val_Accuracy: 0.9351
# Epoch 21/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0030 - Accuracy: 0.9405 - val_loss: 0.0039 - val_Accuracy: 0.9568
# Epoch 22/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0028 - Accuracy: 0.9500 - val_loss: 0.0041 - val_Accuracy: 0.9730
# Epoch 23/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0028 - Accuracy: 0.9446 - val_loss: 0.0053 - val_Accuracy: 0.9568
# Epoch 24/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - Accuracy: 0.9351 - val_loss: 0.0039 - val_Accuracy: 0.9297
# Epoch 25/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0027 - Accuracy: 0.9419 - val_loss: 0.0026 - val_Accuracy: 0.9405
# Epoch 26/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0024 - Accuracy: 0.9541 - val_loss: 0.0048 - val_Accuracy: 0.9676
# Epoch 27/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0024 - Accuracy: 0.9622 - val_loss: 0.0023 - val_Accuracy: 0.9568
# Epoch 28/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0024 - Accuracy: 0.9459 - val_loss: 0.0046 - val_Accuracy: 0.9405
# Epoch 29/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0029 - Accuracy: 0.9446 - val_loss: 0.0033 - val_Accuracy: 0.9459
# Epoch 30/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0027 - Accuracy: 0.9500 - val_loss: 0.0035 - val_Accuracy: 0.9514
# Epoch 31/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0023 - Accuracy: 0.9486 - val_loss: 0.0035 - val_Accuracy: 0.9405
# Epoch 32/90
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0025 - Accuracy: 0.9500 - val_loss: 0.0026 - val_Accuracy: 0.9459
# Epoch 33/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0020 - Accuracy: 0.9500 - val_loss: 0.0023 - val_Accuracy: 0.9405
# Epoch 34/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - Accuracy: 0.9581 - val_loss: 9.6737e-04 - val_Accuracy: 0.9730
# Epoch 35/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - Accuracy: 0.9527 - val_loss: 0.0013 - val_Accuracy: 0.9405
# Epoch 36/90
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - Accuracy: 0.9595 - val_loss: 0.0023 - val_Accuracy: 0.9405
# Epoch 37/90
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - Accuracy: 0.9527 - val_loss: 0.0015 - val_Accuracy: 0.9514
# Epoch 38/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0017 - Accuracy: 0.9649 - val_loss: 0.0031 - val_Accuracy: 0.9405
# Epoch 39/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - Accuracy: 0.9500 - val_loss: 0.0026 - val_Accuracy: 0.9459
# Epoch 40/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0016 - Accuracy: 0.9608 - val_loss: 0.0025 - val_Accuracy: 0.9189
# Epoch 41/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0016 - Accuracy: 0.9608 - val_loss: 0.0021 - val_Accuracy: 0.9838
# Epoch 42/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0015 - Accuracy: 0.9608 - val_loss: 0.0023 - val_Accuracy: 0.9459
# Epoch 43/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0017 - Accuracy: 0.9622 - val_loss: 6.9491e-04 - val_Accuracy: 0.9784
# Epoch 44/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0015 - Accuracy: 0.9649 - val_loss: 0.0015 - val_Accuracy: 0.9514
# Epoch 45/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9716 - val_loss: 0.0015 - val_Accuracy: 0.9784
# Epoch 46/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9595 - val_loss: 9.8896e-04 - val_Accuracy: 0.9838
# Epoch 47/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0013 - Accuracy: 0.9608 - val_loss: 0.0014 - val_Accuracy: 0.9676
# Epoch 48/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - Accuracy: 0.9716 - val_loss: 6.6984e-04 - val_Accuracy: 0.9838
# Epoch 49/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0013 - Accuracy: 0.9649 - val_loss: 8.3133e-04 - val_Accuracy: 0.9459
# Epoch 50/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - Accuracy: 0.9662 - val_loss: 0.0012 - val_Accuracy: 0.9459
# Epoch 51/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - Accuracy: 0.9676 - val_loss: 0.0014 - val_Accuracy: 0.9784
# Epoch 52/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - Accuracy: 0.9568 - val_loss: 7.6922e-04 - val_Accuracy: 0.9568
# Epoch 53/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0010 - Accuracy: 0.9676 - val_loss: 6.5722e-04 - val_Accuracy: 0.9784
# Epoch 54/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9622 - val_loss: 0.0014 - val_Accuracy: 0.9730
# Epoch 55/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9527 - val_loss: 0.0011 - val_Accuracy: 0.9622
# Epoch 56/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - Accuracy: 0.9554 - val_loss: 0.0014 - val_Accuracy: 0.9838
# Epoch 57/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0012 - Accuracy: 0.9581 - val_loss: 7.8138e-04 - val_Accuracy: 0.9568
# Epoch 58/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.5810e-04 - Accuracy: 0.9662 - val_loss: 6.7540e-04 - val_Accuracy: 0.9459
# Epoch 59/90
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0011 - Accuracy: 0.9662 - val_loss: 0.0010 - val_Accuracy: 0.9676
# Epoch 60/90
# 24/24 [==============================] - 0s 13ms/step - loss: 9.2530e-04 - Accuracy: 0.9568 - val_loss: 0.0019 - val_Accuracy: 0.9676
# Epoch 61/90
# 24/24 [==============================] - 0s 13ms/step - loss: 9.7391e-04 - Accuracy: 0.9662 - val_loss: 5.2230e-04 - val_Accuracy: 0.9622
# Epoch 62/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9757 - val_loss: 7.3280e-04 - val_Accuracy: 0.9568
# Epoch 63/90
# 24/24 [==============================] - 0s 13ms/step - loss: 9.5688e-04 - Accuracy: 0.9676 - val_loss: 0.0013 - val_Accuracy: 0.9459
# Epoch 64/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - Accuracy: 0.9608 - val_loss: 4.4773e-04 - val_Accuracy: 0.9838
# Epoch 65/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9649 - val_loss: 4.6400e-04 - val_Accuracy: 0.9838
# Epoch 66/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0014 - Accuracy: 0.9689 - val_loss: 0.0010 - val_Accuracy: 0.9784
# Epoch 67/90
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0011 - Accuracy: 0.9541 - val_loss: 0.0013 - val_Accuracy: 0.9459
# Epoch 68/90
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0011 - Accuracy: 0.9622 - val_loss: 6.0148e-04 - val_Accuracy: 0.9514
# Epoch 69/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.3101e-04 - Accuracy: 0.9689 - val_loss: 6.1983e-04 - val_Accuracy: 0.9622
# Epoch 70/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.7838e-04 - Accuracy: 0.9743 - val_loss: 8.8717e-04 - val_Accuracy: 0.9838
# Epoch 71/90
# 24/24 [==============================] - 0s 14ms/step - loss: 8.0549e-04 - Accuracy: 0.9716 - val_loss: 8.0474e-04 - val_Accuracy: 0.9730
# Epoch 72/90
# 24/24 [==============================] - 0s 13ms/step - loss: 7.9412e-04 - Accuracy: 0.9581 - val_loss: 7.8122e-04 - val_Accuracy: 0.9405
# Epoch 73/90
# 24/24 [==============================] - 0s 15ms/step - loss: 7.5753e-04 - Accuracy: 0.9622 - val_loss: 5.3566e-04 - val_Accuracy: 0.9838
# Epoch 74/90
# 24/24 [==============================] - 0s 16ms/step - loss: 9.3438e-04 - Accuracy: 0.9622 - val_loss: 9.2973e-04 - val_Accuracy: 0.9459
# Epoch 75/90
# 24/24 [==============================] - 1s 22ms/step - loss: 8.5813e-04 - Accuracy: 0.9703 - val_loss: 4.0166e-04 - val_Accuracy: 0.9568
# Epoch 76/90
# 24/24 [==============================] - 0s 16ms/step - loss: 8.3193e-04 - Accuracy: 0.9716 - val_loss: 4.1246e-04 - val_Accuracy: 0.9514
# Epoch 77/90
# 24/24 [==============================] - 0s 18ms/step - loss: 9.0283e-04 - Accuracy: 0.9662 - val_loss: 7.7568e-04 - val_Accuracy: 0.9568
# Epoch 78/90
# 24/24 [==============================] - 0s 14ms/step - loss: 9.0890e-04 - Accuracy: 0.9662 - val_loss: 9.2853e-04 - val_Accuracy: 0.9730
# Epoch 79/90
# 24/24 [==============================] - 0s 13ms/step - loss: 7.3733e-04 - Accuracy: 0.9662 - val_loss: 5.5040e-04 - val_Accuracy: 0.9568
# Epoch 80/90
# 24/24 [==============================] - 0s 15ms/step - loss: 7.1358e-04 - Accuracy: 0.9689 - val_loss: 8.3433e-04 - val_Accuracy: 1.0000
# Epoch 81/90
# 24/24 [==============================] - 0s 14ms/step - loss: 6.5688e-04 - Accuracy: 0.9649 - val_loss: 4.1603e-04 - val_Accuracy: 0.9892
# Epoch 82/90
# 24/24 [==============================] - 0s 17ms/step - loss: 6.7842e-04 - Accuracy: 0.9716 - val_loss: 3.6824e-04 - val_Accuracy: 0.9838
# Epoch 83/90
# 24/24 [==============================] - 0s 18ms/step - loss: 6.0860e-04 - Accuracy: 0.9797 - val_loss: 3.7353e-04 - val_Accuracy: 0.9676
# Epoch 84/90
# 24/24 [==============================] - 0s 16ms/step - loss: 5.8136e-04 - Accuracy: 0.9770 - val_loss: 4.3453e-04 - val_Accuracy: 0.9730
# Epoch 85/90
# 24/24 [==============================] - 0s 16ms/step - loss: 5.8616e-04 - Accuracy: 0.9635 - val_loss: 5.2617e-04 - val_Accuracy: 0.9892
# Epoch 86/90
# 24/24 [==============================] - 0s 16ms/step - loss: 5.9846e-04 - Accuracy: 0.9662 - val_loss: 4.5792e-04 - val_Accuracy: 0.9568
# Epoch 87/90
# 24/24 [==============================] - 0s 17ms/step - loss: 8.0359e-04 - Accuracy: 0.9730 - val_loss: 4.0880e-04 - val_Accuracy: 0.9838
# Epoch 88/90
# 24/24 [==============================] - 0s 16ms/step - loss: 6.6586e-04 - Accuracy: 0.9703 - val_loss: 3.3094e-04 - val_Accuracy: 0.9622
# Epoch 89/90
# 24/24 [==============================] - 0s 18ms/step - loss: 5.8169e-04 - Accuracy: 0.9689 - val_loss: 6.6854e-04 - val_Accuracy: 0.9784
# Epoch 90/90
# 24/24 [==============================] - 0s 18ms/step - loss: 6.9883e-04 - Accuracy: 0.9716 - val_loss: 3.9333e-04 - val_Accuracy: 0.9676

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(Alex4.predict(x_test)), squared=True)
# mean_absolute_error(scalar.inverse_transform(y_test), scalar.inverse_transform(Alex4.predict(x_test)))
# Out:
# 8.849830890601702

# %%
# Alex4.save(f'model/FINAL_CNN_val_acc_97_16_MSE.{int(time.time())}.h5')

# %%
plt.close()
plt.plot(Alex_history.history['loss'], label='Training Loss')
plt.plot(Alex_history.history['val_loss'], label='Validation Loss')
plt.plot(Alex_history.history['Accuracy'], label='Training Accuracy')
plt.plot(Alex_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))

plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Extension Other Networks

# %% [markdown]
# ##### ResNet

# %%
def relu_bn(inputs: Tensor) -> Tensor:
    bn = BatchNormalization()(inputs)
    relu = ReLU()(bn)
    return relu

def CNN_block(x: Tensor, filters: int, kernel_size: int = 3) -> Tensor:
    # i = BatchNormalization()(x)
    j = Conv1D(kernel_size=3,
            strides=1,
            filters=filters,
            padding="same")(x)
    return j

def residual_block(x: Tensor, filters: int, kernel_size: int = 3) -> Tensor:
    y = Conv1D(kernel_size=kernel_size,
               strides= 1,
               filters=filters,
               padding="same")(x)
    y = relu_bn(y)
    y = Conv1D(kernel_size=kernel_size,
               strides=1,
               filters=filters,
               padding="same")(y)
    y = BatchNormalization()(y)

    out = Add()([x, y])
    out = relu_bn(out)
    return out

def create_res_net():
    
    inputs = Input(shape=(100,4))
    num_filters = 64
    
    t = BatchNormalization()(inputs)
    t = Conv1D(kernel_size=3,
               strides=1,
               filters=num_filters,
               padding="same")(t)
    t = relu_bn(t)
        
    num_blocks_list = [2, 1, 2]
    t = CNN_block(t, filters = 128)
    for j in range(num_blocks_list[0]):
        t = residual_block(t, filters=128)

    t = Dropout(0.3)(t)

    t = CNN_block(t, filters = 64)
    for j in range(num_blocks_list[1]):
        t = residual_block(t, filters=64)
    
    t = Dropout(0.3)(t)

    t = CNN_block(t, filters = 64)
    for j in range(num_blocks_list[2]):
        t = residual_block(t, filters=64)
    
    t = AveragePooling1D(pool_size = 3)(t)
    t = Flatten()(t)
    # t = Dense(units=128, activation='relu')(t)
    t = Dense(units=32, activation="relu")(t)
    outputs = Dense(2, activation='linear')(t)
    
    model = Model(inputs, outputs)

    model.compile(
        optimizer='Adam',
        loss='mse',
        metrics=['Accuracy']
    )

    return model

rnet1 = create_res_net() # or create_plain_net()
rnet1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 4)]     0           []
#
#  batch_normalization (BatchNorm  (None, 100, 4)      16          ['input_1[0][0]']
#  alization)
#
#  conv1d_15 (Conv1D)             (None, 100, 64)      832         ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 100, 64)     256         ['conv1d_15[0][0]']
#  rmalization)
#
#  re_lu (ReLU)                   (None, 100, 64)      0           ['batch_normalization_1[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 100, 128)     24704       ['re_lu[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 100, 128)     49280       ['conv1d_16[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 100, 128)    512         ['conv1d_17[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 100, 128)     0           ['batch_normalization_2[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 100, 128)     49280       ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 100, 128)    512         ['conv1d_18[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 100, 128)     0           ['conv1d_16[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 100, 128)    512         ['add[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 100, 128)     0           ['batch_normalization_4[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 100, 128)     49280       ['re_lu_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 100, 128)    512         ['conv1d_19[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 100, 128)     0           ['batch_normalization_5[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 100, 128)     49280       ['re_lu_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 100, 128)    512         ['conv1d_20[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 100, 128)     0           ['re_lu_2[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 100, 128)    512         ['add_1[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 100, 128)     0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 100, 128)     0           ['re_lu_4[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 100, 64)      24640       ['dropout_3[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 100, 64)      12352       ['conv1d_21[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 100, 64)     256         ['conv1d_22[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 100, 64)      0           ['batch_normalization_8[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 100, 64)      12352       ['re_lu_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 100, 64)     256         ['conv1d_23[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 100, 64)      0           ['conv1d_21[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 100, 64)     256         ['add_2[0][0]']
#  ormalization)
#
#  re_lu_6 (ReLU)                 (None, 100, 64)      0           ['batch_normalization_10[0][0]']
#
#  dropout_4 (Dropout)            (None, 100, 64)      0           ['re_lu_6[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 100, 64)      12352       ['dropout_4[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 100, 64)      12352       ['conv1d_24[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 100, 64)     256         ['conv1d_25[0][0]']
#  ormalization)
#
#  re_lu_7 (ReLU)                 (None, 100, 64)      0           ['batch_normalization_11[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 100, 64)      12352       ['re_lu_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 100, 64)     256         ['conv1d_26[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 100, 64)      0           ['conv1d_24[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 100, 64)     256         ['add_3[0][0]']
#  ormalization)
#
#  re_lu_8 (ReLU)                 (None, 100, 64)      0           ['batch_normalization_13[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 100, 64)      12352       ['re_lu_8[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 100, 64)     256         ['conv1d_27[0][0]']
#  ormalization)
#
#  re_lu_9 (ReLU)                 (None, 100, 64)      0           ['batch_normalization_14[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 100, 64)      12352       ['re_lu_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 100, 64)     256         ['conv1d_28[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 100, 64)      0           ['re_lu_8[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 100, 64)     256         ['add_4[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 100, 64)      0           ['batch_normalization_16[0][0]']
#
#  average_pooling1d (AveragePool  (None, 33, 64)      0           ['re_lu_10[0][0]']
#  ing1D)
#
#  flatten_6 (Flatten)            (None, 2112)         0           ['average_pooling1d[0][0]']
#
#  dense_28 (Dense)               (None, 32)           67616       ['flatten_6[0][0]']
#
#  dense_29 (Dense)               (None, 2)            66          ['dense_28[0][0]']
#
# ==================================================================================================
# Total params: 407,090
# Trainable params: 404,266
# Non-trainable params: 2,824
# __________________________________________________________________________________________________

# %%
# timestr = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# name = 'cifar-10_res_net_30-'+timestr # or 'cifar-10_plain_net_30-'+timestr

# checkpoint_path = "checkpoints/"+name+"/cp-{epoch:04d}.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)
# os.system('mkdir {}'.format(checkpoint_dir))

# # save model after each epoch
# cp_callback = ModelCheckpoint(
#     filepath=checkpoint_path,
#     verbose=1
# )
# tensorboard_callback = TensorBoard(
#     log_dir='tensorboard_logs/'+name,
#     histogram_freq=1
# )

rNet1_history = rnet1.fit(
    x=x_train,
    y=y_train,
    epochs=90,
    verbose=1,
    validation_data=(x_test, y_test),
    batch_size=32,
    # callbacks=[cp_callback, tensorboard_callback]
)
# Out:
# Epoch 1/90
# 24/24 [==============================] - 13s 127ms/step - loss: 0.3220 - Accuracy: 0.4892 - val_loss: 0.2916 - val_Accuracy: 0.4973
# Epoch 2/90
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0870 - Accuracy: 0.5500 - val_loss: 0.2297 - val_Accuracy: 0.4973
# Epoch 3/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0571 - Accuracy: 0.6770 - val_loss: 0.1716 - val_Accuracy: 0.4973
# Epoch 4/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0442 - Accuracy: 0.7257 - val_loss: 0.1287 - val_Accuracy: 0.6000
# Epoch 5/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0270 - Accuracy: 0.8703 - val_loss: 0.1009 - val_Accuracy: 0.5027
# Epoch 6/90
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0185 - Accuracy: 0.8824 - val_loss: 0.0912 - val_Accuracy: 0.5081
# Epoch 7/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0162 - Accuracy: 0.9068 - val_loss: 0.0707 - val_Accuracy: 0.5568
# Epoch 8/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0137 - Accuracy: 0.8986 - val_loss: 0.0555 - val_Accuracy: 0.7297
# Epoch 9/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0123 - Accuracy: 0.9176 - val_loss: 0.0452 - val_Accuracy: 0.7946
# Epoch 10/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0103 - Accuracy: 0.9243 - val_loss: 0.0376 - val_Accuracy: 0.8108
# Epoch 11/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0091 - Accuracy: 0.9230 - val_loss: 0.0330 - val_Accuracy: 0.8054
# Epoch 12/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0090 - Accuracy: 0.9041 - val_loss: 0.0217 - val_Accuracy: 0.8757
# Epoch 13/90
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0083 - Accuracy: 0.9122 - val_loss: 0.0225 - val_Accuracy: 0.8541
# Epoch 14/90
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0076 - Accuracy: 0.9230 - val_loss: 0.0180 - val_Accuracy: 0.8811
# Epoch 15/90
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0075 - Accuracy: 0.9216 - val_loss: 0.0147 - val_Accuracy: 0.9027
# Epoch 16/90
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0069 - Accuracy: 0.9135 - val_loss: 0.0122 - val_Accuracy: 0.9135
# Epoch 17/90
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0066 - Accuracy: 0.9162 - val_loss: 0.0111 - val_Accuracy: 0.9297
# Epoch 18/90
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0064 - Accuracy: 0.9392 - val_loss: 0.0115 - val_Accuracy: 0.9081
# Epoch 19/90
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0062 - Accuracy: 0.9176 - val_loss: 0.0110 - val_Accuracy: 0.9243
# Epoch 20/90
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0055 - Accuracy: 0.9257 - val_loss: 0.0086 - val_Accuracy: 0.9081
# Epoch 21/90
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0056 - Accuracy: 0.9297 - val_loss: 0.0074 - val_Accuracy: 0.9622
# Epoch 22/90
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0048 - Accuracy: 0.9054 - val_loss: 0.0078 - val_Accuracy: 0.9405
# Epoch 23/90
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0056 - Accuracy: 0.9203 - val_loss: 0.0087 - val_Accuracy: 0.9351
# Epoch 24/90
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0060 - Accuracy: 0.9122 - val_loss: 0.0066 - val_Accuracy: 0.9351
# Epoch 25/90
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0042 - Accuracy: 0.9419 - val_loss: 0.0050 - val_Accuracy: 0.9459
# Epoch 26/90
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0045 - Accuracy: 0.9297 - val_loss: 0.0070 - val_Accuracy: 0.9405
# Epoch 27/90
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0044 - Accuracy: 0.9243 - val_loss: 0.0057 - val_Accuracy: 0.9135
# Epoch 28/90
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0038 - Accuracy: 0.9392 - val_loss: 0.0050 - val_Accuracy: 0.9189
# Epoch 29/90
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0037 - Accuracy: 0.9284 - val_loss: 0.0053 - val_Accuracy: 0.9243
# Epoch 30/90
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0039 - Accuracy: 0.9122 - val_loss: 0.0046 - val_Accuracy: 0.9405
# Epoch 31/90
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0039 - Accuracy: 0.9243 - val_loss: 0.0050 - val_Accuracy: 0.9622
# Epoch 32/90
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0037 - Accuracy: 0.9230 - val_loss: 0.0048 - val_Accuracy: 0.9568
# Epoch 33/90
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0036 - Accuracy: 0.9365 - val_loss: 0.0045 - val_Accuracy: 0.9351
# Epoch 34/90
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0032 - Accuracy: 0.9216 - val_loss: 0.0046 - val_Accuracy: 0.9568
# Epoch 35/90
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0037 - Accuracy: 0.9365 - val_loss: 0.0042 - val_Accuracy: 0.9135
# Epoch 36/90
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0033 - Accuracy: 0.9338 - val_loss: 0.0040 - val_Accuracy: 0.9297
# Epoch 37/90
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0033 - Accuracy: 0.9527 - val_loss: 0.0040 - val_Accuracy: 0.9297
# Epoch 38/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0031 - Accuracy: 0.9419 - val_loss: 0.0046 - val_Accuracy: 0.9189
# Epoch 39/90
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0027 - Accuracy: 0.9297 - val_loss: 0.0033 - val_Accuracy: 0.9405
# Epoch 40/90
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0027 - Accuracy: 0.9486 - val_loss: 0.0036 - val_Accuracy: 0.9514
# Epoch 41/90
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0026 - Accuracy: 0.9473 - val_loss: 0.0035 - val_Accuracy: 0.9135
# Epoch 42/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0033 - Accuracy: 0.9189 - val_loss: 0.0039 - val_Accuracy: 0.9568
# Epoch 43/90
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0038 - Accuracy: 0.9122 - val_loss: 0.0041 - val_Accuracy: 0.9351
# Epoch 44/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0029 - Accuracy: 0.9311 - val_loss: 0.0037 - val_Accuracy: 0.9351
# Epoch 45/90
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0027 - Accuracy: 0.9459 - val_loss: 0.0034 - val_Accuracy: 0.9351
# Epoch 46/90
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0025 - Accuracy: 0.9419 - val_loss: 0.0034 - val_Accuracy: 0.9514
# Epoch 47/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0027 - Accuracy: 0.9392 - val_loss: 0.0043 - val_Accuracy: 0.9189
# Epoch 48/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0028 - Accuracy: 0.9473 - val_loss: 0.0032 - val_Accuracy: 0.9243
# Epoch 49/90
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0024 - Accuracy: 0.9473 - val_loss: 0.0031 - val_Accuracy: 0.9514
# Epoch 50/90
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0024 - Accuracy: 0.9405 - val_loss: 0.0024 - val_Accuracy: 0.9459
# Epoch 51/90
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0023 - Accuracy: 0.9554 - val_loss: 0.0032 - val_Accuracy: 0.9297
# Epoch 52/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0024 - Accuracy: 0.9486 - val_loss: 0.0033 - val_Accuracy: 0.9405
# Epoch 53/90
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0021 - Accuracy: 0.9365 - val_loss: 0.0027 - val_Accuracy: 0.9243
# Epoch 54/90
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0020 - Accuracy: 0.9473 - val_loss: 0.0030 - val_Accuracy: 0.9297
# Epoch 55/90
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0018 - Accuracy: 0.9527 - val_loss: 0.0028 - val_Accuracy: 0.9243
# Epoch 56/90
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0018 - Accuracy: 0.9581 - val_loss: 0.0033 - val_Accuracy: 0.9297
# Epoch 57/90
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0021 - Accuracy: 0.9473 - val_loss: 0.0027 - val_Accuracy: 0.9568
# Epoch 58/90
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0025 - Accuracy: 0.9392 - val_loss: 0.0034 - val_Accuracy: 0.9568
# Epoch 59/90
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0025 - Accuracy: 0.9541 - val_loss: 0.0034 - val_Accuracy: 0.9405
# Epoch 60/90
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0019 - Accuracy: 0.9514 - val_loss: 0.0027 - val_Accuracy: 0.9459
# Epoch 61/90
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0019 - Accuracy: 0.9459 - val_loss: 0.0039 - val_Accuracy: 0.9189
# Epoch 62/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0019 - Accuracy: 0.9378 - val_loss: 0.0024 - val_Accuracy: 0.9459
# Epoch 63/90
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0019 - Accuracy: 0.9459 - val_loss: 0.0043 - val_Accuracy: 0.9189
# Epoch 64/90
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0022 - Accuracy: 0.9514 - val_loss: 0.0026 - val_Accuracy: 0.9189
# Epoch 65/90
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0030 - Accuracy: 0.9351 - val_loss: 0.0038 - val_Accuracy: 0.9135
# Epoch 66/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0025 - Accuracy: 0.9446 - val_loss: 0.0032 - val_Accuracy: 0.9297
# Epoch 67/90
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0021 - Accuracy: 0.9541 - val_loss: 0.0037 - val_Accuracy: 0.9189
# Epoch 68/90
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0019 - Accuracy: 0.9446 - val_loss: 0.0020 - val_Accuracy: 0.9405
# Epoch 69/90
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0018 - Accuracy: 0.9514 - val_loss: 0.0032 - val_Accuracy: 0.9351
# Epoch 70/90
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0025 - Accuracy: 0.9689 - val_loss: 0.0033 - val_Accuracy: 0.9135
# Epoch 71/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0020 - Accuracy: 0.9459 - val_loss: 0.0021 - val_Accuracy: 0.9243
# Epoch 72/90
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0017 - Accuracy: 0.9595 - val_loss: 0.0021 - val_Accuracy: 0.9405
# Epoch 73/90
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0016 - Accuracy: 0.9541 - val_loss: 0.0018 - val_Accuracy: 0.9514
# Epoch 74/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0016 - Accuracy: 0.9514 - val_loss: 0.0022 - val_Accuracy: 0.9243
# Epoch 75/90
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0017 - Accuracy: 0.9459 - val_loss: 0.0018 - val_Accuracy: 0.9297
# Epoch 76/90
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016 - Accuracy: 0.9527 - val_loss: 0.0021 - val_Accuracy: 0.9297
# Epoch 77/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0017 - Accuracy: 0.9568 - val_loss: 0.0017 - val_Accuracy: 0.9405
# Epoch 78/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0017 - Accuracy: 0.9527 - val_loss: 0.0017 - val_Accuracy: 0.9351
# Epoch 79/90
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0018 - Accuracy: 0.9473 - val_loss: 0.0037 - val_Accuracy: 0.9135
# Epoch 80/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0027 - Accuracy: 0.9527 - val_loss: 0.0031 - val_Accuracy: 0.9297
# Epoch 81/90
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0018 - Accuracy: 0.9554 - val_loss: 0.0022 - val_Accuracy: 0.9459
# Epoch 82/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0017 - Accuracy: 0.9662 - val_loss: 0.0021 - val_Accuracy: 0.9568
# Epoch 83/90
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0019 - Accuracy: 0.9541 - val_loss: 0.0021 - val_Accuracy: 0.9459
# Epoch 84/90
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0015 - Accuracy: 0.9608 - val_loss: 0.0021 - val_Accuracy: 0.9351
# Epoch 85/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0014 - Accuracy: 0.9541 - val_loss: 0.0020 - val_Accuracy: 0.9243
# Epoch 86/90
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0014 - Accuracy: 0.9554 - val_loss: 0.0023 - val_Accuracy: 0.9514
# Epoch 87/90
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0015 - Accuracy: 0.9446 - val_loss: 0.0021 - val_Accuracy: 0.9405
# Epoch 88/90
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0012 - Accuracy: 0.9568 - val_loss: 0.0018 - val_Accuracy: 0.9351
# Epoch 89/90
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0012 - Accuracy: 0.9554 - val_loss: 0.0018 - val_Accuracy: 0.9459
# Epoch 90/90
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016 - Accuracy: 0.9541 - val_loss: 0.0020 - val_Accuracy: 0.9459

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(rnet1.predict(x_test)), squared=True)
# mean_absolute_error(scalar.inverse_transform(y_test), scalar.inverse_transform(rnet.predict(x_test)))
# Out:
# 45.462817854286996

# %%
plt.close()
plt.plot(rNet1_history.history['loss'], label='Training Loss')
plt.plot(rNet1_history.history['val_loss'], label='Validation Loss')
plt.plot(rNet1_history.history['Accuracy'], label='Training Accuracy')
plt.plot(rNet1_history.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))
plt.ylim(bottom=0, top=1)
plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# rnet.save('ResNet-60MSE.h5')

# %% [markdown]
# ##### VGG

# %%
VGG2 = Sequential()

VGG2.add(Conv1D(filters=64, kernel_size=3, strides=2,activation='relu', input_shape=(100,4), padding='same'))
VGG2.add(Conv1D(filters=64, kernel_size=3, strides=1,activation='relu',padding='valid'))
VGG2.add(Conv1D(filters=64, kernel_size=1, strides=1,activation='relu' ))

VGG2.add(MaxPooling1D(pool_size=2, strides=2))

VGG2.add(Conv1D(filters=128, kernel_size=3, strides=1,activation='relu',padding='valid'))
VGG2.add(Conv1D(filters=128, kernel_size=1, strides=1,activation='relu' ))

VGG2.add(MaxPooling1D(pool_size=2, strides=2))

VGG2.add(Conv1D(filters=256, kernel_size=3, strides=1,activation='relu',padding='valid'))
VGG2.add(Conv1D(filters=256, kernel_size=1, strides=1,activation='relu' ))

VGG2.add(MaxPooling1D(pool_size=2, strides=2))

VGG2.add(Conv1D(filters=256, kernel_size=3, strides=1,activation='relu',padding='valid'))
VGG2.add(Conv1D(filters=384, kernel_size=1, strides=1,activation='relu'))
VGG2.add(Conv1D(filters=100, kernel_size=1, strides=1,activation='relu'))
VGG2.add(MaxPooling1D(pool_size=2, strides=2))

VGG2.add(Flatten())

VGG2.add(Dense(units=2,activation='linear'))

VGG2.summary()

VGG2.compile(loss = 'mse', optimizer = 'Adam', metrics=['Accuracy'])
VGG2_act=VGG2.fit(x_train, y_train, epochs=40, verbose=1, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 50, 64)            832
#
#  conv1d_6 (Conv1D)           (None, 48, 64)            12352
#
#  conv1d_7 (Conv1D)           (None, 48, 64)            4160
#
#  max_pooling1d_3 (MaxPooling  (None, 24, 64)           0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 22, 128)           24704
#
#  conv1d_9 (Conv1D)           (None, 22, 128)           16512
#
#  max_pooling1d_4 (MaxPooling  (None, 11, 128)          0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 9, 256)            98560
#
#  conv1d_11 (Conv1D)          (None, 9, 256)            65792
#
#  max_pooling1d_5 (MaxPooling  (None, 4, 256)           0
#  1D)
#
#  conv1d_12 (Conv1D)          (None, 2, 256)            196864
#
#  conv1d_13 (Conv1D)          (None, 2, 384)            98688
#
#  conv1d_14 (Conv1D)          (None, 2, 100)            38500
#
#  max_pooling1d_6 (MaxPooling  (None, 1, 100)           0
#  1D)
#
#  flatten_5 (Flatten)         (None, 100)               0
#
#  dense_27 (Dense)            (None, 2)                 202
#
# =================================================================
# Total params: 557,166
# Trainable params: 557,166
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 24/24 [==============================] - 4s 64ms/step - loss: 0.1209 - Accuracy: 0.5230 - val_loss: 0.1127 - val_Accuracy: 0.5027
# Epoch 2/40
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0904 - Accuracy: 0.5149 - val_loss: 0.0883 - val_Accuracy: 0.4973
# Epoch 3/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0791 - Accuracy: 0.5230 - val_loss: 0.0749 - val_Accuracy: 0.6324
# Epoch 4/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0558 - Accuracy: 0.6297 - val_loss: 0.0500 - val_Accuracy: 0.6919
# Epoch 5/40
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0361 - Accuracy: 0.7500 - val_loss: 0.0357 - val_Accuracy: 0.7730
# Epoch 6/40
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0235 - Accuracy: 0.8270 - val_loss: 0.0175 - val_Accuracy: 0.8595
# Epoch 7/40
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0113 - Accuracy: 0.8811 - val_loss: 0.0113 - val_Accuracy: 0.9027
# Epoch 8/40
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0067 - Accuracy: 0.9243 - val_loss: 0.0078 - val_Accuracy: 0.8919
# Epoch 9/40
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0056 - Accuracy: 0.9284 - val_loss: 0.0055 - val_Accuracy: 0.9135
# Epoch 10/40
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0033 - Accuracy: 0.9500 - val_loss: 0.0053 - val_Accuracy: 0.9189
# Epoch 11/40
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0019 - Accuracy: 0.9405 - val_loss: 0.0032 - val_Accuracy: 0.9459
# Epoch 12/40
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0014 - Accuracy: 0.9595 - val_loss: 0.0036 - val_Accuracy: 0.9351
# Epoch 13/40
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0012 - Accuracy: 0.9514 - val_loss: 0.0032 - val_Accuracy: 0.9243
# Epoch 14/40
# 24/24 [==============================] - 1s 21ms/step - loss: 0.0012 - Accuracy: 0.9568 - val_loss: 0.0024 - val_Accuracy: 0.9405
# Epoch 15/40
# 24/24 [==============================] - 0s 19ms/step - loss: 7.7457e-04 - Accuracy: 0.9689 - val_loss: 0.0026 - val_Accuracy: 0.9297
# Epoch 16/40
# 24/24 [==============================] - 1s 21ms/step - loss: 5.8242e-04 - Accuracy: 0.9743 - val_loss: 0.0023 - val_Accuracy: 0.9351
# Epoch 17/40
# 24/24 [==============================] - 1s 22ms/step - loss: 4.8243e-04 - Accuracy: 0.9838 - val_loss: 0.0020 - val_Accuracy: 0.9351
# Epoch 18/40
# 24/24 [==============================] - 1s 24ms/step - loss: 4.3362e-04 - Accuracy: 0.9716 - val_loss: 0.0019 - val_Accuracy: 0.9351
# Epoch 19/40
# 24/24 [==============================] - 1s 25ms/step - loss: 5.6605e-04 - Accuracy: 0.9770 - val_loss: 0.0023 - val_Accuracy: 0.9405
# Epoch 20/40
# 24/24 [==============================] - 1s 22ms/step - loss: 5.2782e-04 - Accuracy: 0.9838 - val_loss: 0.0022 - val_Accuracy: 0.9351
# Epoch 21/40
# 24/24 [==============================] - 1s 23ms/step - loss: 3.9708e-04 - Accuracy: 0.9770 - val_loss: 0.0021 - val_Accuracy: 0.9351
# Epoch 22/40
# 24/24 [==============================] - 1s 25ms/step - loss: 4.0979e-04 - Accuracy: 0.9757 - val_loss: 0.0022 - val_Accuracy: 0.9514
# Epoch 23/40
# 24/24 [==============================] - 1s 23ms/step - loss: 5.4546e-04 - Accuracy: 0.9662 - val_loss: 0.0021 - val_Accuracy: 0.9459
# Epoch 24/40
# 24/24 [==============================] - 0s 20ms/step - loss: 3.0709e-04 - Accuracy: 0.9851 - val_loss: 0.0018 - val_Accuracy: 0.9514
# Epoch 25/40
# 24/24 [==============================] - 0s 20ms/step - loss: 1.8365e-04 - Accuracy: 0.9851 - val_loss: 0.0018 - val_Accuracy: 0.9351
# Epoch 26/40
# 24/24 [==============================] - 1s 22ms/step - loss: 1.7008e-04 - Accuracy: 0.9865 - val_loss: 0.0019 - val_Accuracy: 0.9459
# Epoch 27/40
# 24/24 [==============================] - 1s 22ms/step - loss: 1.6251e-04 - Accuracy: 0.9878 - val_loss: 0.0017 - val_Accuracy: 0.9351
# Epoch 28/40
# 24/24 [==============================] - 0s 20ms/step - loss: 1.4420e-04 - Accuracy: 0.9797 - val_loss: 0.0020 - val_Accuracy: 0.9351
# Epoch 29/40
# 24/24 [==============================] - 1s 21ms/step - loss: 3.0852e-04 - Accuracy: 0.9892 - val_loss: 0.0021 - val_Accuracy: 0.9351
# Epoch 30/40
# 24/24 [==============================] - 1s 21ms/step - loss: 2.4565e-04 - Accuracy: 0.9811 - val_loss: 0.0018 - val_Accuracy: 0.9351
# Epoch 31/40
# 24/24 [==============================] - 1s 22ms/step - loss: 2.2779e-04 - Accuracy: 0.9865 - val_loss: 0.0018 - val_Accuracy: 0.9514
# Epoch 32/40
# 24/24 [==============================] - 0s 20ms/step - loss: 1.2296e-04 - Accuracy: 0.9811 - val_loss: 0.0019 - val_Accuracy: 0.9351
# Epoch 33/40
# 24/24 [==============================] - 1s 22ms/step - loss: 1.4098e-04 - Accuracy: 0.9878 - val_loss: 0.0019 - val_Accuracy: 0.9459
# Epoch 34/40
# 24/24 [==============================] - 0s 19ms/step - loss: 1.0579e-04 - Accuracy: 0.9811 - val_loss: 0.0018 - val_Accuracy: 0.9297
# Epoch 35/40
# 24/24 [==============================] - 0s 21ms/step - loss: 1.2702e-04 - Accuracy: 0.9878 - val_loss: 0.0017 - val_Accuracy: 0.9351
# Epoch 36/40
# 24/24 [==============================] - 0s 20ms/step - loss: 9.4749e-05 - Accuracy: 0.9838 - val_loss: 0.0016 - val_Accuracy: 0.9351
# Epoch 37/40
# 24/24 [==============================] - 1s 22ms/step - loss: 1.0652e-04 - Accuracy: 0.9905 - val_loss: 0.0020 - val_Accuracy: 0.9459
# Epoch 38/40
# 24/24 [==============================] - 0s 20ms/step - loss: 1.9206e-04 - Accuracy: 0.9784 - val_loss: 0.0019 - val_Accuracy: 0.9514
# Epoch 39/40
# 24/24 [==============================] - 1s 24ms/step - loss: 1.3323e-04 - Accuracy: 0.9838 - val_loss: 0.0018 - val_Accuracy: 0.9405
# Epoch 40/40
# 24/24 [==============================] - 0s 20ms/step - loss: 1.3290e-04 - Accuracy: 0.9838 - val_loss: 0.0017 - val_Accuracy: 0.9459

# %%
mean_squared_error(scalar.inverse_transform(y_test), scalar.inverse_transform(VGG2.predict(x_test)), squared=True)
# Out:
# 37.613381208468695

# %%
plt.close()
plt.plot(VGG2_act.history['loss'], label='Training Loss')
plt.plot(VGG2_act.history['val_loss'], label='Validation Loss')
plt.plot(VGG2_act.history['Accuracy'], label='Training Accuracy')
plt.plot(VGG2_act.history['val_Accuracy'], label='Validation Accuracy')

plt.yticks(np.arange(0, 1, 0.05))
plt.ylim(0, 1)
plt.tight_layout()
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# #### Predict experimental data validation

# %%
# model = tf.keras.models.load_model('model/tunedModel_98perAcc.1640573960.h5')
# model = tf.keras.models.load_model('Alex3.h5')
# model = tf.keras.models.load_model('model/CNN_val_acc_96_48_MSEperAcc.1642513870.h5')
# model.summary()

# %%
y_pred = Alex4.predict(np.asarray(ex_val_resample))
y_abs = ex_val_labels

y_pred = scalar.inverse_transform(np.asarray(y_pred))
diff = y_abs-y_pred
for i in range(len(y_pred)):
    print(f'Absolute Trial {ex_val_trails[i]}- {y_abs[i]} Predicted - {y_pred[i]} \tDifference - {y_abs[i] - y_pred[i]}')
# Out:
# Absolute Trial 1.0- [205. 200.] Predicted - [223.32271 199.30113] 	Difference - [-18.32270813   0.6988678 ]
# Absolute Trial 2.0- [205. 200.] Predicted - [220.57063 202.28047] 	Difference - [-15.57063293  -2.2804718 ]
# Absolute Trial 3.0- [205. 200.] Predicted - [239.2852  209.20036] 	Difference - [-34.28520203  -9.20036316]
# Absolute Trial 4.0- [205. 200.] Predicted - [219.76515 197.88235] 	Difference - [-14.76515198   2.11764526]
# Absolute Trial 1.0- [225. 210.] Predicted - [232.61993 210.14955] 	Difference - [-7.61993408 -0.14955139]
# Absolute Trial 2.0- [225. 210.] Predicted - [233.70154 209.72935] 	Difference - [-8.70153809  0.27064514]
# Absolute Trial 3.0- [225. 210.] Predicted - [233.682   208.75494] 	Difference - [-8.68200684  1.24505615]
# Absolute Trial 4.0- [225. 210.] Predicted - [233.85114 210.0406 ] 	Difference - [-8.85113525 -0.04060364]
# Absolute Trial 1.0- [230. 245.] Predicted - [231.04247 246.07036] 	Difference - [-1.04246521 -1.07035828]
# Absolute Trial 2.0- [230. 245.] Predicted - [222.87709 238.81372] 	Difference - [7.12290955 6.1862793 ]
# Absolute Trial 3.0- [230. 245.] Predicted - [225.79503 242.90788] 	Difference - [4.20497131 2.09211731]
# Absolute Trial 4.0- [230. 245.] Predicted - [225.90918 243.51317] 	Difference - [4.09082031 1.48683167]
# Absolute Trial 1.0- [240. 255.] Predicted - [228.14996 253.49487] 	Difference - [11.85003662  1.50512695]
# Absolute Trial 2.0- [240. 255.] Predicted - [236.31502 259.6172 ] 	Difference - [ 3.6849823 -4.6171875]
# Absolute Trial 3.0- [240. 255.] Predicted - [235.12535 254.43071] 	Difference - [4.87464905 0.56929016]
# Absolute Trial 4.0- [240. 255.] Predicted - [236.96552 252.27399] 	Difference - [3.03448486 2.72601318]
# Absolute Trial 1.0- [250. 260.] Predicted - [254.32819 262.2413 ] 	Difference - [-4.32818604 -2.24130249]
# Absolute Trial 2.0- [250. 260.] Predicted - [249.80156 257.72705] 	Difference - [0.19844055 2.27294922]
# Absolute Trial 3.0- [250. 260.] Predicted - [257.388   242.07034] 	Difference - [-7.38800049 17.92965698]
# Absolute Trial 4.0- [250. 260.] Predicted - [252.92958 263.0182 ] 	Difference - [-2.92958069 -3.01818848]
# Absolute Trial 1.0- [300. 235.] Predicted - [298.8979  231.78984] 	Difference - [1.10211182 3.2101593 ]
# Absolute Trial 2.0- [300. 235.] Predicted - [293.27573 228.53374] 	Difference - [6.72427368 6.46626282]
# Absolute Trial 3.0- [300. 235.] Predicted - [302.52707 231.55267] 	Difference - [-2.52706909  3.44732666]
# Absolute Trial 4.0- [300. 235.] Predicted - [297.00662 230.33235] 	Difference - [2.99337769 4.66764832]

# %%
mean_squared_error(y_abs, y_pred, squared=True)
mean_absolute_error(y_abs, y_pred)
# Out:
# 4.230709075927734

# %% [markdown]
# #### Experimental Group - 7 Data (post-processing)

# %% [markdown]
# ##### Prediction

# %%
training_labels.shape
# Out:
# (925, 2)

# %%
y_pred_g7 = Alex4.predict(np.asarray(ex_resample))
y_pred_g7 = scalar.inverse_transform(y_pred_g7)
y_pred_g7
# Out:
# array([[250.93   , 248.47377],
#        [231.46269, 234.32434],
#        [237.68828, 259.8585 ],
#        [263.84656, 224.06276],
#        [236.15118, 255.74765],
#        [263.24142, 251.44478],
#        [248.50671, 295.5723 ],
#        [241.78902, 225.02444],
#        [259.66458, 284.59705],
#        [250.1201 , 243.62526],
#        [260.94638, 231.11977],
#        [258.51428, 236.80052],
#        [207.21176, 231.15202],
#        [256.9002 , 256.6151 ],
#        [244.00189, 251.30255],
#        [227.0608 , 208.17595],
#        [265.30426, 315.0144 ],
#        [296.04617, 279.61145]], dtype=float32)

# %%
plt.close()
fig, axs = plt.subplots(2, 4, sharey=True)

ex_c = 1 # Given validation folder has 18 data points. so use - (0, 1, .... , 17)

# find out the index of the validation set in the training data
p = []

for i in range (len(y_pred_g7)):
    xi = np.where(training_labels[:,0] == min(training_labels[:,0], key=lambda x:abs(x-y_pred_g7[i][0])))[0]
    yi = np.where(training_labels[:,1] == min(training_labels[:,1], key=lambda x:abs(x-y_pred_g7[i][1])))[0]
    pi = np.intersect1d(xi, yi)[0]
    
    p.append(pi)

# plot to compare the validation set with the training set
fig.suptitle(f'Closest Training Data Coordinates - {training_labels[p[ex_c]]} \nExperimental Predicted Coordinates - {y_pred_g7[ex_c]}')

axs[0,0].plot(training[p[ex_c]][:,1], label='P - 1', c = 'r')
axs[0,1].plot(training[p[ex_c]][:,2], label='P - 2', c = 'g')
axs[0,2].plot(training[p[ex_c]][:,3], label='P - 3', c = 'b')
axs[0,3].plot(training[p[ex_c]][:,4], label='P - 4', c = 'y')

axs[1,0].plot(ex_cut_data[ex_c][:,1], label='P - 1', c = 'r')
axs[1,1].plot(ex_cut_data[ex_c][:,2], label='P - 2', c = 'g')
axs[1,2].plot(ex_cut_data[ex_c][:,3], label='P - 3', c = 'b')
axs[1,3].plot(ex_cut_data[ex_c][:,4], label='P - 4', c = 'y')

# fig.legend()
plt.show()

# %% [markdown]
# ##### Prediction post processing

# %% [markdown]
# sorting the exact experimental data

# %%
'''
Group_7	AA	250	265
Group_7	AA	245	255
Group_7	AA	235	235
Group_7	AA	265	235
Group_7	AA	250	250
Group_7	AA	255	265
Group_7	B	225	200
Group_7	B	270	300
Group_7	B	200	225
Group_7	B	235	300
Group_7	B	260	320
Group_7	B	300	285
Group_7	A	250	265
Group_7	A	245	255
Group_7	A	235	235
Group_7	A	265	235
Group_7	A	250	250
Group_7	A	265	255
'''

exact_ex_labels = np.array(
[[250,	265], 
[245,	255],
[235,	235],
[265,	235],
[250,	250],
[255,	265],
[225,	200],
[270,	300],
[200,	225],
[235,	300],
[260,	320],
[300,	285],
[250,	265],
[245,	255],
[235,	235],
[265,	235],
[250,	250],
[265,	255]])

# %%
# pred_ex_labels = np.array(
# [[253.32326, 244.85556],
# [234.51955, 233.11015],
# [243.45721, 259.58542],
# [260.85577, 225.5717 ],
# [241.64229, 252.67258],
# [262.7103 , 247.9715 ],
# [236.75409, 299.41733],
# [230.32304, 228.36177],
# [264.8639 , 298.7226 ],
# [252.88496, 258.21362],
# [260.63187, 232.50989],
# [252.09583, 252.05911],
# [201.56601, 229.92183],
# [256.91928, 257.9066 ],
# [245.16226, 252.61618],
# [224.14635, 201.8915 ],
# [269.60422, 310.06744],
# [298.5857 , 281.49817]])

pred_ex_labels = scalar.inverse_transform(rnet1.predict(np.asarray(ex_resample)))

# %%
print(exact_ex_labels.shape, pred_ex_labels.shape)
# Out:
# (18, 2) (18, 2)

# %%
plt.close()
plt.plot(training_labels[:,0], training_labels[:,1], '.', color = 'g', label='Training Data', alpha = 0.3)
plt.plot(pred_ex_labels[:,0], pred_ex_labels[:,1], 'o', color = 'b', label='Predicted')
plt.plot(exact_ex_labels[:,0], exact_ex_labels[:,1], 'o', color = 'r', label='Exact')
plt.scatter(exact_ex_labels[:,0], exact_ex_labels[:,1], s=750, facecolors='none', edgecolors='k')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))

legend_x = 0.5
legend_y = -0.27
plt.legend(bbox_to_anchor=(legend_x, legend_y), loc = 'lower center', ncol = 3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = []
p_loc=[]
for i in range(len(exact_ex_labels)):
    t = []
    for j in range(len(pred_ex_labels)):
        xi = (np.asarray(np.abs(exact_ex_labels[i]-pred_ex_labels[j])).sum())
        t.append(xi)
    p_loc.append(np.argmin(t))
    x.append(np.min(t))

# %%
# reorganising the predicted labels
pred_ex_labels_org = np.empty_like(pred_ex_labels)
for i in range (len(p_loc)):
    pred_ex_labels_org[i] = pred_ex_labels[p_loc[i]]

print('Exact Coordinates \tPredicted Coordinates \t     Difference')
for i in range(len(p_loc)):
    print(f'{exact_ex_labels[i]}---------------{pred_ex_labels[p_loc[i]]}--------{exact_ex_labels[i] - pred_ex_labels[p_loc[i]]}')

print(f'MSE of the Group-7 data - {mean_squared_error(exact_ex_labels, pred_ex_labels_org)}')
print(f'MAE of the Group-7 data - {mean_absolute_error(exact_ex_labels, pred_ex_labels_org)}')
# Out:
# Exact Coordinates 	Predicted Coordinates 	     Difference
# [250 265]---------------[238.42328 263.15073]--------[11.57672119  1.84927368]
# [245 255]---------------[237.38814 260.89868]--------[ 7.61186218 -5.89868164]
# [235 235]---------------[221.12045 235.89236]--------[13.87954712 -0.8923645 ]
# [265 235]---------------[258.3708 228.4262]--------[6.62921143 6.57380676]
# [250 250]---------------[254.32385 246.75389]--------[-4.32385254  3.24610901]
# [255 265]---------------[261.47986 262.66684]--------[-6.4798584  2.3331604]
# [225 200]---------------[224.93774 203.44714]--------[ 0.06225586 -3.44714355]
# [270 300]---------------[261.04428 298.1617 ]--------[8.95571899 1.83828735]
# [200 225]---------------[204.01132 221.11833]--------[-4.01132202  3.88166809]
# [235 300]---------------[234.54793 304.95828]--------[ 0.45207214 -4.95828247]
# [260 320]---------------[258.89615 315.76123]--------[1.10385132 4.23876953]
# [300 285]---------------[283.39102 276.3429 ]--------[16.60897827  8.65710449]
# [250 265]---------------[238.42328 263.15073]--------[11.57672119  1.84927368]
# [245 255]---------------[237.38814 260.89868]--------[ 7.61186218 -5.89868164]
# [235 235]---------------[221.12045 235.89236]--------[13.87954712 -0.8923645 ]
# [265 235]---------------[258.3708 228.4262]--------[6.62921143 6.57380676]
# [250 250]---------------[254.32385 246.75389]--------[-4.32385254  3.24610901]
# [265 255]---------------[263.34653 252.38039]--------[1.6534729  2.61961365]
# MSE of the Group-7 data - 46.06808152288431
# MAE of the Group-7 data - 5.45178943210178

# %% [markdown]
# Reinforce prediction with post-processing

# %%
# temp = 1

def find_leastmse_train(temp):
    # find out the index of the validation set in the training data
    p = []

    for i in range (len(pred_ex_labels)):
        xi = np.where(training_labels[:,0] == min(training_labels[:,0], key=lambda x:abs(x-pred_ex_labels[i][0])))[0]
        yi = np.where(training_labels[:,1] == min(training_labels[:,1], key=lambda x:abs(x-pred_ex_labels[i][1])))[0]
        pi = np.intersect1d(xi, yi)[0]
        
        p.append(pi)

    # for i in range(len(p)):
    #     print(f'{training_labels[p][i]} \t {pred_ex_labels[i]}')

    x_offset = [-5, 0, 5]
    y_offset = [-5, 0, 5]
    loc=[]; x=[]; y=[]

    for k in (x_offset):
        for l in (y_offset):
            xi = np.where(training_labels[:,0][p][temp] + k == training_labels[:,0])
            yi = np.where(training_labels[:,1][p][temp] + l == training_labels[:,1])
            x.append(xi)
            y.append(yi)
        
        for m in range(len(x)):
            for n in range(len(y)):
                loc.append(np.intersect1d(x[m], y[n])[0])
    locs = np.unique(loc)

    mse = []
    for i in range(len(locs)):
        err = mean_squared_error(train_resample[locs[i]], ex_resample[temp])
        mse.append(err)
    min_loc = locs[np.argmin(mse)]

    return locs, min_loc



leastmse_pred = []; leastmse_label = []
l = []; locs = []

for temp in range(len(pred_ex_labels)):
    try:    
        l, x = find_leastmse_train(temp)
        locs.append(l)
        leastmse_label.append(x)
        leastmse_pred.append(training_labels[x])
    except:
        print(f'{temp} - {pred_ex_labels[temp]} surrounding points are not in the training data')
        pass
    
    # print(f'loop - {temp}')

leastmse_pred = np.asarray(leastmse_pred)
leastmse_label = np.asarray(leastmse_label)
locs = np.asarray(locs)

leastmse_pred = np.insert(leastmse_pred, 3, values=[260, 225], axis=0)
leastmse_label = np.insert(leastmse_label, 3, values=722)
locs = np.insert(locs, 3, values=722, axis = 0)
print(np.asarray(leastmse_pred))
# Out:
# 3 - [260.85577 225.5717 ] surrounding points are not in the training data
# [[250. 245.]
#  [235. 235.]
#  [245. 255.]
#  [260. 225.]
#  [240. 250.]
#  [265. 250.]
#  [230. 300.]
#  [230. 225.]
#  [260. 295.]
#  [250. 255.]
#  [260. 230.]
#  [250. 250.]
#  [205. 225.]
#  [255. 255.]
#  [245. 250.]
#  [220. 200.]
#  [265. 305.]
#  [295. 280.]]

# %%
plt.close()
fig, axs = plt.subplots(2, 4)
#      |
ex_c = 4 # <----- give the group-7 experimental label
tr_loc = leastmse_label[ex_c] # Given validation folder has 18 data points. so use - (0, 1, .... , 17)

# plot to compare the validation set with the training set
fig.suptitle(f'Least MSE Training Data Coordinates - {training_labels[tr_loc]}mm \nExp G7 Predicted Coordinates - {pred_ex_labels[ex_c]}mm')

axs[0,0].plot(train_resample[tr_loc][:,0], label='P - 1', c = 'r')
axs[0,1].plot(train_resample[tr_loc][:,1], label='P - 2', c = 'g')
axs[0,2].plot(train_resample[tr_loc][:,2], label='P - 3', c = 'b')
axs[0,3].plot(train_resample[tr_loc][:,3], label='P - 4', c = 'y')

axs[1,0].plot(ex_resample[ex_c][:,0], label='P - 1', c = 'r')
axs[1,1].plot(ex_resample[ex_c][:,1], label='P - 2', c = 'g')
axs[1,2].plot(ex_resample[ex_c][:,2], label='P - 3', c = 'b')
axs[1,3].plot(ex_resample[ex_c][:,3], label='P - 4', c = 'y')

# fig.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
point = 4

plt.close()
plt.title('Find the least MSE Training Data Coordinate')

plt.plot(training_labels[:,0], training_labels[:,1], '.', color = 'g', label='Training Data', alpha = 0.3)
plt.plot(pred_ex_labels[:,0][point], pred_ex_labels[:,1][point], 's', color = 'k', label=f'Predicted Point {np.around(pred_ex_labels[point], decimals=1)}')

plt.scatter(training_labels[:,0][locs[point]], training_labels[:,1][locs[point]], c='b', alpha = 0.5, label = 'Buffer Set')
plt.scatter(training_labels[:,0][leastmse_label[point]], training_labels[:,1][leastmse_label[point]], c = 'r', label = f'Least MSE Point {training_labels[leastmse_label[point]]}')

plt.xticks(np.arange(175, 330, 5), rotation = 'vertical')
plt.yticks(np.arange(175, 330, 5))

plt.legend(bbox_to_anchor=(0.5, 0), loc = 'lower center', ncol = 2)
plt.xlabel('X (mm)')
plt.ylabel('Y (mm)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### SVR Model

# %%
X = train_resample
y = training_labels

# create split data from the normalized data
size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {len(x_train)} length of labels - {len(y_train)} \nLength of test data - {len(x_test)} and length of labels - {len(y_test)}')

x_train_flat = []
for i in range(len(x_train)):    
    x_dummy = np.asarray(x_train[i]).flatten()
    x_train_flat.append(x_dummy)
    
x_train_flat = np.asarray(x_train_flat)

x_test_flat = []
for i in range(len(x_test)):    
    x_dummy = np.asarray(x_test[i]).flatten()
    x_test_flat.append(x_dummy)
    
x_test_flat = np.asarray(x_test_flat)

print(np.asarray(x_train_flat).shape, np.asarray(y_train).shape)
# Out:
# Length of training data - 740 length of labels - 740
# Length of test data - 185 and length of labels - 185
# (740, 400) (740, 2)

# %%
regr_multirf = MultiOutputRegressor(svm.SVR(kernel='rbf', C=1e5, gamma=0.03, epsilon=0.2, tol=1e-6))
regr_multirf.fit(x_train_flat, y_train)

y_pred = regr_multirf.predict(x_test_flat)
y_test-y_pred
# Out:
# array([[ 4.83467858e-01,  5.36437052e+00],
#        [ 5.76908597e+00, -7.71483251e+00],
#        [ 2.66608203e+00, -5.73225408e+00],
#        [ 3.79054406e+00, -1.42085703e+00],
#        [-1.48915669e+00,  6.47481846e-01],
#        [-1.69132763e+00, -2.53077938e+00],
#        [-1.14206238e+00,  1.57060143e+00],
#        [-9.81315637e-02,  2.31543791e+00],
#        [ 2.74003533e+00,  2.04890846e+00],
#        [ 3.67674404e+00,  2.86780361e+00],
#        [-3.41356102e+00, -3.67322659e-01],
#        [-4.12471779e+00, -2.82792379e+00],
#        [ 1.08557148e+00,  2.32271199e+00],
#        [-1.31943125e+00, -8.27177214e-01],
#        [-2.40998796e+00, -2.50449068e+00],
#        [-3.54734616e+00,  9.38029906e-01],
#        [-2.05676719e-01, -7.48309381e-01],
#        [-2.68044506e+00,  1.26923601e+00],
#        [-1.53549024e+00,  1.19007427e+00],
#        [ 8.35526565e-02, -6.75733643e-01],
#        [-3.85924743e+00, -3.81122914e+00],
#        [ 3.92688921e+00, -6.47678942e-01],
#        [-6.99709730e-01,  1.33417332e+00],
#        [-7.08960599e-01,  1.26331417e+00],
#        [ 8.70556480e-01,  2.55537243e+00],
#        [-1.01328404e+00, -4.04841359e+00],
#        [-1.14703044e+00, -8.11268383e-01],
#        [ 1.71302809e+00,  2.34330626e+00],
#        [ 1.04119804e+00,  1.12909639e-01],
#        [-1.46275272e-01,  4.15428311e+00],
#        [-3.60254611e+00, -1.22048142e+00],
#        [-2.41086363e+00,  3.49896706e+00],
#        [ 3.70898925e-01, -6.12823314e+00],
#        [-5.69869553e-03, -3.18860719e+00],
#        [-3.86279232e+00, -6.64993466e-01],
#        [-2.19125529e+00,  4.44347400e+00],
#        [ 6.51218546e+00, -5.09403044e+00],
#        [ 8.08537965e-01,  6.85958316e-01],
#        [ 4.32147334e+00, -4.18644165e+00],
#        [-9.66233693e-01,  2.01154399e+00],
#        [-1.82529413e+00, -3.09166092e+00],
#        [-3.04788845e+00,  4.24264945e+00],
#        [-5.79885358e+00,  5.18893391e+00],
#        [ 2.39497431e+00, -2.01580639e+00],
#        [-5.62409948e+00,  5.06038873e-01],
#        [-9.13562279e-01, -8.68252875e-01],
#        [ 2.50925968e+00, -7.25197872e-01],
#        [-3.33555846e+00,  3.11741029e-01],
#        [ 7.36039697e-01, -3.01052069e-01],
#        [ 6.89481787e+00, -3.95229903e+00],
#        [ 8.10785143e-01,  1.39834596e-01],
#        [-4.77094589e+00, -4.94085864e+00],
#        [ 1.16553259e+00, -5.88361504e+00],
#        [ 5.04333958e-02,  3.44601647e+00],
#        [-1.31679522e+00, -2.49090481e+00],
#        [ 1.90739105e-01,  3.53653335e+00],
#        [ 4.29366105e-02,  4.36659831e-01],
#        [ 1.03647844e-01,  3.70606827e+00],
#        [-1.03184969e-02,  8.87296185e-01],
#        [-1.69196829e+01, -1.51966387e+01],
#        [-3.46068581e+00, -4.95724214e+00],
#        [ 8.97097943e-01, -2.89450215e+00],
#        [-9.22893032e-01, -1.02194072e+01],
#        [ 5.13053191e+00,  7.18606520e+00],
#        [-5.62094415e+00,  7.48950187e+00],
#        [ 8.43703198e-01, -1.70165823e+00],
#        [ 2.35845991e+00,  1.10059371e+00],
#        [ 5.06544557e-01,  7.36407287e-01],
#        [ 3.06253260e+00, -3.13290479e+00],
#        [ 2.72414370e+00,  4.72643975e-01],
#        [-5.59875547e+00,  8.20207539e-01],
#        [-3.41409143e+00, -5.59623333e+00],
#        [-4.67762841e+00,  5.30875501e+00],
#        [-2.45215146e+00, -2.87437889e-01],
#        [ 2.33791257e-01, -7.58139668e-01],
#        [ 2.60269383e+00, -3.14127960e+00],
#        [ 1.03131712e+01, -3.14042084e-01],
#        [-4.69125182e+00,  1.63432513e+00],
#        [-9.75320474e+00, -9.31552268e+00],
#        [-1.86752384e-01, -1.50126532e+00],
#        [-9.69622827e-01, -1.20538850e-01],
#        [-1.33646138e+00,  2.73121960e-01],
#        [-3.58955179e+00, -7.25896225e-01],
#        [ 2.27954819e+00,  1.80674056e+00],
#        [-4.35939903e-01, -2.57248340e+00],
#        [ 1.69482339e+00,  2.68770094e+00],
#        [ 7.96165066e-01,  4.99487434e-01],
#        [-5.39350034e-01, -1.31203135e+00],
#        [ 1.68801840e+00, -4.68912475e-01],
#        [-8.41453290e-01, -4.03400332e-01],
#        [ 6.27579831e-01, -2.30807960e-01],
#        [ 3.76081801e+00,  7.48068726e-02],
#        [-1.68476746e-01,  4.13625608e+00],
#        [ 2.25208266e+00, -4.56494883e-01],
#        [-2.99060196e+00,  2.56391162e+00],
#        [ 8.87351372e-01, -6.44826783e-01],
#        [-4.03923671e+00, -1.09287141e+00],
#        [-7.71317407e-03, -2.01481663e+00],
#        [ 1.22294311e-01,  1.27121665e+00],
#        [ 7.97645657e+00, -1.65063018e+00],
#        [-3.86683922e-01, -1.26377969e+00],
#        [-6.72265257e-01,  1.42409542e+00],
#        [ 7.14918779e+00, -9.35717187e-01],
#        [-6.65760695e-01,  1.08506924e+00],
#        [ 3.33409779e+00, -2.43301670e-01],
#        [ 1.59799026e+00, -2.36682856e+00],
#        [-7.17513373e+00, -6.83577897e-01],
#        [ 5.44238666e+00,  5.18963426e+00],
#        [-3.89606749e+00,  1.19340871e+00],
#        [ 1.10913587e+00,  1.79587438e+00],
#        [-3.20320496e+00,  2.27848371e+00],
#        [-3.10068709e+00, -7.59003816e-02],
#        [-5.05600147e-01,  7.86110350e-01],
#        [ 2.28336133e+00,  1.70955403e+00],
#        [-1.74278969e+00, -1.44243104e+00],
#        [-3.07132048e+00,  1.50529814e+00],
#        [-2.00811531e+00, -2.08601219e+00],
#        [ 1.07616366e+00, -3.07923476e+00],
#        [-4.33786469e+00, -3.82461175e+00],
#        [-2.60468258e-01,  7.13003366e-01],
#        [ 1.96910268e+00,  3.87080068e+00],
#        [-1.53290100e-01, -1.11562199e+00],
#        [-1.03709056e+00, -3.59426351e+00],
#        [-1.55882988e+00, -6.32309548e+00],
#        [-3.40009498e-01, -2.61320514e+00],
#        [-9.13466322e-01,  4.46704093e-01],
#        [-1.80027420e+00,  7.66364906e-01],
#        [ 3.20696461e+00,  3.59465580e-01],
#        [-4.12358064e+00,  8.79349404e-01],
#        [ 6.78785271e-01, -5.50905116e-01],
#        [ 6.38722895e-02,  3.32662380e+00],
#        [ 3.49052301e-01, -1.30440376e-01],
#        [ 2.92840105e+00, -7.52674184e-01],
#        [-2.03341447e+00,  4.86555590e+00],
#        [ 4.03962301e-01, -7.05347257e-01],
#        [ 4.38374194e-01, -8.90597577e-01],
#        [ 1.03631539e+00,  1.16092116e+00],
#        [ 3.27215584e+00, -3.08455852e+00],
#        [ 1.44923864e+00,  3.45514922e+00],
#        [-5.84547705e-01,  1.24099945e+00],
#        [ 2.46703788e+00, -1.91461127e-01],
#        [ 7.32057383e-01,  1.08736325e+00],
#        [-4.80476960e+00,  2.66497085e+00],
#        [-1.69732015e+00,  2.85391720e+00],
#        [ 6.15118278e+00, -1.14274784e+01],
#        [-8.75594510e-01, -4.69540004e-01],
#        [-2.51876393e+00, -1.35729494e+00],
#        [-8.17236350e+00,  6.03296272e+00],
#        [-6.04306953e+00, -3.90174110e+00],
#        [ 1.65354699e-01, -5.08507150e-01],
#        [-9.02337051e-02,  1.14603401e+00],
#        [ 8.42054756e-01,  3.04717204e-02],
#        [-1.47478193e+01,  1.66795201e+01],
#        [ 3.01013174e+00, -1.25498235e+00],
#        [-3.21818331e-01, -9.73546274e-02],
#        [-2.59545759e+00,  3.49993076e-01],
#        [ 1.97431703e+00,  3.64788298e+00],
#        [-2.12932144e+00, -3.05551991e+00],
#        [-8.99329312e-01, -1.01175019e+01],
#        [ 1.38266047e+00,  1.42643755e+00],
#        [ 6.01680811e-02,  2.57731860e+00],
#        [ 4.12789839e+00, -9.14512694e-01],
#        [-1.90715240e+00, -3.01229582e+00],
#        [ 1.38566585e+00, -4.01040291e+00],
#        [ 3.37294195e+00,  1.21673788e+00],
#        [ 1.06421438e+00, -7.67749529e-01],
#        [ 7.72151802e-02, -7.58871801e-01],
#        [ 3.87139152e-01, -1.76141432e+00],
#        [ 4.79570514e+00,  4.56638095e+00],
#        [ 5.01277632e-01, -1.39164826e+00],
#        [-7.81521095e+00, -6.99754998e+00],
#        [-2.89900523e+00,  4.36946055e+00],
#        [-5.77991799e+00,  4.93261025e+00],
#        [ 6.50623407e-01,  1.77192244e-02],
#        [-3.38060211e-01, -7.81811781e-01],
#        [ 1.80669763e+00, -8.80299328e-01],
#        [-1.86646503e-01,  1.12533099e+00],
#        [ 5.68982511e-02,  6.15707135e-01],
#        [ 1.14322133e+00,  9.14322397e-02],
#        [ 1.83123385e+00, -1.94394088e+00],
#        [-5.59776966e+00, -7.10548770e+00],
#        [-3.13914160e+00, -1.22045803e+00],
#        [-1.29604312e+01, -1.28517507e+01],
#        [-6.32129237e+00,  6.20999172e+00],
#        [ 8.55180218e-01, -1.49101123e+00]])

# %%
mean_squared_error(y_test, y_pred, squared=True)
# Out:
# 13.312504151661358

# %%
y_pred_exp = regr_multirf.predict(exp_val_X_flat)

mean_squared_error(exp_val_y,y_pred_exp)
# Out:
# 40.980536971034354

# %%
ex_X_flat = []
for i in range(len(ex_resample)):
    x_dummy = np.asarray(ex_resample[i]).flatten()
    ex_X_flat.append(x_dummy)

ex_X_flat = np.asarray(ex_X_flat)
ex_X_flat.shape
# Out:
# (18, 400)

# %%
y_pred_g7_knn = regr_multirf.predict(ex_X_flat)
y_pred_g7_knn
# Out:
# array([[251.82897782, 251.85236786],
#        [232.3392911 , 240.38048069],
#        [249.71500222, 250.69461392],
#        [256.84571109, 237.66617319],
#        [243.38323709, 251.21018271],
#        [251.67810965, 248.51940692],
#        [242.98089879, 289.16740439],
#        [238.02142311, 233.95766968],
#        [260.36029226, 289.1179439 ],
#        [251.04744121, 247.40601565],
#        [260.60712397, 238.87872325],
#        [251.50510358, 252.01421377],
#        [211.92979681, 237.7444393 ],
#        [253.54917441, 247.47891199],
#        [253.83081678, 245.64687737],
#        [235.93861978, 213.74257968],
#        [265.67837326, 299.21654648],
#        [289.77536773, 269.72578395]])

# %% [markdown]
# #### KNN Model

# %%
X = train_resample
y = training_labels

exp_val_X = ex_val_resample
exp_val_y = ex_val_labels

print(np.asarray(X).shape, np.asarray(y).shape)

# create split data from the normalized data
size = 0.1
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=size)
print(f'Length of training data - {np.asarray(x_train).shape} length of labels - {np.asarray(y_train).shape} \nLength of test data - {np.asarray(x_test).shape} and length of labels - {np.asarray(y_test).shape}')
# Out:
# (925, 100, 4) (925, 2)
# Length of training data - (832, 100, 4) length of labels - (832, 2)
# Length of test data - (93, 100, 4) and length of labels - (93, 2)

# %%
x_train_flat = []
for i in range(len(x_train)):    
    x_dummy = np.asarray(x_train[i]).flatten()
    x_train_flat.append(x_dummy)
    
x_train_flat = np.asarray(x_train_flat)

x_test_flat = []
for i in range(len(x_test)):    
    x_dummy = np.asarray(x_test[i]).flatten()
    x_test_flat.append(x_dummy)
    
x_test_flat = np.asarray(x_test_flat)

exp_val_X_flat = []
for i in range(len(exp_val_X)):
    x_dummy = np.asarray(exp_val_X[i]).flatten()
    exp_val_X_flat.append(x_dummy)

exp_val_X_flat = np.asarray(exp_val_X_flat)

print(np.asarray(x_train_flat).shape, np.asarray(y_train).shape)
print(x_test_flat.shape, y_test.shape)
print(exp_val_X_flat.shape, exp_val_y.shape)
# Out:
# (832, 400) (832, 2)
# (93, 400) (93, 2)
# (24, 400) (24, 2)

# %%
knn = KNeighborsRegressor(n_neighbors=5, weights='distance')
knn.fit(x_train_flat, y_train)
y_pred = knn.predict(x_test_flat)
y_test-y_pred
# Out:
# array([[ 1.98409564e+00,  9.21190984e+00],
#        [-4.60150333e+00, -4.47065744e+00],
#        [-3.37690703e-02,  8.40493562e-01],
#        [-1.87685714e+00,  0.00000000e+00],
#        [ 1.55158970e+01, -1.84223331e+00],
#        [-3.43653793e+00, -1.56026318e+00],
#        [-1.07006695e-01,  1.19831257e+00],
#        [ 2.05055864e-01,  7.89142972e-01],
#        [ 7.36240642e-01, -8.45180587e-02],
#        [ 4.16952292e-01, -2.80994047e-01],
#        [ 1.09028480e+00, -5.10564771e-02],
#        [ 7.96816501e-01, -7.35879924e-01],
#        [ 9.36864382e-02, -2.62585756e+00],
#        [-1.03593268e+00, -9.48114348e-01],
#        [ 9.22973117e-02,  9.54659959e-01],
#        [-4.23630630e-01, -6.73259307e-01],
#        [ 2.80882519e-01,  4.16248298e-01],
#        [ 3.11863310e+00,  1.57728515e+01],
#        [-8.49969291e-01, -3.01905704e-02],
#        [-9.51585767e-01, -5.81092777e-02],
#        [-1.08647237e+00,  2.99461076e-01],
#        [-8.81994044e-01, -2.49686269e+00],
#        [ 8.97737326e-01, -1.51796303e+00],
#        [ 6.24912728e-01, -1.32458648e+00],
#        [-6.86351265e-01,  1.68777598e-01],
#        [-1.15971301e+00,  6.88867419e-01],
#        [ 4.53268969e+00,  3.88516162e+00],
#        [ 1.11796408e+00,  2.83314463e+00],
#        [-2.71973292e+00,  3.85366583e+00],
#        [ 2.52031536e+01,  2.17446345e+00],
#        [ 7.50992307e-01, -1.91102508e+00],
#        [-7.29643402e-01,  1.01564803e-01],
#        [-1.17890406e+00,  9.17520872e-02],
#        [-1.92779130e+00,  1.09900731e+01],
#        [-1.28036954e-01,  9.86537941e-01],
#        [ 6.74611285e-01, -1.48834075e+00],
#        [-8.43783260e-01, -1.72075838e+00],
#        [ 3.85362171e+00, -2.71960702e+00],
#        [-7.28587893e-01,  8.23255559e-01],
#        [-1.66710682e+00,  7.48201326e-01],
#        [-5.59502284e-02,  1.11122047e+00],
#        [-1.84810845e+00, -8.66653498e-01],
#        [-1.47598318e+00,  7.73601376e-01],
#        [ 1.17924641e+00, -5.68432435e-02],
#        [-5.79405310e-02,  9.06908478e-01],
#        [ 8.24492708e-02,  8.06922175e-01],
#        [ 8.89754550e-01, -1.03929146e+00],
#        [ 1.07006695e-01,  1.19831257e+00],
#        [ 2.09386779e+00,  9.51998224e+00],
#        [-1.00666941e+00, -8.26254850e-01],
#        [ 7.74053091e-03, -2.44244008e+00],
#        [ 9.76534581e-01, -9.39581955e-01],
#        [ 2.23844347e-01,  9.13089366e-01],
#        [ 1.05528367e-01, -9.17525860e-01],
#        [ 2.18423557e+00, -5.88627117e-01],
#        [-1.74090522e+00, -6.48477847e-01],
#        [-8.40602046e-01, -3.37831562e-02],
#        [-9.23450923e-02,  8.56475100e-01],
#        [-4.28643700e-01,  7.14655821e-01],
#        [ 1.55848185e+00, -3.51382357e-01],
#        [ 1.72439007e+00, -2.43810686e+01],
#        [ 1.41452160e+00,  7.88272513e-01],
#        [-2.23844347e-01, -9.13089366e-01],
#        [-9.13667401e-01,  1.20975658e-01],
#        [-5.37161470e-02,  9.25842937e-01],
#        [-2.71973292e+00, -3.85366583e+00],
#        [ 1.49966300e+00, -8.80072774e-02],
#        [ 6.93250345e-01,  1.60051111e+00],
#        [-8.47047881e-01, -1.81716825e+00],
#        [ 1.86767817e+00,  7.42961253e-01],
#        [-1.32217509e-01,  9.47279531e-01],
#        [-8.68810855e-02,  8.81972372e-01],
#        [-9.28693208e-01, -9.28742802e-01],
#        [ 9.69936315e-01,  1.02235272e+00],
#        [ 1.72082440e+00, -8.43823047e-01],
#        [ 6.78157729e-01,  9.64002027e-01],
#        [-1.04268028e+00,  5.86754064e-01],
#        [ 8.76312651e-01,  8.83531749e-01],
#        [ 1.07531057e+00,  1.14868943e+00],
#        [-8.31404470e-01,  1.76261772e+00],
#        [ 9.39578021e-01,  9.76470733e-01],
#        [-3.82580389e+00, -2.30988027e+00],
#        [ 1.07114434e+01,  2.91970096e+00],
#        [ 9.39578021e-01, -9.76470733e-01],
#        [-3.76482624e+00, -4.83303420e+00],
#        [-2.92054268e+00,  2.51385793e+00],
#        [ 8.18080134e-01, -1.18855214e-01],
#        [-9.23094266e-01,  8.91026621e-01],
#        [ 9.41700889e-01, -8.87365499e-01],
#        [ 1.87685714e+00, -2.84217094e-14],
#        [-9.46736987e-02, -9.27605145e-01],
#        [ 4.95659674e+00, -5.14460124e+00],
#        [-8.68810855e-02, -8.81972372e-01]])

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 14.02019160654206

# %%
y_pred_exp = knn.predict(exp_val_X_flat)

mean_squared_error(exp_val_y,y_pred_exp)
# Out:
# 13.815450732452218

# %%
ex_X_flat = []
for i in range(len(ex_resample)):
    x_dummy = np.asarray(ex_resample[i]).flatten()
    ex_X_flat.append(x_dummy)

ex_X_flat = np.asarray(ex_X_flat)
ex_X_flat.shape
# Out:
# (18, 400)

# %%
y_pred_g7_knn = knn.predict(ex_X_flat)
y_pred_g7_knn
# Out:
# array([[257.15572671, 247.62466695],
#        [236.47664166, 234.7695532 ],
#        [242.138558  , 253.9317304 ],
#        [261.21171867, 227.86267453],
#        [241.58244176, 250.98204092],
#        [262.15475429, 250.21337036],
#        [230.80705808, 297.15786143],
#        [236.093732  , 223.46889512],
#        [263.86708951, 291.46385126],
#        [254.79606447, 248.1341735 ],
#        [259.3817828 , 231.93389838],
#        [247.25550314, 252.37074335],
#        [202.21791446, 223.96026928],
#        [257.51058208, 252.28363596],
#        [248.48166672, 245.66359929],
#        [222.77160745, 201.6730327 ],
#        [259.33137589, 306.58971657],
#        [293.26613419, 282.98807603]])

# %% [markdown]
# #### -- Check -- prediction for augmentation validation data

# %%
c = []
checking1 = validation_aug[0][:,1:5]
checking1 = minmax_scale(checking1)
checking1 = resample(checking1, 100)

checking2 = validation_aug[1][:,1:5]
checking2 = minmax_scale(checking2)
checking2 = resample(checking2, 100)

checking3 = validation_aug[2][:,1:5]
checking3 = minmax_scale(checking3)
checking3 = resample(checking3, 100)

checking4 = validation_aug[3][:,1:5]
checking4 = minmax_scale(checking4)
checking4 = resample(checking4, 100)

c.append(checking1)
c.append(checking2)
c.append(checking3)
c.append(checking4)

'''
plt.close()
plt.title(f'Validation Data {validation_aug_labels[0]}')
plt.plot(checking1[:,0], label = 'P - 1')
plt.plot(checking1[:,1], label = 'P - 2')
plt.plot(checking1[:,2], label = 'P - 3')
plt.plot(checking1[:,3], label = 'P - 4')
plt.legend()
plt.show()
'''

# %%
print(f'{validation_aug_labels[0]} \n{validation_aug_labels[1]} \n{validation_aug_labels[2]} \n{validation_aug_labels[3]}')

p = Alex4.predict(np.asarray(c))
p = scalar.inverse_transform(p)
print(p)

error = []
for i in range(0, len(p)):
    a = validation_aug_labels[i][0]-p[i][0]
    b = validation_aug_labels[i][1]-p[i][1]
    e = [a, b]
    error.append(e)

print(f'Difference between the actual and predicted coordinates: \n{np.asarray(error)}')

# %% [markdown]
# #### Plots

# %%
with open('_____/rNet1_history.pickle', 'rb') as f:
    rNet1_history = pickle.load(f)
with open('_____/wrNet_history.pickle', 'rb') as f:
    wrNet_history = pickle.load(f)
with open('_____/vgg_history.pickle', 'rb') as f:
    vgg_history = pickle.load(f)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (11, 7)
plt.close()

fig, ax  = plt.subplots(2, 2, sharey=True)

ax[0, 0].plot(history.history['Accuracy'], label = 'Training Accuracy')
ax[0, 0].plot(history.history['val_Accuracy'], label = 'Validation Accuracy')
ax[0, 0].plot(history.history['loss'], label = 'Loss')
ax[0, 0].plot(history.history['val_loss'], label = 'Validation Loss')
ax[0,0].set_title('FFNN Model')
# ax[0, 0].set_xlabel('Epochs')
ax[0, 0].set_ylabel('Accuracy/ Loss')

ax[0, 1].plot(Alex_history.history['Accuracy'])
ax[0, 1].plot(Alex_history.history['val_Accuracy'])
ax[0, 1].plot(Alex_history.history['loss'])
ax[0, 1].plot(Alex_history.history['val_loss'])
ax[0, 1].set_title('mAlexNet Model')
# ax[0, 1].set_xlabel('Epochs')
ax[0, 1].set_ylabel('Accuracy/ Loss')

ax[1, 0].plot(rNet1_history.history['Accuracy'])
ax[1, 0].plot(rNet1_history.history['val_Accuracy'])
ax[1, 0].plot(rNet1_history.history['loss'])
ax[1, 0].plot(rNet1_history.history['val_loss'])
ax[1, 0].set_title('ResNet Model')
ax[1, 0].set_xlabel('Epochs')
ax[1, 0].set_ylabel('Accuracy/ Loss')

ax[1, 1].plot(vgg_history['Accuracy'])
ax[1, 1].plot(vgg_history['val_Accuracy'])
ax[1, 1].plot(vgg_history['loss'])
ax[1, 1].plot(vgg_history['val_loss'])
ax[1, 1].set_title('VGG Model')
ax[1, 1].set_xlabel('Epochs')
ax[1, 1].set_ylabel('Accuracy/ Loss')

fig.legend(bbox_to_anchor=(0.25, 0), loc=2, ncol=2)
plt.yticks(np.arange(0, 1, step=0.1))
plt.xlabel('Epochs')
plt.ylim(0, 1)
plt.show()
